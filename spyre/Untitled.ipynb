# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
mdl_yr = 2008
mdl_nm = 'ACCORD'
df = pd.read_csv("/home/pybokeh/Dropbox/python/jupyter_notebooks/spyre/sales.csv")
yr_crit = df.MDL_YR == mdl_yr
mdl_crit = df.MDL_NM == mdl_nm
data = df[yr_crit & mdl_crit]
grouped = pd.pivot_table(data, values='QTY', index='SALE_MTH', aggfunc='sum')

# %%
result = pd.DataFrame(data={'Sale_Month': grouped.index, 'Qty': grouped.values}, columns=['Sale_Month','Qty'])

# %%
result
# Out:
#    Sale_Month    Qty
# 0     2007-09   9575
# 1     2007-10  23092
# 2     2007-11  23511
# 3     2007-12  26064
# 4     2008-01  24250
# 5     2008-02  26810
# 6     2008-03  35389
# 7     2008-04  34245
# 8     2008-05  41649
# 9     2008-06  41459
# 10    2008-07  41209
# 11    2008-08  32861
# 12    2008-09  10210
# 13    2008-10   3650
# 14    2008-11   1570
# 15    2008-12   1403
# 16    2009-01   1135
# 17    2009-02   1008
# 18    2009-03    802
# 19    2009-04    647
# 20    2009-05    362
# 21    2009-06    288
# 22    2009-07    212
# 23    2009-08    117
# 24    2009-09     50
# 25    2009-10     19
# 26    2009-11     25
# 27    2009-12     37
# 28    2010-01      5
# 29    2010-02      2
# 30    2010-03      1
# 31    2010-05      5
# 32    2010-06      1
# 33    2010-07      1
# 34    2010-08      1
# 35    2010-11      1
# 36    2011-05      3
# 37    2014-12      1

# %%
result.plot.bar(x='Sale_Month', y='Qty')

# %%
result
# Out:
#             Qty
# SALE_MTH
# 2007-09    9575
# 2007-10   23092
# 2007-11   23511
# 2007-12   26064
# 2008-01   24250
# 2008-02   26810
# 2008-03   35389
# 2008-04   34245
# 2008-05   41649
# 2008-06   41459
# 2008-07   41209
# 2008-08   32861
# 2008-09   10210
# 2008-10    3650
# 2008-11    1570
# 2008-12    1403
# 2009-01    1135
# 2009-02    1008
# 2009-03     802
# 2009-04     647
# 2009-05     362
# 2009-06     288
# 2009-07     212
# 2009-08     117
# 2009-09      50
# 2009-10      19
# 2009-11      25
# 2009-12      37
# 2010-01       5
# 2010-02       2
# 2010-03       1
# 2010-05       5
# 2010-06       1
# 2010-07       1
# 2010-08       1
# 2010-11       1
# 2011-05       3
# 2014-12       1
