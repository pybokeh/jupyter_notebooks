# %%
# %load_ext rpy2.ipython

# %%
import pandas.rpy.common as com

# %%
# %%R -w 1000 -h 600 -u px -o df_pop_state
# library(choroplethr)
#
# data(df_pop_state)
# head(df_pop_state)
# Out:
#       region    value
# 1    alabama  4777326
# 2     alaska   711139
# 3    arizona  6410979
# 4   arkansas  2916372
# 5 california 37325068
# 6   colorado  5042853

# %%
# %%R -w 800 -h 500 -u px
# state_choropleth(df_pop_state)

# %%
r_df = com.load_data('df_pop_state')

# %%
type(r_df)
# Out:
# pandas.core.frame.DataFrame

# %%
r_df.head()
# Out:
#        region     value
# 1     alabama   4777326
# 2      alaska    711139
# 3     arizona   6410979
# 4    arkansas   2916372
# 5  california  37325068
