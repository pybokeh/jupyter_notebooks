# %%
import toyplot
import pandas as pd

# %%
df = pd.read_clipboard()
df = df.applymap(lambda x: float(str(x).replace('%','')))

# %%
toyplot.data.Table(df)
# Out:
# <table class="toyplot-data-Table" style="border-collapse:collapse; border:none; color: #292724"><tr style="border:none;border-bottom:1px solid #292724"><th style="text-align:left;border:none;padding-right:1em;">A</th><th style="text-align:left;border:none;padding-right:1em;">B</th></tr><tr style="border:none"><td style="border:none;padding-right:1em;">0.0</td><td style="border:none;padding-right:1em;">0.0</td></tr><tr style="border:none"><td style="border:none;padding-right:1em;">0.18</td><td style="border:none;padding-right:1em;">0.07</td></tr><tr style="border:none"><td style="border:none;padding-right:1em;">0.22</td><td style="border:none;padding-right:1em;">0.11</td></tr><tr style="border:none"><td style="border:none;padding-right:1em;">0.3</td><td style="border:none;padding-right:1em;">0.17</td></tr><tr style="border:none"><td style="border:none;padding-right:1em;">0.35</td><td style="border:none;padding-right:1em;">0.25</td></tr><tr style="border:none"><td style="border:none;padding-right:1em;">0.6</td><td style="border:none;padding-right:1em;">0.3</td></tr><tr style="border:none"><td style="border:none;padding-right:1em;">0.68</td><td style="border:none;padding-right:1em;">0.5</td></tr></table>

# %%
canvas = toyplot.Canvas(width=600, height=400)
axes = canvas.axes(label='Hard Drive Failures', xlabel="Months From Start Of Sales", 
                   ylabel="Cumulative Defect Rate (%)")

series = []
for column in df.columns:
    series.append(axes.plot(df[column].values, stroke_width=3))

legend_data = []
for i, column in enumerate(df.columns):
    legend_data.append((column, series[i]))
    
canvas.legend(legend_data,
    corner=("top-left", 50, 50, 50)
);
# Out:
# <div align="center" class="toyplot" id="t101db542dd964e6b9bfaa5e237837bb3"><svg class="toyplot-canvas-Canvas" height="400.0px" id="t8df4578fd42c43af80d326747cce52d7" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600.0 400.0" width="600.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t2cc5d4607a82473f81c3c315714fa416"><clipPath id="t905f9fc43ce74aafabf862cd6da1a240"><rect height="320.0" width="520.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t905f9fc43ce74aafabf862cd6da1a240)"><g class="toyplot-mark-Plot" id="t64c239d4e2c44be2bab58757018a3906" style="fill:none"><g class="toyplot-Series"><path d="M 50.0 350.0 L 133.33333333333331 278.0 L 216.66666666666666 262.0 L 300.0 230.00000000000003 L 383.33333333333331 210.00000000000006 L 466.66666666666669 110.00000000000003 L 550.0 77.999999999999972" style="stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0;stroke-width:3.0"></path></g></g><g class="toyplot-mark-Plot" id="tfe334b24061e4c9da55b5b80d591e29b" style="fill:none"><g class="toyplot-Series"><path d="M 50.0 350.0 L 133.33333333333331 322.0 L 216.66666666666666 305.99999999999994 L 300.0 282.0 L 383.33333333333331 250.00000000000003 L 466.66666666666669 230.00000000000003 L 550.0 150.0" style="stroke:rgb(98.8%,55.3%,38.4%);stroke-opacity:1.0;stroke-width:3.0"></path></g></g></g><g class="toyplot-coordinates-Axis" id="tf6328fdb5de348b9b4991a5531e85bc5" transform="translate(50.0,350.0)translate(0,10.0)"><line style="" x1="0" x2="500.0" y1="0" y2="0"></line><g><text style="dominant-baseline:hanging;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(0.0,6)"><tspan style="dominant-baseline:inherit">0</tspan></text><text style="dominant-baseline:hanging;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(166.66666666666666,6)"><tspan style="dominant-baseline:inherit">2</tspan></text><text style="dominant-baseline:hanging;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(333.3333333333333,6)"><tspan style="dominant-baseline:inherit">4</tspan></text><text style="dominant-baseline:hanging;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(500.0,6)"><tspan style="dominant-baseline:inherit">6</tspan></text></g><text style="dominant-baseline:middle;font-size:12px;font-weight:bold;stroke:none;text-anchor:middle" transform="translate(250.0,0)translate(0,24.0)"><tspan style="dominant-baseline:inherit">Months From Start Of Sales</tspan></text><g class="toyplot-coordinates-Axis-coordinates" style="visibility:hidden" transform=""><line style="stroke:rgb(43.9%,50.2%,56.5%);stroke-opacity:1.0;stroke-width:1.0" x1="0" x2="0" y1="-3.0" y2="4.5"></line><text style="alignment-baseline:alphabetic;fill:rgb(43.9%,50.2%,56.5%);fill-opacity:1.0;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" x="0" y="-6"></text></g></g><g class="toyplot-coordinates-Axis" id="taa0603e765a14533b94379cda2af7701" transform="translate(50.0,350.0)rotate(-90.0)translate(0,-10.0)"><line style="" x1="0" x2="272.0" y1="0" y2="0"></line><g><text style="dominant-baseline:alphabetic;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(0.0,-6)"><tspan style="dominant-baseline:inherit">0.0</tspan></text><text style="dominant-baseline:alphabetic;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(100.0,-6)"><tspan style="dominant-baseline:inherit">0.2</tspan></text><text style="dominant-baseline:alphabetic;font-size:10px;font-weight:normal;stroke:none;text-anchor:middle" transform="translate(200.0,-6)"><tspan style="dominant-baseline ...
#             <li class="toyplot-mark-popup-title" style="color:lightgray;cursor:default;padding:5px;list-style:none;margin:0"></li>
#             <li class="toyplot-mark-popup-save-csv" onmouseout="this.style.color='white';this.style.background='steelblue'" onmouseover="this.style.color='steelblue';this.style.background='white'" style="border-radius:3px;padding:5px;list-style:none;margin:0">
#                 Save as .csv
#             </li>
#         </ul><script>
#         (function()
#         {
#           var data_tables = [{"id": "t64c239d4e2c44be2bab58757018a3906", "title": "Plot Data", "data": [[0, 1, 2, 3, 4, 5, 6], [0.0, 0.18, 0.22, 0.3, 0.35, 0.6, 0.68]], "names": ["x", "y0"], "filename": "toyplot"}, {"id": "tfe334b24061e4c9da55b5b80d591e29b", "title": "Plot Data", "data": [[0, 1, 2, 3, 4, 5, 6], [0.0, 0.07, 0.11, 0.17, 0.25, 0.3, 0.5]], "names": ["x", "y0"], "filename": "toyplot"}];
#
#           function save_csv(data_table)
#           {
#             var uri = "data:text/csv;charset=utf-8,";
#             uri += data_table.names.join(",") + "\n";
#             for(var i = 0; i != data_table.data[0].length; ++i)
#             {
#               for(var j = 0; j != data_table.data.length; ++j)
#               {
#                 if(j)
#                   uri += ",";
#                 uri += data_table.data[j][i];
#               }
#               uri += "\n";
#             }
#             uri = encodeURI(uri);
#
#             var link = document.createElement("a");
#             if(typeof link.download != "undefined")
#             {
#               link.href = uri;
#               link.style = "visibility:hidden";
#               link.download = data_table.filename + ".csv";
#
#               document.body.appendChild(link);
#               link.click();
#               document.body.removeChild(link);
#             }
#             else
#             {
#               window.open(uri);
#             }
#           }
#
#           function open_popup(data_table)
#           {
#             re

# %%
df = pd.read_clipboard(index_col=0)
df = df.applymap(lambda x: float(str(x).replace('%','')))

# %%
df
# Out:
#               A     B
# BUILD_MTH
# 2014-01    0.43   NaN
# 2014-02    0.37   NaN
# 2014-03    0.33   NaN
# 2014-04    0.30   NaN
# 2014-05    0.28   NaN
# 2014-06    0.25   NaN
# 2014-07    0.22   NaN
# 2014-08     NaN  0.21
# 2014-09     NaN  0.19
# 2014-10     NaN  0.10
# 2014-11     NaN  0.07
# 2014-12     NaN  0.03

# %%
canvas = toyplot.Canvas(width=600, height=400)
axes = canvas.axes(label='Hard Drive Failures', xlabel="Vehicle Build Month", 
                   ylabel="Defect Rate (%)")

series = []
for column in df.columns:
    series.append(axes.bars(df[column].values))

legend_data = []
for i, column in enumerate(df.columns):
    legend_data.append((column, series[i]))
    
canvas.legend(legend_data,
    corner=("top-right", 5, 5, 5)
)
    
axes.x.ticks.locator = toyplot.locator.Explicit(labels=df.index)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/pybokeh/envs/jupyter/lib/python3.5/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     341             method = _safe_get_formatter_method(obj, self.print_method)
#     342             if method is not None:
# --> 343                 return method()
#     344             return None
#     345         else:
#
# /home/pybokeh/envs/jupyter/lib/python3.5/site-packages/toyplot-0.12.0.dev0-py3.5.egg/toyplot/canvas.py in _repr_html_(self)
#     145         return toyplot.compatibility.unicode_type(
#     146             xml.tostring(
# --> 147                 toyplot.html.render(self),
#     148                 encoding="utf-8",
#     149                 method="html"),
#
# /home/pybokeh/envs/jupyter/lib/python3.5/site-packages/toyplot-0.12.0.dev0-py3.5.egg/toyplot/html.py in render(canvas, fobj, animation)
#     180     # Render the canvas.
#     181     context = _RenderContext(root=root_xml)
# --> 182     _render(canvas, context.copy(parent=root_xml))
#     183
#     184     # Return / write the results.
#
# /home/pybokeh/envs/jupyter/lib/python3.5/site-packages/multipledispatch/dispatcher.py in __call__(self, *args, **kwargs)
#     162             self._cache[types] = func
#     163         try:
# --> 164             return func(*args, **kwargs)
#     165
#     166         except MDNotImplementedError:
#
# /home/pybokeh/envs/jupyter/lib/python3.5/site-packages/toyplot-0.12.0.dev0-py3.5.egg/toyplot/html.py in _render(canvas, context)
#     622
#     623     for child in canvas._children:
# --> 624         _render(canvas, child, context.copy(parent=svg_xml))
#     625
#     626     interactive_xml = xml.SubElement(
#
# /home/pybokeh/envs/jupyter/lib/python3.5/site-packages/multipledispatch/dispatcher.py in __call__(self, *args, **kwargs)
#     162             self._cache[types] = func
#     163         try:
# --> 164             return func(*args, **kwargs)
#     165
#     166         except MDNotImplementedError:
#
# /home/pybokeh/envs/jupyter/lib/python3.5/site-packages/toyplot-0.12.0.dev0-py3.5.egg/toyplot/html.py in _render(canvas, legend, context)
#    2069             elif isinstance(mark, (toyplot.mark.BarBoundaries, toyplot.mark.BarMagnitudes, toyplot.mark.FillBoundaries, toyplot.mark.FillMagnitudes)):
#    2070                 dstyle = toyplot.style.combine({"fill": toyplot.color.to_css(
# -> 2071                     mark._fill[0]), "opacity": mark._opacity[0]}, mark._style)
#    2072                 xml.SubElement(
#    2073                     context.parent,
#
# /home/pybokeh/envs/jupyter/lib/python3.5/site-packages/toyplot-0.12.0.dev0-py3.5.egg/toyplot/color.py in to_css(color)
#    1429     css: :class:`str` containing a CSS color value.
#    1430       """
# -> 1431     return "rgba(%.1f%%,%.1f%%,%.1f%%,%.3f)" % (color["r"] * 100, color["g"] * 100, color["b"] * 100, color["a"])
#    1432
#    1433
#
# TypeError: string indices must be integers

# %%
canvas = toyplot.Canvas(width=600, height=400)
axes = canvas.axes(label='Hard Drive Failures', xlabel='Vehicle Build Month',
                   ylabel="Defect Rate (%)")

series = []
for column in df.columns:
    series.append(axes.bars(df[column].values))
'''
legend_data = []
for i, column in enumerate(df.columns):
    legend_data.append((column, series[i]))
    
canvas.legend(legend_data,
    corner=("top-right", 50, 50, 50)
);'''
    
axes.x.ticks.locator = toyplot.locator.Explicit(labels=df.index)
# Out:
# <div align="center" class="toyplot" id="td3c8ac2ec1fc4a5285646095e12209a7"><svg class="toyplot-canvas-Canvas" height="400.0px" id="t190eb68d38154a12a91bec37992a51f8" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600.0 400.0" width="600.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="tcfbe18fdee944d418e2b2eba1beeb95f"><clipPath id="t42e82b571d5c479ab7e454020371f234"><rect height="320.0" width="520.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t42e82b571d5c479ab7e454020371f234)"><g class="toyplot-mark-BarMagnitudes" id="tdc0c424b93f942d4b9b15c2b0253963e" style="stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"><g class="toyplot-Series"><rect class="toyplot-Datum" height="300.0" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="41.666666666666657" x="50.0" y="50.0"></rect><rect class="toyplot-Datum" height="258.1395348837209" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="41.666666666666657" x="91.666666666666657" y="91.860465116279073"></rect><rect class="toyplot-Datum" height="230.23255813953489" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="41.666666666666686" x="133.33333333333331" y="119.76744186046511"></rect><rect class="toyplot-Datum" height="209.30232558139534" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="41.666666666666657" x="175.0" y="140.69767441860466"></rect><rect class="toyplot-Datum" height="195.34883720930236" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="41.666666666666714" x="216.66666666666666" y="154.65116279069764"></rect><rect class="toyplot-Datum" height="174.41860465116278" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="41.666666666666629" x="258.33333333333337" y="175.58139534883722"></rect><rect class="toyplot-Datum" height="153.48837209302326" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="41.666666666666686" x="300.0" y="196.51162790697674"></rect></g></g><g class="toyplot-mark-BarMagnitudes" id="t1af6f57a80334ad5bacf674b870f73ef" style="stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"><g class="toyplot-Series"><rect class="toyplot-Datum" height="146.51162790697674" style="fill:rgb(98.8%,55.3%,38.4%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="41.666666666666629" x="341.66666666666669" y="203.48837209302326"></rect><rect class="toyplot-Datum" height="132.55813953488371" style="fill:rgb(98.8%,55.3%,38.4%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="41.666666666666686" x="383.33333333333331" y="217.44186046511629"></rect><rect class="toyplot-Datum" height="69.767441860465055" style="fill:rgb(98.8%,55.3%,38.4%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="41.666666666666686" x="425.0" y="280.23255813953494"></rect><rect class="toyplot-Datum" height="48.837209302325562" style="fill:rgb(98.8%,55.3%,38.4%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="41.666666666666629" x="466.66666666666669" y="301.16279069767444"></rect><rect class="to ...

# %%
canvas = toyplot.Canvas(width=600, height=400)
axes = canvas.axes(label='Hard Drive Failures',
                   ylabel="Defect Rate (%)")

series = []
for column in df.columns:
    series.append(axes.bars(df[column].values))
'''
legend_data = []
for i, column in enumerate(df.columns):
    legend_data.append((column, series[i]))
    
canvas.legend(legend_data,
    corner=("top-right", 50, 50, 50)
);'''
    
axes.x.ticks.locator = toyplot.locator.Explicit(labels=df.index)

axes.x.ticks.labels.angle = 90
canvas.text(300, 395, "Vehicle Build Month", style={"font-weight":"bold"});
# Out:
# <div align="center" class="toyplot" id="tc31a9f94d9444af9adf9b43589fe2c5a"><svg class="toyplot-canvas-Canvas" height="400.0px" id="t49f86f37928e44b18aad7eb26fb8edaa" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600.0 400.0" width="600.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t35283b69948b409e897b30e7fda2d397"><clipPath id="ta305e572fd404f6c9c1b002add7c5267"><rect height="320.0" width="520.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#ta305e572fd404f6c9c1b002add7c5267)"><g class="toyplot-mark-BarMagnitudes" id="t1b022df2eb6c420ab23beb6ead2edb8e" style="stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"><g class="toyplot-Series"><rect class="toyplot-Datum" height="300.0" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="41.666666666666657" x="50.0" y="50.0"></rect><rect class="toyplot-Datum" height="258.1395348837209" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="41.666666666666657" x="91.666666666666657" y="91.860465116279073"></rect><rect class="toyplot-Datum" height="230.23255813953489" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="41.666666666666686" x="133.33333333333331" y="119.76744186046511"></rect><rect class="toyplot-Datum" height="209.30232558139534" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="41.666666666666657" x="175.0" y="140.69767441860466"></rect><rect class="toyplot-Datum" height="195.34883720930236" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="41.666666666666714" x="216.66666666666666" y="154.65116279069764"></rect><rect class="toyplot-Datum" height="174.41860465116278" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="41.666666666666629" x="258.33333333333337" y="175.58139534883722"></rect><rect class="toyplot-Datum" height="153.48837209302326" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="41.666666666666686" x="300.0" y="196.51162790697674"></rect></g></g><g class="toyplot-mark-BarMagnitudes" id="t5b499c56744448e3bbb9afd67d5f03c4" style="stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"><g class="toyplot-Series"><rect class="toyplot-Datum" height="146.51162790697674" style="fill:rgb(98.8%,55.3%,38.4%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="41.666666666666629" x="341.66666666666669" y="203.48837209302326"></rect><rect class="toyplot-Datum" height="132.55813953488371" style="fill:rgb(98.8%,55.3%,38.4%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="41.666666666666686" x="383.33333333333331" y="217.44186046511629"></rect><rect class="toyplot-Datum" height="69.767441860465055" style="fill:rgb(98.8%,55.3%,38.4%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="41.666666666666686" x="425.0" y="280.23255813953494"></rect><rect class="toyplot-Datum" height="48.837209302325562" style="fill:rgb(98.8%,55.3%,38.4%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" width="41.666666666666629" x="466.66666666666669" y="301.16279069767444"></rect><rect class="to ...
