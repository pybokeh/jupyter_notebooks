# %%
# %matplotlib inline
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
pd.set_option("display.max_rows",1000)
pd.set_option("display.max_columns",50)

# %%
df = pd.read_csv('/home/pybokeh/Downloads/NYPD_Motor_Vehicle_Collisions.csv', parse_dates=['DATE'])

# %%
data2015.head()
# Out:
#         DATE   TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0 2015-10-27  10:10        NaN       NaN        NaN        NaN
# 1 2015-10-27   9:15        NaN       NaN        NaN        NaN
# 2 2015-10-27   9:20  MANHATTAN     10028  40.778815 -73.956083
# 3 2015-10-27   9:20        NaN       NaN  40.847461 -73.944234
# 4 2015-10-27   9:20   BROOKLYN     11229  40.606217 -73.953924
#
#                     LOCATION      ON STREET NAME      CROSS STREET NAME  \
# 0                        NaN  BRUCKNER BOULEVARD          ZEREGA AVENUE
# 1                        NaN          164 STREET  GRAND CENTRAL PARKWAY
# 2  (40.7788145, -73.9560828)    LEXINGTON AVENUE         EAST 85 STREET
# 3   (40.8474611, -73.944234)                 NaN                    NaN
# 4  (40.6062171, -73.9539239)            AVENUE R         EAST 19 STREET
#
#   OFF STREET NAME  NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  \
# 0             NaN                          0                         0
# ...

# %%
criteria = df['DATE'] >= datetime(2015,1,1)
data2015 = df[criteria]

# %%
borough_counts = data2015.BOROUGH.value_counts()
borough_counts
# Out:
# BROOKLYN         41580
# MANHATTAN        34725
# QUEENS           34710
# BRONX            17297
# STATEN ISLAND     5084
# Name: BOROUGH, dtype: int64

# %%
borough_counts.plot.bar()
plt.show()
