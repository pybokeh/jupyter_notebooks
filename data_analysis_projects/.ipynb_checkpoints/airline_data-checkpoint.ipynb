# %% [markdown]
# This problem set features data from the United States Department of Transportation on Airline On-Time Statistics and Delay Causes.
#
# [Data Download and Description](http://teamleada.us8.list-manage.com/track/click?u=ed489e61d3051497688b56bb7&id=575619e92d&e=7b87884d8e)
#
# Instructions:
# We will only work with the first million rows. Download year 2008.
#
# **Problem 1:** Find the IATA code that is in the Origin column, but is NOT in the Dest column.
#
# **Problem 2:**  Which airport, as defined by the IATA code, has at least 10,000 flights and had the lowest probability for a delayed flight in the data?
#
# Define a delay as:<br>
# - If ArrDelay > 0, then count as a delayed flight to Origin airport.
# - If DepDelay > 0, then count as a delayed flight to Dest airport.
#
# Total delayed flights equals the sum of the two above.
#
# Probability of delay equals total delayed flights divided by total flights (Origin & Dest) that go through that airport.
#
# **Problem 3:** Create a spreadsheet of data which calculates the historical probability of flight delay in each of the twenty carriers based off of two characteristics.
#
#     DayofWeek - Weekday (1,2,3,4,5) or Weekend (6,7)
#     DepTime - Day Time (0501 to 1700), Night Time (1701 to 2400), or Red Eye (0000 to 0500)
#     UniqueCarrier - Carrier (20)
#
# For example, for an AA day time flight on the weekday, the percentage of delayed flights was ~29.3%.

# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
import pandas as pd
pd.set_option("display.max_rows",1000)
pd.set_option("display.max_columns",50)

# %%
df = pd.read_csv('/home/pybokeh/Downloads/2008.csv', nrows=1000000) # read only the first million rows

# %%
len(df)
# Out:
# 1000000

# %%
df.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4     2003        1955     2211
# 1  2008      1           3          4      754         735     1002
# 2  2008      1           3          4      628         620      804
# 3  2008      1           3          4      926         930     1054
# 4  2008      1           3          4     1829        1755     1959
#
#    CRSArrTime UniqueCarrier  FlightNum TailNum  ActualElapsedTime  \
# 0        2225            WN        335  N712SW                128
# 1        1000            WN       3231  N772SW                128
# 2         750            WN        448  N428WN                 96
# 3        1100            WN       1746  N612SW                 88
# 4        1925            WN       3920  N464WN                 90
#
#    CRSElapsedTime  AirTime  ArrDelay  DepDelay Origin Dest  Distance  TaxiIn  \
# 0             150      116       -14         8    IAD  TPA       810       4
# 1             145      113         2        19    IAD  TPA       810       5
# 2              90       76        14         8    IND  BWI       515       3
# 3              90       78        -6        -4    IND  BWI       515       3
# 4              90       77        34        34    IND  BWI       515       3
#
#    TaxiOut  Cancelled CancellationCode  Diverted  CarrierDelay  WeatherDelay  \
# 0        8          0              NaN         0           NaN           NaN
# 1       10          0              NaN         0           NaN           NaN
# 2       17          0              NaN         0           NaN           NaN
# 3        7          0              NaN         0           NaN           NaN
# 4       10          0              NaN         0             2             0
#
#    NASDelay  SecurityDelay  LateAircraftDelay
# 0       NaN            NaN                NaN
# 1       NaN            NaN                NaN
# 2       NaN            NaN                NaN
# 3       NaN            NaN                NaN
# 4         0              0                 32

# %%
origin = pd.DataFrame({'origin':df['Origin']})
origin.drop_duplicates(inplace=True)
origin
# Out:
#        origin
# 0         IAD
# 2         IND
# 19        ISP
# 47        JAN
# 56        JAX
# 79        LAS
# 320       LAX
# 442       LBB
# 455       LIT
# 469       MAF
# 481       MCI
# 553       MCO
# 669       MDW
# 896       MHT
# 927       MSY
# 962       OAK
# 1106      OKC
# 1128      OMA
# 1144      ONT
# 1200      ORF
# 1213      PBI
# 1226      PDX
# 1268      PHL
# 1331      PHX
# 1531      PIT
# 1554      PVD
# 1588      RDU
# 1619      RNO
# 1659      RSW
# 1670      SAN
# 1773      SAT
# 1821      SDF
# 1842      SEA
# 1889      SFO
# 1915      SJC
# 1995      SLC
# 2044      SMF
# 2128      SNA
# 2166      STL
# 2241      TPA
# 2326      TUL
# 2346      TUS
# 2367      ABQ
# 2432      ALB
# 2446      AMA
# 2458      AUS
# 2507      BDL
# 2526      BHM
# 2553      BNA
# 2639      BOI
# 2658      BUF
# 2675      BUR
# 2736      BWI
# 2908      CLE
# 2926      CMH
# 2955      CRP
# 2961      DAL
# 3098      DEN
# 3154      DTW
# 3175      ELP
# 3209      FLL
# 3253      GEG
# 3269      HOU
# 3416      HRL
# 94055     ROC
# 94056     DAY
# 94059     ORD
# 94063     EWR
# 94068     SYR
# 94070     IAH
# 94074     LFT
# 94085     MKE
# 94087     CHS
# 94091     LCH
# 94096     CLT
# 94098     BTR
# 94107     CRW
# 94169     FAT
# 94231     COS
# 94716     MRY
# 94866     LGB
# 95418     BFL
# 100001    EUG
# 101920    ICT
# 102714    MEM
# 102723    LGA
# 102725    DCA
# 102726    BTV
# 102729    GRK
# 102737    BRO
# 102738    TYS
# 102739    DSM
# 102740    BPT
# 102741    GPT
# 102748    GRR
# 102778    PWM
# 102785    MSP
# 102786    RIC
# 102787    CVG
# 102789    SAV
# 102795    SRQ
# 102809    GSO
# 102818    CHA
# 102821    XNA
# 102823    GSP
# 102880    LEX
# 102889    MFE
# 102898    ABE
# 102909    MLU
# 102928    MOB
# 102958    LRD
# 102960    SHV
# 103022    TLH
# 103041    CAE
# 103081    AEX
# 103149    ATL
# 103218    DFW
# 103276    BGR
# 103286    AVL
# 103327    BOS
# 103509    MSN
# 103519    HSV
# 103622    MGM
# 103706    MYR
# 103968    VPS
# 104025    CLL
# 104097    PNS
# 104715    MTJ
# 111049    DAB
# 122942    PSP
# 129117    ASE
# 129129    ATW
# 129134    AVP
# 129147    BMI
# 129169    CAK
# 129178    CID
# 129179    CLD
# 129253    COD
# 129261    CPR
# 129266    CWA
# 129307    DRO
# 129324    EGE
# 129342    FLG
# 129346    FSD
# 129347    FWA
# 129348    GJT
# 129356    GRB
# 129368    HDN
# 129370    HNL
# 129468    ILM
# 129473    ITO
# 129481    JFK
# 129484    KOA
# 129490    LAN
# 129517    LIH
# 129523    MBS
# 129528    MDT
# 129537    MFR
# 129552    OGG
# 129735    RAP
# 129745    ROA
# 129756    SBA
# 129762    SBN
# 129763    SBP
# 129773    SPI
# 129781    TEX
# 129794    YUM
# 130539    TVC
# 151285    HPN
# 151314    MIA
# 151381    MLB
# 151399    SGF
# 152511    TRI
# 157518    ACY
# 169280    TWF
# 169281    SUN
# 169282    PIH
# 169306    EKO
# 169310    SGU
# 169353    PSC
# 169365    BTM
# 169372    SLE
# 169375    IDA
# 169396    HLN
# 169398    FCA
# 169403    MSO
# 169404    GTF
# 169408    LWS
# 169415    YKM
# 169423    BZN
# 169441    BIL
# 169461    RDM
# 169554    FAR
# 169603    JAC
# 169742    IYK
# 169761    SMX
# 169779    ACV
# 169788    OXR
# 169833    RDD
# 169947    CEC
# 169957    MOD
# 169979    CIC
# 169983    IPL
# 170118    PIA
# 170124    MLI
# 170138    GUC
# 170145    AZO
# 170268    LNK
# 170442    PMD
# 170528    BIS
# 170650    RFD
# 171137    BLI
# 179148    CDC
# 245597    SJU
# 245611    STT
# 256213    ANC
# 262599    STX
# 302773    PHF
# 323256    DHN
# 323658    PFN
# 324056    TOL
# 324208    AGS
# 324825    FAY
# 325003    HHH
# 325057    EVV
# 326366    GNV
# 326481    ABY
# 327036    FNT
# 327126    OAJ
# 327241    BQK
# 328830    SWF
# 328949    EWN
# 329138    MEI
# 329952    GTR
# 330550    LYH
# 330847    FSM
# 331313    EYW
# 331611    VLD
# 332120    CSG
# 338704    MCN
# 338844    CHO
# 339762    TUP
# 340868    FLO
# 342438    SCE
# 382961    TYR
# 383019    LAW
# 383291    SPS
# 383352    ABI
# 383636    GGG
# 384221    ACT
# 384341    SJT
# 384395    TXK
# 388876    CMI
# 394788    ROW
# 401764    RST
# 401857    MQT
# 402868    LSE
# 408303    DBQ
# 423374    GFK
# 438137    MOT
# 444694    DLH
# 454648    SUX
# 459282    PLN
# 459405    BGM
# 461119    ERI
# 462881    ALO
# 463636    CMX
# 465634    RHI
# 472489    ELM
# 533589    JNU
# 533591    KTN
# 533611    ADQ
# 533619    FAI
# 533633    SIT
# 533780    PSG
# 533783    WRG
# 533798    SCC
# 533799    BET
# 533801    CDV
# 533803    OME
# 533805    YAK
# 533810    BRW
# 533811    OTZ
# 534480    ADK
# 546348    BQN
# 546777    PSE

# %%
dest = pd.DataFrame({'dest':df['Dest']})
dest.drop_duplicates(inplace=True)
dest
# Out:
#        dest
# 0       TPA
# 2       BWI
# 5       JAX
# 6       LAS
# 8       MCI
# 10      MCO
# 12      MDW
# 16      PHX
# 26      FLL
# 40      PBI
# 43      RSW
# 49      HOU
# 56      BHM
# 57      BNA
# 71      IND
# 72      ORF
# 74      PHL
# 79      ABQ
# 86      ALB
# 87      AMA
# 88      AUS
# 91      BDL
# 97      BOI
# 99      BUF
# 100     BUR
# 116     CLE
# 117     CMH
# 119     DEN
# 126     ELP
# 128     GEG
# 134     IAD
# 137     ISP
# 138     LAX
# 152     LBB
# 153     LIT
# 154     MAF
# 174     MHT
# 175     MSY
# 177     OAK
# 191     OKC
# 192     OMA
# 195     ONT
# 206     PDX
# 230     PIT
# 232     PVD
# 233     RDU
# 235     RNO
# 248     SAN
# 262     SAT
# 266     SDF
# 267     SEA
# 271     SFO
# 278     SJC
# 287     SLC
# 295     SMF
# 303     SNA
# 309     STL
# 313     TUL
# 314     TUS
# 445     DAL
# 589     DTW
# 612     JAN
# 1804    HRL
# 3290    CRP
# 94055   EWR
# 94056   IAH
# 94071   XNA
# 94075   DCA
# 94077   GSO
# 94083   ROC
# 94084   MYR
# 94088   SYR
# 94094   ATL
# 94103   SAV
# 94110   RIC
# 94262   COS
# 94324   FAT
# 94810   MRY
# 94841   LGB
# 95510   BFL
# 99694   EUG
# 101982  ICT
# 102731  MSN
# 102734  CAE
# 102736  DAY
# 102743  BTR
# 102747  TLH
# 102750  DFW
# 102755  LFT
# 102756  PWM
# 102760  SHV
# 102772  MKE
# 102775  CHS
# 102790  CRW
# 102791  HSV
# 102793  TYS
# 102796  MTJ
# 102801  MGM
# 102803  MFE
# 102805  MSP
# 102811  GSP
# 102833  GRR
# 102835  MEM
# 102855  BTV
# 102874  CLT
# 102923  BRO
# 102932  CVG
# 102976  LGA
# 102998  VPS
# 102999  LEX
# 103018  BPT
# 103040  PNS
# 103061  ORD
# 103074  ABE
# 103114  LRD
# 103118  BGR
# 103126  GRK
# 103136  SRQ
# 103200  LCH
# 103221  AEX
# 103230  AVL
# 103246  GPT
# 103389  MLU
# 103450  MOB
# 103577  BOS
# 103624  DSM
# 103785  CHA
# 103954  CLL
# 104270  PSP
# 104980  DAB
# 129220  ILM
# 129224  JFK
# 129228  MDT
# 129267  ASE
# 129271  COD
# 129275  CPR
# 129280  DRO
# 129285  EGE
# 129289  GJT
# 129294  HDN
# 129303  RAP
# 129370  ITO
# 129376  KOA
# 129382  LIH
# 129388  OGG
# 129450  ROA
# 129455  SPI
# 129473  HNL
# 129496  MFR
# 129501  SBA
# 129503  SBP
# 129507  YUM
# 129565  ATW
# 129569  AVP
# 129572  BMI
# 129584  CAK
# 129588  CID
# 129594  CWA
# 129598  FSD
# 129599  FWA
# 129601  GRB
# 129609  LAN
# 129611  MBS
# 129618  SBN
# 129637  CLD
# 129656  FLG
# 129701  TEX
# 130358  TVC
# 151380  MLB
# 151464  SGF
# 151552  MIA
# 151723  HPN
# 151927  TRI
# 169279  TWF
# 169284  PIH
# 169287  SUN
# 169307  EKO
# 169312  SGU
# 169354  PSC
# 169366  BTM
# 169367  BIL
# 169369  FAR
# 169379  IDA
# 169384  BZN
# 169393  MSO
# 169399  FCA
# 169400  HLN
# 169405  GTF
# 169424  LWS
# 169429  YKM
# 169440  SLE
# 169464  RDM
# 169511  BLI
# 169593  JAC
# 169743  IYK
# 169760  SMX
# 169780  ACV
# 169787  OXR
# 169835  RDD
# 169956  MOD
# 169968  CEC
# 169980  CIC
# 169985  IPL
# 170107  PIA
# 170114  LNK
# 170137  GUC
# 170146  AZO
# 170238  MLI
# 170415  PMD
# 170529  BIS
# 170649  RFD
# 179084  CDC
# 205959  OGD
# 245583  STT
# 245611  SJU
# 256693  ANC
# 261748  STX
# 302772  PHF
# 323174  MCN
# 323185  VLD
# 323470  CSG
# 323690  SWF
# 323794  BQK
# 323900  DHN
# 323931  ABY
# 324209  AGS
# 324794  MEI
# 325482  FAY
# 325676  EWN
# 326252  SCE
# 326888  EYW
# 327152  EVV
# 327274  PFN
# 327821  GNV
# 328254  OAJ
# 328919  FNT
# 329935  CHO
# 331976  FSM
# 334392  FLO
# 334649  HHH
# 335202  TOL
# 337098  LYH
# 338428  GTR
# 339029  TUP
# 342284  ACY
# 382992  LAW
# 383046  TYR
# 383379  ABI
# 383437  TXK
# 383609  ACT
# 384004  SPS
# 384368  SJT
# 384488  GGG
# 388907  CMI
# 394873  ROW
# 400835  MQT
# 401733  RST
# 402810  LSE
# 403258  DBQ
# 422895  DLH
# 423269  GFK
# 438013  MOT
# 454726  RHI
# 455547  SUX
# 456154  CMX
# 459142  BGM
# 459257  PLN
# 459349  ERI
# 462939  ALO
# 471416  ELM
# 533581  FAI
# 533589  KTN
# 533591  SIT
# 533626  JNU
# 533778  WRG
# 533783  PSG
# 533797  CDV
# 533800  BET
# 533803  OTZ
# 533808  YAK
# 533811  OME
# 533817  ADQ
# 533820  BRW
# 533826  SCC
# 534642  ADK
# 546438  PSE
# 546491  BQN

# %%
len(origin)
# Out:
# 286

# %%
len(dest)
# Out:
# 287

# %%
left_merged = pd.merge(dest, origin, how='left', left_on='dest', right_on='origin')

# %%
left_merged.sort(columns='dest', inplace=True)
left_merged
# Out:
#     dest origin
# 113  ABE    ABE
# 247  ABI    ABI
# 17   ABQ    ABQ
# 224  ABY    ABY
# 249  ACT    ACT
# 196  ACV    ACV
# 244  ACY    ACY
# 284  ADK    ADK
# 281  ADQ    ADQ
# 119  AEX    AEX
# 225  AGS    AGS
# 18   ALB    ALB
# 268  ALO    ALO
# 19   AMA    AMA
# 215  ANC    ANC
# 133  ASE    ASE
# 72   ATL    ATL
# 152  ATW    ATW
# 20   AUS    AUS
# 120  AVL    AVL
# 153  AVP    AVP
# 206  AZO    AZO
# 21   BDL    BDL
# 277  BET    BET
# 79   BFL    BFL
# 265  BGM    BGM
# 115  BGR    BGR
# 12   BHM    BHM
# 180  BIL    BIL
# 209  BIS    BIS
# 192  BLI    BLI
# 154  BMI    BMI
# 13   BNA    BNA
# 22   BOI    BOI
# 124  BOS    BOS
# 110  BPT    BPT
# 222  BQK    BQK
# 286  BQN    BQN
# 105  BRO    BRO
# 282  BRW    BRW
# 179  BTM    BTM
# 85   BTR    BTR
# 103  BTV    BTV
# 23   BUF    BUF
# 24   BUR    BUR
# 1    BWI    BWI
# 183  BZN    BZN
# 83   CAE    CAE
# 155  CAK    CAK
# 211  CDC    CDC
# 276  CDV    CDV
# 200  CEC    CEC
# 126  CHA    CHA
# 236  CHO    CHO
# 92   CHS    CHS
# 201  CIC    CIC
# 156  CID    CID
# 164  CLD    CLD
# 25   CLE    CLE
# 127  CLL    CLL
# 104  CLT    CLT
# 26   CMH    CMH
# 253  CMI    CMI
# 264  CMX    CMX
# 134  COD    COD
# 75   COS    COS
# 135  CPR    CPR
# 63   CRP    CRP
# 93   CRW    CRW
# 220  CSG    CSG
# 106  CVG    CVG
# 157  CWA    CWA
# 129  DAB    DAB
# 59   DAL    DAL
# 84   DAY    DAY
# 258  DBQ    DBQ
# 67   DCA    DCA
# 27   DEN    DEN
# 87   DFW    DFW
# 223  DHN    DHN
# 259  DLH    DLH
# 136  DRO    DRO
# 125  DSM    DSM
# 60   DTW    DTW
# 137  EGE    EGE
# 176  EKO    EKO
# 269  ELM    ELM
# 28   ELP    ELP
# 267  ERI    ERI
# 80   EUG    EUG
# 231  EVV    EVV
# 228  EWN    EWN
# 64   EWR    EWR
# 230  EYW    EYW
# 270  FAI    FAI
# 181  FAR    FAR
# 76   FAT    FAT
# 227  FAY    FAY
# 185  FCA    FCA
# 165  FLG    FLG
# 8    FLL    FLL
# 238  FLO    FLO
# 235  FNT    FNT
# 158  FSD    FSD
# 237  FSM    FSM
# 159  FWA    FWA
# 29   GEG    GEG
# 260  GFK    GFK
# 252  GGG    GGG
# 138  GJT    GJT
# 233  GNV    GNV
# 121  GPT    GPT
# 160  GRB    GRB
# 116  GRK    GRK
# 101  GRR    GRR
# 68   GSO    GSO
# 100  GSP    GSP
# 187  GTF    GTF
# 242  GTR    GTR
# 205  GUC    GUC
# 139  HDN    HDN
# 239  HHH    HHH
# 186  HLN    HLN
# 147  HNL    HNL
# 11   HOU    HOU
# 171  HPN    HPN
# 62   HRL    HRL
# 94   HSV    HSV
# 30   IAD    IAD
# 65   IAH    IAH
# 81   ICT    ICT
# 182  IDA    IDA
# 130  ILM    ILM
# 14   IND    IND
# 202  IPL    IPL
# 31   ISP    ISP
# 141  ITO    ITO
# 194  IYK    IYK
# 193  JAC    JAC
# 61   JAN    JAN
# 2    JAX    JAX
# 131  JFK    JFK
# 273  JNU    JNU
# 142  KOA    KOA
# 271  KTN    KTN
# 161  LAN    LAN
# 3    LAS    LAS
# 245  LAW    LAW
# 32   LAX    LAX
# 33   LBB    LBB
# 118  LCH    LCH
# 109  LEX    LEX
# 88   LFT    LFT
# 107  LGA    LGA
# 78   LGB    LGB
# 143  LIH    LIH
# 34   LIT    LIT
# 204  LNK    LNK
# 114  LRD    LRD
# 257  LSE    LSE
# 188  LWS    LWS
# 241  LYH    LYH
# 35   MAF    MAF
# 162  MBS    MBS
# 4    MCI    MCI
# 218  MCN    MCN
# 5    MCO    MCO
# 132  MDT    MDT
# 6    MDW    MDW
# 226  MEI    MEI
# 102  MEM    MEM
# 98   MFE    MFE
# 148  MFR    MFR
# 97   MGM    MGM
# 36   MHT    MHT
# 170  MIA    MIA
# 91   MKE    MKE
# 168  MLB    MLB
# 207  MLI    MLI
# 122  MLU    MLU
# 123  MOB    MOB
# 199  MOD    MOD
# 261  MOT    MOT
# 255  MQT    MQT
# 77   MRY    MRY
# 82   MSN    MSN
# 184  MSO    MSO
# 99   MSP    MSP
# 37   MSY    MSY
# 96   MTJ    MTJ
# 70   MYR    MYR
# 234  OAJ    OAJ
# 38   OAK    OAK
# 212  OGD    NaN
# 144  OGG    OGG
# 39   OKC    OKC
# 40   OMA    OMA
# 280  OME    OME
# 41   ONT    ONT
# 112  ORD    ORD
# 15   ORF    ORF
# 278  OTZ    OTZ
# 197  OXR    OXR
# 9    PBI    PBI
# 42   PDX    PDX
# 232  PFN    PFN
# 217  PHF    PHF
# 16   PHL    PHL
# 7    PHX    PHX
# 203  PIA    PIA
# 174  PIH    PIH
# 43   PIT    PIT
# 266  PLN    PLN
# 208  PMD    PMD
# 111  PNS    PNS
# 178  PSC    PSC
# 285  PSE    PSE
# 275  PSG    PSG
# 128  PSP    PSP
# 44   PVD    PVD
# 89   PWM    PWM
# 140  RAP    RAP
# 198  RDD    RDD
# 191  RDM    RDM
# 45   RDU    RDU
# 210  RFD    RFD
# 262  RHI    RHI
# 74   RIC    RIC
# 46   RNO    RNO
# 145  ROA    ROA
# 69   ROC    ROC
# 254  ROW    ROW
# 256  RST    RST
# 10   RSW    RSW
# 47   SAN    SAN
# 48   SAT    SAT
# 73   SAV    SAV
# 149  SBA    SBA
# 163  SBN    SBN
# 150  SBP    SBP
# 283  SCC    SCC
# 229  SCE    SCE
# 49   SDF    SDF
# 50   SEA    SEA
# 51   SFO    SFO
# 169  SGF    SGF
# 177  SGU    SGU
# 90   SHV    SHV
# 272  SIT    SIT
# 52   SJC    SJC
# 251  SJT    SJT
# 214  SJU    SJU
# 53   SLC    SLC
# 190  SLE    SLE
# 54   SMF    SMF
# 195  SMX    SMX
# 55   SNA    SNA
# 146  SPI    SPI
# 250  SPS    SPS
# 117  SRQ    SRQ
# 56   STL    STL
# 213  STT    STT
# 216  STX    STX
# 175  SUN    SUN
# 263  SUX    SUX
# 221  SWF    SWF
# 71   SYR    SYR
# 166  TEX    TEX
# 86   TLH    TLH
# 240  TOL    TOL
# 0    TPA    TPA
# 172  TRI    TRI
# 57   TUL    TUL
# 243  TUP    TUP
# 58   TUS    TUS
# 167  TVC    TVC
# 173  TWF    TWF
# 248  TXK    TXK
# 246  TYR    TYR
# 95   TYS    TYS
# 219  VLD    VLD
# 108  VPS    VPS
# 274  WRG    WRG
# 66   XNA    XNA
# 279  YAK    YAK
# 189  YKM    YKM
# 151  YUM    YUM

# %%
left_merged.isnull().any(axis=1)
# Out:
# 113    False
# 247    False
# 17     False
# 224    False
# 249    False
# 196    False
# 244    False
# 284    False
# 281    False
# 119    False
# 225    False
# 18     False
# 268    False
# 19     False
# 215    False
# 133    False
# 72     False
# 152    False
# 20     False
# 120    False
# 153    False
# 206    False
# 21     False
# 277    False
# 79     False
# 265    False
# 115    False
# 12     False
# 180    False
# 209    False
# 192    False
# 154    False
# 13     False
# 22     False
# 124    False
# 110    False
# 222    False
# 286    False
# 105    False
# 282    False
# 179    False
# 85     False
# 103    False
# 23     False
# 24     False
# 1      False
# 183    False
# 83     False
# 155    False
# 211    False
# 276    False
# 200    False
# 126    False
# 236    False
# 92     False
# 201    False
# 156    False
# 164    False
# 25     False
# 127    False
# 104    False
# 26     False
# 253    False
# 264    False
# 134    False
# 75     False
# 135    False
# 63     False
# 93     False
# 220    False
# 106    False
# 157    False
# 129    False
# 59     False
# 84     False
# 258    False
# 67     False
# 27     False
# 87     False
# 223    False
# 259    False
# 136    False
# 125    False
# 60     False
# 137    False
# 176    False
# 269    False
# 28     False
# 267    False
# 80     False
# 231    False
# 228    False
# 64     False
# 230    False
# 270    False
# 181    False
# 76     False
# 227    False
# 185    False
# 165    False
# 8      False
# 238    False
# 235    False
# 158    False
# 237    False
# 159    False
# 29     False
# 260    False
# 252    False
# 138    False
# 233    False
# 121    False
# 160    False
# 116    False
# 101    False
# 68     False
# 100    False
# 187    False
# 242    False
# 205    False
# 139    False
# 239    False
# 186    False
# 147    False
# 11     False
# 171    False
# 62     False
# 94     False
# 30     False
# 65     False
# 81     False
# 182    False
# 130    False
# 14     False
# 202    False
# 31     False
# 141    False
# 194    False
# 193    False
# 61     False
# 2      False
# 131    False
# 273    False
# 142    False
# 271    False
# 161    False
# 3      False
# 245    False
# 32     False
# 33     False
# 118    False
# 109    False
# 88     False
# 107    False
# 78     False
# 143    False
# 34     False
# 204    False
# 114    False
# 257    False
# 188    False
# 241    False
# 35     False
# 162    False
# 4      False
# 218    False
# 5      False
# 132    False
# 6      False
# 226    False
# 102    False
# 98     False
# 148    False
# 97     False
# 36     False
# 170    False
# 91     False
# 168    False
# 207    False
# 122    False
# 123    False
# 199    False
# 261    False
# 255    False
# 77     False
# 82     False
# 184    False
# 99     False
# 37     False
# 96     False
# 70     False
# 234    False
# 38     False
# 212     True
# 144    False
# 39     False
# 40     False
# 280    False
# 41     False
# 112    False
# 15     False
# 278    False
# 197    False
# 9      False
# 42     False
# 232    False
# 217    False
# 16     False
# 7      False
# 203    False
# 174    False
# 43     False
# 266    False
# 208    False
# 111    False
# 178    False
# 285    False
# 275    False
# 128    False
# 44     False
# 89     False
# 140    False
# 198    False
# 191    False
# 45     False
# 210    False
# 262    False
# 74     False
# 46     False
# 145    False
# 69     False
# 254    False
# 256    False
# 10     False
# 47     False
# 48     False
# 73     False
# 149    False
# 163    False
# 150    False
# 283    False
# 229    False
# 49     False
# 50     False
# 51     False
# 169    False
# 177    False
# 90     False
# 272    False
# 52     False
# 251    False
# 214    False
# 53     False
# 190    False
# 54     False
# 195    False
# 55     False
# 146    False
# 250    False
# 117    False
# 56     False
# 213    False
# 216    False
# 175    False
# 263    False
# 221    False
# 71     False
# 166    False
# 86     False
# 240    False
# 0      False
# 172    False
# 57     False
# 243    False
# 58     False
# 167    False
# 173    False
# 248    False
# 246    False
# 95     False
# 219    False
# 108    False
# 274    False
# 66     False
# 279    False
# 189    False
# 151    False
# Length: 287, dtype: bool

# %%
left_merged[left_merged.isnull().any(axis=1)]
# Out:
#     dest origin
# 212  OGD    NaN

# %%
left_merged[left_merged.isnull().any(axis=1)]
# Out:
#     dest origin
# 212  OGD    NaN

# %%
df = pd.DataFrame([range(3), [0, np.NaN, 0], [0, 0, np.NaN], range(3), range(3)])
df
# Out:
#    0   1   2
# 0  0   1   2
# 1  0 NaN   0
# 2  0   0 NaN
# 3  0   1   2
# 4  0   1   2
