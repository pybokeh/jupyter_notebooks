# %% [markdown]
# <center><img src="http://xpo38498/www/images/honda_logo_small.jpg"></center>

# %% [markdown]
# <h2 align="center">Scipt that updates the LET database</h2>

# %%
# %run d:\_dev\webapps\denso\let\parse.py update
# Out:
# -----------------------
# | LET Update Database |
# -----------------------
#
# Testing connection to sqlite LET:   OK
#
# Testing connection to mmp-sqlp-warranty:
# OK
#
# Date last run: 2012-11-13
# Factory: mapdata
# Dir: \\naslet01p\mapdata\2012\201211\20121113\
# Removing tempdata directory...
# Copying network data to tempdata for local processing...
# ----------------------------------------------------------
# Loading: lwc_angle
# From: mapdata
# Date: 2012-11-13
# ----------------------------------------------------------
# Digging in: tempdata
# Digging in: tempdata\MassPro
# Digging in: tempdata\MassPro\1LINE
# Digging in: tempdata\MassPro\2LINE
# Digging in: tempdata\MassPro\3LINE
# Digging in: tempdata\MassPro\4LINE
# Digging in: tempdata\MassPro\ALINE
# Digging in: tempdata\MassPro\RLINE
# 0.0100% complete,
#  file: 1 of 10043
# 0.0299% complete, file: 3 of 10043
# 0.0498% complete, file: 5 of 10043
# 0.0697% complete, file: 7 of 10043
# ...
