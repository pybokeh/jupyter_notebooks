# %%
# %matplotlib inline
import seaborn
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.dates import MonthLocator, WeekdayLocator, DayLocator, DateFormatter
import xlwings as xw
import pandas as pd
from pandas_datareader import data as web
import datetime
import dateutil

# %%
start = datetime.datetime(2015,1,1)
end   = datetime.datetime(2015,11,10)

honda = web.DataReader("HMC", 'yahoo', start, end)

# %%
fig = plt.figure(figsize=(10,6))
ax = plt.subplot(1,1,1)

# Let's define x-axis date interval sizes: month, week, or day
month_interval = 1   
months = MonthLocator(interval=month_interval)
month  = MonthLocator(bymonth=range(1,13),  bymonthday=1, interval=1)
week   = WeekdayLocator(byweekday=dateutil.rrule.MO)  # Every MOnday
day    = DayLocator(bymonthday=range(1,32), interval=1)

# Let's define x-axis formatting intervals
monthsFmt = DateFormatter("%b '%y")

ax.xaxis.set_major_locator(months)
ax.xaxis.set_major_formatter(monthsFmt)

plt.plot_date(honda.index, honda['Adj Close'].values, '-')
plt.xticks(rotation=270)
plt.title("Honda Stock Price")
plt.show()

# %%
# wb = xw.Workbook()   # creates new workbook
wb = xw.Workbook.active()  # make changes to active Excel workbook
plot = xw.Plot(fig)
plot.show('My First xlwings Chart')
