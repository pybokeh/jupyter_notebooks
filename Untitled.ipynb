# %%
library(choroplethr)

data(df_pop_state)
head(df_pop_state)
# Out:
#       region    value
# 1    alabama  4777326
# 2     alaska   711139
# 3    arizona  6410979
# 4   arkansas  2916372
# 5 california 37325068
# 6   colorado  5042853

# %%
state_choropleth(df_pop_state)
