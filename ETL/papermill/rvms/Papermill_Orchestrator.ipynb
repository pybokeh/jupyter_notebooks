# %% [markdown]
# # PURPOSE:

# %% [markdown]
# #### This is a jupyter notebook that will orchestrate the data processing notebook scripts that will perform the following:

# %% [markdown]
# 1. check the before and after CPUs and then
# 2. generate the raw "Red and Green sheet" data
# 3. Creates the summarized "Red and Green Sheet" in native currency
# 4. Creates the summarized "Red and Green Sheet" in USD

# %% [markdown]
# Orchestration of notebooks are handled by a library called [papermill](https://github.com/nteract/papermill).  To pass data between notebooks, the [scrapbook](https://github.com/nteract/scrapbook/) library is being used.

# %%
from win10toast import ToastNotifier
import papermill as pm
import time

# %%
start_time = time.time()

# %% [markdown]
# # Enter necessary parameters:

# %% [markdown]
# ### Enter parameter for CLA claim month or RVMS reporting month:

# %%
CLA_MONTH = input("Enter CLA Claim Month ('YYYYMM'): ")
# Out:
# Enter CLA Claim Month ('YYYYMM'): 201901

# %% [markdown]
# ### Enter start and ending model years that are being adjusted or reported on:

# %%
start_year = int(input("Enter starting model year (YYYY): "))
end_year = int(input("Enter ending model year (YYYY): "))
# Out:
# Enter starting model year (YYYY): 2010
# Enter ending model year (YYYY): 2019

# %% [markdown]
# ### For the summarized Red and Green Sheet, enter KC to USD exchange rate:

# %%
exchange_rate = float(input("Enter KC to USD exhange rate: "))
# Out:
# Enter KC to USD exhange rate: 0.7464

# %% [markdown]
# ## 1) Execute jupyter notebook that obtains the current budgeted CPUs in the the RVMS database server:

# %%
# %%time
pm.execute_notebook(
    '1_Obtaining_Current_RVMS_GraphCat_Group_SubGroup_Budgeted_CPUs-Access.ipynb',
    'output/CurrentBudgetedCPUs.ipynb',
    cwd='D:\\jupyter\\rvms\\production',
    parameters = dict(CLA_MONTH=CLA_MONTH)
)
# Out:
# HBox(children=(IntProgress(value=0, max=60), HTML(value='')))
# Wall time: 5min 28s
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:16:34.136921',
#      'end_time': '2019-03-22T13:16:34.152550',
#      'duration': 0.015629,
#      'status': 'completed'}},
#    'source': '# Process for Obtaining Current RVMS GraphCat Group-SubGroup Budgeted CPUs'},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:16:34.199425',
#      'end_time': '2019-03-22T13:16:37.437796',
#      'duration': 3.238371,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'import great_expectations as ge\nimport pyodbc\nimport time\nfrom pathlib import Path\nfrom win10toast import ToastNotifier\nimport os\nimport pyodbc  # used for connecting to ODBC data sources\nimport pandas as pd  # data analysis library\npd.options.display.max_rows=1000\npd.options.display.max_columns=100'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:16:37.469049',
#      'end_time': '2019-03-22T13:16:37.515930',
#      'duration': 0.046881,
#      'status': 'completed'}},
#    'source': '### RVMS Database Credentials'},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:16:37.573267',
#      'end_time': '2019-03-22T13:16:37.620843',
#      'duration': 0.047576,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "userid_rvms = os.environ['windowsuser']\npw_rvms     = os.environ['windowspwd']\ndsn_rvms = 'HDC-SQLP-RVMS'"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:16:37.663005',
#      'end_time': '2019-03-22T13:16:37.709887',
#      'duration': 0.046882,
#      'status': 'completed'}},
#    'source': '### Enter CLA claim month ("YYYYMM"):'},
#   {'cell_type': 'code',
#    'execution_count': 3,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:16:37.741141',
#      'end_time': '2019-03-22T13:16:37.799577',
#      'duration': 0.058436,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': '# If using papermill, have to comment this out.  It doesn\'t support getting input from the user\n# CLA_MONTH = input("Enter CLA Claim Month (\'YYYYMM\'): ")'},
#   {'cell_type': 'code',
#    'execution_count': 4,
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:16:37.835673',
#      'end_time': '2019-03-22T13:16:37.940926',
#      'duration': 0.105253,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "CLA_MONTH = '201901'"},
#   {'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:16:37.972183',
#      'end_time': '2019-03-22T13:16:38.134896',
#      'duration': 0.162713,
#      'status': 'completed'}},
#    'execution_count': 5,
#    'source': '# Parameters\nCLA_MONTH = "201901"\n',
#    'outputs': []},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:16:38.166149',
#      'end_time': '2019-03-22T13:16:38.213031',
#      'duration': 0.046882,
#      'status': 'completed'}},
#    'source': '### Define where the current budgeted CPUs will be saved:'},
#   {'cell_type': 'code',
#    'execution_count': 6,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:16:38.262869',
#      'end_time': '2019-03-22T13:16:38.325839',
#      'duration': 0.06297,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'base_dir = "//207.130.185.67/aqgbudget2/Cost/Reserve Adjustments/Reports/Normal Reserve Balance Verification/RVMS_Current_Budgeted_CPUs"\np = Path(base_dir)\nsave_dir = p / CLA_MONTH\nif not os.path.exists(save_dir):\n    os.makedirs(save_dir)'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:16:38.357091',
#      'end_time': '2019-03-22T13:16:38.372718',
#      'duration': 0.015627,
#      'status': 'completed'}},
#    'source': '### Run modified "Larry\'s Query"'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:16:38.430108',
#      'end_time': '2019-03-22T13:16:38.472218',
#      'duration': 0.04211,
#      'status': 'completed'}},
#    'source': 'This query obtains the current budgeted CPUs and "Planned" Sales that are in RVMS at the group-subgroup level.'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:16:38.513328',
#      'end_time': '2019-03-22T13:16:38.555582',
#      'duration': 0.042254,
#      'status': 'completed'}},
#    'source': '**VERY IMPORTANT:** The CPU at the GraphCat level is calculated from summing the CPUs at the subgroup level using all decimal places.  The CPU at the GraphCat level is then rounded to 2 decimal places.'},
#   {'cell_type': 'code',
#    'execution_count': 7,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:16:38.594685',
#      'end_time': '2019-03-22T13:18:03.174860',
#      'duration': 84.580175,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Wall time: 1min 24s\n'}],
#    'source': '%%time\n\ncnxn_string = \'DSN=\' + dsn_rvms + \';UID=\' + userid_rvms + \';PWD=\' + pw_rvms\n\ncnxn = pyodbc.connect(cnxn_string)\ncursor = cnxn.cursor()\n\n# Copy/Paste your SQL text here\nsql = """\n/** Query to obtain current budgeted CPUs at the SubGroup level and also at the GraphCat level\n    NOTE: The CPU at the GraphCat level was derived from summing the CPUs at the SubGroup level using all decimal places.\n          Then the CPU at the GraphCat level was rounded to 2 decimal places\n**/\nWITH CPU_SUBGRP_LEVEL AS (\n\nSELECT\n    A.GraphCatID,\n    RTRIM(D.GraphCatDesc) AS GraphCatDesc,\n    B.GRP_NM,\n    C.SUBGRP_NM,\n    SUM(COALESCE(E.Budgeted_CPU,0.000)) AS Budgeted_CPU_SubGroup_Level\n\nFROM dbo.tbl_GC_GRPS AS A\n    INNER JOIN dbo.tbl_MQ_GRPKEYS AS F ON A.GRPKEY_ID = F.GRPKEY_ID\n    INNER JOIN dbo.tbl_MQ_GRPS AS B ON F.GRP_ID = B.GRP_ID\n    INNER JOIN tbl_MQ_SUBGRPS AS C ON F.SUBGRP_ID = C.SUBGRP_ID\n    INNER JOIN tbl_GraphCatMaster AS D ON A.GraphCatID = D.GraphCatID\n    LEFT JOIN tbl_GraphCat_MIS AS E ON A.GC_GRP_ID = E.GC_GRP_ID\n\nWHERE\n    D.GraphCatType = \'R\'\n    and D.GraphCatDesc like \'R %\'\n\nGROUP BY\n    A.GraphCatID,\n    D.GraphCatDesc,\n    B.GRP_NM,\n    C.SUBGRP_NM\n),\n\nGC_SALES as (\n\nSELECT\n    GraphCatID,\n    sum(PlannedSales) as Planned_Sales_RVMS\n\nFROM\n    tbl_GraphCatMonthlySales\n\nGROUP BY\n    GraphCatID\n),\n\nCPU_GC_LEVEL as (\nSELECT\n    GraphCatID,\n    SUM(Budgeted_CPU_SubGroup_Level) AS Budgeted_CPU_GC_Level,\n    SUM(Orig_Saturation_CPU) as Orig_Saturation_CPU_GC_Level\n\nFROM (\n\nSELECT\n    A.GraphCatID,\n    RTRIM(D.GraphCatDesc) AS GraphCatDesc,\n    B.GRP_NM,\n    C.SUBGRP_NM,\n    SUM(COALESCE(E.Budgeted_CPU,0.000)) AS Budgeted_CPU_SubGroup_Level,\n    SUM(COALESCE(E.OriginalReserve_CPU,0.000)) as Orig_Saturation_CPU\n\nFROM dbo.tbl_GC_GRPS AS A\n    INNER JOIN dbo.tbl_MQ_GRPKEYS AS F ON A.GRPKEY_ID = F.GRPKEY_ID\n    INNER JOIN dbo.tbl_MQ_GRPS AS B ON F.GRP_ID = B.GRP_ID\n    INNER JOIN tbl_MQ_SUBGRPS AS C ON F.SUBGRP_ID = C.SUBGRP_ID\n    INNER JOIN tbl_GraphCatMaster AS D ON A.GraphCatID = D.GraphCatID\n    LEFT JOIN tbl_GraphCat_MIS AS E ON A.GC_GRP_ID = E.GC_GRP_ID\n\nWHERE\n    D.GraphCatType = \'R\'\n    and D.GraphCatDesc like \'R %\'\n\nGROUP BY\n    A.GraphCatID,\n    D.GraphCatDesc,\n    B.GRP_NM,\n    C.SUBGRP_NM\n\n) AS CPU_GC_LEVEL\n\nGROUP BY\n    GraphCatID\n\n),\n\n\nGC_BudgetMatrix AS (\n\n    SELECT\n        GC_Budget.SaleMonth,\n        GC_Master.GraphCatID,\n        GC_Master.GraphCatDesc as GraphCat,\n        CummActual_CPU as CumActual_CPU,\n        CummBudgeted_Cpu as CumBudgeted_CPU\n\n    FROM dbo.tbl_GraphCat_BudgetedMatrix as GC_Budget\n\n        LEFT JOIN dbo.tbl_GC_GRPS AS GC_GRPS ON\n        GC_Budget.GC_GRP_ID = GC_GRPS.GC_GRP_ID\n\n        LEFT JOIN dbo.tbl_MQ_GRPKEYS AS MQ_GRPKEYS ON\n        GC_GRPS.GRPKEY_ID = MQ_GRPKEYS.GRPKEY_ID\n\n        LEFT JOIN dbo.tbl_MQ_GRPS AS MQ_GRPS ON\n        MQ_GRPKEYS.GRP_ID = MQ_GRPS.GRP_ID\n\n        LEFT JOIN dbo.tbl_MQ_SUBGRPS AS MQ_SUBGRPS ON\n        MQ_GRPKEYS.SUBGRP_ID = MQ_SUBGRPS.SUBGRP_ID\n\n        LEFT JOIN dbo.tbl_GraphCatMaster as GC_Master ON\n        GC_GRPS.GraphCatID = GC_Master.GraphCatID\n\n\n    WHERE\n        GC_Master.GraphCatType = \'R\'\n        and GC_Master.GraphCatDesc like \'R %\'\n\n),\n\n\nActual_CPU_GC_Level as (\n\nSELECT\n    GraphCatID,\n    GraphCat,\n    max(CumActual_CPU) as CumActual_CPU\n\nFROM (\n\n\nSELECT\n    SaleMonth,\n    GraphCatID,\n    GraphCat,\n    sum(CumActual_CPU) as CumActual_CPU\n\nFROM (\n\n    SELECT\n        SaleMonth,\n        GraphCatID,\n        GraphCat,\n        CASE\n            WHEN CumActual_CPU = 0 THEN NULL\n        ELSE\n            CumActual_CPU\n        END AS CumActual_CPU,\n        CumBudgeted_CPU\n\n    FROM\n        GC_BudgetMatrix\n\n) AS TEMP1\n\nGROUP BY\n    SaleMonth,\n    GraphCatID,\n    GraphCat\n\n) AS TEMP2\n\nGROUP BY\n    GraphCatID,\n    GraphCat\n)\n\nSELECT\n    CPU_SUBGRP_LEVEL.*, ...
#   {'cell_type': 'code',
#    'execution_count': 8,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:03.206109',
#      'end_time': '2019-03-22T13:18:03.268191',
#      'duration': 0.062082,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '(58680, 9)'},
#      'execution_count': 8}],
#    'source': 'RVMS_Current_Budgeted_CPU.shape'},
#   {'cell_type': 'code',
#    'execution_count': 9,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:03.308281',
#      'end_time': '2019-03-22T13:18:03.887515',
#      'duration': 0.579234,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '   GraphCatID             GraphCatDesc   GRP_NM                 SUBGRP_NM  \\\n0         449  R HMI CIVIC 2010 4DR KA  Chassis  Calipers/Disk/Drums/Pads   \n1         449  R HMI CIVIC 2010 4DR KA  Chassis               Drive Shaft   \n2         449  R HMI CIVIC 2010 4DR KA  Chassis         Hand/cable Brakes   \n3         449  R HMI CIVIC 2010 4DR KA  Chassis           Master Cylinder   \n4         449  R HMI CIVIC 2010 4DR KA  Chassis        Steering Vibration   \n\n   Budgeted_CPU_SubGroup_Level  Planned_Sales_RVMS  Budgeted_CPU_GC_Level  \\\n0                     0.834396               94558                 102.01   \n1                    15.891899               94558                 102.01   \n2                     0.048017               94558                 102.01   \n3                     0.049997               94558                 102.01   \n4                     0.325561               94558                 102.01   \n\n   Orig_Saturation_CPU_GC_Level  Cum_Actual_CPU_GC_Level  \n0                        152.72                   101.69  \n1                        152.72                   101.69  \n2                        152.72                   101.69  \n3                        152.72                   101.69  \n4                        152.72                   101.69  ',
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>GraphCatID</th>\n      <th>GraphCatDesc</th>\n      <th>GRP_NM</th>\n      <th>SUBGRP_NM</th>\n      <th>Budgeted_CPU_SubGroup_Level</th>\n      <th>Planned_Sales_RVMS</th>\n      <th>Budgeted_CPU_GC_Level</th>\n      <th>Orig_Saturation_CPU_GC_Level</th>\n      <th>Cum_Actual_CPU_GC_Level</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Calipers/Disk/Drums/Pads</td>\n      <td>0.834396</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Drive Shaft</td>\n      <td>15.891899</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Hand/cable Brakes</td>\n      <td>0.048017</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Master Cylinder</td>\n      <td>0.049997</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Steering Vibration</td>\n      <td>0.325561</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n    </tr>\n  </tbody>\n</table>\n</div>'},
#      'execution_count': 9}],
#    'source': 'RVMS_Current_Budgeted_CPU.head()'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:03.918768',
#      'end_time': '2019-03-22T13:18:03.950020',
#      'duration': 0.031252,
#      'status': 'completed'}},
#    'source': '### Create ```RVMS_Claim_Month``` column to contain the CLA claim month:'},
#   {'cell_type': 'code',
#    'execution_count': 10,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:04.009850',
#      'end_time': '2019-03-22T13:18:04.050592',
#      'duration': 0.040742,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "RVMS_Current_Budgeted_CPU['RVMS_Claim_Month'] = CLA_MONTH"},
#   {'cell_type': 'code',
#    'execution_count': 11,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:04.081847',
#      'end_time': '2019-03-22T13:18:04.217016',
#      'duration': 0.135169,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '   GraphCatID             GraphCatDesc   GRP_NM                 SUBGRP_NM  \\\n0         449  R HMI CIVIC 2010 4DR KA  Chassis  Calipers/Disk/Drums/Pads   \n1         449  R HMI CIVIC 2010 4DR KA  Chassis               Drive Shaft   \n2         449  R HMI CIVIC 2010 4DR KA  Chassis         Hand/cable Brakes   \n3         449  R HMI CIVIC 2010 4DR KA  Chassis           Master Cylinder   \n4         449  R HMI CIVIC 2010 4DR KA  Chassis        Steering Vibration   \n\n   Budgeted_CPU_SubGroup_Level  Planned_Sales_RVMS  Budgeted_CPU_GC_Level  \\\n0                     0.834396               94558                 102.01   \n1                    15.891899               94558                 102.01   \n2                     0.048017               94558                 102.01   \n3                     0.049997               94558                 102.01   \n4                     0.325561               94558                 102.01   \n\n   Orig_Saturation_CPU_GC_Level  Cum_Actual_CPU_GC_Level RVMS_Claim_Month  \n0                        152.72                   101.69           201901  \n1                        152.72                   101.69           201901  \n2                        152.72                   101.69           201901  \n3                        152.72                   101.69           201901  \n4                        152.72                   101.69           201901  ',
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>GraphCatID</th>\n      <th>GraphCatDesc</th>\n      <th>GRP_NM</th>\n      <th>SUBGRP_NM</th>\n      <th>Budgeted_CPU_SubGroup_Level</th>\n      <th>Planned_Sales_RVMS</th>\n      <th>Budgeted_CPU_GC_Level</th>\n      <th>Orig_Saturation_CPU_GC_Level</th>\n      <th>Cum_Actual_CPU_GC_Level</th>\n      <th>RVMS_Claim_Month</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Calipers/Disk/Drums/Pads</td>\n      <td>0.834396</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Drive Shaft</td>\n      <td>15.891899</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Hand/cable Brakes</td>\n      <td>0.048017</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Master Cylinder</td>\n      <td>0.049997</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Steering Vibration</td>\n      <td>0.325561</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n    </tr>\n  </tbody>\n</table>\n</div>'},
#      'execution_count': 11}],
#    'source': 'RVMS_Current_Budgeted_CPU.head()'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:04.233735',
#      'end_time': '2019-03-22T13:18:04.290949',
#      'duration': 0.057214,
#      'status': 'completed'}},
#    'source': '### Create data set of CPUs at GraphCat level:'},
#   {'cell_type': 'code',
#    'execution_count': 12,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:04.327043',
#      'end_time': '2019-03-22T13:18:04.381006',
#      'duration': 0.053963,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "cpu_at_gc_level = RVMS_Current_Budgeted_CPU[['GraphCatID', 'Budgeted_CPU_GC_Level']].drop_duplicates()"},
#   {'cell_type': 'code',
#    'execution_count': 13,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:04.427886',
#      'end_time': '2019-03-22T13:18:04.506855',
#      'duration': 0.078969,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '     GraphCatID  Budgeted_CPU_GC_Level\n0           449                 102.01\n120         450                 105.92\n240         470                 229.81\n360         484                  92.30\n480         485                  75.27',
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>GraphCatID</th>\n      <th>Budgeted_CPU_GC_Level</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>449</td>\n      <td>102.01</td>\n    </tr>\n    <tr>\n      <th>120</th>\n      <td>450</td>\n      <td>105.92</td>\n    </tr>\n    <tr>\n      <th>240</th>\n      <td>470</td>\n      <td>229.81</td>\n    </tr>\n    <tr>\n      <th>360</th>\n      <td>484</td>\n      <td>92.30</td>\n    </tr>\n    <tr>\n      <th>480</th>\n      <td>485</td>\n      <td>75.27</td>\n    </tr>\n  </tbody>\n</table>\n</div>'},
#      'execution_count': 13}],
#    'source': 'cpu_at_gc_level.head()'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:04.532569',
#      'end_time': '2019-03-22T13:18:04.579448',
#      'duration': 0.046879,
#      'status': 'completed'}},
#    'source': '### Create data set of original saturation CPUs at GraphCat level:'},
#   {'cell_type': 'code',
#    'execution_count': 14,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:04.628836',
#      'end_time': '2019-03-22T13:18:04.712267',
#      'duration': 0.083431,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "orig_sat_cpu_at_gc_level = RVMS_Current_Budgeted_CPU[['GraphCatID', 'Orig_Saturation_CPU_GC_Level']].drop_duplicates()"},
#   {'cell_type': 'code',
#    'execution_count': 15,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:04.759145',
#      'end_time': '2019-03-22T13:18:04.960411',
#      'duration': 0.201266,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '     GraphCatID  Orig_Saturation_CPU_GC_Level\n0           449                        152.72\n120         450                        177.24\n240         470                        280.50\n360         484                        127.33\n480         485                        119.83',
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>GraphCatID</th>\n      <th>Orig_Saturation_CPU_GC_Level</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>449</td>\n      <td>152.72</td>\n    </tr>\n    <tr>\n      <th>120</th>\n      <td>450</td>\n      <td>177.24</td>\n    </tr>\n    <tr>\n      <th>240</th>\n      <td>470</td>\n      <td>280.50</td>\n    </tr>\n    <tr>\n      <th>360</th>\n      <td>484</td>\n      <td>127.33</td>\n    </tr>\n    <tr>\n      <th>480</th>\n      <td>485</td>\n      <td>119.83</td>\n    </tr>\n  </tbody>\n</table>\n</div>'},
#      'execution_count': 15}],
#    'source': 'orig_sat_cpu_at_gc_level.head()'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:04.991633',
#      'end_time': '2019-03-22T13:18:05.022886',
#      'duration': 0.031253,
#      'status': 'completed'}},
#    'source': '### Create data set of cumulative actual CPUs at GraphCat level:'},
#   {'cell_type': 'code',
#    'execution_count': 16,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:05.070513',
#      'end_time': '2019-03-22T13:18:05.130892',
#      'duration': 0.060379,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "actual_cpu_at_gc_level = RVMS_Current_Budgeted_CPU[['GraphCatID', 'Cum_Actual_CPU_GC_Level']].drop_duplicates()"},
#   {'cell_type': 'code',
#    'execution_count': 17,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:05.177770',
#      'end_time': '2019-03-22T13:18:05.263584',
#      'duration': 0.085814,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '     GraphCatID  Cum_Actual_CPU_GC_Level\n0           449                   101.69\n120         450                   102.60\n240         470                   229.51\n360         484                    92.39\n480         485                    74.27',
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>GraphCatID</th>\n      <th>Cum_Actual_CPU_GC_Level</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>449</td>\n      <td>101.69</td>\n    </tr>\n    <tr>\n      <th>120</th>\n      <td>450</td>\n      <td>102.60</td>\n    </tr>\n    <tr>\n      <th>240</th>\n      <td>470</td>\n      <td>229.51</td>\n    </tr>\n    <tr>\n      <th>360</th>\n      <td>484</td>\n      <td>92.39</td>\n    </tr>\n    <tr>\n      <th>480</th>\n      <td>485</td>\n      <td>74.27</td>\n    </tr>\n  </tbody>\n</table>\n</div>'},
#      'execution_count': 17}],
#    'source': 'actual_cpu_at_gc_level.head()'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:05.298737',
#      'end_time': '2019-03-22T13:18:05.329994',
#      'duration': 0.031257,
#      'status': 'completed'}},
#    'source': '### Ensure that the sum of the CPUs at the subgroup level differ from the sum of the CPUs at the GraphCat level is less than 1 currency unit'},
#   {'cell_type': 'code',
#    'execution_count': 18,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:05.381012',
#      'end_time': '2019-03-22T13:18:05.444801',
#      'duration': 0.063789,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "assert abs(RVMS_Current_Budgeted_CPU['Budgeted_CPU_SubGroup_Level'].sum() - cpu_at_gc_level['Budgeted_CPU_GC_Level'].sum()) < 1.0"},
#   {'cell_type': 'code',
#    'execution_count': 19,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:05.476052',
#      'end_time': '2019-03-22T13:18:05.570922',
#      'duration': 0.09487,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '163473.98846287144'},
#      'execution_count': 19}],
#    'source': "RVMS_Current_Budgeted_CPU['Budgeted_CPU_SubGroup_Level'].sum()"},
#   {'cell_type': 'code',
#    'execution_count': 20,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:05.614677',
#      'end_time': '2019-03-22T13:18:05.713582',
#      'duration': 0.098905,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '163474.02'},
#      'execution_count': 20}],
#    'source': "cpu_at_gc_level['Budgeted_CPU_GC_Level'].sum()"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:05.747293',
#      'end_time': '2019-03-22T13:18:05.778547',
#      'duration': 0.031254,
#      'status': 'completed'}},
#    'source': '### Create helper functions to Add Model Year, Factory, Model Name, and custom destination code to the RVMS Original Budgeted CPU data set:'},
#   {'cell_type': 'code',
#    'execution_count': 21,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:05.828917',
#      'end_time': '2019-03-22T13:18:05.988645',
#      'duration': 0.159728,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def getModelYear(row) -> str:\n    word_token = row['GraphCatDesc'].strip().split()\n    \n    model_year = word_token[3]\n    \n    if model_year.isdigit():\n        return model_year\n    else:\n        return word_token[4]\n        \n\ndef getFactoryCode(row) -> str:\n    word_token = row['GraphCatDesc'].strip().split()\n    factory_code = word_token[1]\n    \n    return factory_code.upper()\n\ndef getModelName(row) -> str:\n    word_token = row['GraphCatDesc'].strip().split()\n    model_name = word_token[2]\n    \n    return model_name.upper()\n    \ndef getDestCode(row) -> str:\n    word_token = row['GraphCatDesc'].strip().split()\n    destination_code = word_token[-1]\n    \n    return destination_code.upper()"},
#   {'cell_type': 'code',
#    'execution_count': 22,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:06.019898',
#      'end_time': '2019-03-22T13:18:11.596285',
#      'duration': 5.576387,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "RVMS_Current_Budgeted_CPU['ModelYear'] = RVMS_Current_Budgeted_CPU.apply(getModelYear, axis='columns')\nRVMS_Current_Budgeted_CPU['Factory'] = RVMS_Current_Budgeted_CPU.apply(getFactoryCode, axis='columns')\nRVMS_Current_Budgeted_CPU['ModelName'] = RVMS_Current_Budgeted_CPU.apply(getModelName, axis='columns')\nRVMS_Current_Budgeted_CPU['DestCode'] = RVMS_Current_Budgeted_CPU.apply(getDestCode, axis='columns')"},
#   {'cell_type': 'code',
#    'execution_count': 23,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:11.643166',
#      'end_time': '2019-03-22T13:18:11.755314',
#      'duration': 0.112148,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '   GraphCatID             GraphCatDesc   GRP_NM                 SUBGRP_NM  \\\n0         449  R HMI CIVIC 2010 4DR KA  Chassis  Calipers/Disk/Drums/Pads   \n1         449  R HMI CIVIC 2010 4DR KA  Chassis               Drive Shaft   \n2         449  R HMI CIVIC 2010 4DR KA  Chassis         Hand/cable Brakes   \n3         449  R HMI CIVIC 2010 4DR KA  Chassis           Master Cylinder   \n4         449  R HMI CIVIC 2010 4DR KA  Chassis        Steering Vibration   \n\n   Budgeted_CPU_SubGroup_Level  Planned_Sales_RVMS  Budgeted_CPU_GC_Level  \\\n0                     0.834396               94558                 102.01   \n1                    15.891899               94558                 102.01   \n2                     0.048017               94558                 102.01   \n3                     0.049997               94558                 102.01   \n4                     0.325561               94558                 102.01   \n\n   Orig_Saturation_CPU_GC_Level  Cum_Actual_CPU_GC_Level RVMS_Claim_Month  \\\n0                        152.72                   101.69           201901   \n1                        152.72                   101.69           201901   \n2                        152.72                   101.69           201901   \n3                        152.72                   101.69           201901   \n4                        152.72                   101.69           201901   \n\n  ModelYear Factory ModelName DestCode  \n0      2010     HMI     CIVIC       KA  \n1      2010     HMI     CIVIC       KA  \n2      2010     HMI     CIVIC       KA  \n3      2010     HMI     CIVIC       KA  \n4      2010     HMI     CIVIC       KA  ',
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>GraphCatID</th>\n      <th>GraphCatDesc</th>\n      <th>GRP_NM</th>\n      <th>SUBGRP_NM</th>\n      <th>Budgeted_CPU_SubGroup_Level</th>\n      <th>Planned_Sales_RVMS</th>\n      <th>Budgeted_CPU_GC_Level</th>\n      <th>Orig_Saturation_CPU_GC_Level</th>\n      <th>Cum_Actual_CPU_GC_Level</th>\n      <th>RVMS_Claim_Month</th>\n      <th>ModelYear</th>\n      <th>Factory</th>\n      <th>ModelName</th>\n      <th>DestCode</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Calipers/Disk/Drums/Pads</td>\n      <td>0.834396</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Drive Shaft</td>\n      <td>15.891899</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Hand/cable Brakes</td>\n      <td>0.048017</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Master Cylinder</td>\n      <td>0.049997</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Steering Vibration</td>\n      <td>0.325561</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n    </tr>\n  </tbody>\n</table>\n</div>'},
#      'execution_count': 23}],
#    'source': 'RVMS_Current_Budgeted_CPU.head()'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:11.802197',
#      'end_time': '2019-03-22T13:18:11.861047',
#      'duration': 0.05885,
#      'status': 'completed'}},
#    'source': '### Perform data validation checks using Great Expectations library'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:11.904225',
#      'end_time': '2019-03-22T13:18:11.951104',
#      'duration': 0.046879,
#      'status': 'completed'}},
#    'source': '#### Create Great Expectations dataframe from pandas dataframe:'},
#   {'cell_type': 'code',
#    'execution_count': 24,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:12.001343',
#      'end_time': '2019-03-22T13:18:12.050903',
#      'duration': 0.04956,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'ge_df = ge.from_pandas(RVMS_Current_Budgeted_CPU)'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:12.097782',
#      'end_time': '2019-03-22T13:18:12.129038',
#      'duration': 0.031256,
#      'status': 'completed'}},
#    'source': '#### Check Model Years are between 1994 and 2099'},
#   {'cell_type': 'code',
#    'execution_count': 25,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:12.185332',
#      'end_time': '2019-03-22T13:18:12.419735',
#      'duration': 0.234403,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Passed Model Year Check\n'}],
#    'source': 'if ge_df.expect_column_values_to_be_between(column="ModelYear", min_value=\'1994\', max_value=\'2099\')[\'success\']:\n    print(\'Passed Model Year Check\')\nelse:\n    print(\'FAILED Model Year Check\')\n    toaster = ToastNotifier()\n    toaster.show_toast("### Check Status ###",\n                   "FAILED Model Year Check",\n                   icon_path="images/honda_logo.ico",\n                   duration=10)\n    raise Exception("ERROR: Failed Model Year Check")'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:12.466614',
#      'end_time': '2019-03-22T13:18:12.497872',
#      'duration': 0.031258,
#      'status': 'completed'}},
#    'source': '#### Check Factory values are limited to one of:'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:12.550814',
#      'end_time': '2019-03-22T13:18:12.584542',
#      'duration': 0.033728,
#      'status': 'completed'}},
#    'source': "'ELP','HCL','HCM','HDM','HMA','HMI','MAP','PMC'"},
#   {'cell_type': 'code',
#    'execution_count': 26,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:12.615796',
#      'end_time': '2019-03-22T13:18:12.796743',
#      'duration': 0.180947,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Passed Factory Check\n'}],
#    'source': 'if ge_df.expect_column_values_to_be_in_set(column="Factory", value_set=[\'ELP\',\'HCL\',\'HCM\',\'HDM\',\'HMA\',\'HMI\',\'MAP\',\'PMC\'])[\'success\']:\n    print(\'Passed Factory Check\')\nelse:\n    print(\'FAILED Factory Check\')\n    toaster = ToastNotifier()\n    toaster.show_toast("### Check Status ###",\n                   "FAILED Factory Check",\n                   icon_path="images/honda_logo.ico",\n                   duration=10)\n    raise Exception("ERROR: Failed Factory Check")'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:12.827995',
#      'end_time': '2019-03-22T13:18:12.874875',
#      'duration': 0.04688,
#      'status': 'completed'}},
#    'source': '#### Check Model Names are limited to one of:'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:12.920087',
#      'end_time': '2019-03-22T13:18:12.950814',
#      'duration': 0.030727,
#      'status': 'completed'}},
#    'source': "'ACCORD','CIVIC','CROSSTOUR','CRV','CSX','EL','ELEMENT','FIT','HRV','ILX','INSIGHT','MDX','NSX','ODYSSEY','PASSPORT','PILOT','RDX','RIDGELINE','TL','TLX','ZDX'"},
#   {'cell_type': 'code',
#    'execution_count': 27,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:13.013320',
#      'end_time': '2019-03-22T13:18:13.150205',
#      'duration': 0.136885,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Passed Model Name Check\n'}],
#    'source': 'if ge_df.expect_column_values_to_be_in_set(column="ModelName", value_set=[\'ACCORD\',\'CIVIC\',\'CROSSTOUR\',\'CRV\',\'CSX\',\'EL\',\n                                                                          \'ELEMENT\',\'FIT\',\'HRV\',\'ILX\',\'INSIGHT\',\'MDX\',\'NSX\',\n                                                                          \'ODYSSEY\',\'PASSPORT\',\'PILOT\',\'RDX\',\'RIDGELINE\',\'TL\',\'TLX\',\'ZDX\'\n                                                                         ])[\'success\']:\n    print(\'Passed Model Name Check\')\nelse:\n    print(\'FAILED Model Name Check\')\n    toaster = ToastNotifier()\n    toaster.show_toast("### Check Status ###",\n                   "FAILED Factory Check",\n                   icon_path="images/honda_logo.ico",\n                   duration=10)\n    raise Exception("ERROR: Failed Model Name Check")'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:13.194324',
#      'end_time': '2019-03-22T13:18:13.233245',
#      'duration': 0.038921,
#      'status': 'completed'}},
#    'source': 'I think Great_Expectations library has a [bug](https://github.com/great-expectations/great_expectations/issues/412).  If my column contains missing model names or None objects, the above test still passes!  So I have to test for Null or missing values with this test below:'},
#   {'cell_type': 'code',
#    'execution_count': 28,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:13.300604',
#      'end_time': '2019-03-22T13:18:13.432657',
#      'duration': 0.132053,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'No model names are null\n'}],
#    'source': 'if ge_df.expect_column_values_to_not_be_null(column="ModelName")[\'success\']:\n    print(\'No model names are null\')\nelse:\n    print(\'Null model names found\')\n    toaster = ToastNotifier()\n    toaster.show_toast("### Check Status ###",\n                   "FAILED Factory Check",\n                   icon_path="images/honda_logo.ico",\n                   duration=10)\n    raise Exception("ERROR: Failed Model Name Check")'},
#   {'cell_type': 'code',
#    'execution_count': 29,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:13.463909',
#      'end_time': '2019-03-22T13:18:52.182817',
#      'duration': 38.718908,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "RVMS_Current_Budgeted_CPU.to_excel(save_dir / 'All_Plants_Budgeted_CPU_By_Group_SubGroup.xlsx', index=False)"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:52.214097',
#      'end_time': '2019-03-22T13:18:52.260954',
#      'duration': 0.046857,
#      'status': 'completed'}},
#    'source': '### Also save the current budgeted CPUs into an MS Access database, but first we must empty the table containing data from a previous run:'},
#   {'cell_type': 'code',
#    'execution_count': 30,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:52.313947',
#      'end_time': '2019-03-22T13:18:53.876586',
#      'duration': 1.562639,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'conn_str = (\n            r\'DRIVER={Microsoft Access Driver (*.mdb, *.accdb)};\'\n            r\'DBQ=\\\\207.130.185.67\\aqgbudget2\\Cost\\Reserve Adjustments\\Reports\\databases\\RVMS.accdb;\'\n           )\n\ncnxn = pyodbc.connect(conn_str)\ncursor = cnxn.cursor()\n\nsql = """\nDELETE\n    \nFROM tbl_Current_Budgeted_CPU\n"""\n\ntry:\n    cursor.execute(sql)\n    cnxn.commit()\n    \n    # Close connections\n    cursor.close()\n    cnxn.close()\nexcept:\n    print("Error connecting to database")\n    cursor.close()\n    cnxn.close()'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:53.907841',
#      'end_time': '2019-03-22T13:18:53.970347',
#      'duration': 0.062506,
#      'status': 'completed'}},
#    'source': '### Now insert the current CPUs into the MS Access database'},
#   {'cell_type': 'code',
#    'execution_count': 31,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:18:54.042116',
#      'end_time': '2019-03-22T13:21:50.880890',
#      'duration': 176.838774,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Wall time: 2min 56s\n'}],
#    'source': '%%time\nconn_str = (\n            r\'DRIVER={Microsoft Access Driver (*.mdb, *.accdb)};\'\n            r\'DBQ=\\\\207.130.185.67\\aqgbudget2\\Cost\\Reserve Adjustments\\Reports\\databases\\RVMS.accdb;\'\n           )\ncnxn = pyodbc.connect(conn_str)\n\ntry:\n    for index, row in RVMS_Current_Budgeted_CPU.iterrows():\n        with cnxn.cursor() as cursor:\n            #cursor.setinputsizes([(pyodbc.SQL_INTEGER,)])\n            cursor.execute("INSERT INTO tbl_Current_Budgeted_CPU(GraphCatID, \\\n                                                                 GraphCatDesc, \\\n                                                                 GRP_NM, \\\n                                                                 SUBGRP_NM, \\\n                                                                 Budgeted_CPU_SubGroup_Level, \\\n                                                                 Planned_Sales_RVMS, \\\n                                                                 Budgeted_CPU_GC_Level, \\\n                                                                 Orig_Saturation_CPU_GC_Level, \\\n                                                                 Cum_Actual_CPU_GC_Level, \\\n                                                                 RVMS_Claim_Month, \\\n                                                                 ModelYear, \\\n                                                                 Factory, \\\n                                                                 ModelName, \\\n                                                                 DestCode \\\n                                                                ) VALUES(?,?,?,?,?,?,?,?,?,?,?,?,?,?)", \n                           row[0],\n                           row[1],\n                           row[2],\n                           row[3],\n                           row[4],\n                           row[5],\n                           row[6],\n                           row[7],\n                           row[8],\n                           row[9],\n                           row[10],\n                           row[11],\n                           row[12],\n                           row[13]\n                          )\n            cursor.commit()\n        \n    cnxn.close()\n\nexcept Exception as e:\n    print("Error connecting to the database: ", str(e))\n    cnxn.close()'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:21:50.927772',
#      'end_time': '2019-03-22T13:21:50.958993',
#      'duration': 0.031221,
#      'status': 'completed'}},
#    'source': '### Confirm that the number of rows inserted into ```tbl_Current_Budgeted_CPU``` matches the``` RVMS_Current_Budgeted_CPU``` dataframe.  There could be in theory, a network drop or latency issue where not all the rows were inserted:'},
#   {'cell_type': 'code',
#    'execution_count': 32,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:21:51.026794',
#      'end_time': '2019-03-22T13:21:51.917557',
#      'duration': 0.890763,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'conn_str = (\n            r\'DRIVER={Microsoft Access Driver (*.mdb, *.accdb)};\'\n            r\'DBQ=\\\\207.130.185.67\\aqgbudget2\\Cost\\Reserve Adjustments\\Reports\\databases\\RVMS.accdb;\'\n           )\ncnxn = pyodbc.connect(conn_str)\ncursor = cnxn.cursor()\n\nsql = """\nSELECT\n    count(*) as Qty\n    \nFROM tbl_Current_Budgeted_CPU\n"""\n\ntry:\n    cpu_current = pd.read_sql(sql, cnxn)\n    #cpu_before = pd.read_sql(sql, cnxn)\n    \n    # Close connections\n    cursor.close()\n    cnxn.close()\nexcept Exception as e:\n    print("Error connecting to the database: ", str(e))\n    cursor.close()\n    cnxn.close()'},
#   {'cell_type': 'code',
#    'execution_count': 33,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:21:51.964428',
#      'end_time': '2019-03-22T13:21:52.023235',
#      'duration': 0.058807,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '58680'},
#      'execution_count': 33}],
#    'source': 'cpu_current.values[0][0]'},
#   {'cell_type': 'code',
#    'execution_count': 34,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:21:52.068485',
#      'end_time': '2019-03-22T13:21:52.147955',
#      'duration': 0.07947,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'assert cpu_current.values[0][0] == RVMS_Current_Budgeted_CPU.shape[0]'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:21:52.205279',
#      'end_time': '2019-03-22T13:21:52.251383',
#      'duration': 0.046104,
#      'status': 'completed'}},
#    'source': '#### If the script made it this far, then it must have completed without errors.  Send out a Windows toast notification that the script has successfully completed:'},
#   {'cell_type': 'code',
#    'execution_count': 35,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:21:52.291735',
#      'end_time': '2019-03-22T13:21:57.510390',
#      'duration': 5.218655,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': 'True'},
#      'execution_count': 35}],
#    'source': 'toaster = ToastNotifier()\ntoaster.show_toast("### Export COMPLETED ###",\n                   "Successfuly Obtained and Validated Current RVMS Group-SubGroup Budgeted CPUs",\n                   icon_path="images/honda_logo.ico",\n                   duration=5)'}],
#  'metadata': {'hide_input': False,
#   'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.7.0',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'parameters': {'CLA_MONTH': '201901'},
#    'environment_variables': {},
#    'version': '0.19.0',
#    'input_path': '1_Obtaining_Current_RVMS_GraphCat_Group_SubGroup_Budgeted_CPUs-Access.ipynb',
#    'output_path': 'output/CurrentBudgetedCPUs.ipynb',
#    'start_time': '2019-03-22T13:16:31.267518',
#    'end_time': '2019-03-22T13:21:59.254686',
#    'duration': 327.987168,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 2}

# %% [markdown]
# ## 2) Execute jupyter notebook that performs the before and after CPU checks, creates CPU differences columns, and creates the raw Red and Green sheet data:

# %%
# %%time
pm.execute_notebook(
    '2_Comparing_Adjusted_GraphCat_CPUs_against_Original_GraphCat_CPUs-Access.ipynb',
    'output/RedAndGreenSheet.ipynb',
    cwd='D:\\jupyter\\rvms\\production',
    parameters = dict(CLA_MONTH=CLA_MONTH)
)
# Out:
# HBox(children=(IntProgress(value=0, max=52), HTML(value='')))
# Wall time: 2min 21s
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:02.780286',
#      'end_time': '2019-03-22T13:22:02.811538',
#      'duration': 0.031252,
#      'status': 'completed'}},
#    'source': '# Comparing Before Budgeted CPU versus After Budgeted CPU'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:02.858419',
#      'end_time': '2019-03-22T13:22:02.889672',
#      'duration': 0.031253,
#      'status': 'completed'}},
#    'source': '### This creates the raw "Red and Green" sheet master data'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:02.937678',
#      'end_time': '2019-03-22T13:22:02.968930',
#      'duration': 0.031252,
#      'status': 'completed'}},
#    'source': '### Overall Process'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:03.015809',
#      'end_time': '2019-03-22T13:22:03.055931',
#      'duration': 0.040122,
#      'status': 'completed'}},
#    'source': '- Get current or "After" budgeted CPU file\n- Get "Before" budgeted CPU file\n- Merge between the 2 using full OUTER JOIN\n- Create 2 new columns:\n    1. After Budgeted CPU minus Before Budgeted CPU (at group-subgroup level)\n    2. After Budgeted CPU minus Before Budgeted CPU (at GraphCat level)\n- Export to Excel and save in ```\\\\207.130.185.67\\aqgbudget2\\Cost\\Reserve Adjustments\\Reports\\Normal Reserve Balance Verification\\RVMS_Before_After_Checks``` folder'},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:03.104105',
#      'end_time': '2019-03-22T13:22:05.927922',
#      'duration': 2.823817,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'from datetime import datetime\nfrom dateutil import relativedelta\nfrom pathlib import Path\nimport os\nimport pandas as pd\nimport pyodbc\nimport scrapbook as sb\nimport time\nfrom win10toast import ToastNotifier\npd.options.display.max_rows=1000\npd.options.display.max_columns=100'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:05.959175',
#      'end_time': '2019-03-22T13:22:05.990427',
#      'duration': 0.031252,
#      'status': 'completed'}},
#    'source': '### Enter CLA Claim Month:'},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:06.038255',
#      'end_time': '2019-03-22T13:22:06.080693',
#      'duration': 0.042438,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': '# If using papermill, have to comment this out.  It doesn\'t support getting input from the user\n# CLA_MONTH = input("Enter CLA Claim Month (\'YYYYMM\'): ")'},
#   {'cell_type': 'code',
#    'execution_count': 3,
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:06.111949',
#      'end_time': '2019-03-22T13:22:06.339368',
#      'duration': 0.227419,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "CLA_MONTH = '201901'"},
#   {'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:06.370583',
#      'end_time': '2019-03-22T13:22:06.526520',
#      'duration': 0.155937,
#      'status': 'completed'}},
#    'execution_count': 4,
#    'source': '# Parameters\nCLA_MONTH = "201901"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'execution_count': 5,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:06.557773',
#      'end_time': '2019-03-22T13:22:06.678995',
#      'duration': 0.121222,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'start_time = time.time()'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:06.725876',
#      'end_time': '2019-03-22T13:22:06.757129',
#      'duration': 0.031253,
#      'status': 'completed'}},
#    'source': "### To obtain previous month's CPUs, need to create variable for obtaining the current CLA month minus one month:"},
#   {'cell_type': 'code',
#    'execution_count': 6,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:06.808928',
#      'end_time': '2019-03-22T13:22:06.860971',
#      'duration': 0.052043,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'current_date = datetime(int(CLA_MONTH[:4]),int(CLA_MONTH[-2:]),1,0,0,0,0)'},
#   {'cell_type': 'code',
#    'execution_count': 7,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:06.876598',
#      'end_time': '2019-03-22T13:22:06.995816',
#      'duration': 0.119218,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': 'datetime.datetime(2019, 1, 1, 0, 0)'},
#      'execution_count': 7}],
#    'source': 'current_date'},
#   {'cell_type': 'code',
#    'execution_count': 8,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:07.034317',
#      'end_time': '2019-03-22T13:22:07.114235',
#      'duration': 0.079918,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "current_date_minus_one_month = (current_date + relativedelta.relativedelta(months=-1)).strftime('%Y%m')"},
#   {'cell_type': 'code',
#    'execution_count': 9,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:07.145490',
#      'end_time': '2019-03-22T13:22:07.323724',
#      'duration': 0.178234,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'201812'"},
#      'execution_count': 9}],
#    'source': 'current_date_minus_one_month'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:07.354978',
#      'end_time': '2019-03-22T13:22:07.401858',
#      'duration': 0.04688,
#      'status': 'completed'}},
#    'source': '### Define where to save the Red and Green raw data file based on CLA claim month:'},
#   {'cell_type': 'code',
#    'execution_count': 10,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:07.436866',
#      'end_time': '2019-03-22T13:22:07.494000',
#      'duration': 0.057134,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'base_dir = "//207.130.185.67/aqgbudget2/Cost/Reserve Adjustments/Reports/Normal Reserve Balance Verification/RVMS_Before_After_Checks"\np = Path(base_dir)\nsave_dir = p / CLA_MONTH\nif not os.path.exists(save_dir):\n    os.makedirs(save_dir)'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:07.525253',
#      'end_time': '2019-03-22T13:22:07.540880',
#      'duration': 0.015627,
#      'status': 'completed'}},
#    'source': '### Define where to retrieve the current budgeted CPUs ("after" CPUs):'},
#   {'cell_type': 'code',
#    'execution_count': 11,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:07.587067',
#      'end_time': '2019-03-22T13:22:07.690031',
#      'duration': 0.102964,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'current_cpu_dir = Path("//207.130.185.67/aqgbudget2/Cost/Reserve Adjustments/Reports/Normal Reserve Balance Verification/RVMS_Current_Budgeted_CPUs/" \n                       + CLA_MONTH + "/All_Plants_Budgeted_CPU_By_Group_SubGroup.xlsx")'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:07.736910',
#      'end_time': '2019-03-22T13:22:07.828529',
#      'duration': 0.091619,
#      'status': 'completed'}},
#    'source': '#### Now fetch the "after" CPUs:'},
#   {'cell_type': 'code',
#    'execution_count': 12,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:07.891030',
#      'end_time': '2019-03-22T13:22:19.642407',
#      'duration': 11.751377,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'cpu_after = pd.read_excel(current_cpu_dir)'},
#   {'cell_type': 'code',
#    'execution_count': 13,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:19.689284',
#      'end_time': '2019-03-22T13:22:19.747211',
#      'duration': 0.057927,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '(58680, 14)'},
#      'execution_count': 13}],
#    'source': 'cpu_after.shape'},
#   {'cell_type': 'code',
#    'execution_count': 14,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:19.789217',
#      'end_time': '2019-03-22T13:22:20.336150',
#      'duration': 0.546933,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "cpu_after['Group-SubGroup'] = cpu_after['GRP_NM'].map(str) + ' - ' + cpu_after['SUBGRP_NM'].map(str)"},
#   {'cell_type': 'code',
#    'execution_count': 15,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:20.367403',
#      'end_time': '2019-03-22T13:22:20.457271',
#      'duration': 0.089868,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '   GraphCatID             GraphCatDesc   GRP_NM                 SUBGRP_NM  \\\n0         449  R HMI CIVIC 2010 4DR KA  Chassis  Calipers/Disk/Drums/Pads   \n1         449  R HMI CIVIC 2010 4DR KA  Chassis               Drive Shaft   \n2         449  R HMI CIVIC 2010 4DR KA  Chassis         Hand/cable Brakes   \n3         449  R HMI CIVIC 2010 4DR KA  Chassis           Master Cylinder   \n4         449  R HMI CIVIC 2010 4DR KA  Chassis        Steering Vibration   \n\n   Budgeted_CPU_SubGroup_Level  Planned_Sales_RVMS  Budgeted_CPU_GC_Level  \\\n0                     0.834396               94558                 102.01   \n1                    15.891899               94558                 102.01   \n2                     0.048017               94558                 102.01   \n3                     0.049997               94558                 102.01   \n4                     0.325561               94558                 102.01   \n\n   Orig_Saturation_CPU_GC_Level  Cum_Actual_CPU_GC_Level  RVMS_Claim_Month  \\\n0                        152.72                   101.69            201901   \n1                        152.72                   101.69            201901   \n2                        152.72                   101.69            201901   \n3                        152.72                   101.69            201901   \n4                        152.72                   101.69            201901   \n\n   ModelYear Factory ModelName DestCode                      Group-SubGroup  \n0       2010     HMI     CIVIC       KA  Chassis - Calipers/Disk/Drums/Pads  \n1       2010     HMI     CIVIC       KA               Chassis - Drive Shaft  \n2       2010     HMI     CIVIC       KA         Chassis - Hand/cable Brakes  \n3       2010     HMI     CIVIC       KA           Chassis - Master Cylinder  \n4       2010     HMI     CIVIC       KA        Chassis - Steering Vibration  ',
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>GraphCatID</th>\n      <th>GraphCatDesc</th>\n      <th>GRP_NM</th>\n      <th>SUBGRP_NM</th>\n      <th>Budgeted_CPU_SubGroup_Level</th>\n      <th>Planned_Sales_RVMS</th>\n      <th>Budgeted_CPU_GC_Level</th>\n      <th>Orig_Saturation_CPU_GC_Level</th>\n      <th>Cum_Actual_CPU_GC_Level</th>\n      <th>RVMS_Claim_Month</th>\n      <th>ModelYear</th>\n      <th>Factory</th>\n      <th>ModelName</th>\n      <th>DestCode</th>\n      <th>Group-SubGroup</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Calipers/Disk/Drums/Pads</td>\n      <td>0.834396</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Calipers/Disk/Drums/Pads</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Drive Shaft</td>\n      <td>15.891899</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Drive Shaft</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Hand/cable Brakes</td>\n      <td>0.048017</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Hand/cable Brakes</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Master Cylinder</td>\n      <td>0.049997</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Master Cylinder</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Steering Vibration</td>\n      <td>0.325561</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Steering Vibration</td>\n    </tr>\n  </tbody>\n</table>\n</div>'},
#      'execution_count': 15}],
#    'source': 'cpu_after.head()'},
#   {'cell_type': 'code',
#    'execution_count': 16,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:20.488196',
#      'end_time': '2019-03-22T13:22:20.572186',
#      'duration': 0.08399,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "after_column_names = [col + '_After' for col in cpu_after.columns]"},
#   {'cell_type': 'code',
#    'execution_count': 17,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:20.587814',
#      'end_time': '2019-03-22T13:22:20.712826',
#      'duration': 0.125012,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "['GraphCatID_After',\n 'GraphCatDesc_After',\n 'GRP_NM_After',\n 'SUBGRP_NM_After',\n 'Budgeted_CPU_SubGroup_Level_After',\n 'Planned_Sales_RVMS_After',\n 'Budgeted_CPU_GC_Level_After',\n 'Orig_Saturation_CPU_GC_Level_After',\n 'Cum_Actual_CPU_GC_Level_After',\n 'RVMS_Claim_Month_After',\n 'ModelYear_After',\n 'Factory_After',\n 'ModelName_After',\n 'DestCode_After',\n 'Group-SubGroup_After']"},
#      'execution_count': 17}],
#    'source': 'after_column_names'},
#   {'cell_type': 'code',
#    'execution_count': 18,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:20.759706',
#      'end_time': '2019-03-22T13:22:20.870643',
#      'duration': 0.110937,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'cpu_after.columns = after_column_names'},
#   {'cell_type': 'code',
#    'execution_count': 19,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:20.917524',
#      'end_time': '2019-03-22T13:22:21.020233',
#      'duration': 0.102709,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '   GraphCatID_After       GraphCatDesc_After GRP_NM_After  \\\n0               449  R HMI CIVIC 2010 4DR KA      Chassis   \n1               449  R HMI CIVIC 2010 4DR KA      Chassis   \n2               449  R HMI CIVIC 2010 4DR KA      Chassis   \n3               449  R HMI CIVIC 2010 4DR KA      Chassis   \n4               449  R HMI CIVIC 2010 4DR KA      Chassis   \n\n            SUBGRP_NM_After  Budgeted_CPU_SubGroup_Level_After  \\\n0  Calipers/Disk/Drums/Pads                           0.834396   \n1               Drive Shaft                          15.891899   \n2         Hand/cable Brakes                           0.048017   \n3           Master Cylinder                           0.049997   \n4        Steering Vibration                           0.325561   \n\n   Planned_Sales_RVMS_After  Budgeted_CPU_GC_Level_After  \\\n0                     94558                       102.01   \n1                     94558                       102.01   \n2                     94558                       102.01   \n3                     94558                       102.01   \n4                     94558                       102.01   \n\n   Orig_Saturation_CPU_GC_Level_After  Cum_Actual_CPU_GC_Level_After  \\\n0                              152.72                         101.69   \n1                              152.72                         101.69   \n2                              152.72                         101.69   \n3                              152.72                         101.69   \n4                              152.72                         101.69   \n\n   RVMS_Claim_Month_After  ModelYear_After Factory_After ModelName_After  \\\n0                  201901             2010           HMI           CIVIC   \n1                  201901             2010           HMI           CIVIC   \n2                  201901             2010           HMI           CIVIC   \n3                  201901             2010           HMI           CIVIC   \n4                  201901             2010           HMI           CIVIC   \n\n  DestCode_After                Group-SubGroup_After  \n0             KA  Chassis - Calipers/Disk/Drums/Pads  \n1             KA               Chassis - Drive Shaft  \n2             KA         Chassis - Hand/cable Brakes  \n3             KA           Chassis - Master Cylinder  \n4             KA        Chassis - Steering Vibration  ',
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>GraphCatID_After</th>\n      <th>GraphCatDesc_After</th>\n      <th>GRP_NM_After</th>\n      <th>SUBGRP_NM_After</th>\n      <th>Budgeted_CPU_SubGroup_Level_After</th>\n      <th>Planned_Sales_RVMS_After</th>\n      <th>Budgeted_CPU_GC_Level_After</th>\n      <th>Orig_Saturation_CPU_GC_Level_After</th>\n      <th>Cum_Actual_CPU_GC_Level_After</th>\n      <th>RVMS_Claim_Month_After</th>\n      <th>ModelYear_After</th>\n      <th>Factory_After</th>\n      <th>ModelName_After</th>\n      <th>DestCode_After</th>\n      <th>Group-SubGroup_After</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Calipers/Disk/Drums/Pads</td>\n      <td>0.834396</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Calipers/Disk/Drums/Pads</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Drive Shaft</td>\n      <td>15.891899</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Drive Shaft</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Hand/cable Brakes</td>\n      <td>0.048017</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Hand/cable Brakes</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Master Cylinder</td>\n      <td>0.049997</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Master Cylinder</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Steering Vibration</td>\n      <td>0.325561</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Steering Vibration</td>\n    </tr>\n  </tbody>\n</table>\n</div>'},
#      'execution_count': 19}],
#    'source': 'cpu_after.head()'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:21.051489',
#      'end_time': '2019-03-22T13:22:21.108516',
#      'duration': 0.057027,
#      'status': 'completed'}},
#    'source': '#### Get "Before" budgeted CPU file and rename columns:'},
#   {'cell_type': 'code',
#    'execution_count': 20,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:21.153473',
#      'end_time': '2019-03-22T13:22:23.723120',
#      'duration': 2.569647,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'conn_str = (\n            r\'DRIVER={Microsoft Access Driver (*.mdb, *.accdb)};\'\n            r\'DBQ=\\\\207.130.185.67\\aqgbudget2\\Cost\\Reserve Adjustments\\Reports\\databases\\RVMS.accdb;\'\n           )\ncnxn = pyodbc.connect(conn_str)\ncursor = cnxn.cursor()\n\nsql = """\nSELECT\n    *\n    \nFROM tbl_Historical_Budgeted_CPU\n\nWHERE\n    RVMS_Claim_Month = ?\n"""\n\ntry:\n    cpu_before = pd.read_sql(sql, cnxn, params=[current_date_minus_one_month])\n    #cpu_before = pd.read_sql(sql, cnxn)\n    \n    # Close connections\n    cursor.close()\n    cnxn.close()\nexcept:\n    print("Error connecting to database")\n    cursor.close()\n    cnxn.close()'},
#   {'cell_type': 'code',
#    'execution_count': 21,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:23.770001',
#      'end_time': '2019-03-22T13:22:23.836528',
#      'duration': 0.066527,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '(51720, 15)'},
#      'execution_count': 21}],
#    'source': 'cpu_before.shape'},
#   {'cell_type': 'code',
#    'execution_count': 22,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:23.865840',
#      'end_time': '2019-03-22T13:22:24.006482',
#      'duration': 0.140642,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '       ID  GraphCatID             GraphCatDesc   GRP_NM      SUBGRP_NM  \\\n0  170914         965  R HMA ACCORD 2010 V6 KA    Denso  Washer System   \n1  170915         965  R HMA ACCORD 2010 V6 KA    Denso    Wiper Motor   \n2  170916         965  R HMA ACCORD 2010 V6 KA      OBD      Fuel Pump   \n3  170917         965  R HMA ACCORD 2010 V6 KA  Chassis         Wheels   \n4  170918         965  R HMA ACCORD 2010 V6 KA      OBD       Missfire   \n\n   Budgeted_CPU_SubGroup_Level  Planned_Sales_RVMS  Budgeted_CPU_GC_Level  \\\n0                     0.000000               18539                 241.08   \n1                     0.029453               18539                 241.08   \n2                     0.109686               18539                 241.08   \n3                     1.572711               18539                 241.08   \n4                     8.216182               18539                 241.08   \n\n  Orig_Saturation_CPU_GC_Level Cum_Actual_CPU_GC_Level RVMS_Claim_Month  \\\n0                         None                    None           201812   \n1                         None                    None           201812   \n2                         None                    None           201812   \n3                         None                    None           201812   \n4                         None                    None           201812   \n\n   ModelYear Factory ModelName DestCode  \n0       2010     HMA    ACCORD       KA  \n1       2010     HMA    ACCORD       KA  \n2       2010     HMA    ACCORD       KA  \n3       2010     HMA    ACCORD       KA  \n4       2010     HMA    ACCORD       KA  ',
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>ID</th>\n      <th>GraphCatID</th>\n      <th>GraphCatDesc</th>\n      <th>GRP_NM</th>\n      <th>SUBGRP_NM</th>\n      <th>Budgeted_CPU_SubGroup_Level</th>\n      <th>Planned_Sales_RVMS</th>\n      <th>Budgeted_CPU_GC_Level</th>\n      <th>Orig_Saturation_CPU_GC_Level</th>\n      <th>Cum_Actual_CPU_GC_Level</th>\n      <th>RVMS_Claim_Month</th>\n      <th>ModelYear</th>\n      <th>Factory</th>\n      <th>ModelName</th>\n      <th>DestCode</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>170914</td>\n      <td>965</td>\n      <td>R HMA ACCORD 2010 V6 KA</td>\n      <td>Denso</td>\n      <td>Washer System</td>\n      <td>0.000000</td>\n      <td>18539</td>\n      <td>241.08</td>\n      <td>None</td>\n      <td>None</td>\n      <td>201812</td>\n      <td>2010</td>\n      <td>HMA</td>\n      <td>ACCORD</td>\n      <td>KA</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>170915</td>\n      <td>965</td>\n      <td>R HMA ACCORD 2010 V6 KA</td>\n      <td>Denso</td>\n      <td>Wiper Motor</td>\n      <td>0.029453</td>\n      <td>18539</td>\n      <td>241.08</td>\n      <td>None</td>\n      <td>None</td>\n      <td>201812</td>\n      <td>2010</td>\n      <td>HMA</td>\n      <td>ACCORD</td>\n      <td>KA</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>170916</td>\n      <td>965</td>\n      <td>R HMA ACCORD 2010 V6 KA</td>\n      <td>OBD</td>\n      <td>Fuel Pump</td>\n      <td>0.109686</td>\n      <td>18539</td>\n      <td>241.08</td>\n      <td>None</td>\n      <td>None</td>\n      <td>201812</td>\n      <td>2010</td>\n      <td>HMA</td>\n      <td>ACCORD</td>\n      <td>KA</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>170917</td>\n      <td>965</td>\n      <td>R HMA ACCORD 2010 V6 KA</td>\n      <td>Chassis</td>\n      <td>Wheels</td>\n      <td>1.572711</td>\n      <td>18539</td>\n      <td>241.08</td>\n      <td>None</td>\n      <td>None</td>\n      <td>201812</td>\n      <td>2010</td>\n      <td>HMA</td>\n      <td>ACCORD</td>\n      <td>KA</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>170918</td>\n      <td>965</td>\n      <td>R HMA ACCORD 2010 V6 KA</td>\n      <td>OBD</td>\n      <td>Missfire</td>\n      <td>8.216182</td>\n      <td>18539</td>\n      <td>241.08</td>\n      <td>None</td>\n      <td>None</td>\n      <td>201812</td>\n      <td>2010</td>\n      <td>HMA</td>\n      <td>ACCORD</td>\n      <td>KA</td>\n    </tr>\n  </tbody>\n</table>\n</div>'},
#      'execution_count': 22}],
#    'source': 'cpu_before.head()'},
#   {'cell_type': 'code',
#    'execution_count': 23,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:24.068988',
#      'end_time': '2019-03-22T13:22:24.181834',
#      'duration': 0.112846,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "before_column_names = [col + '_Before' for col in cpu_before.columns]"},
#   {'cell_type': 'code',
#    'execution_count': 24,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:24.213087',
#      'end_time': '2019-03-22T13:22:24.304522',
#      'duration': 0.091435,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'cpu_before.columns = before_column_names'},
#   {'cell_type': 'code',
#    'execution_count': 25,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:24.331606',
#      'end_time': '2019-03-22T13:22:24.462756',
#      'duration': 0.13115,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '   ID_Before  GraphCatID_Before      GraphCatDesc_Before GRP_NM_Before  \\\n0     170914                965  R HMA ACCORD 2010 V6 KA         Denso   \n1     170915                965  R HMA ACCORD 2010 V6 KA         Denso   \n2     170916                965  R HMA ACCORD 2010 V6 KA           OBD   \n3     170917                965  R HMA ACCORD 2010 V6 KA       Chassis   \n4     170918                965  R HMA ACCORD 2010 V6 KA           OBD   \n\n  SUBGRP_NM_Before  Budgeted_CPU_SubGroup_Level_Before  \\\n0    Washer System                            0.000000   \n1      Wiper Motor                            0.029453   \n2        Fuel Pump                            0.109686   \n3           Wheels                            1.572711   \n4         Missfire                            8.216182   \n\n   Planned_Sales_RVMS_Before  Budgeted_CPU_GC_Level_Before  \\\n0                      18539                        241.08   \n1                      18539                        241.08   \n2                      18539                        241.08   \n3                      18539                        241.08   \n4                      18539                        241.08   \n\n  Orig_Saturation_CPU_GC_Level_Before Cum_Actual_CPU_GC_Level_Before  \\\n0                                None                           None   \n1                                None                           None   \n2                                None                           None   \n3                                None                           None   \n4                                None                           None   \n\n  RVMS_Claim_Month_Before  ModelYear_Before Factory_Before ModelName_Before  \\\n0                  201812              2010            HMA           ACCORD   \n1                  201812              2010            HMA           ACCORD   \n2                  201812              2010            HMA           ACCORD   \n3                  201812              2010            HMA           ACCORD   \n4                  201812              2010            HMA           ACCORD   \n\n  DestCode_Before  \n0              KA  \n1              KA  \n2              KA  \n3              KA  \n4              KA  ',
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>ID_Before</th>\n      <th>GraphCatID_Before</th>\n      <th>GraphCatDesc_Before</th>\n      <th>GRP_NM_Before</th>\n      <th>SUBGRP_NM_Before</th>\n      <th>Budgeted_CPU_SubGroup_Level_Before</th>\n      <th>Planned_Sales_RVMS_Before</th>\n      <th>Budgeted_CPU_GC_Level_Before</th>\n      <th>Orig_Saturation_CPU_GC_Level_Before</th>\n      <th>Cum_Actual_CPU_GC_Level_Before</th>\n      <th>RVMS_Claim_Month_Before</th>\n      <th>ModelYear_Before</th>\n      <th>Factory_Before</th>\n      <th>ModelName_Before</th>\n      <th>DestCode_Before</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>170914</td>\n      <td>965</td>\n      <td>R HMA ACCORD 2010 V6 KA</td>\n      <td>Denso</td>\n      <td>Washer System</td>\n      <td>0.000000</td>\n      <td>18539</td>\n      <td>241.08</td>\n      <td>None</td>\n      <td>None</td>\n      <td>201812</td>\n      <td>2010</td>\n      <td>HMA</td>\n      <td>ACCORD</td>\n      <td>KA</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>170915</td>\n      <td>965</td>\n      <td>R HMA ACCORD 2010 V6 KA</td>\n      <td>Denso</td>\n      <td>Wiper Motor</td>\n      <td>0.029453</td>\n      <td>18539</td>\n      <td>241.08</td>\n      <td>None</td>\n      <td>None</td>\n      <td>201812</td>\n      <td>2010</td>\n      <td>HMA</td>\n      <td>ACCORD</td>\n      <td>KA</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>170916</td>\n      <td>965</td>\n      <td>R HMA ACCORD 2010 V6 KA</td>\n      <td>OBD</td>\n      <td>Fuel Pump</td>\n      <td>0.109686</td>\n      <td>18539</td>\n      <td>241.08</td>\n      <td>None</td>\n      <td>None</td>\n      <td>201812</td>\n      <td>2010</td>\n      <td>HMA</td>\n      <td>ACCORD</td>\n      <td>KA</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>170917</td>\n      <td>965</td>\n      <td>R HMA ACCORD 2010 V6 KA</td>\n      <td>Chassis</td>\n      <td>Wheels</td>\n      <td>1.572711</td>\n      <td>18539</td>\n      <td>241.08</td>\n      <td>None</td>\n      <td>None</td>\n      <td>201812</td>\n      <td>2010</td>\n      <td>HMA</td>\n      <td>ACCORD</td>\n      <td>KA</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>170918</td>\n      <td>965</td>\n      <td>R HMA ACCORD 2010 V6 KA</td>\n      <td>OBD</td>\n      <td>Missfire</td>\n      <td>8.216182</td>\n      <td>18539</td>\n      <td>241.08</td>\n      <td>None</td>\n      <td>None</td>\n      <td>201812</td>\n      <td>2010</td>\n      <td>HMA</td>\n      <td>ACCORD</td>\n      <td>KA</td>\n    </tr>\n  </tbody>\n</table>\n</div>'},
#      'execution_count': 25}],
#    'source': 'cpu_before.head()'},
#   {'cell_type': 'code',
#    'execution_count': 26,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:24.493992',
#      'end_time': '2019-03-22T13:22:29.941592',
#      'duration': 5.4476,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'ERROR!!! - Number of rows do not match between CPU after and CPU before data sets'},
#     {'output_type': 'stream', 'name': 'stdout', 'text': '\n'}],
#    'source': 'try:\n    assert cpu_before.shape[0] == cpu_after.shape[0]\nexcept:\n    toaster = ToastNotifier()\n    toaster.show_toast("### ERROR ###",\n                   "Number of rows don\'t match between CPU after and CPU before data sets",\n                   icon_path=None,\n                   duration=5)\n    print(\'ERROR!!! - Number of rows do not match between CPU after and CPU before data sets\')'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:29.972846',
#      'end_time': '2019-03-22T13:22:30.022239',
#      'duration': 0.049393,
#      'status': 'completed'}},
#    'source': '### Merge the after CPU data set with the before CPU data set'},
#   {'cell_type': 'code',
#    'execution_count': 27,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:30.062349',
#      'end_time': '2019-03-22T13:22:30.415461',
#      'duration': 0.353112,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "cpu_before_after_merge = pd.merge(cpu_after, cpu_before, how='outer', \n                                  left_on=['GraphCatID_After','GRP_NM_After','SUBGRP_NM_After'], \n                                  right_on=['GraphCatID_Before','GRP_NM_Before','SUBGRP_NM_Before']\n                                 )"},
#   {'cell_type': 'code',
#    'execution_count': 28,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:30.446677',
#      'end_time': '2019-03-22T13:22:30.506836',
#      'duration': 0.060159,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '(58680, 30)'},
#      'execution_count': 28}],
#    'source': 'cpu_before_after_merge.shape'},
#   {'cell_type': 'code',
#    'execution_count': 29,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:30.552823',
#      'end_time': '2019-03-22T13:22:30.685099',
#      'duration': 0.132276,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '   GraphCatID_After       GraphCatDesc_After GRP_NM_After  \\\n0               449  R HMI CIVIC 2010 4DR KA      Chassis   \n1               449  R HMI CIVIC 2010 4DR KA      Chassis   \n2               449  R HMI CIVIC 2010 4DR KA      Chassis   \n3               449  R HMI CIVIC 2010 4DR KA      Chassis   \n4               449  R HMI CIVIC 2010 4DR KA      Chassis   \n\n            SUBGRP_NM_After  Budgeted_CPU_SubGroup_Level_After  \\\n0  Calipers/Disk/Drums/Pads                           0.834396   \n1               Drive Shaft                          15.891899   \n2         Hand/cable Brakes                           0.048017   \n3           Master Cylinder                           0.049997   \n4        Steering Vibration                           0.325561   \n\n   Planned_Sales_RVMS_After  Budgeted_CPU_GC_Level_After  \\\n0                     94558                       102.01   \n1                     94558                       102.01   \n2                     94558                       102.01   \n3                     94558                       102.01   \n4                     94558                       102.01   \n\n   Orig_Saturation_CPU_GC_Level_After  Cum_Actual_CPU_GC_Level_After  \\\n0                              152.72                         101.69   \n1                              152.72                         101.69   \n2                              152.72                         101.69   \n3                              152.72                         101.69   \n4                              152.72                         101.69   \n\n   RVMS_Claim_Month_After  ModelYear_After Factory_After ModelName_After  \\\n0                  201901             2010           HMI           CIVIC   \n1                  201901             2010           HMI           CIVIC   \n2                  201901             2010           HMI           CIVIC   \n3                  201901             2010           HMI           CIVIC   \n4                  201901             2010           HMI           CIVIC   \n\n  DestCode_After                Group-SubGroup_After  ID_Before  \\\n0             KA  Chassis - Calipers/Disk/Drums/Pads   180847.0   \n1             KA               Chassis - Drive Shaft   180793.0   \n2             KA         Chassis - Hand/cable Brakes   180832.0   \n3             KA           Chassis - Master Cylinder   180790.0   \n4             KA        Chassis - Steering Vibration   180853.0   \n\n   GraphCatID_Before      GraphCatDesc_Before GRP_NM_Before  \\\n0              449.0  R HMI CIVIC 2010 4DR KA       Chassis   \n1              449.0  R HMI CIVIC 2010 4DR KA       Chassis   \n2              449.0  R HMI CIVIC 2010 4DR KA       Chassis   \n3              449.0  R HMI CIVIC 2010 4DR KA       Chassis   \n4              449.0  R HMI CIVIC 2010 4DR KA       Chassis   \n\n           SUBGRP_NM_Before  Budgeted_CPU_SubGroup_Level_Before  \\\n0  Calipers/Disk/Drums/Pads                            0.834394   \n1               Drive Shaft                           15.891603   \n2         Hand/cable Brakes                            0.048016   \n3           Master Cylinder                            0.049997   \n4        Steering Vibration                            0.325561   \n\n   Planned_Sales_RVMS_Before  Budgeted_CPU_GC_Level_Before  \\\n0                    94558.0                        101.97   \n1                    94558.0                        101.97   \n2                    94558.0                        101.97   \n3                    94558.0                        101.97   \n4                    94558.0                        101.97   \n\n  Orig_Saturation_CPU_GC_Level_Before Cum_Actual_CPU_GC_Level_Before  \\\n0                                None                           None   \n1                                None                           None   \n2                                None                           None   \n3                                 ...
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>GraphCatID_After</th>\n      <th>GraphCatDesc_After</th>\n      <th>GRP_NM_After</th>\n      <th>SUBGRP_NM_After</th>\n      <th>Budgeted_CPU_SubGroup_Level_After</th>\n      <th>Planned_Sales_RVMS_After</th>\n      <th>Budgeted_CPU_GC_Level_After</th>\n      <th>Orig_Saturation_CPU_GC_Level_After</th>\n      <th>Cum_Actual_CPU_GC_Level_After</th>\n      <th>RVMS_Claim_Month_After</th>\n      <th>ModelYear_After</th>\n      <th>Factory_After</th>\n      <th>ModelName_After</th>\n      <th>DestCode_After</th>\n      <th>Group-SubGroup_After</th>\n      <th>ID_Before</th>\n      <th>GraphCatID_Before</th>\n      <th>GraphCatDesc_Before</th>\n      <th>GRP_NM_Before</th>\n      <th>SUBGRP_NM_Before</th>\n      <th>Budgeted_CPU_SubGroup_Level_Before</th>\n      <th>Planned_Sales_RVMS_Before</th>\n      <th>Budgeted_CPU_GC_Level_Before</th>\n      <th>Orig_Saturation_CPU_GC_Level_Before</th>\n      <th>Cum_Actual_CPU_GC_Level_Before</th>\n      <th>RVMS_Claim_Month_Before</th>\n      <th>ModelYear_Before</th>\n      <th>Factory_Before</th>\n      <th>ModelName_Before</th>\n      <th>DestCode_Before</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Calipers/Disk/Drums/Pads</td>\n      <td>0.834396</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Calipers/Disk/Drums/Pads</td>\n      <td>180847.0</td>\n      <td>449.0</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Calipers/Disk/Drums/Pads</td>\n      <td>0.834394</td>\n      <td>94558.0</td>\n      <td>101.97</td>\n      <td>None</td>\n      <td>None</td>\n      <td>201812</td>\n      <td>2010.0</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Drive Shaft</td>\n      <td>15.891899</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Drive Shaft</td>\n      <td>180793.0</td>\n      <td>449.0</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Drive Shaft</td>\n      <td>15.891603</td>\n      <td>94558.0</td>\n      <td>101.97</td>\n      <td>None</td>\n      <td>None</td>\n      <td>201812</td>\n      <td>2010.0</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Hand/cable Brakes</td>\n      <td>0.048017</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Hand/cable Brakes</td>\n      <td>180832.0</td>\n      <td>449.0</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Hand/cable Brakes</td>\n      <td>0.048016</td>\n      <td>94558.0</td>\n      <td>101.97</td>\n      <td>None</td>\n      <td>None</td>\n      <td>201812</td>\n      <td>2010.0</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td> ...
#      'execution_count': 29}],
#    'source': 'cpu_before_after_merge.head()'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:30.731979',
#      'end_time': '2019-03-22T13:22:30.794488',
#      'duration': 0.062509,
#      'status': 'completed'}},
#    'source': '### Create columns that represent the before and after CPUs at GraphCat level, subgroup level, and total adjustment costs'},
#   {'cell_type': 'code',
#    'execution_count': 30,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:30.853860',
#      'end_time': '2019-03-22T13:22:30.934753',
#      'duration': 0.080893,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "cpu_before_after_merge['Budgeted_CPU_SubGroup_Level_After_Minus_Before'] = cpu_before_after_merge['Budgeted_CPU_SubGroup_Level_After'] \\\n                                                            - cpu_before_after_merge['Budgeted_CPU_SubGroup_Level_Before']\ncpu_before_after_merge['Budgeted_CPU_GC_Level_After_Minus_Before'] = cpu_before_after_merge['Budgeted_CPU_GC_Level_After'] \\\n                                                                     - cpu_before_after_merge['Budgeted_CPU_GC_Level_Before']\ncpu_before_after_merge['CPU_DIFF_SubGroup_Level_x_SALES'] = cpu_before_after_merge['Budgeted_CPU_SubGroup_Level_After_Minus_Before'] \\\n                                                      * cpu_before_after_merge['Planned_Sales_RVMS_After']\ncpu_before_after_merge['CPU_DIFF_GC_LEVEL_x_SALES'] = cpu_before_after_merge['Budgeted_CPU_GC_Level_After_Minus_Before'] \\\n                                                      * cpu_before_after_merge['Planned_Sales_RVMS_After']"},
#   {'cell_type': 'code',
#    'execution_count': 31,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:30.981631',
#      'end_time': '2019-03-22T13:22:31.099872',
#      'duration': 0.118241,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '   GraphCatID_After       GraphCatDesc_After GRP_NM_After  \\\n0               449  R HMI CIVIC 2010 4DR KA      Chassis   \n1               449  R HMI CIVIC 2010 4DR KA      Chassis   \n2               449  R HMI CIVIC 2010 4DR KA      Chassis   \n3               449  R HMI CIVIC 2010 4DR KA      Chassis   \n4               449  R HMI CIVIC 2010 4DR KA      Chassis   \n\n            SUBGRP_NM_After  Budgeted_CPU_SubGroup_Level_After  \\\n0  Calipers/Disk/Drums/Pads                           0.834396   \n1               Drive Shaft                          15.891899   \n2         Hand/cable Brakes                           0.048017   \n3           Master Cylinder                           0.049997   \n4        Steering Vibration                           0.325561   \n\n   Planned_Sales_RVMS_After  Budgeted_CPU_GC_Level_After  \\\n0                     94558                       102.01   \n1                     94558                       102.01   \n2                     94558                       102.01   \n3                     94558                       102.01   \n4                     94558                       102.01   \n\n   Orig_Saturation_CPU_GC_Level_After  Cum_Actual_CPU_GC_Level_After  \\\n0                              152.72                         101.69   \n1                              152.72                         101.69   \n2                              152.72                         101.69   \n3                              152.72                         101.69   \n4                              152.72                         101.69   \n\n   RVMS_Claim_Month_After  ModelYear_After Factory_After ModelName_After  \\\n0                  201901             2010           HMI           CIVIC   \n1                  201901             2010           HMI           CIVIC   \n2                  201901             2010           HMI           CIVIC   \n3                  201901             2010           HMI           CIVIC   \n4                  201901             2010           HMI           CIVIC   \n\n  DestCode_After                Group-SubGroup_After  ID_Before  \\\n0             KA  Chassis - Calipers/Disk/Drums/Pads   180847.0   \n1             KA               Chassis - Drive Shaft   180793.0   \n2             KA         Chassis - Hand/cable Brakes   180832.0   \n3             KA           Chassis - Master Cylinder   180790.0   \n4             KA        Chassis - Steering Vibration   180853.0   \n\n   GraphCatID_Before      GraphCatDesc_Before GRP_NM_Before  \\\n0              449.0  R HMI CIVIC 2010 4DR KA       Chassis   \n1              449.0  R HMI CIVIC 2010 4DR KA       Chassis   \n2              449.0  R HMI CIVIC 2010 4DR KA       Chassis   \n3              449.0  R HMI CIVIC 2010 4DR KA       Chassis   \n4              449.0  R HMI CIVIC 2010 4DR KA       Chassis   \n\n           SUBGRP_NM_Before  Budgeted_CPU_SubGroup_Level_Before  \\\n0  Calipers/Disk/Drums/Pads                            0.834394   \n1               Drive Shaft                           15.891603   \n2         Hand/cable Brakes                            0.048016   \n3           Master Cylinder                            0.049997   \n4        Steering Vibration                            0.325561   \n\n   Planned_Sales_RVMS_Before  Budgeted_CPU_GC_Level_Before  \\\n0                    94558.0                        101.97   \n1                    94558.0                        101.97   \n2                    94558.0                        101.97   \n3                    94558.0                        101.97   \n4                    94558.0                        101.97   \n\n  Orig_Saturation_CPU_GC_Level_Before Cum_Actual_CPU_GC_Level_Before  \\\n0                                None                           None   \n1                                None                           None   \n2                                None                           None   \n3                                 ...
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>GraphCatID_After</th>\n      <th>GraphCatDesc_After</th>\n      <th>GRP_NM_After</th>\n      <th>SUBGRP_NM_After</th>\n      <th>Budgeted_CPU_SubGroup_Level_After</th>\n      <th>Planned_Sales_RVMS_After</th>\n      <th>Budgeted_CPU_GC_Level_After</th>\n      <th>Orig_Saturation_CPU_GC_Level_After</th>\n      <th>Cum_Actual_CPU_GC_Level_After</th>\n      <th>RVMS_Claim_Month_After</th>\n      <th>ModelYear_After</th>\n      <th>Factory_After</th>\n      <th>ModelName_After</th>\n      <th>DestCode_After</th>\n      <th>Group-SubGroup_After</th>\n      <th>ID_Before</th>\n      <th>GraphCatID_Before</th>\n      <th>GraphCatDesc_Before</th>\n      <th>GRP_NM_Before</th>\n      <th>SUBGRP_NM_Before</th>\n      <th>Budgeted_CPU_SubGroup_Level_Before</th>\n      <th>Planned_Sales_RVMS_Before</th>\n      <th>Budgeted_CPU_GC_Level_Before</th>\n      <th>Orig_Saturation_CPU_GC_Level_Before</th>\n      <th>Cum_Actual_CPU_GC_Level_Before</th>\n      <th>RVMS_Claim_Month_Before</th>\n      <th>ModelYear_Before</th>\n      <th>Factory_Before</th>\n      <th>ModelName_Before</th>\n      <th>DestCode_Before</th>\n      <th>Budgeted_CPU_SubGroup_Level_After_Minus_Before</th>\n      <th>Budgeted_CPU_GC_Level_After_Minus_Before</th>\n      <th>CPU_DIFF_SubGroup_Level_x_SALES</th>\n      <th>CPU_DIFF_GC_LEVEL_x_SALES</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Calipers/Disk/Drums/Pads</td>\n      <td>0.834396</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Calipers/Disk/Drums/Pads</td>\n      <td>180847.0</td>\n      <td>449.0</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Calipers/Disk/Drums/Pads</td>\n      <td>0.834394</td>\n      <td>94558.0</td>\n      <td>101.97</td>\n      <td>None</td>\n      <td>None</td>\n      <td>201812</td>\n      <td>2010.0</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>2.020800e-06</td>\n      <td>0.04</td>\n      <td>0.191083</td>\n      <td>3782.32</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Drive Shaft</td>\n      <td>15.891899</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Drive Shaft</td>\n      <td>180793.0</td>\n      <td>449.0</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Drive Shaft</td>\n      <td>15.891603</td>\n      <td>94558.0</td>\n      <td>101.97</td>\n      <td>None</td>\n      <td>None</td>\n      <td>201812</td>\n      <td>2010.0</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>2.962053e-04</td>\n      <td>0.04</td>\n      <td>28.008581</td>\n      <td>3782.32</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Hand/cable Brakes</td>\n      <td>0.048017</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Hand/cable Brakes</td>\n      <td>180832.0</td>\n      <td>449.0</td>\n      <td>R HMI CIV ...
#      'execution_count': 31}],
#    'source': 'cpu_before_after_merge.head()'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:31.146753',
#      'end_time': '2019-03-22T13:22:31.171315',
#      'duration': 0.024562,
#      'status': 'completed'}},
#    'source': '### Define file name format:'},
#   {'cell_type': 'code',
#    'execution_count': 32,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:31.219868',
#      'end_time': '2019-03-22T13:22:31.282376',
#      'duration': 0.062508,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "date_hour_stamp = time.strftime('%Y-%m-%d_%H_%M')\nfile_name = 'All_Plants_Before_After_Budgeted_CPUs_' + date_hour_stamp + '.xlsx'"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:31.329257',
#      'end_time': '2019-03-22T13:22:31.376136',
#      'duration': 0.046879,
#      'status': 'completed'}},
#    'source': '### Write/save file to designated network share drive location:'},
#   {'cell_type': 'code',
#    'execution_count': 33,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:22:31.419131',
#      'end_time': '2019-03-22T13:24:12.370493',
#      'duration': 100.951362,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'cpu_before_after_merge.to_excel(save_dir / file_name, index=False)'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:24:12.432817',
#      'end_time': '2019-03-22T13:24:12.464069',
#      'duration': 0.031252,
#      'status': 'completed'}},
#    'source': '### Now, we need to "glue" the location of the saved file location to this notebook so that another notebook can retrieve/reference from it:'},
#   {'cell_type': 'code',
#    'execution_count': 34,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:24:12.514659',
#      'end_time': '2019-03-22T13:24:12.568703',
#      'duration': 0.054044,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'\\\\\\\\207.130.185.67\\\\aqgbudget2\\\\Cost\\\\Reserve Adjustments\\\\Reports\\\\Normal Reserve Balance Verification\\\\RVMS_Before_After_Checks\\\\201901\\\\All_Plants_Before_After_Budgeted_CPUs_2019-03-22_09_22.xlsx'"},
#      'execution_count': 34}],
#    'source': 'str(save_dir / file_name)'},
#   {'cell_type': 'code',
#    'execution_count': 35,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:24:12.615583',
#      'end_time': '2019-03-22T13:24:12.707169',
#      'duration': 0.091586,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'display_data',
#      'metadata': {'scrapbook': {'name': 'path_to_red_green_sheet_excel_file',
#        'data': True,
#        'display': False}},
#      'data': {'application/scrapbook.scrap.text+json': {'name': 'path_to_red_green_sheet_excel_file',
#        'data': '\\\\207.130.185.67\\aqgbudget2\\Cost\\Reserve Adjustments\\Reports\\Normal Reserve Balance Verification\\RVMS_Before_After_Checks\\201901\\All_Plants_Before_After_Budgeted_CPUs_2019-03-22_09_22.xlsx',
#        'encoder': 'text',
#        'version': 1}}}],
#    'source': 'sb.glue("path_to_red_green_sheet_excel_file", str(save_dir / file_name))'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:24:12.785021',
#      'end_time': '2019-03-22T13:24:12.863154',
#      'duration': 0.078133,
#      'status': 'completed'}},
#    'source': '### Send Windows Toast notification when script completes'},
#   {'cell_type': 'code',
#    'execution_count': 36,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:24:12.921462',
#      'end_time': '2019-03-22T13:24:18.076365',
#      'duration': 5.154903,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': 'True'},
#      'execution_count': 36}],
#    'source': 'toaster = ToastNotifier()\ntoaster.show_toast("### Before vs After CPU Status ###",\n                   "Successfuly compared before CPUs with after CPU adjustments",\n                   icon_path="images/honda_logo.ico",\n                   duration=5)'}],
#  'metadata': {'_draft': {'nbviewer_url': 'https://gist.github.com/434e290a1af3636a3f84097e3aa45a72'},
#   'gist': {'data': {'description': 'pandas_memory_error', 'public': True},
#    'id': '434e290a1af3636a3f84097e3aa45a72'},
#   'hide_input': False,
#   'jupytext': {'text_representation': {'extension': '.md',
#     'format_name': 'markdown',
#     'format_version': '1.0',
#     'jupytext_version': '0.8.6'}},
#   'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.7.0',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'parameters': {'CLA_MONTH': '201901'},
#    'environment_variables': {},
#    'version': '0.19.0',
#    'input_path': '2_Comparing_Adjusted_GraphCat_CPUs_against_Original_GraphCat_CPUs-Access.ipynb',
#    'output_path': 'output/RedAndGreenSheet.ipynb',
#    'start_time': '2019-03-22T13:21:59.582762',
#    'end_time': '2019-03-22T13:24:20.630746',
#    'duration': 141.047984,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 2}

# %% [markdown]
# ## 3) Execute jupyter notebook that summarizes the raw "Red and Green Sheet" data in native currency:

# %%
# %%time
pm.execute_notebook(
    '3_Get_Top3_Bottom3_Group_SubGroup_Adjustments_Native_Currency.ipynb',
    'output/RedAndGreenSheet_Summarized_Native.ipynb',
    cwd='D:\\jupyter\\rvms\\production',
    parameters = dict(start_year=start_year,
                      end_year=end_year,
                      CLA_MONTH=CLA_MONTH
                     )
)
# Out:
# HBox(children=(IntProgress(value=0, max=86), HTML(value='')))
# Wall time: 1min 19s
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:24:24.091641',
#      'end_time': '2019-03-22T13:24:24.154148',
#      'duration': 0.062507,
#      'status': 'completed'}},
#    'source': '# PURPOSE:'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:24:24.232280',
#      'end_time': '2019-03-22T13:24:24.294788',
#      'duration': 0.062508,
#      'status': 'completed'}},
#    'source': '### To obtain the top 3 and bottom 3 GraphCat adjustments'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:24:24.371810',
#      'end_time': '2019-03-22T13:24:24.449942',
#      'duration': 0.078132,
#      'status': 'completed'}},
#    'source': '**Procedure:** User just has to copy their graphcat data into "clipboard" and then execute all cells in this notebook'},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:24:24.521196',
#      'end_time': '2019-03-22T13:24:27.432870',
#      'duration': 2.911674,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "from pathlib import Path\nimport os\nimport pandas as pd\nimport numpy as np\nimport scrapbook as sb\nfrom win10toast import ToastNotifier\npd.options.display.max_rows=1000\npd.options.display.max_columns=100\npd.options.display.float_format = '{:20,.2f}'.format"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:24:27.495381',
#      'end_time': '2019-03-22T13:24:27.583261',
#      'duration': 0.08788,
#      'status': 'completed'}},
#    'source': '### Parameters that will be used by the papermill library'},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:24:27.664649',
#      'end_time': '2019-03-22T13:24:27.746338',
#      'duration': 0.081689,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "start_year = 2010\nend_year = 2019\nCLA_MONTH = '201901'"},
#   {'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:24:27.813153',
#      'end_time': '2019-03-22T13:24:27.979702',
#      'duration': 0.166549,
#      'status': 'completed'}},
#    'execution_count': 3,
#    'source': '# Parameters\nstart_year = 2010\nend_year = 2019\nCLA_MONTH = "201901"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'execution_count': 4,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:24:28.042209',
#      'end_time': '2019-03-22T13:24:28.287661',
#      'duration': 0.245452,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': '#df = pd.read_clipboard()'},
#   {'cell_type': 'code',
#    'execution_count': 5,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:24:28.334542',
#      'end_time': '2019-03-22T13:24:28.650399',
#      'duration': 0.315857,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "nb = sb.read_notebook('D:\\\\jupyter\\\\rvms\\\\production\\\\output\\\\RedAndGreenSheet.ipynb')"},
#   {'cell_type': 'code',
#    'execution_count': 6,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:24:28.712903',
#      'end_time': '2019-03-22T13:24:28.901183',
#      'duration': 0.18828,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'\\\\\\\\207.130.185.67\\\\aqgbudget2\\\\Cost\\\\Reserve Adjustments\\\\Reports\\\\Normal Reserve Balance Verification\\\\RVMS_Before_After_Checks\\\\201901\\\\All_Plants_Before_After_Budgeted_CPUs_2019-03-22_09_22.xlsx'"},
#      'execution_count': 6}],
#    'source': "nb.scraps['path_to_red_green_sheet_excel_file'].data"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:24:28.948027',
#      'end_time': '2019-03-22T13:24:28.994907',
#      'duration': 0.04688,
#      'status': 'completed'}},
#    'source': '### Define where to save the Red and Green raw data file based on CLA claim month:'},
#   {'cell_type': 'code',
#    'execution_count': 7,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:24:29.043841',
#      'end_time': '2019-03-22T13:24:29.390873',
#      'duration': 0.347032,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'base_dir = "//207.130.185.67/aqgbudget2/Cost/Reserve Adjustments/Reports/Normal Reserve Balance Verification/RVMS_Before_After_Checks"\np = Path(base_dir)\nsave_dir = p / CLA_MONTH\nif not os.path.exists(save_dir):\n    os.makedirs(save_dir)'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:24:29.437718',
#      'end_time': '2019-03-22T13:24:29.484633',
#      'duration': 0.046915,
#      'status': 'completed'}},
#    'source': '### Now retrieve the Excel file containing the raw "Red and Green Sheet" data:'},
#   {'cell_type': 'code',
#    'execution_count': 8,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:24:29.546058',
#      'end_time': '2019-03-22T13:25:04.393133',
#      'duration': 34.847075,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "df = pd.read_excel(nb.scraps['path_to_red_green_sheet_excel_file'].data)"},
#   {'cell_type': 'code',
#    'execution_count': 9,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:04.455640',
#      'end_time': '2019-03-22T13:25:04.580061',
#      'duration': 0.124421,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '(58680, 34)'},
#      'execution_count': 9}],
#    'source': 'df.shape'},
#   {'cell_type': 'code',
#    'execution_count': 10,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:04.658194',
#      'end_time': '2019-03-22T13:25:04.810491',
#      'duration': 0.152297,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '   GraphCatID_After       GraphCatDesc_After GRP_NM_After  \\\n0               449  R HMI CIVIC 2010 4DR KA      Chassis   \n1               449  R HMI CIVIC 2010 4DR KA      Chassis   \n2               449  R HMI CIVIC 2010 4DR KA      Chassis   \n3               449  R HMI CIVIC 2010 4DR KA      Chassis   \n4               449  R HMI CIVIC 2010 4DR KA      Chassis   \n\n            SUBGRP_NM_After  Budgeted_CPU_SubGroup_Level_After  \\\n0  Calipers/Disk/Drums/Pads                               0.83   \n1               Drive Shaft                              15.89   \n2         Hand/cable Brakes                               0.05   \n3           Master Cylinder                               0.05   \n4        Steering Vibration                               0.33   \n\n   Planned_Sales_RVMS_After  Budgeted_CPU_GC_Level_After  \\\n0                     94558                       102.01   \n1                     94558                       102.01   \n2                     94558                       102.01   \n3                     94558                       102.01   \n4                     94558                       102.01   \n\n   Orig_Saturation_CPU_GC_Level_After  Cum_Actual_CPU_GC_Level_After  \\\n0                              152.72                         101.69   \n1                              152.72                         101.69   \n2                              152.72                         101.69   \n3                              152.72                         101.69   \n4                              152.72                         101.69   \n\n   RVMS_Claim_Month_After  ModelYear_After Factory_After ModelName_After  \\\n0                  201901             2010           HMI           CIVIC   \n1                  201901             2010           HMI           CIVIC   \n2                  201901             2010           HMI           CIVIC   \n3                  201901             2010           HMI           CIVIC   \n4                  201901             2010           HMI           CIVIC   \n\n  DestCode_After                Group-SubGroup_After            ID_Before  \\\n0             KA  Chassis - Calipers/Disk/Drums/Pads           180,847.00   \n1             KA               Chassis - Drive Shaft           180,793.00   \n2             KA         Chassis - Hand/cable Brakes           180,832.00   \n3             KA           Chassis - Master Cylinder           180,790.00   \n4             KA        Chassis - Steering Vibration           180,853.00   \n\n     GraphCatID_Before      GraphCatDesc_Before GRP_NM_Before  \\\n0               449.00  R HMI CIVIC 2010 4DR KA       Chassis   \n1               449.00  R HMI CIVIC 2010 4DR KA       Chassis   \n2               449.00  R HMI CIVIC 2010 4DR KA       Chassis   \n3               449.00  R HMI CIVIC 2010 4DR KA       Chassis   \n4               449.00  R HMI CIVIC 2010 4DR KA       Chassis   \n\n           SUBGRP_NM_Before  Budgeted_CPU_SubGroup_Level_Before  \\\n0  Calipers/Disk/Drums/Pads                                0.83   \n1               Drive Shaft                               15.89   \n2         Hand/cable Brakes                                0.05   \n3           Master Cylinder                                0.05   \n4        Steering Vibration                                0.33   \n\n   Planned_Sales_RVMS_Before  Budgeted_CPU_GC_Level_Before  \\\n0                  94,558.00                        101.97   \n1                  94,558.00                        101.97   \n2                  94,558.00                        101.97   \n3                  94,558.00                        101.97   \n4                  94,558.00                        101.97   \n\n   Orig_Saturation_CPU_GC_Level_Before  Cum_Actual_CPU_GC_Level_Before  \\\n0                                  nan                             nan   \n1                                  nan                             nan   \n2                            ...
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>GraphCatID_After</th>\n      <th>GraphCatDesc_After</th>\n      <th>GRP_NM_After</th>\n      <th>SUBGRP_NM_After</th>\n      <th>Budgeted_CPU_SubGroup_Level_After</th>\n      <th>Planned_Sales_RVMS_After</th>\n      <th>Budgeted_CPU_GC_Level_After</th>\n      <th>Orig_Saturation_CPU_GC_Level_After</th>\n      <th>Cum_Actual_CPU_GC_Level_After</th>\n      <th>RVMS_Claim_Month_After</th>\n      <th>ModelYear_After</th>\n      <th>Factory_After</th>\n      <th>ModelName_After</th>\n      <th>DestCode_After</th>\n      <th>Group-SubGroup_After</th>\n      <th>ID_Before</th>\n      <th>GraphCatID_Before</th>\n      <th>GraphCatDesc_Before</th>\n      <th>GRP_NM_Before</th>\n      <th>SUBGRP_NM_Before</th>\n      <th>Budgeted_CPU_SubGroup_Level_Before</th>\n      <th>Planned_Sales_RVMS_Before</th>\n      <th>Budgeted_CPU_GC_Level_Before</th>\n      <th>Orig_Saturation_CPU_GC_Level_Before</th>\n      <th>Cum_Actual_CPU_GC_Level_Before</th>\n      <th>RVMS_Claim_Month_Before</th>\n      <th>ModelYear_Before</th>\n      <th>Factory_Before</th>\n      <th>ModelName_Before</th>\n      <th>DestCode_Before</th>\n      <th>Budgeted_CPU_SubGroup_Level_After_Minus_Before</th>\n      <th>Budgeted_CPU_GC_Level_After_Minus_Before</th>\n      <th>CPU_DIFF_SubGroup_Level_x_SALES</th>\n      <th>CPU_DIFF_GC_LEVEL_x_SALES</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Calipers/Disk/Drums/Pads</td>\n      <td>0.83</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Calipers/Disk/Drums/Pads</td>\n      <td>180,847.00</td>\n      <td>449.00</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Calipers/Disk/Drums/Pads</td>\n      <td>0.83</td>\n      <td>94,558.00</td>\n      <td>101.97</td>\n      <td>nan</td>\n      <td>nan</td>\n      <td>201,812.00</td>\n      <td>2,010.00</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>0.00</td>\n      <td>0.04</td>\n      <td>0.19</td>\n      <td>3,782.32</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Drive Shaft</td>\n      <td>15.89</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Drive Shaft</td>\n      <td>180,793.00</td>\n      <td>449.00</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Drive Shaft</td>\n      <td>15.89</td>\n      <td>94,558.00</td>\n      <td>101.97</td>\n      <td>nan</td>\n      <td>nan</td>\n      <td>201,812.00</td>\n      <td>2,010.00</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>0.00</td>\n      <td>0.04</td>\n      <td>28.01</td>\n      <td>3,782.32</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Hand/cable Brakes</td>\n      <td>0.05</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Hand/cable Brakes</td>\n      <td>180,832.00</td>\n      <td>449.00</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n ...
#      'execution_count': 10}],
#    'source': 'df.head()'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:04.888624',
#      'end_time': '2019-03-22T13:25:04.962802',
#      'duration': 0.074178,
#      'status': 'completed'}},
#    'source': '### But we need to limit our data to just the model years that are under RVMS adjustments:'},
#   {'cell_type': 'code',
#    'execution_count': 11,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:05.056563',
#      'end_time': '2019-03-22T13:25:05.149951',
#      'duration': 0.093388,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'rvms_years = list(range(start_year, end_year + 1))'},
#   {'cell_type': 'code',
#    'execution_count': 12,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:05.225958',
#      'end_time': '2019-03-22T13:25:05.342316',
#      'duration': 0.116358,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '[2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]'},
#      'execution_count': 12}],
#    'source': 'rvms_years'},
#   {'cell_type': 'code',
#    'execution_count': 13,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:05.420447',
#      'end_time': '2019-03-22T13:25:05.587492',
#      'duration': 0.167045,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'df = df.query("ModelYear_After in(@rvms_years)")'},
#   {'cell_type': 'code',
#    'execution_count': 14,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:05.665624',
#      'end_time': '2019-03-22T13:25:05.762951',
#      'duration': 0.097327,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '(58440, 34)'},
#      'execution_count': 14}],
#    'source': 'df.shape'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:05.872187',
#      'end_time': '2019-03-22T13:25:05.960793',
#      'duration': 0.088606,
#      'status': 'completed'}},
#    'source': '### Create unique list of GraphCat descriptions:'},
#   {'cell_type': 'code',
#    'execution_count': 15,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:06.078950',
#      'end_time': '2019-03-22T13:25:06.331308',
#      'duration': 0.252358,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "gc_list = df[['GraphCatID_After','GraphCatDesc_After', 'Planned_Sales_RVMS_After','Budgeted_CPU_GC_Level_After_Minus_Before',\n              'Budgeted_CPU_GC_Level_After', 'Budgeted_CPU_GC_Level_Before',\n              'Orig_Saturation_CPU_GC_Level_After', 'Cum_Actual_CPU_GC_Level_After']].drop_duplicates()"},
#   {'cell_type': 'code',
#    'execution_count': 16,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:06.425069',
#      'end_time': '2019-03-22T13:25:06.539793',
#      'duration': 0.114724,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '(487, 8)'},
#      'execution_count': 16}],
#    'source': 'gc_list.shape'},
#   {'cell_type': 'code',
#    'execution_count': 17,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:06.617926',
#      'end_time': '2019-03-22T13:25:07.145519',
#      'duration': 0.527593,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '       GraphCatID_After               GraphCatDesc_After  \\\n0                   449          R HMI CIVIC 2010 4DR KA   \n120                 450          R MAP Accord 2010 L4 KA   \n240                 470          R MAP Accord 2010 V6 KA   \n360                 484            R ELP CRV 2010 4WD KA   \n480                 485            R ELP CRV 2010 2WD KA   \n600                 490          R MAP Accord 2010 L4 KC   \n720                 492          R MAP Accord 2010 V6 KC   \n840                 493        R ELP Element 2010 2WD KA   \n960                 494        R ELP Element 2010 2WD KC   \n1080                495        R ELP Element 2010 4WD KA   \n1200                496        R ELP Element 2010 4WD KC   \n1320                497      R ELP Crosstour 2010 2WD KA   \n1440                498      R ELP Crosstour 2010 2WD KC   \n1560                499      R ELP Crosstour 2010 4WD KA   \n1680                500      R ELP Crosstour 2010 4WD KC   \n1800                501             R MAP TL 2010 2WD KA   \n1920                502           R MAP TL 2010 SHAWD KA   \n2040                503             R MAP TL 2010 2WD KC   \n2160                504           R MAP TL 2010 SHAWD KC   \n2280                505            R MAP RDX 2010 2WD KA   \n2400                506            R MAP RDX 2010 4WD KA   \n2520                508            R MAP RDX 2010 4WD KC   \n2640                509            R ELP CRV 2010 2WD KC   \n2760                510            R ELP CRV 2010 4WD KC   \n2880                541            R MAP RDX 2011 2WD KA   \n3000                542            R MAP RDX 2011 4WD KA   \n3120                543            R MAP RDX 2011 4WD KC   \n3240                544      R ELP Crosstour 2011 2WD KA   \n3360                545      R ELP Crosstour 2011 2WD KC   \n3480                546      R ELP Crosstour 2011 4WD KA   \n3600                547      R ELP Crosstour 2011 4WD KC   \n3720                548            R ELP CRV 2011 2WD KA   \n3840                549            R ELP CRV 2011 4WD KA   \n3960                550            R ELP CRV 2011 2WD KC   \n4080                551            R ELP CRV 2011 4WD KC   \n4200                552        R ELP Element 2011 2WD KA   \n4320                553        R ELP Element 2011 4WD KA   \n4440                554        R ELP Element 2011 2WD KC   \n4560                555        R ELP Element 2011 4WD KC   \n4680                556          R MAP Accord 2011 L4 KA   \n4800                557          R MAP Accord 2011 V6 KA   \n4920                558          R MAP Accord 2011 L4 KC   \n5040                559          R MAP Accord 2011 V6 KC   \n5160                560             R MAP TL 2011 2WD KA   \n5280                562            R HMA ODYSSEY 2011 KA   \n5400                563           R MAP TL 2011 SHAWD KA   \n5520                564             R MAP TL 2011 2WD KC   \n5640                565           R MAP TL 2011 SHAWD KC   \n5760                568          R HMI CIVIC 2011 4DR KA   \n5880                575          R MAP Accord 2012 L4 KA   \n6000                576          R MAP Accord 2012 V6 KA   \n6120                577          R MAP Accord 2012 L4 KC   \n6240                578          R MAP Accord 2012 V6 KC   \n6360                579          R MAP Accord 2012 L4 KY   \n6480                580          R MAP Accord 2012 V6 KY   \n6600                581            R ELP CRV 2012 2WD KA   \n6720                582            R ELP CRV 2012 2WD KC   \n6840                583            R ELP CRV 2012 4WD KA   \n6960                584            R ELP CRV 2012 4WD KC   \n7080                585             R MAP TL 2012 2WD KA   \n7200                586             R MAP TL 2012 2WD KC   \n7320                587           R MAP TL 2012 SHAWD KA   \n7440                588           R MAP TL 2012 SHAWD KC   \n7560                589            R MAP RDX 2012 2WD KA   \n7680  ...
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>GraphCatID_After</th>\n      <th>GraphCatDesc_After</th>\n      <th>Planned_Sales_RVMS_After</th>\n      <th>Budgeted_CPU_GC_Level_After_Minus_Before</th>\n      <th>Budgeted_CPU_GC_Level_After</th>\n      <th>Budgeted_CPU_GC_Level_Before</th>\n      <th>Orig_Saturation_CPU_GC_Level_After</th>\n      <th>Cum_Actual_CPU_GC_Level_After</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>94558</td>\n      <td>0.04</td>\n      <td>102.01</td>\n      <td>101.97</td>\n      <td>152.72</td>\n      <td>101.69</td>\n    </tr>\n    <tr>\n      <th>120</th>\n      <td>450</td>\n      <td>R MAP Accord 2010 L4 KA</td>\n      <td>225412</td>\n      <td>0.45</td>\n      <td>105.92</td>\n      <td>105.47</td>\n      <td>177.24</td>\n      <td>102.60</td>\n    </tr>\n    <tr>\n      <th>240</th>\n      <td>470</td>\n      <td>R MAP Accord 2010 V6 KA</td>\n      <td>44941</td>\n      <td>0.00</td>\n      <td>229.81</td>\n      <td>229.81</td>\n      <td>280.50</td>\n      <td>229.51</td>\n    </tr>\n    <tr>\n      <th>360</th>\n      <td>484</td>\n      <td>R ELP CRV 2010 4WD KA</td>\n      <td>102615</td>\n      <td>0.00</td>\n      <td>92.30</td>\n      <td>92.30</td>\n      <td>127.33</td>\n      <td>92.39</td>\n    </tr>\n    <tr>\n      <th>480</th>\n      <td>485</td>\n      <td>R ELP CRV 2010 2WD KA</td>\n      <td>51299</td>\n      <td>0.00</td>\n      <td>75.27</td>\n      <td>75.27</td>\n      <td>119.83</td>\n      <td>74.27</td>\n    </tr>\n    <tr>\n      <th>600</th>\n      <td>490</td>\n      <td>R MAP Accord 2010 L4 KC</td>\n      <td>9840</td>\n      <td>0.00</td>\n      <td>259.28</td>\n      <td>259.28</td>\n      <td>245.30</td>\n      <td>259.28</td>\n    </tr>\n    <tr>\n      <th>720</th>\n      <td>492</td>\n      <td>R MAP Accord 2010 V6 KC</td>\n      <td>2100</td>\n      <td>0.00</td>\n      <td>376.98</td>\n      <td>376.98</td>\n      <td>366.80</td>\n      <td>374.96</td>\n    </tr>\n    <tr>\n      <th>840</th>\n      <td>493</td>\n      <td>R ELP Element 2010 2WD KA</td>\n      <td>7080</td>\n      <td>0.00</td>\n      <td>91.25</td>\n      <td>91.25</td>\n      <td>169.87</td>\n      <td>89.64</td>\n    </tr>\n    <tr>\n      <th>960</th>\n      <td>494</td>\n      <td>R ELP Element 2010 2WD KC</td>\n      <td>60</td>\n      <td>0.00</td>\n      <td>197.04</td>\n      <td>197.04</td>\n      <td>205.65</td>\n      <td>196.57</td>\n    </tr>\n    <tr>\n      <th>1080</th>\n      <td>495</td>\n      <td>R ELP Element 2010 4WD KA</td>\n      <td>9480</td>\n      <td>0.00</td>\n      <td>91.10</td>\n      <td>91.10</td>\n      <td>175.84</td>\n      <td>89.50</td>\n    </tr>\n    <tr>\n      <th>1200</th>\n      <td>496</td>\n      <td>R ELP Element 2010 4WD KC</td>\n      <td>300</td>\n      <td>0.00</td>\n      <td>241.26</td>\n      <td>241.26</td>\n      <td>210.18</td>\n      <td>240.66</td>\n    </tr>\n    <tr>\n      <th>1320</th>\n      <td>497</td>\n      <td>R ELP Crosstour 2010 2WD KA</td>\n      <td>16761</td>\n      <td>0.00</td>\n      <td>199.40</td>\n      <td>199.40</td>\n      <td>341.09</td>\n      <td>198.78</td>\n    </tr>\n    <tr>\n      <th>1440</th>\n      <td>498</td>\n      <td>R ELP Crosstour 2010 2WD KC</td>\n      <td>270</td>\n      <td>0.00</td>\n      <td>291.99</td>\n      <td>291.99</td>\n      <td>458.34</td>\n      <td>291.26</td>\n    </tr>\n    <tr>\n      <th>1560</th>\n      <td>499</td>\n      <td>R ELP Crosstour 2010 4WD KA</td>\n      <td>18216</td>\n      <td>0.00</td>\n      <td>183.57</td>\n      <td>183.57</td ...
#      'execution_count': 17}],
#    'source': 'gc_list'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:07.254905',
#      'end_time': '2019-03-22T13:25:07.356523',
#      'duration': 0.101618,
#      'status': 'completed'}},
#    'source': '### Create helper functions to Add Model Year, Factory, and Model Name columns:'},
#   {'cell_type': 'code',
#    'execution_count': 18,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:07.450285',
#      'end_time': '2019-03-22T13:25:07.587092',
#      'duration': 0.136807,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "def getModelYear(row) -> str:\n    # executing strip() also because someone can make a graphcat description with a trailing whitespace\n    word_token = row['GraphCatDesc_After'].strip().split()\n    \n    model_year = word_token[3]\n    \n    if model_year.isdigit():\n        return model_year\n    else:\n        return word_token[4]\n\ndef getFactoryCode(row) -> str:\n    # executing strip() also because someone can make a graphcat description with a trailing whitespace\n    word_token = row['GraphCatDesc_After'].strip().split()\n    factory_code = word_token[1]\n    \n    return factory_code.upper()\n\ndef getModelName(row) -> str:\n    # executing strip() also because someone can make a graphcat description with a trailing whitespace\n    word_token = row['GraphCatDesc_After'].strip().split()\n    model_name = word_token[2]\n    \n    return model_name.upper()\n\ndef getDestCode(row) -> str:\n    # executing strip() also because someone can make a graphcat description with a trailing whitespace\n    word_token = row['GraphCatDesc_After'].strip().split()\n    destination_code = word_token[-1]\n    \n    return destination_code.upper()"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:07.680852',
#      'end_time': '2019-03-22T13:25:07.788537',
#      'duration': 0.107685,
#      'status': 'completed'}},
#    'source': '### Apply the above functions to create the model year, factory, and model name columns'},
#   {'cell_type': 'code',
#    'execution_count': 19,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:07.897924',
#      'end_time': '2019-03-22T13:25:08.239714',
#      'duration': 0.34179,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "gc_list['ModelYear'] = gc_list.apply(getModelYear, axis='columns')\ngc_list['Factory'] = gc_list.apply(getFactoryCode, axis='columns')\ngc_list['ModelName'] = gc_list.apply(getModelName, axis='columns')\ngc_list['DestCodeCustom'] = gc_list.apply(getDestCode, axis='columns')"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:08.333473',
#      'end_time': '2019-03-22T13:25:08.469690',
#      'duration': 0.136217,
#      'status': 'completed'}},
#    'source': "#### Let's confirm the new columns were added:"},
#   {'cell_type': 'code',
#    'execution_count': 20,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:08.579076',
#      'end_time': '2019-03-22T13:25:08.718540',
#      'duration': 0.139464,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '     GraphCatID_After       GraphCatDesc_After  Planned_Sales_RVMS_After  \\\n0                 449  R HMI CIVIC 2010 4DR KA                     94558   \n120               450  R MAP Accord 2010 L4 KA                    225412   \n240               470  R MAP Accord 2010 V6 KA                     44941   \n360               484    R ELP CRV 2010 4WD KA                    102615   \n480               485    R ELP CRV 2010 2WD KA                     51299   \n\n     Budgeted_CPU_GC_Level_After_Minus_Before  Budgeted_CPU_GC_Level_After  \\\n0                                        0.04                       102.01   \n120                                      0.45                       105.92   \n240                                      0.00                       229.81   \n360                                      0.00                        92.30   \n480                                      0.00                        75.27   \n\n     Budgeted_CPU_GC_Level_Before  Orig_Saturation_CPU_GC_Level_After  \\\n0                          101.97                              152.72   \n120                        105.47                              177.24   \n240                        229.81                              280.50   \n360                         92.30                              127.33   \n480                         75.27                              119.83   \n\n     Cum_Actual_CPU_GC_Level_After ModelYear Factory ModelName DestCodeCustom  \n0                           101.69      2010     HMI     CIVIC             KA  \n120                         102.60      2010     MAP    ACCORD             KA  \n240                         229.51      2010     MAP    ACCORD             KA  \n360                          92.39      2010     ELP       CRV             KA  \n480                          74.27      2010     ELP       CRV             KA  ',
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>GraphCatID_After</th>\n      <th>GraphCatDesc_After</th>\n      <th>Planned_Sales_RVMS_After</th>\n      <th>Budgeted_CPU_GC_Level_After_Minus_Before</th>\n      <th>Budgeted_CPU_GC_Level_After</th>\n      <th>Budgeted_CPU_GC_Level_Before</th>\n      <th>Orig_Saturation_CPU_GC_Level_After</th>\n      <th>Cum_Actual_CPU_GC_Level_After</th>\n      <th>ModelYear</th>\n      <th>Factory</th>\n      <th>ModelName</th>\n      <th>DestCodeCustom</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>94558</td>\n      <td>0.04</td>\n      <td>102.01</td>\n      <td>101.97</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n    </tr>\n    <tr>\n      <th>120</th>\n      <td>450</td>\n      <td>R MAP Accord 2010 L4 KA</td>\n      <td>225412</td>\n      <td>0.45</td>\n      <td>105.92</td>\n      <td>105.47</td>\n      <td>177.24</td>\n      <td>102.60</td>\n      <td>2010</td>\n      <td>MAP</td>\n      <td>ACCORD</td>\n      <td>KA</td>\n    </tr>\n    <tr>\n      <th>240</th>\n      <td>470</td>\n      <td>R MAP Accord 2010 V6 KA</td>\n      <td>44941</td>\n      <td>0.00</td>\n      <td>229.81</td>\n      <td>229.81</td>\n      <td>280.50</td>\n      <td>229.51</td>\n      <td>2010</td>\n      <td>MAP</td>\n      <td>ACCORD</td>\n      <td>KA</td>\n    </tr>\n    <tr>\n      <th>360</th>\n      <td>484</td>\n      <td>R ELP CRV 2010 4WD KA</td>\n      <td>102615</td>\n      <td>0.00</td>\n      <td>92.30</td>\n      <td>92.30</td>\n      <td>127.33</td>\n      <td>92.39</td>\n      <td>2010</td>\n      <td>ELP</td>\n      <td>CRV</td>\n      <td>KA</td>\n    </tr>\n    <tr>\n      <th>480</th>\n      <td>485</td>\n      <td>R ELP CRV 2010 2WD KA</td>\n      <td>51299</td>\n      <td>0.00</td>\n      <td>75.27</td>\n      <td>75.27</td>\n      <td>119.83</td>\n      <td>74.27</td>\n      <td>2010</td>\n      <td>ELP</td>\n      <td>CRV</td>\n      <td>KA</td>\n    </tr>\n  </tbody>\n</table>\n</div>'},
#      'execution_count': 20}],
#    'source': 'gc_list.head()'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:08.835985',
#      'end_time': '2019-03-22T13:25:08.944148',
#      'duration': 0.108163,
#      'status': 'completed'}},
#    'source': '### DEPRECATED Create pivot table where ```graphcat description``` is rows and sum of ```CPU_DIFF_SubGroup_Level_x_SALES``` column:'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:09.049004',
#      'end_time': '2019-03-22T13:25:09.171545',
#      'duration': 0.122541,
#      'status': 'completed'}},
#    'source': 'Basically, this is our list of top total cost adjustments by GraphCat description.'},
#   {'cell_type': 'code',
#    'execution_count': 21,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:09.287702',
#      'end_time': '2019-03-22T13:25:09.416218',
#      'duration': 0.128516,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "#total_adj_gc_level = df.pivot_table(values=['CPU_DIFF_SubGroup_Level_x_SALES'], index=['GraphCatDesc_After'], \n                                    #aggfunc='sum').sort_values(by=['CPU_DIFF_SubGroup_Level_x_SALES'], ascending=False)"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:09.541232',
#      'end_time': '2019-03-22T13:25:09.667176',
#      'duration': 0.125944,
#      'status': 'completed'}},
#    'source': '### Create distinct list of GraphCats and their CPU at the GraphCat level'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:09.807815',
#      'end_time': '2019-03-22T13:25:09.923376',
#      'duration': 0.115561,
#      'status': 'completed'}},
#    'source': 'Basically, this is our list of top total cost adjustments by GraphCat description.'},
#   {'cell_type': 'code',
#    'execution_count': 22,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:10.014590',
#      'end_time': '2019-03-22T13:25:10.152623',
#      'duration': 0.138033,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "total_adj_gc_level = df[['GraphCatDesc_After', 'CPU_DIFF_GC_LEVEL_x_SALES']].drop_duplicates()"},
#   {'cell_type': 'code',
#    'execution_count': 23,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:10.262010',
#      'end_time': '2019-03-22T13:25:10.554306',
#      'duration': 0.292296,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '                    GraphCatDesc_After  CPU_DIFF_GC_LEVEL_x_SALES\n0              R HMI CIVIC 2010 4DR KA                   3,782.32\n120            R MAP Accord 2010 L4 KA                 101,435.40\n240            R MAP Accord 2010 V6 KA                       0.00\n360              R ELP CRV 2010 4WD KA                       0.00\n480              R ELP CRV 2010 2WD KA                       0.00\n600            R MAP Accord 2010 L4 KC                       0.00\n720            R MAP Accord 2010 V6 KC                       0.00\n840          R ELP Element 2010 2WD KA                       0.00\n960          R ELP Element 2010 2WD KC                       0.00\n1080         R ELP Element 2010 4WD KA                       0.00\n1200         R ELP Element 2010 4WD KC                       0.00\n1320       R ELP Crosstour 2010 2WD KA                       0.00\n1440       R ELP Crosstour 2010 2WD KC                       0.00\n1560       R ELP Crosstour 2010 4WD KA                       0.00\n1680       R ELP Crosstour 2010 4WD KC                       0.00\n1800              R MAP TL 2010 2WD KA                       0.00\n1920            R MAP TL 2010 SHAWD KA                       0.00\n2040              R MAP TL 2010 2WD KC                       0.00\n2160            R MAP TL 2010 SHAWD KC                       0.00\n2280             R MAP RDX 2010 2WD KA                       0.00\n2400             R MAP RDX 2010 4WD KA                       0.00\n2520             R MAP RDX 2010 4WD KC                       0.00\n2640             R ELP CRV 2010 2WD KC                       0.00\n2760             R ELP CRV 2010 4WD KC                       0.00\n2880             R MAP RDX 2011 2WD KA                  -4,750.02\n3000             R MAP RDX 2011 4WD KA                  -3,565.77\n3120             R MAP RDX 2011 4WD KC                  -4,500.00\n3240       R ELP Crosstour 2011 2WD KA                  -1,072.25\n3360       R ELP Crosstour 2011 2WD KC                       0.00\n3480       R ELP Crosstour 2011 4WD KA                  -2,486.70\n3600       R ELP Crosstour 2011 4WD KC                    -344.10\n3720             R ELP CRV 2011 2WD KA                   1,843.14\n3840             R ELP CRV 2011 4WD KA                  38,630.96\n3960             R ELP CRV 2011 2WD KC                   2,613.00\n4080             R ELP CRV 2011 4WD KC                  -4,425.60\n4200         R ELP Element 2011 2WD KA                    -331.20\n4320         R ELP Element 2011 4WD KA                   1,756.80\n4440         R ELP Element 2011 2WD KC                       0.00\n4560         R ELP Element 2011 4WD KC                       0.00\n4680           R MAP Accord 2011 L4 KA                  12,586.56\n4800           R MAP Accord 2011 V6 KA                  -7,925.94\n4920           R MAP Accord 2011 L4 KC                   1,069.20\n5040           R MAP Accord 2011 V6 KC                    -372.60\n5160              R MAP TL 2011 2WD KA                  -1,771.02\n5280             R HMA ODYSSEY 2011 KA                  -6,671.88\n5400            R MAP TL 2011 SHAWD KA                    -258.88\n5520              R MAP TL 2011 2WD KC                     -75.60\n5640            R MAP TL 2011 SHAWD KC                    -201.60\n5760           R HMI CIVIC 2011 4DR KA                  14,571.09\n5880           R MAP Accord 2012 L4 KA                  21,932.96\n6000           R MAP Accord 2012 V6 KA                  12,907.14\n6120           R MAP Accord 2012 L4 KC                     450.90\n6240           R MAP Accord 2012 V6 KC                     572.40\n6360           R MAP Accord 2012 L4 KY                   2,714.13\n6480           R MAP Accord 2012 V6 KY                     800.82\n6600             R ELP CRV 2012 2WD KA                  30,298.59\n6720             R ELP CRV 2012 2WD KC                   1,384.20\n6840             R ELP CRV 2012 4WD KA                  68,111.94\n6960             R ...
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>GraphCatDesc_After</th>\n      <th>CPU_DIFF_GC_LEVEL_x_SALES</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>3,782.32</td>\n    </tr>\n    <tr>\n      <th>120</th>\n      <td>R MAP Accord 2010 L4 KA</td>\n      <td>101,435.40</td>\n    </tr>\n    <tr>\n      <th>240</th>\n      <td>R MAP Accord 2010 V6 KA</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>360</th>\n      <td>R ELP CRV 2010 4WD KA</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>480</th>\n      <td>R ELP CRV 2010 2WD KA</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>600</th>\n      <td>R MAP Accord 2010 L4 KC</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>720</th>\n      <td>R MAP Accord 2010 V6 KC</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>840</th>\n      <td>R ELP Element 2010 2WD KA</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>960</th>\n      <td>R ELP Element 2010 2WD KC</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>1080</th>\n      <td>R ELP Element 2010 4WD KA</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>1200</th>\n      <td>R ELP Element 2010 4WD KC</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>1320</th>\n      <td>R ELP Crosstour 2010 2WD KA</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>1440</th>\n      <td>R ELP Crosstour 2010 2WD KC</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>1560</th>\n      <td>R ELP Crosstour 2010 4WD KA</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>1680</th>\n      <td>R ELP Crosstour 2010 4WD KC</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>1800</th>\n      <td>R MAP TL 2010 2WD KA</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>1920</th>\n      <td>R MAP TL 2010 SHAWD KA</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>2040</th>\n      <td>R MAP TL 2010 2WD KC</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>2160</th>\n      <td>R MAP TL 2010 SHAWD KC</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>2280</th>\n      <td>R MAP RDX 2010 2WD KA</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>2400</th>\n      <td>R MAP RDX 2010 4WD KA</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>2520</th>\n      <td>R MAP RDX 2010 4WD KC</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>2640</th>\n      <td>R ELP CRV 2010 2WD KC</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>2760</th>\n      <td>R ELP CRV 2010 4WD KC</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>2880</th>\n      <td>R MAP RDX 2011 2WD KA</td>\n      <td>-4,750.02</td>\n    </tr>\n    <tr>\n      <th>3000</th>\n      <td>R MAP RDX 2011 4WD KA</td>\n      <td>-3,565.77</td>\n    </tr>\n    <tr>\n      <th>3120</th>\n      <td>R MAP RDX 2011 4WD KC</td>\n      <td>-4,500.00</td>\n    </tr>\n    <tr>\n      <th>3240</th>\n      <td>R ELP Crosstour 2011 2WD KA</td>\n      <td>-1,072.25</td>\n    </tr>\n    <tr>\n      <th>3360</th>\n      <td>R ELP Crosstour 2011 2WD KC</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>3480</th>\n      <td>R ELP Crosstour 2011 4WD KA</td>\n      <td>-2,486.70</td>\n    </tr>\n    <tr>\n      <th>3600</th>\n      <td>R ELP Crosstour 2011 4WD KC</td>\n      <td>-344.10</td>\n    </tr>\n    <tr>\n      <th>3720</th>\n      <td>R ELP CRV 2011 2WD KA</td>\n      <td>1,843.14</td>\n    </tr>\n    <tr>\n      <th>3840</th>\n      <td>R ELP CRV 2011 4WD KA</td>\n      <td>38,630.96</td>\n    </tr>\n    <tr>\n      <th>3960</th>\n      <td>R ELP CRV 2011 2WD KC</td>\n      ...
#      'execution_count': 23}],
#    'source': 'total_adj_gc_level'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:10.679320',
#      'end_time': '2019-03-22T13:25:10.798043',
#      'duration': 0.118723,
#      'status': 'completed'}},
#    'source': '### Create list of CPU differences at the GraphCat level:'},
#   {'cell_type': 'code',
#    'execution_count': 24,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:10.923056',
#      'end_time': '2019-03-22T13:25:11.064123',
#      'duration': 0.141067,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "### DEPRECATED ###\n# cpu_diff_gc_level = df[['GraphCatDesc_After', 'Budgeted_CPU_GC_Level_After_Minus_Before']].drop_duplicates()"},
#   {'cell_type': 'code',
#    'execution_count': 25,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:11.190429',
#      'end_time': '2019-03-22T13:25:11.313148',
#      'duration': 0.122719,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': '# cpu_diff_gc_level'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:11.422533',
#      'end_time': '2019-03-22T13:25:11.546371',
#      'duration': 0.123838,
#      'status': 'completed'}},
#    'source': '### Create pivot table where GraphCat-SubGroup is the rows and sum the SubGroup level graphcat CPU adjustments:'},
#   {'cell_type': 'code',
#    'execution_count': 26,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:11.655757',
#      'end_time': '2019-03-22T13:25:11.920118',
#      'duration': 0.264361,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "pivot = df.pivot_table(values=['Budgeted_CPU_SubGroup_Level_After_Minus_Before'], index=['GraphCatDesc_After','Group-SubGroup_After'], aggfunc='sum')"},
#   {'cell_type': 'code',
#    'execution_count': 27,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:12.013878',
#      'end_time': '2019-03-22T13:25:12.363217',
#      'duration': 0.349339,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
# ...
#      'execution_count': 43}],
#    'source': 'top3_bottom3.head(6)'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:23.431218',
#      'end_time': '2019-03-22T13:25:23.577040',
#      'duration': 0.145822,
#      'status': 'completed'}},
#    'source': '### I want to now re-order columns'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:23.717680',
#      'end_time': '2019-03-22T13:25:23.890451',
#      'duration': 0.172771,
#      'status': 'completed'}},
#    'source': "#### Let's get print out of column names:"},
#   {'cell_type': 'code',
#    'execution_count': 44,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:24.031092',
#      'end_time': '2019-03-22T13:25:24.191115',
#      'duration': 0.160023,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "Index(['GraphCatDesc', 'Group-SubGroup', 'Total_CPU_Adj_at_SubGroup_Level',\n       'Total_Adjustment_Cost_Native', 'GraphCatID', 'Planned_Sales',\n       'Total_CPU_Adj_at_GraphCat_Level', 'Budgeted_CPU_GC_Level_After',\n       'Budgeted_CPU_GC_Level_Before', 'Orig_Saturation_CPU_GC_Level',\n       'Cum_Actual_CPU_GC_Level', 'ModelYear', 'Factory', 'ModelName',\n       'DestCodeCustom', 'ROW_NUM'],\n      dtype='object')"},
#      'execution_count': 44}],
#    'source': 'top3_bottom3.columns'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:24.331755',
#      'end_time': '2019-03-22T13:25:24.474951',
#      'duration': 0.143196,
#      'status': 'completed'}},
#    'source': '#### Now, re-order the column names:'},
#   {'cell_type': 'code',
#    'execution_count': 45,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:24.604282',
#      'end_time': '2019-03-22T13:25:24.757219',
#      'duration': 0.152937,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "top3_bottom3 = top3_bottom3[['GraphCatID',\n                             'GraphCatDesc',\n                             'ModelYear',\n                             'Factory',\n                             'ModelName',\n                             'DestCodeCustom',\n                             'Total_Adjustment_Cost_Native',\n                             'Total_CPU_Adj_at_GraphCat_Level',\n                             'Budgeted_CPU_GC_Level_After',\n                             'Budgeted_CPU_GC_Level_Before',\n                             'Group-SubGroup',\n                             'Total_CPU_Adj_at_SubGroup_Level',\n                             'ROW_NUM',\n                             'Planned_Sales',\n                             'Orig_Saturation_CPU_GC_Level',\n                             'Cum_Actual_CPU_GC_Level'\n                            ]]"},
#   {'cell_type': 'code',
#    'execution_count': 46,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:24.900324',
#      'end_time': '2019-03-22T13:25:25.097047',
#      'duration': 0.196723,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '      GraphCatID       GraphCatDesc ModelYear Factory ModelName  \\\n1560        1376  R HDM CRV 2014 KX      2014     HDM       CRV   \n1561        1376  R HDM CRV 2014 KX      2014     HDM       CRV   \n1562        1376  R HDM CRV 2014 KX      2014     HDM       CRV   \n1563        1376  R HDM CRV 2014 KX      2014     HDM       CRV   \n1564        1376  R HDM CRV 2014 KX      2014     HDM       CRV   \n1565        1376  R HDM CRV 2014 KX      2014     HDM       CRV   \n\n     DestCodeCustom  Total_Adjustment_Cost_Native  \\\n1560             KX                  4,966,219.58   \n1561             KX                          0.00   \n1562             KX                          0.00   \n1563             KX                          0.00   \n1564             KX                          0.00   \n1565             KX                          0.00   \n\n      Total_CPU_Adj_at_GraphCat_Level  Budgeted_CPU_GC_Level_After  \\\n1560                           172.66                       262.65   \n1561                             0.00                         0.00   \n1562                             0.00                         0.00   \n1563                             0.00                         0.00   \n1564                             0.00                         0.00   \n1565                             0.00                         0.00   \n\n      Budgeted_CPU_GC_Level_Before               Group-SubGroup  \\\n1560                         89.99    Chassis - Steering System   \n1561                          0.00           Engine - Oil Leaks   \n1562                          0.00              Denso - Battery   \n1563                          0.00  Chassis - Brake Pipes/hoses   \n1564                          0.00             Chassis - Clutch   \n1565                          0.00        Chassis - Engine Trim   \n\n      Total_CPU_Adj_at_SubGroup_Level  ROW_NUM  Planned_Sales  \\\n1560                            22.69        1          28763   \n1561                            14.22        2          28763   \n1562                            12.99        3          28763   \n1563                             0.00        4          28763   \n1564                             0.00        5          28763   \n1565                             0.00        6          28763   \n\n      Orig_Saturation_CPU_GC_Level  Cum_Actual_CPU_GC_Level  \n1560                        262.65                   239.90  \n1561                          0.00                     0.00  \n1562                          0.00                     0.00  \n1563                          0.00                     0.00  \n1564                          0.00                     0.00  \n1565                          0.00                     0.00  ',
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>GraphCatID</th>\n      <th>GraphCatDesc</th>\n      <th>ModelYear</th>\n      <th>Factory</th>\n      <th>ModelName</th>\n      <th>DestCodeCustom</th>\n      <th>Total_Adjustment_Cost_Native</th>\n      <th>Total_CPU_Adj_at_GraphCat_Level</th>\n      <th>Budgeted_CPU_GC_Level_After</th>\n      <th>Budgeted_CPU_GC_Level_Before</th>\n      <th>Group-SubGroup</th>\n      <th>Total_CPU_Adj_at_SubGroup_Level</th>\n      <th>ROW_NUM</th>\n      <th>Planned_Sales</th>\n      <th>Orig_Saturation_CPU_GC_Level</th>\n      <th>Cum_Actual_CPU_GC_Level</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>1560</th>\n      <td>1376</td>\n      <td>R HDM CRV 2014 KX</td>\n      <td>2014</td>\n      <td>HDM</td>\n      <td>CRV</td>\n      <td>KX</td>\n      <td>4,966,219.58</td>\n      <td>172.66</td>\n      <td>262.65</td>\n      <td>89.99</td>\n      <td>Chassis - Steering System</td>\n      <td>22.69</td>\n      <td>1</td>\n      <td>28763</td>\n      <td>262.65</td>\n      <td>239.90</td>\n    </tr>\n    <tr>\n      <th>1561</th>\n      <td>1376</td>\n      <td>R HDM CRV 2014 KX</td>\n      <td>2014</td>\n      <td>HDM</td>\n      <td>CRV</td>\n      <td>KX</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>Engine - Oil Leaks</td>\n      <td>14.22</td>\n      <td>2</td>\n      <td>28763</td>\n      <td>0.00</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>1562</th>\n      <td>1376</td>\n      <td>R HDM CRV 2014 KX</td>\n      <td>2014</td>\n      <td>HDM</td>\n      <td>CRV</td>\n      <td>KX</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>Denso - Battery</td>\n      <td>12.99</td>\n      <td>3</td>\n      <td>28763</td>\n      <td>0.00</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>1563</th>\n      <td>1376</td>\n      <td>R HDM CRV 2014 KX</td>\n      <td>2014</td>\n      <td>HDM</td>\n      <td>CRV</td>\n      <td>KX</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>Chassis - Brake Pipes/hoses</td>\n      <td>0.00</td>\n      <td>4</td>\n      <td>28763</td>\n      <td>0.00</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>1564</th>\n      <td>1376</td>\n      <td>R HDM CRV 2014 KX</td>\n      <td>2014</td>\n      <td>HDM</td>\n      <td>CRV</td>\n      <td>KX</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>Chassis - Clutch</td>\n      <td>0.00</td>\n      <td>5</td>\n      <td>28763</td>\n      <td>0.00</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>1565</th>\n      <td>1376</td>\n      <td>R HDM CRV 2014 KX</td>\n      <td>2014</td>\n      <td>HDM</td>\n      <td>CRV</td>\n      <td>KX</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>Chassis - Engine Trim</td>\n      <td>0.00</td>\n      <td>6</td>\n      <td>28763</td>\n      <td>0.00</td>\n      <td>0.00</td>\n    </tr>\n  </tbody>\n</table>\n</div>'},
#      'execution_count': 46}],
#    'source': 'top3_bottom3.head(6)'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:25.266999',
#      'end_time': '2019-03-22T13:25:25.449986',
#      'duration': 0.182987,
#      'status': 'completed'}},
#    'source': "### We're done!  Now we can export to Excel, to clipboard, etc"},
#   {'cell_type': 'code',
#    'execution_count': 47,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:25.612418',
#      'end_time': '2019-03-22T13:25:25.848547',
#      'duration': 0.236129,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "# top3_bottom3.to_excel(r'D:\\temp\\top3_bottom3.xlsx', index=False)"},
#   {'cell_type': 'code',
#    'execution_count': 48,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:25.994935',
#      'end_time': '2019-03-22T13:25:26.184941',
#      'duration': 0.190006,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "file_name = 'top3_bottom3_native.xlsx'"},
#   {'cell_type': 'code',
#    'execution_count': 49,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:26.320804',
#      'end_time': '2019-03-22T13:25:32.259722',
#      'duration': 5.938918,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'top3_bottom3.to_excel(save_dir / file_name, index=False)'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:32.337856',
#      'end_time': '2019-03-22T13:25:32.443206',
#      'duration': 0.10535,
#      'status': 'completed'}},
#    'source': '### If script made it this far, send out Windows 10 toast notification:'},
#   {'cell_type': 'code',
#    'execution_count': 50,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:32.536965',
#      'end_time': '2019-03-22T13:25:37.738705',
#      'duration': 5.20174,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': 'True'},
#      'execution_count': 50}],
#    'source': 'toaster = ToastNotifier()\ntoaster.show_toast("### Job Status ###",\n                   "Successfuly Summarized Red and Green Sheet Data to Native Currency",\n                   icon_path="images/honda_logo.ico",\n                   duration=5)'}],
#  'metadata': {'hide_input': False,
#   'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.7.0',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'parameters': {'start_year': 2010,
#     'end_year': 2019,
#     'CLA_MONTH': '201901'},
#    'environment_variables': {},
#    'version': '0.19.0',
#    'input_path': '3_Get_Top3_Bottom3_Group_SubGroup_Adjustments_Native_Currency.ipynb',
#    'output_path': 'output/RedAndGreenSheet_Summarized_Native.ipynb',
#    'start_time': '2019-03-22T13:24:21.109055',
#    'end_time': '2019-03-22T13:25:39.557006',
#    'duration': 78.447951,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 2}

# %% [markdown]
# ## 4) Execute jupyter notebook that summarizes the raw "Red and Green Sheet" data in US dollars:

# %%
# %%time
pm.execute_notebook(
    '4_Get_Top3_Bottom3_Group_SubGroup_Adjustments-USD.ipynb',
    'output/RedAndGreenSheet_Summarized_USD.ipynb',
    cwd='D:\\jupyter\\rvms\\production',
    parameters = dict(exchange_rate=exchange_rate,
                      start_year=start_year,
                      end_year=end_year,
                      CLA_MONTH=CLA_MONTH
                     )
)
# Out:
# HBox(children=(IntProgress(value=0, max=98), HTML(value='')))
# Wall time: 1min 26s
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:45.089569',
#      'end_time': '2019-03-22T13:25:45.255009',
#      'duration': 0.16544,
#      'status': 'completed'}},
#    'source': '# PURPOSE:'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:45.444513',
#      'end_time': '2019-03-22T13:25:45.577868',
#      'duration': 0.133355,
#      'status': 'completed'}},
#    'source': '### To obtain the top 3 and bottom 3 GraphCat adjustments in USD'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:45.702148',
#      'end_time': '2019-03-22T13:25:45.875036',
#      'duration': 0.172888,
#      'status': 'completed'}},
#    'source': '**Procedure:** User enters exchange rate, copy their graphcat data into "clipboard", and then execute all cells in this notebook'},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:46.077912',
#      'end_time': '2019-03-22T13:25:49.549410',
#      'duration': 3.471498,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "from pathlib import Path\nimport os\nimport pandas as pd\nimport numpy as np\nimport scrapbook as sb\nfrom win10toast import ToastNotifier\npd.options.display.max_rows=1000\npd.options.display.max_columns=100\npd.options.display.float_format = '{:20,.2f}'.format"},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:49.627541',
#      'end_time': '2019-03-22T13:25:49.743349',
#      'duration': 0.115808,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': '#exchange_rate = float(input("Enter exchange rate: "))'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:49.865108',
#      'end_time': '2019-03-22T13:25:49.958139',
#      'duration': 0.093031,
#      'status': 'completed'}},
#    'source': '### Parameters that will be used by the papermill library:'},
#   {'cell_type': 'code',
#    'execution_count': 3,
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:50.036274',
#      'end_time': '2019-03-22T13:25:50.147889',
#      'duration': 0.111615,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "exchange_rate = 0.7464\nstart_year = 2010\nend_year = 2019\nCLA_MONTH = '201901'"},
#   {'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:50.225040',
#      'end_time': '2019-03-22T13:25:50.360742',
#      'duration': 0.135702,
#      'status': 'completed'}},
#    'execution_count': 4,
#    'source': '# Parameters\nexchange_rate = 0.7464\nstart_year = 2010\nend_year = 2019\nCLA_MONTH = "201901"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'execution_count': 5,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:50.470129',
#      'end_time': '2019-03-22T13:25:50.636586',
#      'duration': 0.166457,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': '# df = pd.read_clipboard()'},
#   {'cell_type': 'code',
#    'execution_count': 6,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:50.751361',
#      'end_time': '2019-03-22T13:25:50.982698',
#      'duration': 0.231337,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "nb = sb.read_notebook('D:\\\\jupyter\\\\rvms\\\\production\\\\output\\\\RedAndGreenSheet.ipynb')"},
#   {'cell_type': 'code',
#    'execution_count': 7,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:51.092082',
#      'end_time': '2019-03-22T13:25:51.318957',
#      'duration': 0.226875,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'\\\\\\\\207.130.185.67\\\\aqgbudget2\\\\Cost\\\\Reserve Adjustments\\\\Reports\\\\Normal Reserve Balance Verification\\\\RVMS_Before_After_Checks\\\\201901\\\\All_Plants_Before_After_Budgeted_CPUs_2019-03-22_09_22.xlsx'"},
#      'execution_count': 7}],
#    'source': "nb.scraps['path_to_red_green_sheet_excel_file'].data"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:51.428344',
#      'end_time': '2019-03-22T13:25:51.506936',
#      'duration': 0.078592,
#      'status': 'completed'}},
#    'source': '### Define where to save the Red and Green raw data file based on CLA claim month:'},
#   {'cell_type': 'code',
#    'execution_count': 8,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:51.600696',
#      'end_time': '2019-03-22T13:25:51.753443',
#      'duration': 0.152747,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'base_dir = "//207.130.185.67/aqgbudget2/Cost/Reserve Adjustments/Reports/Normal Reserve Balance Verification/RVMS_Before_After_Checks"\np = Path(base_dir)\nsave_dir = p / CLA_MONTH\nif not os.path.exists(save_dir):\n    os.makedirs(save_dir)'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:51.847203',
#      'end_time': '2019-03-22T13:25:51.939267',
#      'duration': 0.092064,
#      'status': 'completed'}},
#    'source': '### Now retrieve the Excel file containing the raw "Red and Green Sheet" data:'},
#   {'cell_type': 'code',
#    'execution_count': 9,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:25:52.048651',
#      'end_time': '2019-03-22T13:26:26.368649',
#      'duration': 34.319998,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "df = pd.read_excel(nb.scraps['path_to_red_green_sheet_excel_file'].data)"},
#   {'cell_type': 'code',
#    'execution_count': 10,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:26.415467',
#      'end_time': '2019-03-22T13:26:26.484565',
#      'duration': 0.069098,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '(58680, 34)'},
#      'execution_count': 10}],
#    'source': 'df.shape'},
#   {'cell_type': 'code',
#    'execution_count': 11,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:26.526444',
#      'end_time': '2019-03-22T13:26:26.986786',
#      'duration': 0.460342,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '   GraphCatID_After       GraphCatDesc_After GRP_NM_After  \\\n0               449  R HMI CIVIC 2010 4DR KA      Chassis   \n1               449  R HMI CIVIC 2010 4DR KA      Chassis   \n2               449  R HMI CIVIC 2010 4DR KA      Chassis   \n3               449  R HMI CIVIC 2010 4DR KA      Chassis   \n4               449  R HMI CIVIC 2010 4DR KA      Chassis   \n\n            SUBGRP_NM_After  Budgeted_CPU_SubGroup_Level_After  \\\n0  Calipers/Disk/Drums/Pads                               0.83   \n1               Drive Shaft                              15.89   \n2         Hand/cable Brakes                               0.05   \n3           Master Cylinder                               0.05   \n4        Steering Vibration                               0.33   \n\n   Planned_Sales_RVMS_After  Budgeted_CPU_GC_Level_After  \\\n0                     94558                       102.01   \n1                     94558                       102.01   \n2                     94558                       102.01   \n3                     94558                       102.01   \n4                     94558                       102.01   \n\n   Orig_Saturation_CPU_GC_Level_After  Cum_Actual_CPU_GC_Level_After  \\\n0                              152.72                         101.69   \n1                              152.72                         101.69   \n2                              152.72                         101.69   \n3                              152.72                         101.69   \n4                              152.72                         101.69   \n\n   RVMS_Claim_Month_After  ModelYear_After Factory_After ModelName_After  \\\n0                  201901             2010           HMI           CIVIC   \n1                  201901             2010           HMI           CIVIC   \n2                  201901             2010           HMI           CIVIC   \n3                  201901             2010           HMI           CIVIC   \n4                  201901             2010           HMI           CIVIC   \n\n  DestCode_After                Group-SubGroup_After            ID_Before  \\\n0             KA  Chassis - Calipers/Disk/Drums/Pads           180,847.00   \n1             KA               Chassis - Drive Shaft           180,793.00   \n2             KA         Chassis - Hand/cable Brakes           180,832.00   \n3             KA           Chassis - Master Cylinder           180,790.00   \n4             KA        Chassis - Steering Vibration           180,853.00   \n\n     GraphCatID_Before      GraphCatDesc_Before GRP_NM_Before  \\\n0               449.00  R HMI CIVIC 2010 4DR KA       Chassis   \n1               449.00  R HMI CIVIC 2010 4DR KA       Chassis   \n2               449.00  R HMI CIVIC 2010 4DR KA       Chassis   \n3               449.00  R HMI CIVIC 2010 4DR KA       Chassis   \n4               449.00  R HMI CIVIC 2010 4DR KA       Chassis   \n\n           SUBGRP_NM_Before  Budgeted_CPU_SubGroup_Level_Before  \\\n0  Calipers/Disk/Drums/Pads                                0.83   \n1               Drive Shaft                               15.89   \n2         Hand/cable Brakes                                0.05   \n3           Master Cylinder                                0.05   \n4        Steering Vibration                                0.33   \n\n   Planned_Sales_RVMS_Before  Budgeted_CPU_GC_Level_Before  \\\n0                  94,558.00                        101.97   \n1                  94,558.00                        101.97   \n2                  94,558.00                        101.97   \n3                  94,558.00                        101.97   \n4                  94,558.00                        101.97   \n\n   Orig_Saturation_CPU_GC_Level_Before  Cum_Actual_CPU_GC_Level_Before  \\\n0                                  nan                             nan   \n1                                  nan                             nan   \n2                            ...
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>GraphCatID_After</th>\n      <th>GraphCatDesc_After</th>\n      <th>GRP_NM_After</th>\n      <th>SUBGRP_NM_After</th>\n      <th>Budgeted_CPU_SubGroup_Level_After</th>\n      <th>Planned_Sales_RVMS_After</th>\n      <th>Budgeted_CPU_GC_Level_After</th>\n      <th>Orig_Saturation_CPU_GC_Level_After</th>\n      <th>Cum_Actual_CPU_GC_Level_After</th>\n      <th>RVMS_Claim_Month_After</th>\n      <th>ModelYear_After</th>\n      <th>Factory_After</th>\n      <th>ModelName_After</th>\n      <th>DestCode_After</th>\n      <th>Group-SubGroup_After</th>\n      <th>ID_Before</th>\n      <th>GraphCatID_Before</th>\n      <th>GraphCatDesc_Before</th>\n      <th>GRP_NM_Before</th>\n      <th>SUBGRP_NM_Before</th>\n      <th>Budgeted_CPU_SubGroup_Level_Before</th>\n      <th>Planned_Sales_RVMS_Before</th>\n      <th>Budgeted_CPU_GC_Level_Before</th>\n      <th>Orig_Saturation_CPU_GC_Level_Before</th>\n      <th>Cum_Actual_CPU_GC_Level_Before</th>\n      <th>RVMS_Claim_Month_Before</th>\n      <th>ModelYear_Before</th>\n      <th>Factory_Before</th>\n      <th>ModelName_Before</th>\n      <th>DestCode_Before</th>\n      <th>Budgeted_CPU_SubGroup_Level_After_Minus_Before</th>\n      <th>Budgeted_CPU_GC_Level_After_Minus_Before</th>\n      <th>CPU_DIFF_SubGroup_Level_x_SALES</th>\n      <th>CPU_DIFF_GC_LEVEL_x_SALES</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Calipers/Disk/Drums/Pads</td>\n      <td>0.83</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Calipers/Disk/Drums/Pads</td>\n      <td>180,847.00</td>\n      <td>449.00</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Calipers/Disk/Drums/Pads</td>\n      <td>0.83</td>\n      <td>94,558.00</td>\n      <td>101.97</td>\n      <td>nan</td>\n      <td>nan</td>\n      <td>201,812.00</td>\n      <td>2,010.00</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>0.00</td>\n      <td>0.04</td>\n      <td>0.19</td>\n      <td>3,782.32</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Drive Shaft</td>\n      <td>15.89</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Drive Shaft</td>\n      <td>180,793.00</td>\n      <td>449.00</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Drive Shaft</td>\n      <td>15.89</td>\n      <td>94,558.00</td>\n      <td>101.97</td>\n      <td>nan</td>\n      <td>nan</td>\n      <td>201,812.00</td>\n      <td>2,010.00</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>0.00</td>\n      <td>0.04</td>\n      <td>28.01</td>\n      <td>3,782.32</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Hand/cable Brakes</td>\n      <td>0.05</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Hand/cable Brakes</td>\n      <td>180,832.00</td>\n      <td>449.00</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n ...
#      'execution_count': 11}],
#    'source': 'df.head()'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:27.033654',
#      'end_time': '2019-03-22T13:26:27.080507',
#      'duration': 0.046853,
#      'status': 'completed'}},
#    'source': '### But we need to limit our data to just the model years that are under RVMS adjustments:'},
#   {'cell_type': 'code',
#    'execution_count': 12,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:27.143315',
#      'end_time': '2019-03-22T13:26:27.243223',
#      'duration': 0.099908,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'rvms_years = list(range(start_year, end_year + 1))'},
#   {'cell_type': 'code',
#    'execution_count': 13,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:27.290101',
#      'end_time': '2019-03-22T13:26:27.532783',
#      'duration': 0.242682,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '[2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]'},
#      'execution_count': 13}],
#    'source': 'rvms_years'},
#   {'cell_type': 'code',
#    'execution_count': 14,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:27.610904',
#      'end_time': '2019-03-22T13:26:28.019855',
#      'duration': 0.408951,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'df = df.query("ModelYear_After in(@rvms_years)")'},
#   {'cell_type': 'code',
#    'execution_count': 15,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:28.066562',
#      'end_time': '2019-03-22T13:26:28.375419',
#      'duration': 0.308857,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '(58440, 34)'},
#      'execution_count': 15}],
#    'source': 'df.shape'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:28.437880',
#      'end_time': '2019-03-22T13:26:28.484784',
#      'duration': 0.046904,
#      'status': 'completed'}},
#    'source': '### Create exchange rate column:'},
#   {'cell_type': 'code',
#    'execution_count': 16,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:28.540510',
#      'end_time': '2019-03-22T13:26:28.703245',
#      'duration': 0.162735,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "df['Exchange_Rate'] = np.where(df['DestCode_After'] == 'KC', exchange_rate, 1)"},
#   {'cell_type': 'code',
#    'execution_count': 17,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:28.750136',
#      'end_time': '2019-03-22T13:26:29.090344',
#      'duration': 0.340208,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "Index(['GraphCatID_After', 'GraphCatDesc_After', 'GRP_NM_After',\n       'SUBGRP_NM_After', 'Budgeted_CPU_SubGroup_Level_After',\n       'Planned_Sales_RVMS_After', 'Budgeted_CPU_GC_Level_After',\n       'Orig_Saturation_CPU_GC_Level_After', 'Cum_Actual_CPU_GC_Level_After',\n       'RVMS_Claim_Month_After', 'ModelYear_After', 'Factory_After',\n       'ModelName_After', 'DestCode_After', 'Group-SubGroup_After',\n       'ID_Before', 'GraphCatID_Before', 'GraphCatDesc_Before',\n       'GRP_NM_Before', 'SUBGRP_NM_Before',\n       'Budgeted_CPU_SubGroup_Level_Before', 'Planned_Sales_RVMS_Before',\n       'Budgeted_CPU_GC_Level_Before', 'Orig_Saturation_CPU_GC_Level_Before',\n       'Cum_Actual_CPU_GC_Level_Before', 'RVMS_Claim_Month_Before',\n       'ModelYear_Before', 'Factory_Before', 'ModelName_Before',\n       'DestCode_Before', 'Budgeted_CPU_SubGroup_Level_After_Minus_Before',\n       'Budgeted_CPU_GC_Level_After_Minus_Before',\n       'CPU_DIFF_SubGroup_Level_x_SALES', 'CPU_DIFF_GC_LEVEL_x_SALES',\n       'Exchange_Rate'],\n      dtype='object')"},
#      'execution_count': 17}],
#    'source': 'df.columns'},
#   {'cell_type': 'code',
#    'execution_count': 18,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:29.137197',
#      'end_time': '2019-03-22T13:26:29.459130',
#      'duration': 0.321933,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '   GraphCatID_After       GraphCatDesc_After GRP_NM_After  \\\n0               449  R HMI CIVIC 2010 4DR KA      Chassis   \n1               449  R HMI CIVIC 2010 4DR KA      Chassis   \n2               449  R HMI CIVIC 2010 4DR KA      Chassis   \n3               449  R HMI CIVIC 2010 4DR KA      Chassis   \n4               449  R HMI CIVIC 2010 4DR KA      Chassis   \n5               449  R HMI CIVIC 2010 4DR KA      Chassis   \n6               449  R HMI CIVIC 2010 4DR KA      Chassis   \n7               449  R HMI CIVIC 2010 4DR KA        Denso   \n8               449  R HMI CIVIC 2010 4DR KA        Denso   \n9               449  R HMI CIVIC 2010 4DR KA        Denso   \n\n            SUBGRP_NM_After  Budgeted_CPU_SubGroup_Level_After  \\\n0  Calipers/Disk/Drums/Pads                               0.83   \n1               Drive Shaft                              15.89   \n2         Hand/cable Brakes                               0.05   \n3           Master Cylinder                               0.05   \n4        Steering Vibration                               0.33   \n5     Suspension Components                               0.63   \n6                    Wheels                               4.18   \n7                      Horn                               0.31   \n8              Power Outlet                               0.05   \n9                Relay/Fuse                               0.51   \n\n   Planned_Sales_RVMS_After  Budgeted_CPU_GC_Level_After  \\\n0                     94558                       102.01   \n1                     94558                       102.01   \n2                     94558                       102.01   \n3                     94558                       102.01   \n4                     94558                       102.01   \n5                     94558                       102.01   \n6                     94558                       102.01   \n7                     94558                       102.01   \n8                     94558                       102.01   \n9                     94558                       102.01   \n\n   Orig_Saturation_CPU_GC_Level_After  Cum_Actual_CPU_GC_Level_After  \\\n0                              152.72                         101.69   \n1                              152.72                         101.69   \n2                              152.72                         101.69   \n3                              152.72                         101.69   \n4                              152.72                         101.69   \n5                              152.72                         101.69   \n6                              152.72                         101.69   \n7                              152.72                         101.69   \n8                              152.72                         101.69   \n9                              152.72                         101.69   \n\n   RVMS_Claim_Month_After  ModelYear_After Factory_After ModelName_After  \\\n0                  201901             2010           HMI           CIVIC   \n1                  201901             2010           HMI           CIVIC   \n2                  201901             2010           HMI           CIVIC   \n3                  201901             2010           HMI           CIVIC   \n4                  201901             2010           HMI           CIVIC   \n5                  201901             2010           HMI           CIVIC   \n6                  201901             2010           HMI           CIVIC   \n7                  201901             2010           HMI           CIVIC   \n8                  201901             2010           HMI           CIVIC   \n9                  201901             2010           HMI           CIVIC   \n\n  DestCode_After                Group-SubGroup_After            ID_Before  \\\n0             KA  Chassis - Calipers/Disk/Drums/Pads           180,847.00   \n1             KA               Chassis - Drive Shaft        ...
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>GraphCatID_After</th>\n      <th>GraphCatDesc_After</th>\n      <th>GRP_NM_After</th>\n      <th>SUBGRP_NM_After</th>\n      <th>Budgeted_CPU_SubGroup_Level_After</th>\n      <th>Planned_Sales_RVMS_After</th>\n      <th>Budgeted_CPU_GC_Level_After</th>\n      <th>Orig_Saturation_CPU_GC_Level_After</th>\n      <th>Cum_Actual_CPU_GC_Level_After</th>\n      <th>RVMS_Claim_Month_After</th>\n      <th>ModelYear_After</th>\n      <th>Factory_After</th>\n      <th>ModelName_After</th>\n      <th>DestCode_After</th>\n      <th>Group-SubGroup_After</th>\n      <th>ID_Before</th>\n      <th>GraphCatID_Before</th>\n      <th>GraphCatDesc_Before</th>\n      <th>GRP_NM_Before</th>\n      <th>SUBGRP_NM_Before</th>\n      <th>Budgeted_CPU_SubGroup_Level_Before</th>\n      <th>Planned_Sales_RVMS_Before</th>\n      <th>Budgeted_CPU_GC_Level_Before</th>\n      <th>Orig_Saturation_CPU_GC_Level_Before</th>\n      <th>Cum_Actual_CPU_GC_Level_Before</th>\n      <th>RVMS_Claim_Month_Before</th>\n      <th>ModelYear_Before</th>\n      <th>Factory_Before</th>\n      <th>ModelName_Before</th>\n      <th>DestCode_Before</th>\n      <th>Budgeted_CPU_SubGroup_Level_After_Minus_Before</th>\n      <th>Budgeted_CPU_GC_Level_After_Minus_Before</th>\n      <th>CPU_DIFF_SubGroup_Level_x_SALES</th>\n      <th>CPU_DIFF_GC_LEVEL_x_SALES</th>\n      <th>Exchange_Rate</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Calipers/Disk/Drums/Pads</td>\n      <td>0.83</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Calipers/Disk/Drums/Pads</td>\n      <td>180,847.00</td>\n      <td>449.00</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Calipers/Disk/Drums/Pads</td>\n      <td>0.83</td>\n      <td>94,558.00</td>\n      <td>101.97</td>\n      <td>nan</td>\n      <td>nan</td>\n      <td>201,812.00</td>\n      <td>2,010.00</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>0.00</td>\n      <td>0.04</td>\n      <td>0.19</td>\n      <td>3,782.32</td>\n      <td>1.00</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Drive Shaft</td>\n      <td>15.89</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Drive Shaft</td>\n      <td>180,793.00</td>\n      <td>449.00</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Drive Shaft</td>\n      <td>15.89</td>\n      <td>94,558.00</td>\n      <td>101.97</td>\n      <td>nan</td>\n      <td>nan</td>\n      <td>201,812.00</td>\n      <td>2,010.00</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>0.00</td>\n      <td>0.04</td>\n      <td>28.01</td>\n      <td>3,782.32</td>\n      <td>1.00</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Hand/cable Brakes</td>\n      <td>0.05</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Hand/cable Brakes</td>\n      <td>180,832. ...
#      'execution_count': 18}],
#    'source': 'df.head(10)'},
#   {'cell_type': 'code',
#    'execution_count': 19,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:29.521609',
#      'end_time': '2019-03-22T13:26:29.730770',
#      'duration': 0.209161,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "# df.rename(columns={'CPU_DIFF_SubGroup_Level_x_SALES': 'Total_Adjustment_Cost_Native'}, inplace=True)"},
#   {'cell_type': 'code',
#    'execution_count': 20,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:29.793277',
#      'end_time': '2019-03-22T13:26:30.091749',
#      'duration': 0.298472,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "df.rename(columns={'CPU_DIFF_GC_LEVEL_x_SALES': 'Total_Adjustment_Cost_Native'}, inplace=True)"},
#   {'cell_type': 'code',
#    'execution_count': 21,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:30.154255',
#      'end_time': '2019-03-22T13:26:30.458153',
#      'duration': 0.303898,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '    GraphCatID_After       GraphCatDesc_After GRP_NM_After  \\\n0                449  R HMI CIVIC 2010 4DR KA      Chassis   \n1                449  R HMI CIVIC 2010 4DR KA      Chassis   \n2                449  R HMI CIVIC 2010 4DR KA      Chassis   \n3                449  R HMI CIVIC 2010 4DR KA      Chassis   \n4                449  R HMI CIVIC 2010 4DR KA      Chassis   \n5                449  R HMI CIVIC 2010 4DR KA      Chassis   \n6                449  R HMI CIVIC 2010 4DR KA      Chassis   \n7                449  R HMI CIVIC 2010 4DR KA        Denso   \n8                449  R HMI CIVIC 2010 4DR KA        Denso   \n9                449  R HMI CIVIC 2010 4DR KA        Denso   \n10               449  R HMI CIVIC 2010 4DR KA       Engine   \n11               449  R HMI CIVIC 2010 4DR KA       Engine   \n\n             SUBGRP_NM_After  Budgeted_CPU_SubGroup_Level_After  \\\n0   Calipers/Disk/Drums/Pads                               0.83   \n1                Drive Shaft                              15.89   \n2          Hand/cable Brakes                               0.05   \n3            Master Cylinder                               0.05   \n4         Steering Vibration                               0.33   \n5      Suspension Components                               0.63   \n6                     Wheels                               4.18   \n7                       Horn                               0.31   \n8               Power Outlet                               0.05   \n9                 Relay/Fuse                               0.51   \n10             Engine Wiring                               0.11   \n11                      HVAC                               2.61   \n\n    Planned_Sales_RVMS_After  Budgeted_CPU_GC_Level_After  \\\n0                      94558                       102.01   \n1                      94558                       102.01   \n2                      94558                       102.01   \n3                      94558                       102.01   \n4                      94558                       102.01   \n5                      94558                       102.01   \n6                      94558                       102.01   \n7                      94558                       102.01   \n8                      94558                       102.01   \n9                      94558                       102.01   \n10                     94558                       102.01   \n11                     94558                       102.01   \n\n    Orig_Saturation_CPU_GC_Level_After  Cum_Actual_CPU_GC_Level_After  \\\n0                               152.72                         101.69   \n1                               152.72                         101.69   \n2                               152.72                         101.69   \n3                               152.72                         101.69   \n4                               152.72                         101.69   \n5                               152.72                         101.69   \n6                               152.72                         101.69   \n7                               152.72                         101.69   \n8                               152.72                         101.69   \n9                               152.72                         101.69   \n10                              152.72                         101.69   \n11                              152.72                         101.69   \n\n    RVMS_Claim_Month_After  ModelYear_After Factory_After ModelName_After  \\\n0                   201901             2010           HMI           CIVIC   \n1                   201901             2010           HMI           CIVIC   \n2                   201901             2010           HMI           CIVIC   \n3                   201901             2010           HMI           CIVIC   \n4                   201901             2010           HMI           CIVIC   \n5                   ...
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>GraphCatID_After</th>\n      <th>GraphCatDesc_After</th>\n      <th>GRP_NM_After</th>\n      <th>SUBGRP_NM_After</th>\n      <th>Budgeted_CPU_SubGroup_Level_After</th>\n      <th>Planned_Sales_RVMS_After</th>\n      <th>Budgeted_CPU_GC_Level_After</th>\n      <th>Orig_Saturation_CPU_GC_Level_After</th>\n      <th>Cum_Actual_CPU_GC_Level_After</th>\n      <th>RVMS_Claim_Month_After</th>\n      <th>ModelYear_After</th>\n      <th>Factory_After</th>\n      <th>ModelName_After</th>\n      <th>DestCode_After</th>\n      <th>Group-SubGroup_After</th>\n      <th>ID_Before</th>\n      <th>GraphCatID_Before</th>\n      <th>GraphCatDesc_Before</th>\n      <th>GRP_NM_Before</th>\n      <th>SUBGRP_NM_Before</th>\n      <th>Budgeted_CPU_SubGroup_Level_Before</th>\n      <th>Planned_Sales_RVMS_Before</th>\n      <th>Budgeted_CPU_GC_Level_Before</th>\n      <th>Orig_Saturation_CPU_GC_Level_Before</th>\n      <th>Cum_Actual_CPU_GC_Level_Before</th>\n      <th>RVMS_Claim_Month_Before</th>\n      <th>ModelYear_Before</th>\n      <th>Factory_Before</th>\n      <th>ModelName_Before</th>\n      <th>DestCode_Before</th>\n      <th>Budgeted_CPU_SubGroup_Level_After_Minus_Before</th>\n      <th>Budgeted_CPU_GC_Level_After_Minus_Before</th>\n      <th>CPU_DIFF_SubGroup_Level_x_SALES</th>\n      <th>Total_Adjustment_Cost_Native</th>\n      <th>Exchange_Rate</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Calipers/Disk/Drums/Pads</td>\n      <td>0.83</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Calipers/Disk/Drums/Pads</td>\n      <td>180,847.00</td>\n      <td>449.00</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Calipers/Disk/Drums/Pads</td>\n      <td>0.83</td>\n      <td>94,558.00</td>\n      <td>101.97</td>\n      <td>nan</td>\n      <td>nan</td>\n      <td>201,812.00</td>\n      <td>2,010.00</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>0.00</td>\n      <td>0.04</td>\n      <td>0.19</td>\n      <td>3,782.32</td>\n      <td>1.00</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Drive Shaft</td>\n      <td>15.89</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Drive Shaft</td>\n      <td>180,793.00</td>\n      <td>449.00</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Drive Shaft</td>\n      <td>15.89</td>\n      <td>94,558.00</td>\n      <td>101.97</td>\n      <td>nan</td>\n      <td>nan</td>\n      <td>201,812.00</td>\n      <td>2,010.00</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>0.00</td>\n      <td>0.04</td>\n      <td>28.01</td>\n      <td>3,782.32</td>\n      <td>1.00</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Hand/cable Brakes</td>\n      <td>0.05</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Hand/cable Brakes</td>\n      <td>180,8 ...
#      'execution_count': 21}],
#    'source': 'df.head(12)'},
#   {'cell_type': 'code',
#    'execution_count': 22,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:30.520658',
#      'end_time': '2019-03-22T13:26:30.698699',
#      'duration': 0.178041,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "df['Total_Adjustment_Cost_USD'] = df['Total_Adjustment_Cost_Native'] * df['Exchange_Rate']\ndf['Budgeted_CPU_GC_Level_After_Minus_Before_USD'] = df['Budgeted_CPU_GC_Level_After_Minus_Before'] * df['Exchange_Rate']\ndf['Budgeted_CPU_SubGroup_Level_After_Minus_Before_USD'] = df['Budgeted_CPU_SubGroup_Level_After_Minus_Before'] * df['Exchange_Rate']\ndf['Budgeted_CPU_GC_Level_After_USD'] = df['Budgeted_CPU_GC_Level_After'] * df['Exchange_Rate']\ndf['Orig_Saturation_CPU_GC_Level_After_USD'] = df['Orig_Saturation_CPU_GC_Level_After'] * df['Exchange_Rate']\ndf['Cum_Actual_CPU_GC_Level_After_USD'] = df['Cum_Actual_CPU_GC_Level_After'] * df['Exchange_Rate']\ndf['Budgeted_CPU_GC_Level_Before_USD'] = df['Budgeted_CPU_GC_Level_Before'] * df['Exchange_Rate']"},
#   {'cell_type': 'code',
#    'execution_count': 23,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:30.792426',
#      'end_time': '2019-03-22T13:26:31.152763',
#      'duration': 0.360337,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '    GraphCatID_After       GraphCatDesc_After GRP_NM_After  \\\n0                449  R HMI CIVIC 2010 4DR KA      Chassis   \n1                449  R HMI CIVIC 2010 4DR KA      Chassis   \n2                449  R HMI CIVIC 2010 4DR KA      Chassis   \n3                449  R HMI CIVIC 2010 4DR KA      Chassis   \n4                449  R HMI CIVIC 2010 4DR KA      Chassis   \n5                449  R HMI CIVIC 2010 4DR KA      Chassis   \n6                449  R HMI CIVIC 2010 4DR KA      Chassis   \n7                449  R HMI CIVIC 2010 4DR KA        Denso   \n8                449  R HMI CIVIC 2010 4DR KA        Denso   \n9                449  R HMI CIVIC 2010 4DR KA        Denso   \n10               449  R HMI CIVIC 2010 4DR KA       Engine   \n11               449  R HMI CIVIC 2010 4DR KA       Engine   \n\n             SUBGRP_NM_After  Budgeted_CPU_SubGroup_Level_After  \\\n0   Calipers/Disk/Drums/Pads                               0.83   \n1                Drive Shaft                              15.89   \n2          Hand/cable Brakes                               0.05   \n3            Master Cylinder                               0.05   \n4         Steering Vibration                               0.33   \n5      Suspension Components                               0.63   \n6                     Wheels                               4.18   \n7                       Horn                               0.31   \n8               Power Outlet                               0.05   \n9                 Relay/Fuse                               0.51   \n10             Engine Wiring                               0.11   \n11                      HVAC                               2.61   \n\n    Planned_Sales_RVMS_After  Budgeted_CPU_GC_Level_After  \\\n0                      94558                       102.01   \n1                      94558                       102.01   \n2                      94558                       102.01   \n3                      94558                       102.01   \n4                      94558                       102.01   \n5                      94558                       102.01   \n6                      94558                       102.01   \n7                      94558                       102.01   \n8                      94558                       102.01   \n9                      94558                       102.01   \n10                     94558                       102.01   \n11                     94558                       102.01   \n\n    Orig_Saturation_CPU_GC_Level_After  Cum_Actual_CPU_GC_Level_After  \\\n0                               152.72                         101.69   \n1                               152.72                         101.69   \n2                               152.72                         101.69   \n3                               152.72                         101.69   \n4                               152.72                         101.69   \n5                               152.72                         101.69   \n6                               152.72                         101.69   \n7                               152.72                         101.69   \n8                               152.72                         101.69   \n9                               152.72                         101.69   \n10                              152.72                         101.69   \n11                              152.72                         101.69   \n\n    RVMS_Claim_Month_After  ModelYear_After Factory_After ModelName_After  \\\n0                   201901             2010           HMI           CIVIC   \n1                   201901             2010           HMI           CIVIC   \n2                   201901             2010           HMI           CIVIC   \n3                   201901             2010           HMI           CIVIC   \n4                   201901             2010           HMI           CIVIC   \n5                   ...
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>GraphCatID_After</th>\n      <th>GraphCatDesc_After</th>\n      <th>GRP_NM_After</th>\n      <th>SUBGRP_NM_After</th>\n      <th>Budgeted_CPU_SubGroup_Level_After</th>\n      <th>Planned_Sales_RVMS_After</th>\n      <th>Budgeted_CPU_GC_Level_After</th>\n      <th>Orig_Saturation_CPU_GC_Level_After</th>\n      <th>Cum_Actual_CPU_GC_Level_After</th>\n      <th>RVMS_Claim_Month_After</th>\n      <th>ModelYear_After</th>\n      <th>Factory_After</th>\n      <th>ModelName_After</th>\n      <th>DestCode_After</th>\n      <th>Group-SubGroup_After</th>\n      <th>ID_Before</th>\n      <th>GraphCatID_Before</th>\n      <th>GraphCatDesc_Before</th>\n      <th>GRP_NM_Before</th>\n      <th>SUBGRP_NM_Before</th>\n      <th>Budgeted_CPU_SubGroup_Level_Before</th>\n      <th>Planned_Sales_RVMS_Before</th>\n      <th>Budgeted_CPU_GC_Level_Before</th>\n      <th>Orig_Saturation_CPU_GC_Level_Before</th>\n      <th>Cum_Actual_CPU_GC_Level_Before</th>\n      <th>RVMS_Claim_Month_Before</th>\n      <th>ModelYear_Before</th>\n      <th>Factory_Before</th>\n      <th>ModelName_Before</th>\n      <th>DestCode_Before</th>\n      <th>Budgeted_CPU_SubGroup_Level_After_Minus_Before</th>\n      <th>Budgeted_CPU_GC_Level_After_Minus_Before</th>\n      <th>CPU_DIFF_SubGroup_Level_x_SALES</th>\n      <th>Total_Adjustment_Cost_Native</th>\n      <th>Exchange_Rate</th>\n      <th>Total_Adjustment_Cost_USD</th>\n      <th>Budgeted_CPU_GC_Level_After_Minus_Before_USD</th>\n      <th>Budgeted_CPU_SubGroup_Level_After_Minus_Before_USD</th>\n      <th>Budgeted_CPU_GC_Level_After_USD</th>\n      <th>Orig_Saturation_CPU_GC_Level_After_USD</th>\n      <th>Cum_Actual_CPU_GC_Level_After_USD</th>\n      <th>Budgeted_CPU_GC_Level_Before_USD</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Calipers/Disk/Drums/Pads</td>\n      <td>0.83</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Calipers/Disk/Drums/Pads</td>\n      <td>180,847.00</td>\n      <td>449.00</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Calipers/Disk/Drums/Pads</td>\n      <td>0.83</td>\n      <td>94,558.00</td>\n      <td>101.97</td>\n      <td>nan</td>\n      <td>nan</td>\n      <td>201,812.00</td>\n      <td>2,010.00</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>0.00</td>\n      <td>0.04</td>\n      <td>0.19</td>\n      <td>3,782.32</td>\n      <td>1.00</td>\n      <td>3,782.32</td>\n      <td>0.04</td>\n      <td>0.00</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>101.97</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>449</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Drive Shaft</td>\n      <td>15.89</td>\n      <td>94558</td>\n      <td>102.01</td>\n      <td>152.72</td>\n      <td>101.69</td>\n      <td>201901</td>\n      <td>2010</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>Chassis - Drive Shaft</td>\n      <td>180,793.00</td>\n      <td>449.00</td>\n      <td>R HMI CIVIC 2010 4DR KA</td>\n      <td>Chassis</td>\n      <td>Drive Shaft</td>\n      <td>15.89</td>\n      <td>94,558.00</td>\n      <td>101.97</td>\n      <td>nan</td>\n      <td>nan</td>\n      <td>201,812.00</td>\n      <td>2,010.00</td>\n      <td>HMI</td>\n      <td>CIVIC</td>\n      <td>KA</td>\n      <td>0. ...
#      'execution_count': 23}],
#    'source': 'df.head(12)'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:31.230896',
#      'end_time': '2019-03-22T13:26:31.322292',
#      'duration': 0.091396,
#      'status': 'completed'}},
#    'source': '### Create unique list of GraphCat descriptions:'},
#   {'cell_type': 'code',
#    'execution_count': 24,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:31.413624',
#      'end_time': '2019-03-22T13:26:31.485812',
#      'duration': 0.072188,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "### DEPRECATED ###\n# gc_list = df[['GraphCatID_After','GraphCatDesc_After', 'Planned_Sales_RVMS_After']].drop_duplicates()"},
#   {'cell_type': 'code',
#    'execution_count': 25,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:31.533348',
#      'end_time': '2019-03-22T13:26:31.932142',
#      'duration': 0.398794,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "gc_list = df[['GraphCatID_After','GraphCatDesc_After', 'Planned_Sales_RVMS_After','Budgeted_CPU_GC_Level_After_Minus_Before_USD',\n              'Budgeted_CPU_GC_Level_After_USD', 'Budgeted_CPU_GC_Level_Before_USD',\n              'Orig_Saturation_CPU_GC_Level_After_USD', 'Cum_Actual_CPU_GC_Level_After_USD']].drop_duplicates()"},
#   {'cell_type': 'code',
#    'execution_count': 26,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:31.979049',
#      'end_time': '2019-03-22T13:26:32.239995',
#      'duration': 0.260946,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
# ...
#      'execution_count': 54}],
#    'source': 'top3_bottom3.head()'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:50.018491',
#      'end_time': '2019-03-22T13:26:50.165481',
#      'duration': 0.14699,
#      'status': 'completed'}},
#    'source': '### I want to now re-order columns'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:50.321748',
#      'end_time': '2019-03-22T13:26:50.528193',
#      'duration': 0.206445,
#      'status': 'completed'}},
#    'source': "#### Let's get print out of column names:"},
#   {'cell_type': 'code',
#    'execution_count': 55,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:50.715714',
#      'end_time': '2019-03-22T13:26:50.906957',
#      'duration': 0.191243,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "Index(['GraphCatDesc', 'Group-SubGroup', 'Total_CPU_Adj_at_SubGroup_Level_USD',\n       'Total_Adjustment_Cost_USD', 'GraphCatID', 'Planned_Sales',\n       'Total_CPU_Adj_at_GraphCat_Level_USD',\n       'Budgeted_CPU_GC_Level_After_USD', 'Budgeted_CPU_GC_Level_Before_USD',\n       'Orig_Saturation_CPU_GC_Level_USD', 'Cum_Actual_CPU_GC_Level_USD',\n       'ModelYear', 'Factory', 'ModelName', 'DestCodeCustom', 'ROW_NUM'],\n      dtype='object')"},
#      'execution_count': 55}],
#    'source': 'top3_bottom3.columns'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:51.078851',
#      'end_time': '2019-03-22T13:26:51.243421',
#      'duration': 0.16457,
#      'status': 'completed'}},
#    'source': '#### Now, re-order the column names:'},
#   {'cell_type': 'code',
#    'execution_count': 56,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:51.430941',
#      'end_time': '2019-03-22T13:26:51.624968',
#      'duration': 0.194027,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "top3_bottom3 = top3_bottom3[['GraphCatID',\n                             'GraphCatDesc',\n                             'ModelYear',\n                             'Factory',\n                             'ModelName',\n                             'DestCodeCustom',\n                             'Total_Adjustment_Cost_USD',\n                             'Total_CPU_Adj_at_GraphCat_Level_USD',\n                             'Budgeted_CPU_GC_Level_After_USD',\n                             'Budgeted_CPU_GC_Level_Before_USD',\n                             'Group-SubGroup',\n                             'Total_CPU_Adj_at_SubGroup_Level_USD',\n                             'ROW_NUM',\n                             'Planned_Sales',\n                             'Orig_Saturation_CPU_GC_Level_USD',\n                             'Cum_Actual_CPU_GC_Level_USD'\n                            ]]"},
#   {'cell_type': 'code',
#    'execution_count': 57,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:51.781236',
#      'end_time': '2019-03-22T13:26:52.021837',
#      'duration': 0.240601,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '      GraphCatID             GraphCatDesc ModelYear Factory ModelName  \\\n1560        1376        R HDM CRV 2014 KX      2014     HDM       CRV   \n1561        1376        R HDM CRV 2014 KX      2014     HDM       CRV   \n1562        1376        R HDM CRV 2014 KX      2014     HDM       CRV   \n1563        1376        R HDM CRV 2014 KX      2014     HDM       CRV   \n1564        1376        R HDM CRV 2014 KX      2014     HDM       CRV   \n1565        1376        R HDM CRV 2014 KX      2014     HDM       CRV   \n1134        1429  R HMA PILOT 2016 6AT KA      2016     HMA     PILOT   \n1135        1429  R HMA PILOT 2016 6AT KA      2016     HMA     PILOT   \n1136        1429  R HMA PILOT 2016 6AT KA      2016     HMA     PILOT   \n1137        1429  R HMA PILOT 2016 6AT KA      2016     HMA     PILOT   \n1138        1429  R HMA PILOT 2016 6AT KA      2016     HMA     PILOT   \n1139        1429  R HMA PILOT 2016 6AT KA      2016     HMA     PILOT   \n\n     DestCodeCustom  Total_Adjustment_Cost_USD  \\\n1560             KX               4,966,219.58   \n1561             KX                       0.00   \n1562             KX                       0.00   \n1563             KX                       0.00   \n1564             KX                       0.00   \n1565             KX                       0.00   \n1134             KA               4,862,961.01   \n1135             KA                       0.00   \n1136             KA                       0.00   \n1137             KA                       0.00   \n1138             KA                       0.00   \n1139             KA                       0.00   \n\n      Total_CPU_Adj_at_GraphCat_Level_USD  Budgeted_CPU_GC_Level_After_USD  \\\n1560                               172.66                           262.65   \n1561                                 0.00                             0.00   \n1562                                 0.00                             0.00   \n1563                                 0.00                             0.00   \n1564                                 0.00                             0.00   \n1565                                 0.00                             0.00   \n1134                                33.83                           320.58   \n1135                                 0.00                             0.00   \n1136                                 0.00                             0.00   \n1137                                 0.00                             0.00   \n1138                                 0.00                             0.00   \n1139                                 0.00                             0.00   \n\n      Budgeted_CPU_GC_Level_Before_USD               Group-SubGroup  \\\n1560                             89.99    Chassis - Steering System   \n1561                              0.00           Engine - Oil Leaks   \n1562                              0.00              Denso - Battery   \n1563                              0.00  Chassis - Brake Pipes/hoses   \n1564                              0.00             Chassis - Clutch   \n1565                              0.00        Chassis - Engine Trim   \n1134                            286.75         Engine - Fuel System   \n1135                              0.00            OBD - ECU/PCM/TCM   \n1136                              0.00               OBD - Missfire   \n1137                              0.00              OBD - O2 Sensor   \n1138                              0.00                 OBD - MIL On   \n1139                              0.00              OBD - Fuel Pump   \n\n      Total_CPU_Adj_at_SubGroup_Level_USD  ROW_NUM  Planned_Sales  \\\n1560                                22.69        1          28763   \n1561                                14.22        2          28763   \n1562                                12.99        3          28763   \n1563                                 0.00        4          28763   \n1564                 ...
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>GraphCatID</th>\n      <th>GraphCatDesc</th>\n      <th>ModelYear</th>\n      <th>Factory</th>\n      <th>ModelName</th>\n      <th>DestCodeCustom</th>\n      <th>Total_Adjustment_Cost_USD</th>\n      <th>Total_CPU_Adj_at_GraphCat_Level_USD</th>\n      <th>Budgeted_CPU_GC_Level_After_USD</th>\n      <th>Budgeted_CPU_GC_Level_Before_USD</th>\n      <th>Group-SubGroup</th>\n      <th>Total_CPU_Adj_at_SubGroup_Level_USD</th>\n      <th>ROW_NUM</th>\n      <th>Planned_Sales</th>\n      <th>Orig_Saturation_CPU_GC_Level_USD</th>\n      <th>Cum_Actual_CPU_GC_Level_USD</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>1560</th>\n      <td>1376</td>\n      <td>R HDM CRV 2014 KX</td>\n      <td>2014</td>\n      <td>HDM</td>\n      <td>CRV</td>\n      <td>KX</td>\n      <td>4,966,219.58</td>\n      <td>172.66</td>\n      <td>262.65</td>\n      <td>89.99</td>\n      <td>Chassis - Steering System</td>\n      <td>22.69</td>\n      <td>1</td>\n      <td>28763</td>\n      <td>262.65</td>\n      <td>239.90</td>\n    </tr>\n    <tr>\n      <th>1561</th>\n      <td>1376</td>\n      <td>R HDM CRV 2014 KX</td>\n      <td>2014</td>\n      <td>HDM</td>\n      <td>CRV</td>\n      <td>KX</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>Engine - Oil Leaks</td>\n      <td>14.22</td>\n      <td>2</td>\n      <td>28763</td>\n      <td>0.00</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>1562</th>\n      <td>1376</td>\n      <td>R HDM CRV 2014 KX</td>\n      <td>2014</td>\n      <td>HDM</td>\n      <td>CRV</td>\n      <td>KX</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>Denso - Battery</td>\n      <td>12.99</td>\n      <td>3</td>\n      <td>28763</td>\n      <td>0.00</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>1563</th>\n      <td>1376</td>\n      <td>R HDM CRV 2014 KX</td>\n      <td>2014</td>\n      <td>HDM</td>\n      <td>CRV</td>\n      <td>KX</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>Chassis - Brake Pipes/hoses</td>\n      <td>0.00</td>\n      <td>4</td>\n      <td>28763</td>\n      <td>0.00</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>1564</th>\n      <td>1376</td>\n      <td>R HDM CRV 2014 KX</td>\n      <td>2014</td>\n      <td>HDM</td>\n      <td>CRV</td>\n      <td>KX</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>Chassis - Clutch</td>\n      <td>0.00</td>\n      <td>5</td>\n      <td>28763</td>\n      <td>0.00</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>1565</th>\n      <td>1376</td>\n      <td>R HDM CRV 2014 KX</td>\n      <td>2014</td>\n      <td>HDM</td>\n      <td>CRV</td>\n      <td>KX</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>Chassis - Engine Trim</td>\n      <td>0.00</td>\n      <td>6</td>\n      <td>28763</td>\n      <td>0.00</td>\n      <td>0.00</td>\n    </tr>\n    <tr>\n      <th>1134</th>\n      <td>1429</td>\n      <td>R HMA PILOT 2016 6AT KA</td>\n      <td>2016</td>\n      <td>HMA</td>\n      <td>PILOT</td>\n      <td>KA</td>\n      <td>4,862,961.01</td>\n      <td>33.83</td>\n      <td>320.58</td>\n      <td>286.75</td>\n      <td>Engine - Fuel System</td>\n      <td>54.38</td>\n      <td>1</td>\n      <td>143747</td>\n      <td>206.20</td>\n      <td>239.66</td>\n    </tr>\n    <tr>\n      <th>1135</th>\n      <td>1429</td>\n      <td>R HMA PILOT 2016 6AT KA</td>\n      <td>2016</td>\n      <td>HMA</td>\n      <td>PILOT</td>\ ...
#      'execution_count': 57}],
#    'source': 'top3_bottom3.head(12)'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:52.178104',
#      'end_time': '2019-03-22T13:26:52.340445',
#      'duration': 0.162341,
#      'status': 'completed'}},
#    'source': "### We're done!  Now we can export to Excel, to clipboard, etc"},
#   {'cell_type': 'code',
#    'execution_count': 58,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:52.542177',
#      'end_time': '2019-03-22T13:26:52.721089',
#      'duration': 0.178912,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "# top3_bottom3.to_excel(r'D:\\temp\\top3_bottom3_USD.xlsx', index=False)"},
#   {'cell_type': 'code',
#    'execution_count': 59,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:52.901726',
#      'end_time': '2019-03-22T13:26:53.090075',
#      'duration': 0.188349,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "file_name = 'top3_bottom3_USD.xlsx'"},
#   {'cell_type': 'code',
#    'execution_count': 60,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:53.276200',
#      'end_time': '2019-03-22T13:26:58.704705',
#      'duration': 5.428505,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'top3_bottom3.to_excel(save_dir / file_name, index=False)'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:58.829718',
#      'end_time': '2019-03-22T13:26:59.060519',
#      'duration': 0.230801,
#      'status': 'completed'}},
#    'source': '### If script made it this far, send out Windows 10 toast notification:'},
#   {'cell_type': 'code',
#    'execution_count': 61,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-03-22T13:26:59.232410',
#      'end_time': '2019-03-22T13:27:04.476194',
#      'duration': 5.243784,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': 'True'},
#      'execution_count': 61}],
#    'source': 'toaster = ToastNotifier()\ntoaster.show_toast("### Job Status ###",\n                   "Successfuly Summarized Red and Green Sheet Data in USD",\n                   icon_path="images/honda_logo.ico",\n                   duration=5)'}],
#  'metadata': {'hide_input': False,
#   'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.7.0',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'parameters': {'exchange_rate': 0.7464,
#     'start_year': 2010,
#     'end_year': 2019,
#     'CLA_MONTH': '201901'},
#    'environment_variables': {},
#    'version': '0.19.0',
#    'input_path': '4_Get_Top3_Bottom3_Group_SubGroup_Adjustments-USD.ipynb',
#    'output_path': 'output/RedAndGreenSheet_Summarized_USD.ipynb',
#    'start_time': '2019-03-22T13:25:40.413137',
#    'end_time': '2019-03-22T13:27:06.266205',
#    'duration': 85.853068,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 2}

# %%
elapsed_time = time.time() - start_time

# elapsed_time is in seconds, but want to define seconds as hour, minute, and seconds
m, s = divmod(elapsed_time, 60)
h, m = divmod(m, 60)
f"{h:1.0f}:{m:1.0f}:{s:.2f}"
# Out:
# '0:11:22.55'

# %% [markdown]
# ### If the script made it this far, then the scripts successfully executed without errors.  Then send Windows 10 toast notification.

# %%
toaster = ToastNotifier()
toaster.show_toast("Papermill Orchestration Status",
                   "Successfully executed all ETL scripts",
                   icon_path="images/honda_logo.ico",
                   duration=5)
# Out:
# True
