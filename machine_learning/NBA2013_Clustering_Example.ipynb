# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
nba = pd.read_csv('/home/pybokeh/Dropbox/python/jupyter_notebooks/machine_learning/nba_2013.csv')

# %%
nba.head()
# Out:
#           player pos  age bref_team_id   g  gs    mp   fg   fga    fg.  \
# 0     Quincy Acy  SF   23          TOT  63   0   847   66   141  0.468
# 1   Steven Adams   C   20          OKC  81  20  1197   93   185  0.503
# 2    Jeff Adrien  PF   27          TOT  53  12   961  143   275  0.520
# 3  Arron Afflalo  SG   28          ORL  73  73  2552  464  1011  0.459
# 4  Alexis Ajinca   C   25          NOP  56  30   951  136   249  0.546
#
#       ...      drb  trb  ast  stl  blk  tov   pf   pts     season  season_end
# 0     ...      144  216   28   23   26   30  122   171  2013-2014        2013
# 1     ...      190  332   43   40   57   71  203   265  2013-2014        2013
# 2     ...      204  306   38   24   36   39  108   362  2013-2014        2013
# 3     ...      230  262  248   35    3  146  136  1330  2013-2014        2013
# 4     ...      183  277   40   23   46   63  187   328  2013-2014        2013
#
# [5 rows x 31 columns]

# %%
from sklearn.cluster import KMeans
kmeans_model = KMeans(n_clusters=5, random_state=1)
good_columns = nba._get_numeric_data().dropna(axis=1) 
kmeans_model.fit(good_columns)
labels = kmeans_model.labels_

# %%
good_columns.head()
# Out:
#    age   g  gs    mp   fg   fga  x3p  x3pa  x2p  x2pa     ...      orb  drb  \
# 0   23  63   0   847   66   141    4    15   62   126     ...       72  144
# 1   20  81  20  1197   93   185    0     0   93   185     ...      142  190
# 2   27  53  12   961  143   275    0     0  143   275     ...      102  204
# 3   28  73  73  2552  464  1011  128   300  336   711     ...       32  230
# 4   25  56  30   951  136   249    0     1  136   248     ...       94  183
#
#    trb  ast  stl  blk  tov   pf   pts  season_end
# 0  216   28   23   26   30  122   171        2013
# 1  332   43   40   57   71  203   265        2013
# 2  306   38   24   36   39  108   362        2013
# 3  262  248   35    3  146  136  1330        2013
# 4  277   40   23   46   63  187   328        2013
#
# [5 rows x 22 columns]

# %%
labels
# Out:
# array([0, 0, 0, 3, 0, 2, 3, 0, 4, 4, 4, 2, 4, 4, 1, 0, 4, 3, 2, 0, 1, 2, 0,
#        0, 1, 2, 0, 2, 2, 2, 4, 4, 1, 4, 2, 1, 4, 3, 4, 2, 0, 3, 0, 1, 0, 4,
#        2, 2, 0, 4, 4, 4, 4, 2, 2, 4, 0, 4, 1, 3, 1, 4, 1, 2, 4, 2, 2, 2, 2,
#        0, 2, 1, 1, 4, 1, 2, 2, 0, 0, 0, 1, 4, 2, 1, 1, 3, 4, 1, 4, 1, 2, 2,
#        0, 2, 2, 4, 2, 1, 0, 3, 2, 3, 2, 2, 1, 1, 0, 4, 2, 2, 3, 4, 2, 2, 2,
#        3, 0, 4, 2, 2, 2, 0, 1, 3, 1, 0, 0, 0, 3, 3, 4, 1, 1, 3, 2, 2, 3, 2,
#        0, 0, 1, 1, 0, 2, 1, 2, 4, 2, 4, 4, 1, 2, 2, 0, 1, 0, 0, 0, 1, 1, 3,
#        0, 3, 1, 4, 2, 2, 2, 2, 2, 1, 3, 0, 2, 4, 4, 1, 3, 0, 3, 2, 0, 2, 0,
#        4, 3, 4, 2, 2, 0, 2, 2, 2, 1, 0, 1, 0, 3, 1, 0, 1, 1, 1, 4, 1, 4, 2,
#        1, 0, 2, 2, 0, 3, 0, 4, 3, 4, 4, 3, 2, 1, 1, 2, 2, 2, 3, 2, 2, 2, 3,
#        1, 2, 3, 0, 1, 0, 0, 3, 2, 1, 2, 2, 0, 2, 1, 1, 0, 0, 1, 2, 4, 4, 0,
#        3, 1, 4, 2, 2, 0, 4, 2, 2, 1, 2, 1, 3, 2, 1, 2, 0, 0, 2, 3, 1, 4, 0,
#        1, 3, 3, 2, 4, 0, 1, 4, 0, 0, 1, 2, 3, 2, 2, 4, 0, 0, 2, 2, 1, 1, 1,
#        2, 1, 0, 0, 0, 4, 0, 4, 3, 2, 2, 3, 4, 2, 4, 1, 4, 0, 2, 4, 2, 2, 2,
#        2, 2, 2, 2, 0, 2, 1, 0, 3, 2, 3, 2, 0, 0, 2, 1, 4, 2, 2, 0, 4, 2, 1,
#        3, 4, 1, 1, 0, 1, 2, 4, 1, 2, 2, 2, 0, 2, 2, 0, 4, 2, 2, 2, 3, 0, 2,
#        0, 4, 2, 4, 0, 0, 0, 2, 1, 1, 2, 0, 4, 0, 0, 4, 4, 4, 0, 1, 2, 2, 4,
#        0, 0, 1, 2, 2, 2, 2, 2, 0, 1, 0, 3, 0, 2, 0, 4, 2, 3, 0, 2, 4, 1, 1,
#        0, 2, 3, 2, 4, 0, 2, 2, 2, 3, 2, 2, 4, 4, 3, 1, 4, 2, 0, 1, 0, 2, 3,
#        2, 0, 0, 1, 4, 2, 4, 0, 2, 1, 2, 1, 1, 3, 3, 4, 2, 0, 2, 2, 1, 3, 4,
#        2, 2, 1, 4, 0, 4, 4, 4, 2, 0, 0, 4, 2, 0, 2, 0, 1, 1, 3, 4, 0], dtype=int32)

# %%
from sklearn.decomposition import PCA
pca_2 = PCA(2)
plot_columns = pca_2.fit_transform(good_columns)
plt.scatter(x=plot_columns[:,0], y=plot_columns[:,1], c=labels)
plt.show()
