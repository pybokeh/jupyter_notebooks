# %%
import toyplot
import pandas as pd

# %%
df = pd.read_clipboard()

# %%
toyplot.data.Table(df)
# Out:
# <table class="toyplot-data-Table" style="border-collapse:collapse; border:none; color: #292724"><tr style="border:none;border-bottom:1px solid #292724"><th style="text-align:left;border:none;padding-right:1em;">Model_Y</th><th style="text-align:left;border:none;padding-right:1em;">Model_X</th></tr><tr style="border:none"><td style="border:none;padding-right:1em;">0.0</td><td style="border:none;padding-right:1em;">0.1</td></tr><tr style="border:none"><td style="border:none;padding-right:1em;">0.21</td><td style="border:none;padding-right:1em;">0.12</td></tr><tr style="border:none"><td style="border:none;padding-right:1em;">0.26</td><td style="border:none;padding-right:1em;">0.22</td></tr><tr style="border:none"><td style="border:none;padding-right:1em;">0.44</td><td style="border:none;padding-right:1em;">0.28</td></tr><tr style="border:none"><td style="border:none;padding-right:1em;">0.66</td><td style="border:none;padding-right:1em;">0.33</td></tr><tr style="border:none"><td style="b
# ...

# %%
canvas = toyplot.Canvas(width=600, height=500)
axes = canvas.cartesian(label='Hard Drive Failures', xlabel='Months In the Market', ylabel='Cumulative Defect Rate (%)')

series = []
for column in df.columns:
    series.append(axes.plot(df[column].values, stroke_width=3))

legend_data = []
for i, column in enumerate(df.columns):
    legend_data.append((column, series[i]))
    
canvas.legend(legend_data,
    corner=("top-left", 50, 50, 50)
);
# Out:
# <div class="toyplot" id="t378b4ca9c9e144eda02b957a0b991901" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="500.0px" id="tce5bf6014d3e401397e28b34bb9c0d1e" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600.0 500.0" width="600.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t29151fd5a3f44c81804480da85db6f73"><clipPath id="t7fdfcc927767467b8a3dfdb8c72107f7"><rect height="420.0" width="520.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t7fdfcc927767467b8a3dfdb8c72107f7)"><g class="toyplot-mark-Plot" id="t81f99f00ed7648e7b409fbd61498c77b" style="fill:none"><g class="toyplot-Series"><path d="M 50.0 450.0 L 112.5 416.4 L 175.0 408.4 L 237
# ...

# %%
df_build = pd.read_clipboard(index_col=0)

# %%
df_build
# Out:
#              Model_X  Model_Y
# Build_Month
# 2017-01         0.80     0.70
# 2017-02         0.75     0.60
# 2017-03         0.70     0.55
# 2017-04         0.62     0.43
# 2017-05         0.40     0.30
# 2017-06         0.30     0.20
# 2017-07         0.22      NaN

# %%
canvas = toyplot.Canvas(width=600, height=500)
axes = canvas.cartesian(label='Failures by Build Month', ylabel='Defect Rate (%)')

series = []
for column in df_build.columns:
    series.append(axes.bars(df_build[column].values))

legend_data = []
for i, column in enumerate(df_build.columns):
    legend_data.append((column, series[i]))
    
canvas.legend(legend_data,
    corner=("top-right", 50, 50, 50)
)

axes.x.ticks.labels.angle = 90
axes.x.ticks.locator = toyplot.locator.Explicit(labels=df_build.index)
# Out:
# <div class="toyplot" id="t986c0490e17d4452b60712ef3ce28bc7" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="500.0px" id="teccd1178c2df4c9da341532a7b917f67" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600.0 500.0" width="600.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="ta7034258049247f7b4ff5b19d1ae4cef"><clipPath id="t86a8b080661844ca8c9805ae29d08d68"><rect height="420.0" width="520.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#t86a8b080661844ca8c9805ae29d08d68)"><g class="toyplot-mark-BarMagnitudes" id="t4743b70fbecb42a5b06568edafa6680e" style="stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"><g class="toyplot-S
# ...
