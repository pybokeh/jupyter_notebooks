# %% [markdown]
# # Example Usage of pydataset

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from pydataset import data
import pandas as pd
from bokeh.charts import BoxPlot, output_notebook, show, hplot
output_notebook()
pd.set_option("display.max_rows",1000)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c2081156-21c2-4c57-b211-4a3beca0d126">Loading BokehJS ...</span>
#     </div>

# %%
df = data('cars')

# %%
df.head()
# Out:
#    speed  dist
# 1      4     2
# 2      4    10
# 3      7     4
# 4      7    22
# 5      8    16

# %%
box = BoxPlot(df, values='speed', title="Auto MPG Box Plot", plot_width=400, plot_height=400, 
              tools='resize, reset')


show(box)
# Out:
#     <div class="plotdiv" id="c745c301-1789-4d0f-97d4-e805c5147d23"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
# ...

# %%
df.plot.scatter('speed','dist')

# %%
df.head(10)
# Out:
#     Reaction  Days  Subject
# 1   249.5600     0      308
# 2   258.7047     1      308
# 3   250.8006     2      308
# 4   321.4398     3      308
# 5   356.8519     4      308
# 6   414.6901     5      308
# 7   382.2038     6      308
# 8   290.1486     7      308
# 9   430.5853     8      308
# 10  466.3535     9      308

# %%
df.boxplot(column='Reaction', by='Days')

# %% [markdown]
# **It appears the more days the subjects were sleep-deprived, the higher their reaction times.  Maybe there is a positive correlation?  Let's find out.**

# %%
sns.lmplot(x="Days", y="Reaction", data=df)

# %%
df.corr()
# Out:
#           Reaction          Days       Subject
# Reaction  1.000000  5.352302e-01  1.828947e-01
# Days      0.535230  1.000000e+00  2.712798e-18
# Subject   0.182895  2.712798e-18  1.000000e+00

# %%
data()
# Out:
#                     dataset_id  \
# 0                AirPassengers
# 1                      BJsales
# 2                          BOD
# 3                 Formaldehyde
# 4                 HairEyeColor
# 5                 InsectSprays
# 6               JohnsonJohnson
# 7                    LakeHuron
# 8             LifeCycleSavings
# 9                         Nile
# 10               OrchardSprays
# 11                 PlantGrowth
# 12                   Puromycin
# 13                     Titanic
# 14                 ToothGrowth
# 15               UCBAdmissions
# 16              UKDriverDeaths
# 17                       UKgas
# 18                 USAccDeaths
# 19                   USArrests
# 20              USJudgeRatings
# 21       USPersonalExpenditure
# 22                    VADeaths
# 23                    WWWusage
# 24                 WorldPhones
# 25                    airmiles
# 26                  airquality
# 27                    anscombe
# 28                      attenu
# ...

# %%
df = data('discoveries')

# %%
iplot(df.iplot(asFigure=True, kind='line', x='time', y='discoveries', title='Plotly Line Example', 
        xTitle='Year', yTitle='# of Discoveries', dimensions=(600,400)))
# Out:
# <div id="974757f4-043b-43c4-801d-264dde2aacc7" style="height: 400; width: 600px;" class="plotly-graph-div"></div><script type="text/javascript">window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("974757f4-043b-43c4-801d-264dde2aacc7", [{"y": [5, 3, 0, 2, 0, 3, 2, 3, 6, 1, 2, 1, 2, 1, 3, 3, 3, 5, 2, 4, 4, 0, 2, 3, 7, 12, 3, 10, 9, 2, 3, 7, 7, 2, 3, 3, 6, 2, 4, 3, 5, 2, 2, 4, 0, 4, 2, 5, 2, 3, 3, 6, 5, 8, 3, 6, 6, 0, 5, 2, 2, 2, 6, 3, 4, 4, 2, 2, 4, 7, 5, 3, 3, 0, 2, 2, 2, 1, 3, 4, 2, 2, 1, 1, 1, 2, 1, 4, 4, 3, 2, 1, 4, 1, 1, 1, 0, 0, 2, 0], "text": "", "line": {"dash": "solid", "width": 1.3, "color": "rgba(255, 153, 51, 1.0)"}, "name": "discoveries", "x": [1860, 1861, 1862, 1863, 1864, 1865, 1866, 1867, 1868, 1869, 1870, 1871, 1872, 1873, 1874, 1875, 1876, 1877, 1878, 1879, 1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907
# ...
