# %%
import pandas as pd
data = pd.read_csv('/home/pybokeh/Dropbox/python/ipython/notebooks/survival_analysis/dd.csv', header=0, index_col=0 )

# %%
data.head()
# Out:
#              cowcode2  politycode un_region_name un_continent_name  \
# ctryname
# Afghanistan       700         700  Southern Asia              Asia
# Afghanistan       700         700  Southern Asia              Asia
# Afghanistan       700         700  Southern Asia              Asia
# Afghanistan       700         700  Southern Asia              Asia
# Afghanistan       700         700  Southern Asia              Asia
#
#                              ehead  \
# ctryname
# Afghanistan    Mohammad Zahir Shah
# Afghanistan  Sardar Mohammad Daoud
# Afghanistan    Mohammad Zahir Shah
# Afghanistan  Sardar Mohammad Daoud
# Afghanistan    Nur Mohammad Taraki
#
#                                                 leaderspellreg      democracy  \
# ctryname
# Afghanistan  Mohammad Zahir Shah.Afghanistan.1946.1952.Mona...  Non-democracy
# Afghanistan  Sardar Mohammad Daoud.Afghanistan.1953.1962.Ci...  Non-democracy
# ...

# %%
from lifelines.estimation import KaplanMeierFitter
kmf = KaplanMeierFitter()

# %%
T = data["duration"] #measure in years
C = data["observed"]

# %%
kmf.fit(T, event_observed=C)
# Out:
# <lifelines.KaplanMeierFitter: fitted with 1808 observations, 340 censored>

# %%
kmf.survival_function_
# Out:
#           KM-estimate
# timeline
# 0            1.000000
# 1            0.721792
# 2            0.601973
# 3            0.510929
# 4            0.418835
# 5            0.334008
# 6            0.280902
# 7            0.256825
# 8            0.221975
# 9            0.205147
# 10           0.181350
# 11           0.161200
# 12           0.150332
# 13           0.139197
# 14           0.124896
# 15           0.117845
# 16           0.113521
# 17           0.108010
# 18           0.099792
# 19           0.093632
# 20           0.090994
# 21           0.085479
# 22           0.078473
# 23           0.074113
# 24           0.071088
# 25           0.069543
# 26           0.066231
# 27           0.062745
# 28           0.060900
# 29           0.056971
# 30           0.052751
# 31           0.050353
# 32           0.043160
# 33           0.038364
# 34           0.038364
# 35           0.030143
# 36           0.030143
# 38           0.030143
# 39           0.030143
# 40           0.030143
# ...

# %%
reliability = 1 - kmf.survival_function_

# %%
reliability
# Out:
#           KM-estimate
# timeline
# 0            0.000000
# 1            0.278208
# 2            0.398027
# 3            0.489071
# 4            0.581165
# 5            0.665992
# 6            0.719098
# 7            0.743175
# 8            0.778025
# 9            0.794853
# 10           0.818650
# 11           0.838800
# 12           0.849668
# 13           0.860803
# 14           0.875104
# 15           0.882155
# 16           0.886479
# 17           0.891990
# 18           0.900208
# 19           0.906368
# 20           0.909006
# 21           0.914521
# 22           0.921527
# 23           0.925887
# 24           0.928912
# 25           0.930457
# 26           0.933769
# 27           0.937255
# 28           0.939100
# 29           0.943029
# 30           0.947249
# 31           0.949647
# 32           0.956840
# 33           0.961636
# 34           0.961636
# 35           0.969857
# 36           0.969857
# 38           0.969857
# 39           0.969857
# 40           0.969857
# ...

# %%
kmf.survival_function_.plot()
plt.title('Survival function of political regimes');

# %%
kmf.survival_function_.ix[10]
# Out:
# KM-estimate    0.18135
# Name: 10.0, dtype: float64

# %%
reliability.plot()
plt.title('Reliability function of political regimes');
