# %% [markdown]
# # Data Science with Python and Dask
# ## Chapter 4: Loading Data Into DataFrames

# %%
# Before beginning, set your working directory to where the data resides
import os
os.chdir('/Users/jesse/Documents')

# %% [markdown]
# ### Section 4.1

# %%
# Listing 4.1
import dask.dataframe as dd
from dask.diagnostics import ProgressBar

fy14 = dd.read_csv('nyc-parking-tickets/Parking_Violations_Issued_-_Fiscal_Year_2014__August_2013___June_2014_.csv')
fy15 = dd.read_csv('nyc-parking-tickets/Parking_Violations_Issued_-_Fiscal_Year_2015.csv')
fy16 = dd.read_csv('nyc-parking-tickets/Parking_Violations_Issued_-_Fiscal_Year_2016.csv')
fy17 = dd.read_csv('nyc-parking-tickets/Parking_Violations_Issued_-_Fiscal_Year_2017.csv')
fy17
# Out:
# Dask DataFrame Structure:
#                Summons Number Plate ID Registration State Plate Type Issue Date Violation Code Vehicle Body Type Vehicle Make Issuing Agency Street Code1 Street Code2 Street Code3 Vehicle Expiration Date Violation Location Violation Precinct Issuer Precinct Issuer Code Issuer Command Issuer Squad Violation Time Time First Observed Violation County Violation In Front Of Or Opposite House Number Street Name Intersecting Street Date First Observed Law Section Sub Division Violation Legal Code Days Parking In Effect     From Hours In Effect To Hours In Effect Vehicle Color Unregistered Vehicle? Vehicle Year Meter Number Feet From Curb Violation Post Code Violation Description No Standing or Stopping Violation Hydrant Violation Double Parking Violation
# npartitions=33
#                         int64   object             object     object     object          int64            object       object         object        int64        int64        int64                   int64            float64              int64           int64       int64         object       object         object              object           object                            object       object      object              object               int64       int64       object               object                     object               object             object        object               float64        int64       object          int64              object                object                           float64           float64                  float64
#                           ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...
# ...                       ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...
#                           ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...
#                           ...      ...                ...        ...        ...            ...               ...          ...            ...          ...          ...          ...                     ...                ...                ...             ...         ...            ...          ...            ...                 ...              ...                               ...          ...         ...                 ...                 ...         ...          ...                  ...                        ...                  ...                ...           ...                   ...          ...          ...            ...                 ...                   ...                               ...               ...                      ...
# Dask Name: from-delayed, 99 tasks

# %%
# Listing 4.2
fy17.columns
# Out:
# Index(['Summons Number', 'Plate ID', 'Registration State', 'Plate Type',
#        'Issue Date', 'Violation Code', 'Vehicle Body Type', 'Vehicle Make',
#        'Issuing Agency', 'Street Code1', 'Street Code2', 'Street Code3',
#        'Vehicle Expiration Date', 'Violation Location', 'Violation Precinct',
#        'Issuer Precinct', 'Issuer Code', 'Issuer Command', 'Issuer Squad',
#        'Violation Time', 'Time First Observed', 'Violation County',
#        'Violation In Front Of Or Opposite', 'House Number', 'Street Name',
#        'Intersecting Street', 'Date First Observed', 'Law Section',
#        'Sub Division', 'Violation Legal Code', 'Days Parking In Effect    ',
#        'From Hours In Effect', 'To Hours In Effect', 'Vehicle Color',
#        'Unregistered Vehicle?', 'Vehicle Year', 'Meter Number',
#        'Feet From Curb', 'Violation Post Code', 'Violation Description',
#        'No Standing or Stopping Violation', 'Hydrant Violation',
#        'Double Parking Violation'],
#       dtype='object')

# %%
# Listing 4.3
# Import for Python 3.x
from functools import reduce

columns = [set(fy14.columns),
    set(fy15.columns),
    set(fy16.columns),
    set(fy17.columns)]
common_columns = list(reduce(lambda a, i: a.intersection(i), columns))
common_columns
# Out:
# ['Vehicle Color',
#  'Violation Location',
#  'Violation Legal Code',
#  'Issuer Command',
#  'Plate ID',
#  'Plate Type',
#  'Violation In Front Of Or Opposite',
#  'Violation Post Code',
#  'Violation Description',
#  'Hydrant Violation',
#  'Violation Code',
#  'Date First Observed',
#  'Vehicle Expiration Date',
#  'Time First Observed',
#  'Vehicle Body Type',
#  'Violation County',
#  'Street Name',
#  'Issuer Squad',
#  'Vehicle Make',
#  'From Hours In Effect',
#  'Meter Number',
#  'Street Code1',
#  'Days Parking In Effect    ',
#  'Issuer Code',
#  'Unregistered Vehicle?',
#  'Double Parking Violation',
#  'Issuer Precinct',
#  'Registration State',
#  'Issue Date',
#  'Intersecting Street',
#  'To Hours In Effect',
#  'Sub Division',
#  'Law Section',
#  'Issuing Agency',
#  'No Standing or Stopping Violation',
#  'Street Code2',
#  'Summons Number',
#  'Feet From Curb',
#  'Street Code3',
#  'Violation Precinct',
#  'Violation Time',
#  'House Number',
#  'Vehicle Year']

# %%
# Listing 4.4
fy17[common_columns].head()
# Out:
#    Feet From Curb  No Standing or Stopping Violation Vehicle Color  \
# 0               0                                NaN            GY
# 1               0                                NaN            GY
# 2               0                                NaN            BK
# 3               0                                NaN            WH
# 4               0                                NaN         WHITE
#
#   Meter Number          Violation Description  Vehicle Year  Street Code1  \
# 0          NaN   FAILURE TO STOP AT RED LIGHT          2001             0
# 1          NaN   FAILURE TO STOP AT RED LIGHT          2001             0
# 2          NaN             BUS LANE VIOLATION          2004             0
# 3          NaN          47-Double PKG-Midtown          2007         10610
# 4          NaN  69-Failure to Disp Muni Recpt          2007         10510
#
#    Date First Observed To Hours In Effect  Summons Number        ...          \
# 0                    0                NaN      5092469481        ...
# 1                    0                NaN      5092451658        ...
# 2                    0                NaN      4006265037        ...
# 3                    0              0700P      8478629828        ...
# 4                    0              0700P      7868300310        ...
#
#             Street Name Violation Legal Code Time First Observed Issuer Code  \
# 0  ALLERTON AVE (W/B) @                    T                 NaN           0
# 1  ALLERTON AVE (W/B) @                    T                 NaN           0
# 2  SB WEBSTER AVE @ E 1                    T                 NaN           0
# 3               7th Ave                  NaN                 NaN      359594
# 4               6th Ave                  NaN                 NaN      364832
#
#    Issuer Command  Street Code2 House Number Violation Precinct Sub Division  \
# 0             NaN             0          NaN                  0            D
# 1             NaN             0          NaN                  0            D
# 2             NaN             0          NaN                  0            C
# 3            T102         34330          330                 14           l2
# 4            T102         34310          799                 13           h1
#
#    Hydrant Violation
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 43 columns]

# %%
# Listing 4.5
# Note: This is supposed to produce an error - scroll down and inspect the ValueError
fy14[common_columns].head()
# Out:
# /anaconda3/lib/python3.6/site-packages/dask/core.py:118: DtypeWarning: Columns (18,29,38,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   args2 = [_execute_task(a, cache) for a in args]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-7fd227edcebd> in <module>()
# ----> 1 fy14[common_columns].head()
#       2 #print("Mismatched dtypes found in `pd.read_csv`/`pd.read_table`.\n\n+-----------------------+---------+----------+\n| Column                | Found   | Expected |\n+-----------------------+---------+----------+\n| Issuer Squad          | object  | int64    |\n| Unregistered Vehicle? | float64 | int64    |\n| Violation Description | object  | float64  |\n| Violation Legal Code  | object  | float64  |\n| Violation Post Code   | object  | float64  |\n+-----------------------+---------+----------+\n\nThe following columns also raised exceptions on conversion:\n\n- Issuer Squad\n  ValueError('cannot convert float NaN to integer',)\n- Violation Description\n  ValueError('invalid literal for float(): 42-Exp. Muni-Mtr (Com. Mtr. Z)',)\n- Violation Legal Code\n  ValueError('could not convert string to float: T',)\n- Violation Post Code\n  ValueError('invalid literal for float(): 05 -',)\n\nUsually this is due to dask's dtype inference failing, and\n*may* be fixed by specifying dtypes manually by adding:\n\ndtype={'Issuer Squad")
#
# /anaconda3/lib/python3.6/site-packages/dask/dataframe/core.py in head(self, n, npartitions, compute)
#     896
#     897         if compute:
# --> 898             result = result.compute()
#     899         return result
#     900
#
# /anaconda3/lib/python3.6/site-packages/dask/base.py in compute(self, **kwargs)
#     154         dask.base.compute
#     155         """
# --> 156         (result,) = compute(self, traverse=False, **kwargs)
#     157         return result
#     158
#
# /anaconda3/lib/python3.6/site-packages/dask/base.py in compute(*args, **kwargs)
#     396     keys = [x.__dask_keys__() for x in collections]
#     397     postcomputes = [x.__dask_postcompute__() for x in collections]
# --> 398     results = schedule(dsk, keys, **kwargs)
#     399     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     400
#
# /anaconda3/lib/python3.6/site-packages/dask/threaded.py in get(dsk, result, cache, num_workers, pool, **kwargs)
#      74     results = get_async(pool.apply_async, len(pool._pool), dsk, result,
#      75                         cache=cache, get_id=_thread_get_id,
# ---> 76                         pack_exception=pack_exception, **kwargs)
#      77
#      78     # Cleanup pools associated to dead threads
#
# /anaconda3/lib/python3.6/site-packages/dask/local.py in get_async(apply_async, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, **kwargs)
#     460                         _execute_task(task, data)  # Re-execute locally
#     461                     else:
# --> 462                         raise_exception(exc, tb)
#     463                 res, worker_id = loads(res_info)
#     464                 state['cache'][key] = res
#
# /anaconda3/lib/python3.6/site-packages/dask/compatibility.py in reraise(exc, tb)
#     110         if exc.__traceback__ is not tb:
#     111             raise exc.with_traceback(tb)
# --> 112         raise exc
#     113
#     114     import pickle as cPickle
#
# /anaconda3/lib/python3.6/site-packages/dask/local.py in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     228     try:
#     229         task, data = loads(task_info)
# --> 230         result = _execute_task(task, data)
#     231         id = get_id()
#     232         result = dumps((result, id))
#
# /anaconda3/lib/python3.6/site-packages/dask/core.py in _execute_task(arg, cache, dsk)
#     116     elif istask(arg):
#     117         func, args = arg[0], arg[1:]
# --> 118         args2 = [_execute_task(a, cache) for a in args]
#     119         return func(*args2)
#     120     elif not ishashable(arg):
#
# /anaconda3/lib/python3.6/site-packages/dask/core.py in <listcomp>(.0)
#     116     elif istask(arg):
#     117         func, args = arg[0], arg[1:]
# --> 118         args2 = [_execute_task(a, cache) for a in args]
#     119         return func(*args2)
#     120     elif not ishashable(arg):
#
# /anaconda3/lib/python3.6/site-packages/dask/core.py in _execute_task(arg, cache, dsk)
#     116     elif istask(arg):
#     117         func, args = arg[0], arg[1:]
# --> 118         args2 = [_execute_task(a, cache) for a in args]
#     119         return func(*args2)
#     120     elif not ishashable(arg):
#
# /anaconda3/lib/python3.6/site-packages/dask/core.py in <listcomp>(.0)
#     116     elif istask(arg):
#     117         func, args = arg[0], arg[1:]
# --> 118         args2 = [_execute_task(a, cache) for a in args]
#     119         return func(*args2)
#     120     elif not ishashable(arg):
#
# /anaconda3/lib/python3.6/site-packages/dask/core.py in _execute_task(arg, cache, dsk)
#     116     elif istask(arg):
#     117         func, args = arg[0], arg[1:]
# --> 118         args2 = [_execute_task(a, cache) for a in args]
#     119         return func(*args2)
#     120     elif not ishashable(arg):
#
# /anaconda3/lib/python3.6/site-packages/dask/core.py in <listcomp>(.0)
#     116     elif istask(arg):
#     117         func, args = arg[0], arg[1:]
# --> 118         args2 = [_execute_task(a, cache) for a in args]
#     119         return func(*args2)
#     120     elif not ishashable(arg):
#
# /anaconda3/lib/python3.6/site-packages/dask/core.py in _execute_task(arg, cache, dsk)
#     117         func, args = arg[0], arg[1:]
#     118         args2 = [_execute_task(a, cache) for a in args]
# --> 119         return func(*args2)
#     120     elif not ishashable(arg):
#     121         return arg
#
# /anaconda3/lib/python3.6/site-packages/dask/compatibility.py in apply(func, args, kwargs)
#      91     def apply(func, args, kwargs=None):
#      92         if kwargs:
# ---> 93             return func(*args, **kwargs)
#      94         else:
#      95             return func(*args)
#
# /anaconda3/lib/python3.6/site-packages/dask/dataframe/io/csv.py in pandas_read_text(reader, b, header, kwargs, dtypes, columns, write_header, enforce, path)
#      66     df = reader(bio, **kwargs)
#      67     if dtypes:
# ---> 68         coerce_dtypes(df, dtypes)
#      69
#      70     if enforce and columns and (list(df.columns) != list(columns)):
#
# /anaconda3/lib/python3.6/site-packages/dask/dataframe/io/csv.py in coerce_dtypes(df, dtypes)
#     161         msg = ("Mismatched dtypes found in `pd.read_csv`/`pd.read_table`.\n\n"
#     162                "%s" % (rule.join(filter(None, [dtype_msg, date_msg]))))
# --> 163         raise ValueError(msg)
#     164
#     165
#
# ValueError: Mismatched dtypes found in `pd.read_csv`/`pd.read_table`.
#
# +-----------------------+---------+----------+
# | Column                | Found   | Expected |
# +-----------------------+---------+----------+
# | Issuer Squad          | object  | int64    |
# | Unregistered Vehicle? | float64 | int64    |
# | Violation Description | object  | float64  |
# | Violation Legal Code  | object  | float64  |
# | Violation Post Code   | object  | float64  |
# +-----------------------+---------+----------+
#
# The following columns also raised exceptions on conversion:
#
# - Issuer Squad
#   ValueError('cannot convert float NaN to integer',)
# - Violation Description
#   ValueError("could not convert string to float: 'BUS LANE VIOLATION'",)
# - Violation Legal Code
#   ValueError("could not convert string to float: 'T'",)
# - Violation Post Code
#   ValueError("could not convert string to float: 'H -'",)
#
# Usually this is due to dask's dtype inference failing, and
# *may* be fixed by specifying dtypes manually by adding:
#
# dtype={'Issuer Squad': 'object',
#        'Unregistered Vehicle?': 'float64',
#        'Violation Description': 'object',
#        'Violation Legal Code': 'object',
#        'Violation Post Code': 'object'}
#
# to the call to `read_csv`/`read_table`.

# %% [markdown]
# ### Section 4.1.2

# %%
# Listing 4.6
import numpy as np
import pandas as pd

dtype_tuples = [(x, np.str) for x in common_columns]
dtypes = dict(dtype_tuples)
dtypes
# Out:
# {'Vehicle Color': str,
#  'Violation Location': str,
#  'Violation Legal Code': str,
#  'Issuer Command': str,
#  'Plate ID': str,
#  'Plate Type': str,
#  'Violation In Front Of Or Opposite': str,
#  'Violation Post Code': str,
#  'Violation Description': str,
#  'Hydrant Violation': str,
#  'Violation Code': str,
#  'Date First Observed': str,
#  'Vehicle Expiration Date': str,
#  'Time First Observed': str,
#  'Vehicle Body Type': str,
#  'Violation County': str,
#  'Street Name': str,
#  'Issuer Squad': str,
#  'Vehicle Make': str,
#  'From Hours In Effect': str,
#  'Meter Number': str,
#  'Street Code1': str,
#  'Days Parking In Effect    ': str,
#  'Issuer Code': str,
#  'Unregistered Vehicle?': str,
#  'Double Parking Violation': str,
#  'Issuer Precinct': str,
#  'Registration State': str,
#  'Issue Date': str,
#  'Intersecting Street': str,
#  'To Hours In Effect': str,
#  'Sub Division': str,
#  'Law Section': str,
#  'Issuing Agency': str,
#  'No Standing or Stopping Violation': str,
#  'Street Code2': str,
#  'Summons Number': str,
#  'Feet From Curb': str,
#  'Street Code3': str,
#  'Violation Precinct': str,
#  'Violation Time': str,
#  'House Number': str,
#  'Vehicle Year': str}

# %%
# Listing 4.7
fy14 = dd.read_csv('nyc-parking-tickets/Parking_Violations_Issued_-_Fiscal_Year_2014__August_2013___June_2014_.csv', dtype=dtypes)

with ProgressBar():
    display(fy14[common_columns].head())
# Out:
# [########################################] | 100% Completed |  2.9s
#   Vehicle Color Violation Location Violation Legal Code Issuer Command  \
# 0            GY               0033                  NaN           0033
# 1            WH               0033                  NaN           0033
# 2           NaN               0033                  NaN           0033
# 3            WH               0033                  NaN           0033
# 4            BR               0033                  NaN           0033
#
#   Plate ID Plate Type Violation In Front Of Or Opposite Violation Post Code  \
# 0  GBB9093        PAS                                 F                 NaN
# 1  62416MB        COM                                 O                 NaN
# 2  78755JZ        COM                                 O                 NaN
# 3  63009MA        COM                                 O                 NaN
# 4  91648MC        COM                                 F                 NaN
#
#   Violation Description Hydrant Violation  ... Issuing Agency  \
# 0                   NaN               NaN  ...              P
# 1                   NaN               NaN  ...              P
# 2                   NaN               NaN  ...              P
# 3                   NaN               NaN  ...              P
# 4                   NaN               NaN  ...              P
#
#   No Standing or Stopping Violation Street Code2 Summons Number  \
# 0                               NaN        13610     1283294138
# 1                               NaN        40404     1283294151
# 2                               NaN        31190     1283294163
# 3                               NaN        11710     1283294175
# 4                               NaN        12010     1283294187
#
#   Feet From Curb Street Code3 Violation Precinct Violation Time House Number  \
# 0              0        21190                 33          0752A          712
# 1              0        40404                 33          1240P          201
# 2              0        13610                 33          1243P          520
# 3              0        12010                 33          0232P          517
# 4              0        31190                 33          1239P          590
#
#   Vehicle Year
# 0         2013
# 1         2012
# 2            0
# 3         2010
# 4         2012
#
# [5 rows x 43 columns]

# %%
# Listing 4.8
with ProgressBar():
    print(fy14['Vehicle Year'].unique().head(10))
# Out:
# [########################################] | 100% Completed |  1min 13.5s
# 0    2013
# 1    2012
# 2       0
# 3    2010
# 4    2011
# 5    2001
# 6    2005
# 7    1998
# 8    1995
# 9    2003
# Name: Vehicle Year, dtype: object

# %%
# Listing 4.9
with ProgressBar():
    print(fy14['Vehicle Year'].isnull().values.any().compute())
# Out:
# [########################################] | 100% Completed |  1min 13.6s
# True

# %%
# Listing 4.10
dtypes = {
 'Date First Observed': np.str,
 'Days Parking In Effect    ': np.str,
 'Double Parking Violation': np.str,
 'Feet From Curb': np.float32,
 'From Hours In Effect': np.str,
 'House Number': np.str,
 'Hydrant Violation': np.str,
 'Intersecting Street': np.str,
 'Issue Date': np.str,
 'Issuer Code': np.float32,
 'Issuer Command': np.str,
 'Issuer Precinct': np.float32,
 'Issuer Squad': np.str,
 'Issuing Agency': np.str,
 'Law Section': np.float32,
 'Meter Number': np.str,
 'No Standing or Stopping Violation': np.str,
 'Plate ID': np.str,
 'Plate Type': np.str,
 'Registration State': np.str,
 'Street Code1': np.uint32,
 'Street Code2': np.uint32,
 'Street Code3': np.uint32,
 'Street Name': np.str,
 'Sub Division': np.str,
 'Summons Number': np.uint32,
 'Time First Observed': np.str,
 'To Hours In Effect': np.str,
 'Unregistered Vehicle?': np.str,
 'Vehicle Body Type': np.str,
 'Vehicle Color': np.str,
 'Vehicle Expiration Date': np.str,
 'Vehicle Make': np.str,
 'Vehicle Year': np.float32,
 'Violation Code': np.uint16,
 'Violation County': np.str,
 'Violation Description': np.str,
 'Violation In Front Of Or Opposite': np.str,
 'Violation Legal Code': np.str,
 'Violation Location': np.str,
 'Violation Post Code': np.str,
 'Violation Precinct': np.float32,
 'Violation Time': np.str
}

# %%
# Listing 4.11
data = dd.read_csv('nyc-parking-tickets/*.csv', dtype=dtypes, usecols=common_columns)

# %% [markdown]
# ### Section 4.2

# %%
# Listing 4.12
username = 'jesse'
password = 'DataScienceRulez'
hostname = 'localhost'
database_name = 'DSAS'
odbc_driver = 'ODBC+Driver+13+for+SQL+Server'

connection_string = 'mssql+pyodbc://{0}:{1}@{2}/{3}?driver={4}'.format(username, password, hostname, database_name, odbc_driver)

data = dd.read_sql_table('violations', connection_string, index_col='Summons Number')

# %%
# Listing 4.13
data = dd.read_sql_table('violations', connection_string, index_col='Vehicle Color', npartitions=200)

# %%
# Listing 4.14
partition_boundaries = sorted(['Red', 'Blue', 'White', 'Black', 'Silver', 'Yellow'])

data = dd.read_sql_table('violations', connection_string, index_col='Vehicle Color', divisions=partition_boundaries)

# %%
# Listing 4.15
column_filter = ['Summons Number', 'Plate ID', 'Vehicle Color']
data = dd.read_sql_table('violations', connection_string, index_col='Summons Number', columns=column_filter)

# %%
# Listing 4.16
data = dd.read_sql_table('violations', connection_string, index_col='Summons Number', schema='chapterFour')

# %% [markdown]
# ### Section 4.3

# %%
# Listing 4.17
data = dd.read_csv('hdfs://localhost/nyc-parking-tickets/*.csv', dtype=dtypes, usecols=common_columns)

# %%
# Listing 4.18
data = dd.read_csv('s3://my-bucket/nyc-parking-tickets/*.csv', dtype=dtypes, usecols=common_columns)

# %% [markdown]
# ### Section 4.4

# %%
# Listing 4.19
data = dd.read_parquet('nyc-parking-tickets-prq')

# %%
# Listing 4.20
data = dd.read_parquet('hdfs://localhost/nyc-parking-tickets-prq')

# OR

data = dd.read_parquet('s3://my-bucket/nyc-parking-tickets-prq')

# %%
# Listing 4.21
columms = ['Summons Number', 'Plate ID', 'Vehicle Color']
data = dd.read_parquet('nyc-parking-tickets-prq', columns=columns, index='Plate ID')
