# %% [markdown]
# <center><h1>Using Dask to Query a Large CSV File</h1></center>

# %% [markdown]
# With [Dask](http://dask.pydata.org/), you don't need a database engine to analyze or query a large CSV file.  Dask is still relatively young and hasn't implemented all of pandas' methods.  But it is getting there!

# %%
from io import BytesIO
from zipfile import ZipFile
from urllib import request

url = request.urlopen('http://www-odi.nhtsa.dot.gov/downloads/folders/Complaints/FLAT_CMPL.zip')
zipfile_in_memory = ZipFile(BytesIO(url.read()))
zipfile_in_memory.extractall('/home/pybokeh/temp/')
zipfile_in_memory.close()
print("zip download and extraction complete")

# %%
import dask.dataframe as dd

# %%
# CSV file does not have a header row, so defining my own columns
columns = [
    'CMPLID',
    'ODINO',
    'MFR_NAME',
    'MAKETXT',
    'MODELTXT',
    'YEARTXT',
    'CRASH',
    'FAILDATE',
    'FIRE',
    'INJURED',
    'DEATHS',
    'COMPDESC',
    'CITY',
    'STATE',
    'VIN',
    'DATEA',
    'LDATE',
    'MILES',
    'OCCURENCES',
    'CDESCR',
    'CMPL_TYPE',
    'POLICE_RPT_YN',
    'PURCH_DT',
    'ORIG_OWNER_YN',
    'ANTI_BRAKES_YN',
    'CRUISE_CONT_YN',
    'NUM_CYLS',
    'DRIVE_TRAIN',
    'FUEL_SYS',
    'FUEL_TYPE',
    'TRANS_TYPE',
    'VEH_SPEED',
    'DOT',
    'TIRE_SIZE',
    'LOC_OF_TIRE',
    'TIRE_FAIL_TYPE',
    'ORIG_EQUIP_YN',
    'MANUF_DT',
    'SEAT_TYPE',
    'RESTRAINT_TYPE',
    'DEALER_NAME',
    'DEALER_TEL',
    'DEALER_CITY',
    'DEALER_STATE',
    'DEALER_ZIP',
    'PROD_TYPE',
    'REPAIRED_YN',
    'MEDICAL_ATTN',
    'VEHICLES_TOWED_YN'
]


# dask's read_csv() dtype=object isn't supported yet.  Therefore, have to define EVERY column's data type.
# I was getting import errors because this CSV file is very dirty, so made every column object type
data_type = {
    'CMPLID':object,
    'ODINO':object,
    'MFR_NAME':object,
    'MAKETXT':object,
    'MODELTXT':object,
    'YEARTXT':object,
    'CRASH':object,
    'FAILDATE':object,
    'FIRE':object,
    'INJURED':object,
    'DEATHS':object,
    'COMPDESC':object,
    'CITY':object,
    'STATE':object,
    'VIN':object,
    'DATEA':object,
    'LDATE':object,
    'MILES':object,
    'OCCURENCES':object,
    'CDESCR':object,
    'CMPL_TYPE':object,
    'POLICE_RPT_YN':object,
    'PURCH_DT':object,
    'ORIG_OWNER_YN':object,
    'ANTI_BRAKES_YN':object,
    'CRUISE_CONT_YN':object,
    'NUM_CYLS':object,
    'DRIVE_TRAIN':object,
    'FUEL_SYS':object,
    'FUEL_TYPE':object,
    'TRANS_TYPE':object,
    'VEH_SPEED':object,
    'DOT':object,
    'TIRE_SIZE':object,
    'LOC_OF_TIRE':object,
    'TIRE_FAIL_TYPE':object,
    'ORIG_EQUIP_YN':object,
    'MANUF_DT':object,
    'SEAT_TYPE':object,
    'RESTRAINT_TYPE':object,
    'DEALER_NAME':object,
    'DEALER_TEL':object,
    'DEALER_CITY':object,
    'DEALER_STATE':object,
    'DEALER_ZIP':object,
    'PROD_TYPE':object,
    'REPAIRED_YN':object,
    'MEDICAL_ATTN':object,
    'VEHICLES_TOWED_YN':object
}

# %%
df = dd.read_csv('/home/pybokeh/temp/FLAT_CMPL.txt', delimiter='\t', names=columns, dtype=data_type,
                encoding='ISO-8859-1', error_bad_lines=False)

# %%
df.head()
# Out:
#   CMPLID   ODINO            MFR_NAME  MAKETXT  MODELTXT YEARTXT CRASH  \
# 0      1  958146  General Motors LLC      GMC    SONOMA    1995   NaN
# 1      2  958146  General Motors LLC      GMC    SONOMA    1995   NaN
# 2      3  958146  General Motors LLC      GMC    SONOMA    1995   NaN
# 3      4  958173  Ford Motor Company  LINCOLN  TOWN CAR    1994     Y
# 4      5  958127  Ford Motor Company     FORD    RANGER    1994   NaN
#
#    FAILDATE FIRE INJURED        ...        RESTRAINT_TYPE DEALER_NAME  \
# 0  19941215    N       0        ...                   NaN         NaN
# 1  19941215    N       0        ...                   NaN         NaN
# 2  19941215    N       0        ...                   NaN         NaN
# 3  19941222    N       0        ...                   NaN         NaN
# 4       NaN    N       0        ...                   NaN         NaN
#
#   DEALER_TEL DEALER_CITY DEALER_STATE DEALER_ZIP PROD_TYPE REPAIRED_YN  \
# 0        NaN         NaN          NaN        NaN         V         NaN
# 1        NaN         NaN          NaN        NaN         V         NaN
# 2        NaN         NaN          NaN        NaN         V         NaN
# 3        NaN         NaN          NaN        NaN         V         NaN
# 4        NaN         NaN          NaN        NaN         V         NaN
#
#   MEDICAL_ATTN VEHICLES_TOWED_YN
# 0          NaN               NaN
# 1          NaN               NaN
# 2          NaN               NaN
# 3          NaN               NaN
# 4          NaN               NaN
#
# [5 rows x 49 columns]

# %%
df.query("MAKETXT == 'FORD' "
         "& (CRASH == 'Y' " 
         "| FIRE == 'Y' "
         "| INJURED == 'Y' "
         "| DEATHS == 'Y' "
         "| MEDICAL_ATTN == 'Y' "
         # query() method does not support LDATE like '2016%'
         "| VEHICLES_TOWED_YN == 'Y')")[df.LDATE.str.startswith("2016")].compute()
# Out:
# /home/pybokeh/envs/jupyter/lib/python3.5/site-packages/pandas/computation/align.py:98: RuntimeWarning: divide by zero encountered in log10
#   ordm = np.log10(abs(reindexer_size - term_axis_size))
# /home/pybokeh/envs/jupyter/lib/python3.5/site-packages/dask/async.py:264: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result = _execute_task(task, data)
#         CMPLID     ODINO            MFR_NAME MAKETXT        MODELTXT YEARTXT  \
# 9202   1249657  10817541  Ford Motor Company    FORD    FIVE HUNDRED    2005
# 9209   1249664  10817547  Ford Motor Company    FORD          FUSION    2015
# 9210   1249665  10817547  Ford Motor Company    FORD          FUSION    2015
# 9242   1249697  10817570  Ford Motor Company    FORD           FOCUS    2010
# 9642   1250097  10818097  Ford Motor Company    FORD        WINDSTAR    2004
# 9801   1250256  10818215  Ford Motor Company    FORD           F-250    1995
# 9802   1250257  10818216  Ford Motor Company    FORD        EXPLORER    2012
# 9879   1250334  10818281  Ford Motor Company    FORD           F-150    2015
# 9943   1250398  10818325  Ford Motor Company    FORD        EXPLORER    2004
# 10585  1251040  10818778  Ford Motor Company    FORD          RANGER    2003
# 10868  1251323  10818974  Ford Motor Company    FORD          TAURUS    2000
# 10869  1251324  10818974  Ford Motor Company    FORD          TAURUS    2000
# 10870  1251325  10818974  Ford Motor Company    FORD          TAURUS    2000
# 11017  1251472  10819080  Ford Motor Company    FORD          TAURUS    2003
# 11018  1251473  10819080  Ford Motor Company    FORD          TAURUS    2003
# 11019  1251474  10819080  Ford Motor Company    FORD          TAURUS    2003
# 11528  1251983  10819459  Ford Motor Company    FORD      EXPEDITION    2000
# 11529  1251984  10819459  Ford Motor Company    FORD      EXPEDITION    2000
# 11567  1252022  10819489  Ford Motor Company    FORD          ESCAPE    2013
# 11568  1252023  10819489  Ford Motor Company    FORD          ESCAPE    2013
# 11616  1252071  10819526  Ford Motor Company    FORD         MUSTANG    2010
# 11617  1252072  10819526  Ford Motor Company    FORD         MUSTANG    2010
# 12205  1252660  10819961  Ford Motor Company    FORD          FUSION    2013
# 12223  1252678  10819974  Ford Motor Company    FORD          RANGER    2006
# 12306  1252761  10820040  Ford Motor Company    FORD          ESCAPE    2013
# 12307  1252762  10820040  Ford Motor Company    FORD          ESCAPE    2013
# 12601  1253056  10820252  Ford Motor Company    FORD        WINDSTAR    2003
# 12613  1253068  10820259  Ford Motor Company    FORD        EXPLORER    2012
# 12614  1253069  10820259  Ford Motor Company    FORD        EXPLORER    2012
# 12703  1253158  10820327  Ford Motor Company    FORD      EXPEDITION    2003
# ...        ...       ...                 ...     ...             ...     ...
# 31887  1272378  10853118  Ford Motor Company    FORD           F-150    1998
# 31888  1272379  10853118  Ford Motor Company    FORD           F-150    1998
# 31889  1272380  10853118  Ford Motor Company    FORD           F-150    1998
# 31931  1272422  10853150  Ford Motor Company    FORD          TAURUS    2014
# 31932  1272423  10853150  Ford Motor Company    FORD          TAURUS    2014
# 31933  1272424  10853150  Ford Motor Company    FORD          TAURUS    2014
# 32058  1272549  10853238  Ford Motor Company    FORD           F-250    2001
# 32059  1272550  10853238  Ford Motor Company    FORD           F-250    2001
# 32232  1272723  10853371  Ford Motor Company    FORD           F-150    2014
# 32238  1272729  10853376  Ford Motor Company    FORD      EXPEDITION    2003
# 32326  1272817  10853439  Ford Motor Company    FORD        WINDSTAR    2003
# 32538  1273029  10853592  Ford Motor Company    FORD           FOCUS    2014
# 32539  1273030  10853592  Ford Motor Company    FORD           FOCUS    2014
# 32540  1273031  10853592  Ford Motor Company    FORD           FOCUS    2014
# 32632  1273123  10853708  Ford Motor Company    FORD           F-150    2016
# 32633  1273124  10853708  Ford Motor Company    FORD           F-150    2016
# 32685  1273176  10853751  Ford Motor Company    FORD           F-150    2014
# 32686  1273177  10853752  Ford Motor Company    FORD           FOCUS    2012
# 32724  1273215  10853781  Ford Motor Company    FORD          RANGER    2003
# 32725  1273216  10853781  Ford Motor Company    FORD          RANGER    2003
# 32780  1273271  10853820  Ford Motor Company    FORD          TAURUS    2008
# 32841  1273332  10853867  Ford Motor Company    FORD           F-250    2005
# 32842  1273333  10853867  Ford Motor Company    FORD           F-250    2005
# 32992  1273483  10853983  Ford Motor Company    FORD        EXPLORER    2007
# 33031  1273522  10854016  Ford Motor Company    FORD          ESCAPE    2014
# 33032  1273523  10854016  Ford Motor Company    FORD          ESCAPE    2014
# 33241  1273732  10854188  Ford Motor Company    FORD  CROWN VICTORIA    2005
# 33405  1273896  10854313  Ford Motor Company    FORD          ESCAPE    2014
# 33575  1274066  10854449  Ford Motor Company    FORD            EDGE    2012
# 34490  1274981  10855183  Ford Motor Company    FORD      EXPEDITION    2001
#
#       CRASH  FAILDATE FIRE INJURED        ...        RESTRAINT_TYPE  \
# 9202      Y  20151201    N       2        ...                   NaN
# 9209      Y  20160103    N       1        ...                   NaN
# 9210      Y  20160103    N       1        ...                   NaN
# 9242      Y  20160101    N     NaN        ...                   NaN
# 9642      N  20160104    Y     NaN        ...                   NaN
# 9801      N  20151231    Y       1        ...                   NaN
# 9802      Y  20151223    N       1        ...                   NaN
# 9879      Y  20151117    N       1        ...                   NaN
# 9943      N  20151226    Y       0        ...                   NaN
# 10585     Y  20151230    N     NaN        ...                   NaN
# 10868     N  20151228    Y     NaN        ...                   NaN
# 10869     N  20151228    Y     NaN        ...                   NaN
# 10870     N  20151228    Y     NaN        ...                   NaN
# 11017     Y  20160108    N     NaN        ...                   NaN
# 11018     Y  20160108    N     NaN        ...                   NaN
# 11019     Y  20160108    N     NaN        ...                   NaN
# 11528     N  20150929    Y     NaN        ...                   NaN
# 11529     N  20150929    Y     NaN        ...                   NaN
# 11567     N  20151231    Y     NaN        ...                   NaN
# 11568     N  20151231    Y     NaN        ...                   NaN
# 11616     N  20160108    N     NaN        ...                   NaN
# 11617     N  20160108    N     NaN        ...                   NaN
# 12205     Y  20151214    Y       1        ...                   NaN
# 12223     Y  20151222    N     NaN        ...                   NaN
# 12306     N  20160112    N     NaN        ...                   NaN
# 12307     N  20160112    N     NaN        ...                   NaN
# 12601     N  20160111    Y     NaN        ...                   NaN
# 12613     N  20160112    Y     NaN        ...                   NaN
# 12614     N  20160112    Y     NaN        ...                   NaN
# 12703     Y  20151215    N     NaN        ...                   NaN
# ...     ...       ...  ...     ...        ...                   ...
# 31887     N  20160401    Y     NaN        ...                   NaN
# 31888     N  20160401    Y     NaN        ...                   NaN
# 31889     N  20160401    Y     NaN        ...                   NaN
# 31931     Y  20160402    N     NaN        ...                   NaN
# 31932     Y  20160402    N     NaN        ...                   NaN
# 31933     Y  20160402    N     NaN        ...                   NaN
# 32058     N  20160403    Y     NaN        ...                   NaN
# 32059     N  20160403    Y     NaN        ...                   NaN
# 32232     Y  20160331    N       1        ...                   NaN
# 32238     Y  20160327    Y     NaN        ...                   NaN
# 32326     N  20160403    Y     NaN        ...                   NaN
# 32538     N  20160405    Y     NaN        ...                   NaN
# 32539     N  20160405    Y     NaN        ...                   NaN
# 32540     N  20160405    Y     NaN        ...                   NaN
# 32632     Y  20160404    N     NaN        ...                   NaN
# 32633     Y  20160404    N     NaN        ...                   NaN
# 32685     N  20160405    N     NaN        ...                   NaN
# 32686     N  20160223    N     NaN        ...                   NaN
# 32724     Y  20151224    N     NaN        ...                   NaN
# 32725     Y  20151224    N     NaN        ...                   NaN
# 32780     Y  20160403    N       1        ...                   NaN
# 32841     N  20160403    N     NaN        ...                   NaN
# 32842     N  20160403    N     NaN        ...                   NaN
# 32992     Y  20160405    N     NaN        ...                   NaN
# 33031     N  20160327    N     NaN        ...                   NaN
# 33032     N  20160327    N     NaN        ...                   NaN
# 33241     N  20120415    Y     NaN        ...                   NaN
# 33405     Y  20160114    N     NaN        ...                   NaN
# 33575     Y  20160404    N     NaN        ...                   NaN
# 34490     N  20160411    N       1        ...                   NaN
#
#       DEALER_NAME DEALER_TEL DEALER_CITY DEALER_STATE DEALER_ZIP PROD_TYPE  \
# 9202          NaN        NaN         NaN          NaN        NaN         V
# 9209          NaN        NaN         NaN          NaN        NaN         V
# 9210          NaN        NaN         NaN          NaN        NaN         V
# 9242          NaN        NaN         NaN          NaN        NaN         V
# 9642          NaN        NaN         NaN          NaN        NaN         V
# 9801          NaN        NaN         NaN          NaN        NaN         V
# 9802          NaN        NaN         NaN          NaN        NaN         V
# 9879          NaN        NaN         NaN          NaN        NaN         V
# 9943          NaN        NaN         NaN          NaN        NaN         V
# 10585         NaN        NaN         NaN          NaN        NaN         V
# 10868         NaN        NaN         NaN          NaN        NaN         V
# 10869         NaN        NaN         NaN          NaN        NaN         V
# 10870         NaN        NaN         NaN          NaN        NaN         V
# 11017         NaN        NaN         NaN          NaN        NaN         V
# 11018         NaN        NaN         NaN          NaN        NaN         V
# 11019         NaN        NaN         NaN          NaN        NaN         V
# 11528         NaN        NaN         NaN          NaN        NaN         V
# 11529         NaN        NaN         NaN          NaN        NaN         V
# 11567         NaN        NaN         NaN          NaN        NaN         V
# 11568         NaN        NaN         NaN          NaN        NaN         V
# 11616         NaN        NaN         NaN          NaN        NaN         V
# 11617         NaN        NaN         NaN          NaN        NaN         V
# 12205         NaN        NaN         NaN          NaN        NaN         V
# 12223         NaN        NaN         NaN          NaN        NaN         V
# 12306         NaN        NaN         NaN          NaN        NaN         V
# 12307         NaN        NaN         NaN          NaN        NaN         V
# 12601         NaN        NaN         NaN          NaN        NaN         V
# 12613         NaN        NaN         NaN          NaN        NaN         V
# 12614         NaN        NaN         NaN          NaN        NaN         V
# 12703         NaN        NaN         NaN          NaN        NaN         V
# ...           ...        ...         ...          ...        ...       ...
# 31887         NaN        NaN         NaN          NaN        NaN         V
# 31888         NaN        NaN         NaN          NaN        NaN         V
# 31889         NaN        NaN         NaN          NaN        NaN         V
# 31931         NaN        NaN         NaN          NaN        NaN         V
# 31932         NaN        NaN         NaN          NaN        NaN         V
# 31933         NaN        NaN         NaN          NaN        NaN         V
# 32058         NaN        NaN         NaN          NaN        NaN         V
# 32059         NaN        NaN         NaN          NaN        NaN         V
# 32232         NaN        NaN         NaN          NaN        NaN         V
# 32238         NaN        NaN         NaN          NaN        NaN         V
# 32326         NaN        NaN         NaN          NaN        NaN         V
# 32538         NaN        NaN         NaN          NaN        NaN         V
# 32539         NaN        NaN         NaN          NaN        NaN         V
# 32540         NaN        NaN         NaN          NaN        NaN         V
# 32632         NaN        NaN         NaN          NaN        NaN         V
# 32633         NaN        NaN         NaN          NaN        NaN         V
# 32685         NaN        NaN         NaN          NaN        NaN         V
# 32686         NaN        NaN         NaN          NaN        NaN         V
# 32724         NaN        NaN         NaN          NaN        NaN         V
# 32725         NaN        NaN         NaN          NaN        NaN         V
# 32780         NaN        NaN         NaN          NaN        NaN         V
# 32841         NaN        NaN         NaN          NaN        NaN         V
# 32842         NaN        NaN         NaN          NaN        NaN         V
# 32992         NaN        NaN         NaN          NaN        NaN         V
# 33031         NaN        NaN         NaN          NaN        NaN         V
# 33032         NaN        NaN         NaN          NaN        NaN         V
# 33241         NaN        NaN         NaN          NaN        NaN         V
# 33405         NaN        NaN         NaN          NaN        NaN         V
# 33575         NaN        NaN         NaN          NaN        NaN         V
# 34490         NaN        NaN         NaN          NaN        NaN         V
#
#       REPAIRED_YN MEDICAL_ATTN VEHICLES_TOWED_YN
# 9202          NaN            Y                 N
# 9209          NaN            N                 N
# 9210          NaN            N                 N
# 9242          NaN            N                 Y
# 9642          NaN            N                 Y
# 9801          NaN            N                 N
# 9802          NaN            N                 Y
# 9879          NaN            Y                 Y
# 9943          NaN            N                 N
# 10585         NaN            N                 N
# 10868         NaN            N                 N
# 10869         NaN            N                 N
# 10870         NaN            N                 N
# 11017         NaN            N                 Y
# 11018         NaN            N                 Y
# 11019         NaN            N                 Y
# 11528         NaN            N                 N
# 11529         NaN            N                 N
# 11567         NaN            N                 N
# 11568         NaN            N                 N
# 11616         NaN            N                 Y
# 11617         NaN            N                 Y
# 12205         NaN            Y                 Y
# 12223         NaN            N                 Y
# 12306         NaN            N                 Y
# 12307         NaN            N                 Y
# 12601         NaN            N                 Y
# 12613         NaN            N                 N
# 12614         NaN            N                 N
# 12703         NaN            N                 N
# ...           ...          ...               ...
# 31887         NaN            N                 N
# 31888         NaN            N                 N
# 31889         NaN            N                 N
# 31931         NaN            N                 Y
# 31932         NaN            N                 Y
# 31933         NaN            N                 Y
# 32058         NaN            N                 N
# 32059         NaN            N                 N
# 32232         NaN            N                 Y
# 32238         NaN            N                 Y
# 32326         NaN            N                 N
# 32538         NaN            N                 N
# 32539         NaN            N                 N
# 32540         NaN            N                 N
# 32632         NaN            N                 N
# 32633         NaN            N                 N
# 32685         NaN            N                 Y
# 32686         NaN            N                 Y
# 32724         NaN            N                 N
# 32725         NaN            N                 N
# 32780         NaN            Y                 Y
# 32841         NaN            N                 Y
# 32842         NaN            N                 Y
# 32992         NaN            N                 Y
# 33031         NaN            N                 Y
# 33032         NaN            N                 Y
# 33241         NaN            N                 N
# 33405         NaN            N                 Y
# 33575         NaN            N                 Y
# 34490         NaN            Y                 N
#
# [264 rows x 49 columns]
