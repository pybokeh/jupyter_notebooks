# %% [markdown]
# <center><h1>Using Dask to Query a Large CSV File</h1></center>

# %% [markdown]
# With [Dask](http://dask.pydata.org/), you don't need a database engine to analyze or query a large CSV file.  Dask is still relatively young and hasn't implemented all of pandas' methods.  But it is getting there!

# %% [markdown]
# ### Obtain the NHTSA complaints data from their [website](http://www-odi.nhtsa.dot.gov/downloads/).

# %% [markdown]
# The meta data on their complaints file can be viewed [here](http://www-odi.nhtsa.dot.gov/downloads/folders/Complaints/CMPL.txt).

# %%
from io import BytesIO
from zipfile import ZipFile
from urllib import request

url = request.urlopen('http://www-odi.nhtsa.dot.gov/downloads/folders/Complaints/FLAT_CMPL.zip')
zipfile_in_memory = ZipFile(BytesIO(url.read()))
zipfile_in_memory.extractall('/home/pybokeh/temp/')
zipfile_in_memory.close()
print("zip download and extraction complete")

# %% [markdown]
# ### Import dask dataframe and numpy

# %%
import dask.dataframe as dd
import numpy as np

# %% [markdown]
# ### The complaints file does not include the header/column names, so I created them myself.

# %%
# CSV file does not have a header row, so defining my own columns
columns = [
    'CMPLID',
    'ODINO',
    'MFR_NAME',
    'MAKETXT',
    'MODELTXT',
    'YEARTXT',
    'CRASH',
    'FAILDATE',
    'FIRE',
    'INJURED',
    'DEATHS',
    'COMPDESC',
    'CITY',
    'STATE',
    'VIN',
    'DATEA',
    'LDATE',
    'MILES',
    'OCCURENCES',
    'CDESCR',
    'CMPL_TYPE',
    'POLICE_RPT_YN',
    'PURCH_DT',
    'ORIG_OWNER_YN',
    'ANTI_BRAKES_YN',
    'CRUISE_CONT_YN',
    'NUM_CYLS',
    'DRIVE_TRAIN',
    'FUEL_SYS',
    'FUEL_TYPE',
    'TRANS_TYPE',
    'VEH_SPEED',
    'DOT',
    'TIRE_SIZE',
    'LOC_OF_TIRE',
    'TIRE_FAIL_TYPE',
    'ORIG_EQUIP_YN',
    'MANUF_DT',
    'SEAT_TYPE',
    'RESTRAINT_TYPE',
    'DEALER_NAME',
    'DEALER_TEL',
    'DEALER_CITY',
    'DEALER_STATE',
    'DEALER_ZIP',
    'PROD_TYPE',
    'REPAIRED_YN',
    'MEDICAL_ATTN',
    'VEHICLES_TOWED_YN'
]

# %% [markdown]
# ## I defined the data type of each column

# %%
data_type = {
    'CMPLID':object,
    'ODINO':object,
    'MFR_NAME':object,
    'MAKETXT':object,
    'MODELTXT':object,
    'YEARTXT':object,
    'CRASH':object,
    'FAILDATE':object,
    'FIRE':object,
    'INJURED':np.int32,
    'DEATHS':np.int32,
    'COMPDESC':object,
    'CITY':object,
    'STATE':object,
    'VIN':object,
    'DATEA':object,
    'LDATE':object,
    'MILES':object,
    'OCCURENCES':object,
    'CDESCR':object,
    'CMPL_TYPE':object,
    'POLICE_RPT_YN':object,
    'PURCH_DT':object,
    'ORIG_OWNER_YN':object,
    'ANTI_BRAKES_YN':object,
    'CRUISE_CONT_YN':object,
    'NUM_CYLS':object,
    'DRIVE_TRAIN':object,
    'FUEL_SYS':object,
    'FUEL_TYPE':object,
    'TRANS_TYPE':object,
    'VEH_SPEED':object,
    'DOT':object,
    'TIRE_SIZE':object,
    'LOC_OF_TIRE':object,
    'TIRE_FAIL_TYPE':object,
    'ORIG_EQUIP_YN':object,
    'MANUF_DT':object,
    'SEAT_TYPE':object,
    'RESTRAINT_TYPE':object,
    'DEALER_NAME':object,
    'DEALER_TEL':object,
    'DEALER_CITY':object,
    'DEALER_STATE':object,
    'DEALER_ZIP':object,
    'PROD_TYPE':object,
    'REPAIRED_YN':object,
    'MEDICAL_ATTN':object,
    'VEHICLES_TOWED_YN':object
}

# %% [markdown]
# ## Now, read in the flat file

# %% [markdown]
# Due to empty/null values, I was getting errors when trying to create a dask data frame.  The converters= argument allows us to replace those empty/null values with whatever we want.  It is a life-saver for dealing with dirty data.  It is so true that data people spend a lot of their time cleaning/tranforming data.

# %%
df = dd.read_csv('/home/pybokeh/temp/FLAT_CMPL.txt', delimiter='\t', names=columns, dtype=data_type,
                 encoding='ISO-8859-1', error_bad_lines=False,
                 converters={'INJURED':lambda x:int(str(x.replace('','0'))), 
                             'DEATHS':lambda x:int(str(x.replace('','0'))),
                             'FAILDATE':lambda x:str(x)
                            }
                )

# %% [markdown]
# ## Let's take a peek at our data

# %%
df.head()
# Out:
#   CMPLID   ODINO            MFR_NAME  MAKETXT  MODELTXT YEARTXT CRASH  \
# 0      1  958146  General Motors LLC      GMC    SONOMA    1995   NaN
# 1      2  958146  General Motors LLC      GMC    SONOMA    1995   NaN
# 2      3  958146  General Motors LLC      GMC    SONOMA    1995   NaN
# 3      4  958173  Ford Motor Company  LINCOLN  TOWN CAR    1994     Y
# 4      5  958127  Ford Motor Company     FORD    RANGER    1994   NaN
#
#    FAILDATE FIRE  INJURED        ...         RESTRAINT_TYPE DEALER_NAME  \
# 0  19941215    N        0        ...                    NaN         NaN
# 1  19941215    N        0        ...                    NaN         NaN
# 2  19941215    N        0        ...                    NaN         NaN
# 3  19941222    N        0        ...                    NaN         NaN
# 4              N        0        ...                    NaN         NaN
#
#   DEALER_TEL DEALER_CITY DEALER_STATE DEALER_ZIP PROD_TYPE REPAIRED_YN  \
# 0        NaN         NaN          NaN        NaN         V         NaN
# 1        NaN         NaN          NaN        NaN         V         NaN
# 2        NaN         NaN          NaN        NaN         V         NaN
# 3        NaN         NaN          NaN        NaN         V         NaN
# 4        NaN         NaN          NaN        NaN         V         NaN
#
#   MEDICAL_ATTN VEHICLES_TOWED_YN
# 0          NaN               NaN
# 1          NaN               NaN
# 2          NaN               NaN
# 3          NaN               NaN
# 4          NaN               NaN
#
# [5 rows x 49 columns]

# %% [markdown]
# ## Now query the data using SQL-like filtering

# %% [markdown]
# The query below will obtain "serious" incidents filed by Ford owners that occurred in 2016.

# %% [markdown]
# In SQL, it would look something like this:
#
#     SELECT *
#
#     FROM complaints
#
#     WHERE
#     MAKETXT = 'FORD'
#     and (CRASH = 'Y'
#         or FIRE = 'Y'
#         or INJURED > 0
#         or DEATHS > 0
#         or MEDICAL_ATTN = 'Y'
#         or VEHICLES_TOWED_YN = 'Y'
#     )
#     and FAILDATE like '2016%'

# %% [markdown]
# In dask/pandas syntax, the query looks like this:

# %%
df.query("MAKETXT == 'FORD' "
         "& (CRASH == 'Y' " 
         "| FIRE == 'Y' "
         "| INJURED > 0 "
         "| DEATHS > 0 "
         "| MEDICAL_ATTN == 'Y' "
         # query() method does not support FAILDATE like '2016%'
         "| VEHICLES_TOWED_YN == 'Y')")[df.FAILDATE.str.startswith("2016")].compute()
# Out:
# /home/pybokeh/envs/jupyter/lib/python3.5/site-packages/pandas/computation/align.py:98: RuntimeWarning: divide by zero encountered in log10
#   ordm = np.log10(abs(reindexer_size - term_axis_size))
# /home/pybokeh/envs/jupyter/lib/python3.5/site-packages/dask/async.py:264: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result = _execute_task(task, data)
#         CMPLID     ODINO            MFR_NAME MAKETXT    MODELTXT YEARTXT  \
# 9209   1249664  10817547  Ford Motor Company    FORD      FUSION    2015
# 9210   1249665  10817547  Ford Motor Company    FORD      FUSION    2015
# 9242   1249697  10817570  Ford Motor Company    FORD       FOCUS    2010
# 9642   1250097  10818097  Ford Motor Company    FORD    WINDSTAR    2004
# 11017  1251472  10819080  Ford Motor Company    FORD      TAURUS    2003
# 11018  1251473  10819080  Ford Motor Company    FORD      TAURUS    2003
# 11019  1251474  10819080  Ford Motor Company    FORD      TAURUS    2003
# 11553  1252008  10819477  Ford Motor Company    FORD       F-150    2013
# 11616  1252071  10819526  Ford Motor Company    FORD     MUSTANG    2010
# 11617  1252072  10819526  Ford Motor Company    FORD     MUSTANG    2010
# 12306  1252761  10820040  Ford Motor Company    FORD      ESCAPE    2013
# 12307  1252762  10820040  Ford Motor Company    FORD      ESCAPE    2013
# 12601  1253056  10820252  Ford Motor Company    FORD    WINDSTAR    2003
# 12613  1253068  10820259  Ford Motor Company    FORD    EXPLORER    2012
# 12614  1253069  10820259  Ford Motor Company    FORD    EXPLORER    2012
# 13065  1253520  10820584  Ford Motor Company    FORD       F-150    2015
# 13066  1253521  10820584  Ford Motor Company    FORD       F-150    2015
# 13687  1254142  10821021  Ford Motor Company    FORD    EXPLORER    2016
# 14324  1254779  10821480  Ford Motor Company    FORD     MUSTANG    2011
# 14497  1254952  10821617  Ford Motor Company    FORD      ESCAPE    2008
# 14615  1255070  10821711  Ford Motor Company    FORD       FOCUS    2014
# 14616  1255071  10821711  Ford Motor Company    FORD       FOCUS    2014
# 14617  1255072  10821711  Ford Motor Company    FORD       FOCUS    2014
# 14625  1255080  10821718  Ford Motor Company    FORD      ESCAPE    2009
# 14879  1255334  10821908  Ford Motor Company    FORD      FIESTA    2011
# 14904  1255359  10821925  Ford Motor Company    FORD       F-150    2010
# 14949  1255404  10821957  Ford Motor Company    FORD      FUSION    2012
# 15179  1255634  10822135  Ford Motor Company    FORD     MUSTANG    2011
# 15252  1255707  10822191  Ford Motor Company    FORD      ESCAPE    2009
# 15292  1255747  10822223  Ford Motor Company    FORD      RANGER    2003
# ...        ...       ...                 ...     ...         ...     ...
# 31637  1272128  10852931  Ford Motor Company    FORD        EDGE    2007
# 31804  1272295  10853055  Ford Motor Company    FORD    EXPLORER    2012
# 31887  1272378  10853118  Ford Motor Company    FORD       F-150    1998
# 31888  1272379  10853118  Ford Motor Company    FORD       F-150    1998
# 31889  1272380  10853118  Ford Motor Company    FORD       F-150    1998
# 31931  1272422  10853150  Ford Motor Company    FORD      TAURUS    2014
# 31932  1272423  10853150  Ford Motor Company    FORD      TAURUS    2014
# 31933  1272424  10853150  Ford Motor Company    FORD      TAURUS    2014
# 32058  1272549  10853238  Ford Motor Company    FORD       F-250    2001
# 32059  1272550  10853238  Ford Motor Company    FORD       F-250    2001
# 32232  1272723  10853371  Ford Motor Company    FORD       F-150    2014
# 32238  1272729  10853376  Ford Motor Company    FORD  EXPEDITION    2003
# 32326  1272817  10853439  Ford Motor Company    FORD    WINDSTAR    2003
# 32538  1273029  10853592  Ford Motor Company    FORD       FOCUS    2014
# 32539  1273030  10853592  Ford Motor Company    FORD       FOCUS    2014
# 32540  1273031  10853592  Ford Motor Company    FORD       FOCUS    2014
# 32632  1273123  10853708  Ford Motor Company    FORD       F-150    2016
# 32633  1273124  10853708  Ford Motor Company    FORD       F-150    2016
# 32685  1273176  10853751  Ford Motor Company    FORD       F-150    2014
# 32686  1273177  10853752  Ford Motor Company    FORD       FOCUS    2012
# 32780  1273271  10853820  Ford Motor Company    FORD      TAURUS    2008
# 32841  1273332  10853867  Ford Motor Company    FORD       F-250    2005
# 32842  1273333  10853867  Ford Motor Company    FORD       F-250    2005
# 32992  1273483  10853983  Ford Motor Company    FORD    EXPLORER    2007
# 33031  1273522  10854016  Ford Motor Company    FORD      ESCAPE    2014
# 33032  1273523  10854016  Ford Motor Company    FORD      ESCAPE    2014
# 33405  1273896  10854313  Ford Motor Company    FORD      ESCAPE    2014
# 33575  1274066  10854449  Ford Motor Company    FORD        EDGE    2012
# 34442  1274933  10855143  Ford Motor Company    FORD    EXPLORER    2016
# 34490  1274981  10855183  Ford Motor Company    FORD  EXPEDITION    2001
#
#       CRASH  FAILDATE FIRE  INJURED        ...         RESTRAINT_TYPE  \
# 9209      Y  20160103    N       10        ...                    NaN
# 9210      Y  20160103    N       10        ...                    NaN
# 9242      Y  20160101    N        0        ...                    NaN
# 9642      N  20160104    Y        0        ...                    NaN
# 11017     Y  20160108    N        0        ...                    NaN
# 11018     Y  20160108    N        0        ...                    NaN
# 11019     Y  20160108    N        0        ...                    NaN
# 11553     N  20160110    N       10        ...                    NaN
# 11616     N  20160108    N        0        ...                    NaN
# 11617     N  20160108    N        0        ...                    NaN
# 12306     N  20160112    N        0        ...                    NaN
# 12307     N  20160112    N        0        ...                    NaN
# 12601     N  20160111    Y        0        ...                    NaN
# 12613     N  20160112    Y        0        ...                    NaN
# 12614     N  20160112    Y        0        ...                    NaN
# 13065     Y  20160113    N        0        ...                    NaN
# 13066     Y  20160113    N        0        ...                    NaN
# 13687     N  20160118    Y        0        ...                    NaN
# 14324     N  20160106    N        0        ...                    NaN
# 14497     N  20160117    N        0        ...                    NaN
# 14615     Y  20160119    N       10        ...                    NaN
# 14616     Y  20160119    N       10        ...                    NaN
# 14617     Y  20160119    N       10        ...                    NaN
# 14625     N  20160121    N        0        ...                    NaN
# 14879     Y  20160107    N       20        ...                    NaN
# 14904     Y  20160122    N       10        ...                    NaN
# 14949     Y  20160102    N       10        ...                    NaN
# 15179     Y  20160104    N        0        ...                    NaN
# 15252     N  20160115    Y        0        ...                    NaN
# 15292     Y  20160109    N        0        ...                    NaN
# ...     ...       ...  ...      ...        ...                    ...
# 31637     N  20160325    N        0        ...                    NaN
# 31804     N  20160229    N       10        ...                    NaN
# 31887     N  20160401    Y        0        ...                    NaN
# 31888     N  20160401    Y        0        ...                    NaN
# 31889     N  20160401    Y        0        ...                    NaN
# 31931     Y  20160402    N        0        ...                    NaN
# 31932     Y  20160402    N        0        ...                    NaN
# 31933     Y  20160402    N        0        ...                    NaN
# 32058     N  20160403    Y        0        ...                    NaN
# 32059     N  20160403    Y        0        ...                    NaN
# 32232     Y  20160331    N       10        ...                    NaN
# 32238     Y  20160327    Y        0        ...                    NaN
# 32326     N  20160403    Y        0        ...                    NaN
# 32538     N  20160405    Y        0        ...                    NaN
# 32539     N  20160405    Y        0        ...                    NaN
# 32540     N  20160405    Y        0        ...                    NaN
# 32632     Y  20160404    N        0        ...                    NaN
# 32633     Y  20160404    N        0        ...                    NaN
# 32685     N  20160405    N        0        ...                    NaN
# 32686     N  20160223    N        0        ...                    NaN
# 32780     Y  20160403    N       10        ...                    NaN
# 32841     N  20160403    N        0        ...                    NaN
# 32842     N  20160403    N        0        ...                    NaN
# 32992     Y  20160405    N        0        ...                    NaN
# 33031     N  20160327    N        0        ...                    NaN
# 33032     N  20160327    N        0        ...                    NaN
# 33405     Y  20160114    N        0        ...                    NaN
# 33575     Y  20160404    N        0        ...                    NaN
# 34442     N  20160227    N       10        ...                    NaN
# 34490     N  20160411    N       10        ...                    NaN
#
#       DEALER_NAME DEALER_TEL DEALER_CITY DEALER_STATE DEALER_ZIP PROD_TYPE  \
# 9209          NaN        NaN         NaN          NaN        NaN         V
# 9210          NaN        NaN         NaN          NaN        NaN         V
# 9242          NaN        NaN         NaN          NaN        NaN         V
# 9642          NaN        NaN         NaN          NaN        NaN         V
# 11017         NaN        NaN         NaN          NaN        NaN         V
# 11018         NaN        NaN         NaN          NaN        NaN         V
# 11019         NaN        NaN         NaN          NaN        NaN         V
# 11553         NaN        NaN         NaN          NaN        NaN         V
# 11616         NaN        NaN         NaN          NaN        NaN         V
# 11617         NaN        NaN         NaN          NaN        NaN         V
# 12306         NaN        NaN         NaN          NaN        NaN         V
# 12307         NaN        NaN         NaN          NaN        NaN         V
# 12601         NaN        NaN         NaN          NaN        NaN         V
# 12613         NaN        NaN         NaN          NaN        NaN         V
# 12614         NaN        NaN         NaN          NaN        NaN         V
# 13065         NaN        NaN         NaN          NaN        NaN         V
# 13066         NaN        NaN         NaN          NaN        NaN         V
# 13687         NaN        NaN         NaN          NaN        NaN         V
# 14324         NaN        NaN         NaN          NaN        NaN         V
# 14497         NaN        NaN         NaN          NaN        NaN         V
# 14615         NaN        NaN         NaN          NaN        NaN         V
# 14616         NaN        NaN         NaN          NaN        NaN         V
# 14617         NaN        NaN         NaN          NaN        NaN         V
# 14625         NaN        NaN         NaN          NaN        NaN         V
# 14879         NaN        NaN         NaN          NaN        NaN         V
# 14904         NaN        NaN         NaN          NaN        NaN         V
# 14949         NaN        NaN         NaN          NaN        NaN         V
# 15179         NaN        NaN         NaN          NaN        NaN         V
# 15252         NaN        NaN         NaN          NaN        NaN         V
# 15292         NaN        NaN         NaN          NaN        NaN         V
# ...           ...        ...         ...          ...        ...       ...
# 31637         NaN        NaN         NaN          NaN        NaN         V
# 31804         NaN        NaN         NaN          NaN        NaN         V
# 31887         NaN        NaN         NaN          NaN        NaN         V
# 31888         NaN        NaN         NaN          NaN        NaN         V
# 31889         NaN        NaN         NaN          NaN        NaN         V
# 31931         NaN        NaN         NaN          NaN        NaN         V
# 31932         NaN        NaN         NaN          NaN        NaN         V
# 31933         NaN        NaN         NaN          NaN        NaN         V
# 32058         NaN        NaN         NaN          NaN        NaN         V
# 32059         NaN        NaN         NaN          NaN        NaN         V
# 32232         NaN        NaN         NaN          NaN        NaN         V
# 32238         NaN        NaN         NaN          NaN        NaN         V
# 32326         NaN        NaN         NaN          NaN        NaN         V
# 32538         NaN        NaN         NaN          NaN        NaN         V
# 32539         NaN        NaN         NaN          NaN        NaN         V
# 32540         NaN        NaN         NaN          NaN        NaN         V
# 32632         NaN        NaN         NaN          NaN        NaN         V
# 32633         NaN        NaN         NaN          NaN        NaN         V
# 32685         NaN        NaN         NaN          NaN        NaN         V
# 32686         NaN        NaN         NaN          NaN        NaN         V
# 32780         NaN        NaN         NaN          NaN        NaN         V
# 32841         NaN        NaN         NaN          NaN        NaN         V
# 32842         NaN        NaN         NaN          NaN        NaN         V
# 32992         NaN        NaN         NaN          NaN        NaN         V
# 33031         NaN        NaN         NaN          NaN        NaN         V
# 33032         NaN        NaN         NaN          NaN        NaN         V
# 33405         NaN        NaN         NaN          NaN        NaN         V
# 33575         NaN        NaN         NaN          NaN        NaN         V
# 34442         NaN        NaN         NaN          NaN        NaN         V
# 34490         NaN        NaN         NaN          NaN        NaN         V
#
#       REPAIRED_YN MEDICAL_ATTN VEHICLES_TOWED_YN
# 9209          NaN            N                 N
# 9210          NaN            N                 N
# 9242          NaN            N                 Y
# 9642          NaN            N                 Y
# 11017         NaN            N                 Y
# 11018         NaN            N                 Y
# 11019         NaN            N                 Y
# 11553         NaN            N                 N
# 11616         NaN            N                 Y
# 11617         NaN            N                 Y
# 12306         NaN            N                 Y
# 12307         NaN            N                 Y
# 12601         NaN            N                 Y
# 12613         NaN            N                 N
# 12614         NaN            N                 N
# 13065         NaN            N                 Y
# 13066         NaN            N                 Y
# 13687         NaN            N                 N
# 14324         NaN            N                 Y
# 14497         NaN            N                 Y
# 14615         NaN            Y                 Y
# 14616         NaN            Y                 Y
# 14617         NaN            Y                 Y
# 14625         NaN            N                 Y
# 14879         NaN            Y                 Y
# 14904         NaN            N                 Y
# 14949         NaN            Y                 Y
# 15179         NaN            N                 N
# 15252         NaN            N                 N
# 15292         NaN            Y                 Y
# ...           ...          ...               ...
# 31637         NaN            N                 Y
# 31804         NaN            Y                 N
# 31887         NaN            N                 N
# 31888         NaN            N                 N
# 31889         NaN            N                 N
# 31931         NaN            N                 Y
# 31932         NaN            N                 Y
# 31933         NaN            N                 Y
# 32058         NaN            N                 N
# 32059         NaN            N                 N
# 32232         NaN            N                 Y
# 32238         NaN            N                 Y
# 32326         NaN            N                 N
# 32538         NaN            N                 N
# 32539         NaN            N                 N
# 32540         NaN            N                 N
# 32632         NaN            N                 N
# 32633         NaN            N                 N
# 32685         NaN            N                 Y
# 32686         NaN            N                 Y
# 32780         NaN            Y                 Y
# 32841         NaN            N                 Y
# 32842         NaN            N                 Y
# 32992         NaN            N                 Y
# 33031         NaN            N                 Y
# 33032         NaN            N                 Y
# 33405         NaN            N                 Y
# 33575         NaN            N                 Y
# 34442         NaN            N                 N
# 34490         NaN            Y                 N
#
# [183 rows x 49 columns]

# %% [markdown]
# ### That's it!  We queried a large flat file and we didn't have to use a database.
