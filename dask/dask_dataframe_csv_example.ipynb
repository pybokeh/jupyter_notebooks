# %% [markdown]
# <center><h1>Using Dask to Query a Large CSV File</h1></center>

# %% [markdown]
# With [Dask](http://dask.pydata.org/), you don't need a database engine to analyze or query a large CSV file.  Dask is still relatively young and hasn't implemented all of pandas' methods yet.  However, if you reduced your resultset to a more manageable size, you can then save the dask data frame as a pandas data frame.

# %% [markdown]
# In a nutshell, dask is like pandas on steroids. It allows you to work with larger than memory data sets and still use pandas-like API that we are all familiar with.  This is a practical example where someone were to be responsible for monitoring customer complaints filed with NHTSA, with dask/Python, he or she can do so without having to first load the data into a database. There were some initial prep work that was required with this process, but now this process can be done repeatedly and reliably. With this process documented in this jupyter notebook, if someone were to question or audit your process, your workflow is now transparent and easily understood.

# %% [markdown]
# ### Obtain the NHTSA complaints data from their [website](http://www-odi.nhtsa.dot.gov/downloads/).

# %% [markdown]
# The meta data on their complaints file can be viewed [here](http://www-odi.nhtsa.dot.gov/downloads/folders/Complaints/CMPL.txt).

# %%
from io import BytesIO
from zipfile import ZipFile
from urllib import request

url = request.urlopen('http://www-odi.nhtsa.dot.gov/downloads/folders/Complaints/FLAT_CMPL.zip')
zipfile_in_memory = ZipFile(BytesIO(url.read()))
zipfile_in_memory.extractall('/home/pybokeh/temp/')
zipfile_in_memory.close()
print("zip download and extraction complete")

# %% [markdown]
# ### Import dask dataframe and numpy

# %%
import dask.dataframe as dd
import numpy as np

# %% [markdown]
# ### The complaints file does not include the header/column names, so I created them myself.

# %%
# CSV file does not have a header row, so defining my own columns
columns = [
    'CMPLID',
    'ODINO',
    'MFR_NAME',
    'MAKETXT',
    'MODELTXT',
    'YEARTXT',
    'CRASH',
    'FAILDATE',
    'FIRE',
    'INJURED',
    'DEATHS',
    'COMPDESC',
    'CITY',
    'STATE',
    'VIN',
    'DATEA',
    'LDATE',
    'MILES',
    'OCCURENCES',
    'CDESCR',
    'CMPL_TYPE',
    'POLICE_RPT_YN',
    'PURCH_DT',
    'ORIG_OWNER_YN',
    'ANTI_BRAKES_YN',
    'CRUISE_CONT_YN',
    'NUM_CYLS',
    'DRIVE_TRAIN',
    'FUEL_SYS',
    'FUEL_TYPE',
    'TRANS_TYPE',
    'VEH_SPEED',
    'DOT',
    'TIRE_SIZE',
    'LOC_OF_TIRE',
    'TIRE_FAIL_TYPE',
    'ORIG_EQUIP_YN',
    'MANUF_DT',
    'SEAT_TYPE',
    'RESTRAINT_TYPE',
    'DEALER_NAME',
    'DEALER_TEL',
    'DEALER_CITY',
    'DEALER_STATE',
    'DEALER_ZIP',
    'PROD_TYPE',
    'REPAIRED_YN',
    'MEDICAL_ATTN',
    'VEHICLES_TOWED_YN'
]

# %% [markdown]
# ## I defined the data type of each column

# %%
data_type = {
    'CMPLID':object,
    'ODINO':object,
    'MFR_NAME':object,
    'MAKETXT':object,
    'MODELTXT':object,
    'YEARTXT':object,
    'CRASH':object,
    'FAILDATE':object,
    'FIRE':object,
    'INJURED':np.int32,
    'DEATHS':np.int32,
    'COMPDESC':object,
    'CITY':object,
    'STATE':object,
    'VIN':object,
    'DATEA':object,
    'LDATE':object,
    'MILES':object,
    'OCCURENCES':object,
    'CDESCR':object,
    'CMPL_TYPE':object,
    'POLICE_RPT_YN':object,
    'PURCH_DT':object,
    'ORIG_OWNER_YN':object,
    'ANTI_BRAKES_YN':object,
    'CRUISE_CONT_YN':object,
    'NUM_CYLS':object,
    'DRIVE_TRAIN':object,
    'FUEL_SYS':object,
    'FUEL_TYPE':object,
    'TRANS_TYPE':object,
    'VEH_SPEED':object,
    'DOT':object,
    'TIRE_SIZE':object,
    'LOC_OF_TIRE':object,
    'TIRE_FAIL_TYPE':object,
    'ORIG_EQUIP_YN':object,
    'MANUF_DT':object,
    'SEAT_TYPE':object,
    'RESTRAINT_TYPE':object,
    'DEALER_NAME':object,
    'DEALER_TEL':object,
    'DEALER_CITY':object,
    'DEALER_STATE':object,
    'DEALER_ZIP':object,
    'PROD_TYPE':object,
    'REPAIRED_YN':object,
    'MEDICAL_ATTN':object,
    'VEHICLES_TOWED_YN':object
}

# %% [markdown]
# ## Now, read in the flat file

# %% [markdown]
# Due to empty/null values, I was getting errors when trying to create a dask data frame.  The converters= argument allows us to replace those empty/null values with whatever we want.  It is a life-saver for dealing with dirty data.  It is so true that data people spend a lot of their time cleaning/transforming data.

# %%
df = dd.read_csv('/home/pybokeh/temp/FLAT_CMPL.txt', delimiter='\t', names=columns, dtype=data_type,
                 encoding='ISO-8859-1', error_bad_lines=False,
                 converters={'INJURED':lambda x:int(str(x.replace('','0'))), 
                             'DEATHS':lambda x:int(str(x.replace('','0'))),
                             'FAILDATE':lambda x:str(x)
                            }
                )

# %% [markdown]
# ## Let's take a peek at our data

# %%
df.head()
# Out:
#   CMPLID   ODINO            MFR_NAME  MAKETXT  MODELTXT YEARTXT CRASH  \
# 0      1  958146  General Motors LLC      GMC    SONOMA    1995   NaN
# 1      2  958146  General Motors LLC      GMC    SONOMA    1995   NaN
# 2      3  958146  General Motors LLC      GMC    SONOMA    1995   NaN
# 3      4  958173  Ford Motor Company  LINCOLN  TOWN CAR    1994     Y
# 4      5  958127  Ford Motor Company     FORD    RANGER    1994   NaN
#
#    FAILDATE FIRE  INJURED        ...         RESTRAINT_TYPE DEALER_NAME  \
# 0  19941215    N        0        ...                    NaN         NaN
# 1  19941215    N        0        ...                    NaN         NaN
# 2  19941215    N        0        ...                    NaN         NaN
# 3  19941222    N        0        ...                    NaN         NaN
# 4              N        0        ...                    NaN         NaN
#
#   DEALER_TEL DEALER_CITY DEALER_STATE DEALER_ZIP PROD_TYPE REPAIRED_YN  \
# 0        NaN         NaN          NaN        NaN         V         NaN
# 1        NaN         NaN          NaN        NaN         V         NaN
# 2        NaN         NaN          NaN        NaN         V         NaN
# 3        NaN         NaN          NaN        NaN         V         NaN
# 4        NaN         NaN          NaN        NaN         V         NaN
#
#   MEDICAL_ATTN VEHICLES_TOWED_YN
# 0          NaN               NaN
# 1          NaN               NaN
# 2          NaN               NaN
# 3          NaN               NaN
# 4          NaN               NaN
#
# [5 rows x 49 columns]

# %% [markdown]
# ## Now query the data using SQL-like filtering

# %% [markdown]
# The query below will obtain "serious" incidents filed by Ford owners that occurred in 2016.

# %% [markdown]
# In SQL, it would look something like this:
#
#     SELECT *
#
#     FROM complaints
#
#     WHERE
#     MAKETXT = 'FORD'
#     and FAILDATE >= '201610'
#     and (CRASH = 'Y'
#         or FIRE = 'Y'
#         or INJURED > 0
#         or DEATHS > 0
#         or MEDICAL_ATTN = 'Y'
#         or POLICE_RPT_YN = 'Y'
#         or VEHICLES_TOWED_YN = 'Y'
#     )

# %% [markdown]
# In dask/pandas syntax, the query looks like this:

# %%
sql = (
    "MAKETXT == 'FORD' "
    "and FAILDATE >= '201603' "
    "and (CRASH == 'Y' " 
    "    or FIRE == 'Y' "
    "    or INJURED > 0 "
    "    or DEATHS > 0 "
    "    or MEDICAL_ATTN == 'Y' "
    "    or POLICE_RPT_YN == 'Y' "
    "    or VEHICLES_TOWED_YN == 'Y' "
    ")"
)

# %%
df.query(sql).compute()
# Out:
#         CMPLID     ODINO            MFR_NAME MAKETXT    MODELTXT YEARTXT  \
# 24618  1265091  10839516  Ford Motor Company    FORD    WINDSTAR    2002
# 24685  1265158  10839568  Ford Motor Company    FORD        EDGE    2008
# 24686  1265159  10839568  Ford Motor Company    FORD        EDGE    2008
# 24785  1265258  10839632  Ford Motor Company    FORD    FREESTAR    2006
# 25816  1266290  10840417  Ford Motor Company    FORD       F-150    2009
# 25845  1266319  10840439  Ford Motor Company    FORD    TAURUS X    2008
# 26051  1266525  10845616  Ford Motor Company    FORD      ESCAPE    2001
# 26052  1266526  10845616  Ford Motor Company    FORD      ESCAPE    2001
# 26137  1266611  10845681  Ford Motor Company    FORD  EXPEDITION    2011
# 26138  1266612  10845681  Ford Motor Company    FORD  EXPEDITION    2011
# 26711  1267185  10846096  Ford Motor Company    FORD    TAURUS X    2009
# 27262  1267736  10846500  Ford Motor Company    FORD      ESCAPE    2014
# 27599  1268073  10849803  Ford Motor Company    FORD   FREESTYLE    2005
# 27687  1268161  10849862  Ford Motor Company    FORD       F-150    2013
# 27771  1268245  10849916  Ford Motor Company    FORD      TAURUS    2015
# 27772  1268246  10849916  Ford Motor Company    FORD      TAURUS    2015
# 27773  1268247  10849916  Ford Motor Company    FORD      TAURUS    2015
# 28150  1268624  10850199  Ford Motor Company    FORD      FUSION    2014
# 28534  1269008  10850488  Ford Motor Company    FORD       F-150    2014
# 29053  1269527  10850867  Ford Motor Company    FORD    FREESTAR    2006
# 29054  1269528  10850867  Ford Motor Company    FORD    FREESTAR    2006
# 29199  1269676  10850989  Ford Motor Company    FORD        EDGE    2015
# 29217  1269694  10851004  Ford Motor Company    FORD       FOCUS    2003
# 29294  1269771  10851059  Ford Motor Company    FORD      ESCAPE    2012
# 30100  1270591  10851716  Ford Motor Company    FORD    EXPLORER    2013
# 30101  1270592  10851716  Ford Motor Company    FORD    EXPLORER    2013
# 30185  1270676  10851785  Ford Motor Company    FORD      ESCAPE    2015
# 30324  1270815  10851899  Ford Motor Company    FORD      TAURUS    1997
# 30325  1270816  10851899  Ford Motor Company    FORD      TAURUS    1997
# 30346  1270837  10851916  Ford Motor Company    FORD      TAURUS    2015
# 30414  1270905  10851957  Ford Motor Company    FORD    WINDSTAR    2001
# 29294     Y  20160311    N       20        ...                    NaN
# 30100     Y  20160323    N       10        ...                    NaN
# 30101     Y  20160323    N       10        ...                    NaN
# 30185     Y  20160316    N       30        ...                    NaN
# 30324     N  20160321    Y        0        ...                    NaN
# 30325     N  20160321    Y        0        ...                    NaN
# 30346     N  20160324    N       10        ...                    NaN
# 30414     N  20160326    N        0        ...                    NaN
# 30455     N  20160325    Y        0        ...                    NaN
# 30502     Y  20160320    N       30        ...                    NaN
# 30645     N  20160326    N        0        ...                    NaN
# 31637     N  20160325    N        0        ...                    NaN
# 31887     N  20160401    Y        0        ...                    NaN
# 31888     N  20160401    Y        0        ...                    NaN
# 31889     N  20160401    Y        0        ...                    NaN
# 31931     Y  20160402    N        0        ...                    NaN
# 31932     Y  20160402    N        0        ...                    NaN
# 31933     Y  20160402    N        0        ...                    NaN
# 32058     N  20160403    Y        0        ...                    NaN
# 32059     N  20160403    Y        0        ...                    NaN
# 32232     Y  20160331    N       10        ...                    NaN
# 32238     Y  20160327    Y        0        ...                    NaN
# 32326     N  20160403    Y        0        ...                    NaN
# 32538     N  20160405    Y        0        ...                    NaN
# 32539     N  20160405    Y        0        ...                    NaN
# 32540     N  20160405    Y        0        ...                    NaN
# 32632     Y  20160404    N        0        ...                    NaN
# 32633     Y  20160404    N        0        ...                    NaN
# 32685     N  20160405    N        0        ...                    NaN
# 32780     Y  20160403    N       10        ...                    NaN
# 32841     N  20160403    N        0        ...                    NaN
# 32842     N  20160403    N        0        ...                    NaN
# 32992     Y  20160405    N        0        ...                    NaN
# 33031     N  20160327    N        0        ...                    NaN
# 33032     N  20160327    N        0        ...                    NaN
# 33575     Y  20160404    N        0        ...                    NaN
# 34490     N  20160411    N       10        ...                    NaN
#
#       DEALER_NAME DEALER_TEL DEALER_CITY DEALER_STATE DEALER_ZIP PROD_TYPE  \
# 24618         NaN        NaN         NaN          NaN        NaN         V
# 24685         NaN        NaN         NaN          NaN        NaN         V
# 24686         NaN        NaN         NaN          NaN        NaN         V
# 24785         NaN        NaN         NaN          NaN        NaN         V
# 25816         NaN        NaN         NaN          NaN        NaN         V
# 25845         NaN        NaN         NaN          NaN        NaN         V
# 26051         NaN        NaN         NaN          NaN        NaN         V
# 26052         NaN        NaN         NaN          NaN        NaN         V
# 26137         NaN        NaN         NaN          NaN        NaN         V
# 26138         NaN        NaN         NaN          NaN        NaN         V
# 26711         NaN        NaN         NaN          NaN        NaN         V
# 27262         NaN        NaN         NaN          NaN        NaN         V
# 27599         NaN        NaN         NaN          NaN        NaN         V
# 27687         NaN        NaN         NaN          NaN        NaN         V
# 27771         NaN        NaN         NaN          NaN        NaN         V
# 27772         NaN        NaN         NaN          NaN        NaN         V
# 27773         NaN        NaN         NaN          NaN        NaN         V
# 28150         NaN        NaN         NaN          NaN        NaN         V
# 28534         NaN        NaN         NaN          NaN        NaN         V
# 29053         NaN        NaN         NaN          NaN        NaN         V
# 29054         NaN        NaN         NaN          NaN        NaN         V
# 29199         NaN        NaN         NaN          NaN        NaN         V
# 29217         NaN        NaN         NaN          NaN        NaN         V
# 29294         NaN        NaN         NaN          NaN        NaN         V
# 30100         NaN        NaN         NaN          NaN        NaN         V
# 30101         NaN        NaN         NaN          NaN        NaN         V
# 30185         NaN        NaN         NaN          NaN        NaN         V
# 30324         NaN        NaN         NaN          NaN        NaN         V
# 30325         NaN        NaN         NaN          NaN        NaN         V
# 30346         NaN        NaN         NaN          NaN        NaN         V
# 30414         NaN        NaN         NaN          NaN        NaN         V
# 30455         NaN        NaN         NaN          NaN        NaN         V
# 30502         NaN        NaN         NaN          NaN        NaN         V
# 30645         NaN        NaN         NaN          NaN        NaN         V
# 31637         NaN        NaN         NaN          NaN        NaN         V
# 31887         NaN        NaN         NaN          NaN        NaN         V
# 31888         NaN        NaN         NaN          NaN        NaN         V
# 31889         NaN        NaN         NaN          NaN        NaN         V
# 31931         NaN        NaN         NaN          NaN        NaN         V
# 31932         NaN        NaN         NaN          NaN        NaN         V
# 31933         NaN        NaN         NaN          NaN        NaN         V
# 32058         NaN        NaN         NaN          NaN        NaN         V
# 32059         NaN        NaN         NaN          NaN        NaN         V
# 32232         NaN        NaN         NaN          NaN        NaN         V
# 32238         NaN        NaN         NaN          NaN        NaN         V
# 32326         NaN        NaN         NaN          NaN        NaN         V
# 32538         NaN        NaN         NaN          NaN        NaN         V
# 32539         NaN        NaN         NaN          NaN        NaN         V
# 32540         NaN        NaN         NaN          NaN        NaN         V
# 32632         NaN        NaN         NaN          NaN        NaN         V
# 32633         NaN        NaN         NaN          NaN        NaN         V
# 32685         NaN        NaN         NaN          NaN        NaN         V
# 32780         NaN        NaN         NaN          NaN        NaN         V
# 32841         NaN        NaN         NaN          NaN        NaN         V
# 32842         NaN        NaN         NaN          NaN        NaN         V
# 32992         NaN        NaN         NaN          NaN        NaN         V
# 33031         NaN        NaN         NaN          NaN        NaN         V
# 33032         NaN        NaN         NaN          NaN        NaN         V
# 33575         NaN        NaN         NaN          NaN        NaN         V
# 34490         NaN        NaN         NaN          NaN        NaN         V
#
#       REPAIRED_YN MEDICAL_ATTN VEHICLES_TOWED_YN
# 24618         NaN            N                 Y
# 24685         NaN            Y                 N
# 24686         NaN            Y                 N
# 24785         NaN            N                 Y
# 25816         NaN            N                 Y
# 25845         NaN            N                 N
# 26051         NaN            N                 Y
# 26052         NaN            N                 Y
# 26137         NaN            N                 Y
# 26138         NaN            N                 Y
# 26711         NaN            N                 N
# 27262         NaN            Y                 N
# 27599         NaN            Y                 N
# 27687         NaN            N                 Y
# 27771         NaN            Y                 Y
# 27772         NaN            Y                 Y
# 27773         NaN            Y                 Y
# 28150         NaN            N                 Y
# 28534         NaN            N                 N
# 29053         NaN            N                 Y
# 29054         NaN            N                 Y
# 29199         NaN            N                 N
# 29217         NaN            N                 Y
# 29294         NaN            Y                 Y
# 30100         NaN            Y                 Y
# 30101         NaN            Y                 Y
# 30185         NaN            Y                 Y
# 30324         NaN            N                 N
# 30325         NaN            N                 N
# 30346         NaN            N                 N
# 30414         NaN            N                 Y
# 30455         NaN            N                 N
# 30502         NaN            Y                 Y
# 30645         NaN            N                 Y
# 31637         NaN            N                 Y
# 31887         NaN            N                 N
# 31888         NaN            N                 N
# 31889         NaN            N                 N
# 31931         NaN            N                 Y
# 31932         NaN            N                 Y
# 31933         NaN            N                 Y
# 32058         NaN            N                 N
# 32059         NaN            N                 N
# 32232         NaN            N                 Y
# 32238         NaN            N                 Y
# 32326         NaN            N                 N
# 32538         NaN            N                 N
# 32539         NaN            N                 N
# 32540         NaN            N                 N
# 32632         NaN            N                 N
# 32633         NaN            N                 N
# 32685         NaN            N                 Y
# 32780         NaN            Y                 Y
# 32841         NaN            N                 Y
# 32842         NaN            N                 Y
# 32992         NaN            N                 Y
# 33031         NaN            N                 Y
# 33032         NaN            N                 Y
# 33575         NaN            N                 Y
# 34490         NaN            Y                 N
#
# [60 rows x 49 columns]

# %% [markdown]
# ### Now that the query results look like what I want, I will convert the results into a pandas data frame

# %%
resultset = df.query(sql).compute()

# %%
type(resultset)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **Resultset has 60 rows and 49 columns**

# %%
resultset.shape
# Out:
# (60, 49)

# %% [markdown]
# **Let's view some basic info on our data set**

# %%
resultset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 183 entries, 9209 to 34490
# Data columns (total 49 columns):
# CMPLID               183 non-null object
# ODINO                183 non-null object
# MFR_NAME             183 non-null object
# MAKETXT              183 non-null object
# MODELTXT             183 non-null object
# YEARTXT              183 non-null object
# CRASH                183 non-null object
# FAILDATE             183 non-null object
# FIRE                 183 non-null object
# INJURED              183 non-null int64
# DEATHS               183 non-null int64
# COMPDESC             183 non-null object
# CITY                 183 non-null object
# STATE                183 non-null object
# VIN                  168 non-null object
# DATEA                183 non-null object
# LDATE                183 non-null object
# MILES                163 non-null object
# OCCURENCES           4 non-null object
# CDESCR               183 non-null object
# CMPL_TYPE            183 non-null object
# POLICE_RPT_YN        183 non-null object
# PURCH_DT             0 non-null object
# ORIG_OWNER_YN        183 non-null object
# ANTI_BRAKES_YN       183 non-null object
# CRUISE_CONT_YN       183 non-null object
# NUM_CYLS             4 non-null object
# DRIVE_TRAIN          4 non-null object
# FUEL_SYS             0 non-null object
# FUEL_TYPE            0 non-null object
# TRANS_TYPE           0 non-null object
# VEH_SPEED            138 non-null object
# DOT                  0 non-null object
# TIRE_SIZE            0 non-null object
# LOC_OF_TIRE          0 non-null object
# TIRE_FAIL_TYPE       0 non-null object
# ORIG_EQUIP_YN        0 non-null object
# MANUF_DT             0 non-null object
# SEAT_TYPE            0 non-null object
# RESTRAINT_TYPE       0 non-null object
# DEALER_NAME          0 non-null object
# DEALER_TEL           0 non-null object
# DEALER_CITY          0 non-null object
# DEALER_STATE         0 non-null object
# DEALER_ZIP           0 non-null object
# PROD_TYPE            183 non-null object
# REPAIRED_YN          0 non-null object
# MEDICAL_ATTN         183 non-null object
# VEHICLES_TOWED_YN    183 non-null object
# dtypes: int64(2), object(47)
# memory usage: 71.5+ KB

# %% [markdown]
# ### Now that I have a pandas data frame, I can take advantage of all of its awesome functions. We can now export the data frame to an Excel or csv file or even to the clipboard.

# %%
resultset.to_excel(r'D:\temp\serious_ford_complaints.xlsx')

# %%
resultset.to_csv(r'D:\temp\serious_ford_complaints.csv', sep=',')

# %%
resultset.to_clipboard()

# %% [markdown]
# ### Or we can output certain columns

# %%
resultset[['YEARTXT','MAKETXT','MODELTXT','CDESCR']].head(10)
# Out:
#       YEARTXT MAKETXT  MODELTXT  \
# 9209     2015    FORD    FUSION
# 9210     2015    FORD    FUSION
# 9242     2010    FORD     FOCUS
# 9642     2004    FORD  WINDSTAR
# 11017    2003    FORD    TAURUS
# 11018    2003    FORD    TAURUS
# 11019    2003    FORD    TAURUS
# 11553    2013    FORD     F-150
# 11616    2010    FORD   MUSTANG
# 11617    2010    FORD   MUSTANG
#
#                                                   CDESCR
# 9209   TL* THE CONTACT OWNS A 2015 FORD FUSION. THE C...
# 9210   TL* THE CONTACT OWNS A 2015 FORD FUSION. THE C...
# 9242   I HAVE OWNED THE CAR SINCE IT WAS NEW NOW HAS ...
# 9642   TL* THE CONTACT OWNED A 2004 FORD WINDSTAR. TH...
# 11017  WE HAD SEVERAL CLOSE CALLS WHERE THE CAR WOULD...
# 11018  WE HAD SEVERAL CLOSE CALLS WHERE THE CAR WOULD...
# 11019  WE HAD SEVERAL CLOSE CALLS WHERE THE CAR WOULD...
# 11553  I¿M REQUESTING THE NHTSA INVESTIGATE F150 ACCE...
# 11616  TL* THE CONTACT OWNS A 2010 FORD MUSTANG. THE ...
# 11617  TL* THE CONTACT OWNS A 2010 FORD MUSTANG. THE ...

# %% [markdown]
# **Since outputting a data frame in a web browser is limiting, here is a simple routine to print and format certain columns. This routine ouputs the first 10 rows of the data frame.**

# %%
for year, make, model, complaint in resultset[['YEARTXT','MAKETXT','MODELTXT','CDESCR']][:10].values:
    print(year + ' ' + make + ' ' + model + ' ==> ' + complaint)
    print('*********************************************************************************************')
# Out:
# 2015 FORD FUSION ==> TL* THE CONTACT OWNS A 2015 FORD FUSION. THE CONTACT STATED THAT WHILE MAKING A TURN, THE BRAKES PULSATED WHEN THE VEHICLE WAS STOPPED. IN ADDITION, THE CONTACT STATED THAT WHILE ATTEMPTING TO PARK, THE BRAKES VIOLENTLY PULSATED AND RESULTED IN AN UNINTENDED ACCELERATION. AS A RESULT, THE CONTACT CRASHED INTO A BUILDING. THE AIR BAGS FAILED TO DEPLOY AND THE SEAT BELT FAILED TO RETRACT. A POLICE REPORT WAS FILED. THERE WAS ONE UNKNOWN INJURY REPORTED THAT DID NOT REQUIRE MEDICAL ATTENTION. THE VEHICLE WAS NOT DIAGNOSED OR REPAIRED. THE MANUFACTURER WAS NOT MADE AWARE OF THE FAILURE. THE FAILURE MILEAGE WAS 30,000.
# *********************************************************************************************
EMPERATURES WERE 30° F. THE THERMOMETER MEASURED TEMPERATURES IN EXCESS OF 140° F FROM ALL VENTS.  THE READING OF THE VENT NEXT TO THE ACCELERATOR WAS 141.5°F. I PLACED AN EMPTY SHOE ON THE ACCELERATOR AND LEFT IT THERE FOR 3 MINUTES. READINGS OF THE SHOE WHILE ON THE ACCELERATOR WERE IN EXCESS OF 120°F. I REMOVED THE SHOE FROM ACCELERATOR AND TOOK READINGS AFTER IT COOLED FOR 3 SECONDS. THE SHOE¿S TEMPERATURE WAS 115°F. THE SHOE REMAINED WARM TO THE TOUCH FOR SEVERAL MINUTES. LEAVING THE VENTS AT THE SAME SETTINGS, I TOOK MEASUREMENTS OF THE BARE SKIN OF MY HANDS AND ARMS. TEMPERATURE READINGS WERE BETWEEN 89-91°F. SKIN CAN BE BURNED IN A RELATIVELY SHORT PERIOD OF TIME WHEN EXPOSED TO TEMPERATURES IN EXCESS OF 120°F. MY OWN DISCOMFORT CONFIRMS THIS. I CONTACTED 3 FORD DEALERS REGARDING THIS PROBLEM AND EXPLAINED MY FINDINGS. TWO DEALERS SAID THAT THE PEDALS IN MY MODEL FORD WERE NONADJUSTABLE, SO THE ISSUE WAS NOT ACTIONABLE. I ALSO CONTACTED FORD DIRECTLY. SO FAR NO SOLUTION.
# *********************************************************************************************
# 2010 FORD MUSTANG ==> TL* THE CONTACT OWNS A 2010 FORD MUSTANG. THE CONTACT STATED THAT WHILE DRIVING AT 65 MPH, THE AUTOMATIC TRACTION CONTROL WARNING LIGHT ILLUMINATED AND THE VEHICLE SUDDENLY ACCELERATED INDEPENDENTLY. THE BRAKE PEDAL WAS DEPRESSED BUT THE VEHICLE FAILED TO STOP. THE CONTACT STATED THAT THE BRAKE PEDAL WAS DEPRESSED THREE TIMES IN ORDER FOR THE VEHICLE TO COME TO A STOP. A POLICE REPORT WAS FILED.  THE VEHICLE WAS TOWED TO THE DEALER. THE VEHICLE WAS NOT DIAGNOSED OR REPAIRED. THE MANUFACTURER WAS NOTIFIED OF THE FAILURE. THE APPROXIMATE FAILURE MILEAGE WAS 13,000.
# *********************************************************************************************
# 2010 FORD MUSTANG ==> TL* THE CONTACT OWNS A 2010 FORD MUSTANG. THE CONTACT STATED THAT WHILE DRIVING AT 65 MPH, THE AUTOMATIC TRACTION CONTROL WARNING LIGHT ILLUMINATED AND THE VEHICLE SUDDENLY ACCELERATED INDEPENDENTLY. THE BRAKE PEDAL WAS DEPRESSED BUT THE VEHICLE FAILED TO STOP. THE CONTACT STATED THAT THE BRAKE PEDAL WAS DEPRESSED THREE TIMES IN ORDER FOR THE VEHICLE TO COME TO A STOP. A POLICE REPORT WAS FILED.  THE VEHICLE WAS TOWED TO THE DEALER. THE VEHICLE WAS NOT DIAGNOSED OR REPAIRED. THE MANUFACTURER WAS NOTIFIED OF THE FAILURE. THE APPROXIMATE FAILURE MILEAGE WAS 13,000.
# *********************************************************************************************

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
def f(x):
    return x

# %%
interact(f, x=10);
# Out:
# interactive(children=(IntSlider(value=10, description='x', max=30, min=-10), Output()), _dom_classes=('widget-interact',))
