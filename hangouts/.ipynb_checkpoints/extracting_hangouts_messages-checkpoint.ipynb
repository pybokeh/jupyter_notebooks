# %%
import pandas as pd
import json

# %%
parsed_json = json.loads(open('/home/pybokeh/temp/Takeout/Hangouts/Hangouts.json').read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-d7bc5256493b> in <module>()
# ----> 1 parsed_json = json.loads(open('/home/pybokeh/temp/Takeout/Hangouts/Hangouts.json').read())
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/pybokeh/temp/Takeout/Hangouts/Hangouts.json'

# %%
annie = parsed_json['conversation_state'][14]['conversation_state']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2ca67edbe6b5> in <module>()
# ----> 1 annie = parsed_json['conversation_state'][14]['conversation_state']
#
# NameError: name 'parsed_json' is not defined

# %%
str_messages = ''
for record in annie['event']:
    try:
        print(record['chat_message']['message_content']['segment'][0]['text'])
        str_messages = str_messages + str(record['chat_message']['message_content']['segment'][0]['text'])
    except:
        continue
        
outfile = open('/home/pybokeh/temp/output.txt','w')
outfile.write(str_messages)
outfile.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-988ab66a3587> in <module>()
#       1 str_messages = ''
# ----> 2 for record in annie['event']:
#       3     try:
#       4         print(record['chat_message']['message_content']['segment'][0]['text'])
#       5         str_messages = str_messages + str(record['chat_message']['message_content']['segment'][0]['text'])
#
# NameError: name 'annie' is not defined

# %%
# %matplotlib inline
from os import path
from scipy.misc import imread
import matplotlib.pyplot as plt
from matplotlib.ticker import NullLocator
from wordcloud import WordCloud, STOPWORDS
d = path.dirname('/home/pybokeh/Downloads/')
# Read the whole text.
#text = strWords
text = open(path.join(d, 'text_messages.txt')).read()

# read the mask image
# taken from
# http://www.stencilry.org/stencils/movies/alice%20in%20wonderland/255fk.jpg
alice_mask = imread(path.join(d, "alice_mask.png"), flatten=True)
wc = WordCloud(background_color="white", max_words=2000, mask=alice_mask)

# generate word cloud
wc.generate(text)
# store to file
wc.to_file(path.join(d, "alice.png"))
# show
plt.imshow(wc)
plt.axis("off")
plt.figure()
plt.imshow(alice_mask, cmap=plt.cm.gray)
plt.axis("off")
plt.show()
# Out:
# /home/pybokeh/envs/jupyter/lib/python3.5/site-packages/wordcloud/wordcloud.py:286: UserWarning: mask image should be unsigned byte between 0 and 255. Got a float array
#   warnings.warn("mask image should be unsigned byte between 0 and"

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("white")

# %%
df = word_freq.sort_values(by='qty', ascending=False)[:50]

fig, axes = plt.subplots(figsize=(14,12))
sns.barplot(x="qty", y='word', data=df, ax=axes)
plt.title("Top 50 Words", fontsize=14, weight='bold')
plt.xticks([])
plt.xlabel('')
plt.ylabel('')
# Add values to the right of the bars
for p, value in zip(range(len(df)), df.qty):
    plt.annotate(str(value), xy=(value + 1, p), va='center')
sns.despine(bottom=True)
