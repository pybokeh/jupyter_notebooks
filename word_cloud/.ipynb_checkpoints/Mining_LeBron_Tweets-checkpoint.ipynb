# %%
#Import the necessary methods from tweepy library
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

#Variables that contains the user credentials to access Twitter API 
access_token = "your_access_token"
access_token_secret = "your_access_secret_token"
consumer_key = "your_consumer_key"
consumer_secret = "your_consumer_secret"


#This is a basic listener that just prints received tweets to stdout.
class StdOutListener(StreamListener):

    def on_data(self, data):
        print(data)
        return True

    def on_error(self, status):
        print(status)


if __name__ == '__main__':

    #This handles Twitter authetification and the connection to Twitter Streaming API
    l = StdOutListener()
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    stream = Stream(auth, l)

    #This line filter Twitter Streams to capture data by the keywords: 'honda'
    stream.filter(track=['lebron','LeBron','LEBRON'])

# %% [markdown]
# ### Then from your terminal, execute this script with output piped to a text file: your_script.py > tweets_data.txt

# %% [markdown]
# # Then run this script below to create a Python dataframe of the tweets data

# %%
# %matplotlib inline
import json
import pandas as pd
import matplotlib.pyplot as plt
from os import path

d = path.dirname('/home/pybokeh/temp/')
#text = open(path.join(d, 'lebron_tweets_data.txt')).read()

tweets_data = []
tweets_file = open(path.join(d, 'lebron_tweets_data.txt'),'r')
for line in tweets_file:
    try:
        tweet = json.loads(line)
        tweets_data.append(tweet)
    except:
        continue

print(len(tweets_data))
# Out:
# 1627

# %%
tweets_data[2]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sun Mar 22 17:42:16 +0000 2015',
#  'entities': {'hashtags': [{'indices': [23, 29], 'text': 'shoes'}],
#   'symbols': [],
#   'trends': [],
#   'urls': [{'display_url': 'ift.tt/1EGrmPo',
#     'expanded_url': 'http://ift.tt/1EGrmPo',
#     'indices': [0, 22],
#     'url': 'http://t.co/VGLmUJgk9K'}],
#   'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 579699629559816192,
#  'id_str': '579699629559816192',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'lang': 'en',
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://ifttt.com" rel="nofollow">IFTTT</a>',
#  'text': 'http://t.co/VGLmUJgk9K #shoes Nike ricardo tisci Rt air force 1 af1 size 11 jordan lebron kobe kd 1 2 3 4 5 11',
#  'timestamp_ms': '1427046136642',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Fri Jan 01 00:51:42 +0000 2010',
#   'default_profile': False,
#   'default_profile_image': False,
#   'description': 'Just a regular tweeter tweeting.  Funding our outer space performance.',
#   'favourites_count': 16,
#   'follow_request_sent': None,
#   'followers_count': 481,
#   'following': None,
#   'friends_count': 2,
#   'geo_enabled': False,
#   'id': 100872317,
#   'id_str': '100872317',
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 79,
#   'location': 'Bossland, KS',
#   'name': 'Band Space Mission',
#   'notifications': None,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/63257525/Buzz-Background-5.jpg',
#   'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/63257525/Buzz-Background-5.jpg',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/603063490/fbbasicdesign2_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/603063490/fbbasicdesign2_normal.jpg',
#   'profile_link_color': '0084B4',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'KKPIOS',
#   'statuses_count': 496894,
#   'time_zone': 'Central Time (US & Canada)',
#   'url': 'http://thezbay.wordpress.com/',
#   'utc_offset': -18000,
#   'verified': False}}

# %%
tweets = pd.DataFrame()
tweets['text']      = [tweet['text'] for tweet in tweets_data]
tweets['lang']      = [tweet['lang'] for tweet in tweets_data]
tweets['retweeted'] = [tweet['retweeted'] for tweet in tweets_data]

# %%
tweets
# Out:
#                                                    text lang retweeted
# 0     http://t.co/q2ye1AdLou #fashion Nike ricardo t...   en     False
# 1     http://t.co/D8yMEryiv1 #fashion LeBron 12 what if   en     False
# 2     http://t.co/VGLmUJgk9K #shoes Nike ricardo tis...   en     False
# 3       http://t.co/d7oqXovgcr #shoes LeBron 12 what if   en     False
# 4     "@GreatValueCeleb: Great value Lebron's hairli...   en     False
# 5     RT @BrosConfessions: Lebron better than Jordan...   en     False
# 6     RT @CauseWereGuys: Lebron better than Jordan? ...   en     False
# 7     RT @Manstagram_: Rt for Jackie Moon fav for Le...   en     False
# 8     RT @Manstagram_: Rt for Jackie Moon fav for Le...   en     False
# 9     RT @otgbasketball: NEW! LeBron Has a Case for ...   en     False
# 10    RT @BrosConfessions: Lebron better than Jordan...   en     False
# 11    RT @SneakerPics23: First look at the LeBron 12...   en     False
# 12    RT @SneakerPics23: First look at the LeBron 12...   en     False
# 13    http://t.co/PWJW8F79Vg #Nike Lebron X 10 Flori...   en     False
# 14    RT @allaccess_nba: “@TheSportsMatrix: Who is t...   en     False
# 15    http://t.co/Sln7zzbtHm #NIKE - LEBRON XI 11 PR...   en     False
# 16    http://t.co/3nNcABUDlg #NIKE JORDAN IV REMASTE...   da     False
# 17    【随時更新中】\n#JORDAN #LEBRON #AIRMAX #DUNK #FOAMPO...   ja     False
# 18    RT @CHlLDHOODRUINER: Lebron better than Jordan...   en     False
# 19    http://t.co/APdv44E7BM #Nike Lebron 12 (XII) i...   hu     False
# 20    RT @Manstagram_: Rt for Jackie Moon fav for Le...   en     False
# 21           Brought the Lebron 9 galaxies out today. .   en     False
# 22    L #NBA #Basketball $300? LOT of (26) LEBRON JA...   en     False
# 23    RT @BrosConfessions: Lebron better than Jordan...   en     False
# 24    L #NBA #Basketball NWT Authentic #Adidas Miami...   en     False
# 25                          So kd uses lebron on 2k ...   en     False
# 26    L #Basketball #Buzz Vintage Cleveland #Cavalie...   en     False
# 27    RT @Trevor_kainn: So this the nigga who been f...   en     False
# 28    L #LeBron #TShirts MEN'S NIKE SHIRT - Size Lar...   en     False
# 29    Comparan a Brittney Griner (Número 1 del Draft...   es     False
# ...                                                 ...  ...       ...
# 1116  RT @MensHumor: Lebron better than Jordan? Phss...   en     False
# 1117                         Que pena - Hermanos Lebron   es     False
# 1118  http://t.co/2bvxjJO904 Nike Lebron XI 10.5 Kin...   en     False
# 1119  http://t.co/4UCMsQzt8n #Nike Lebron XI 10.5 Ki...   en     False
# 1120  RT @SneakerPics23: First look at the LeBron 12...   en     False
# 1121  James Harden Suspended 1 Game for Kicking LeBr...   en     False
# 1122  RT @MensHumor: Lebron better than Jordan? Phss...   en     False
# 1123  RT @AcrossTheCourt_: Players to average 30 PPG...   en     False
# 1124  RT @MensHumor: Lebron better than Jordan? Phss...   en     False
# 1125  LEBRON JAMES KID / VINE - YouTube http://t.co/...   en     False
# 1126                         @OG_Kaci Lebron Jaaaames 😂   en     False
# 1127                           #Papa #Lebron cn la bola   es     False
# 1128  RT @MensHumor: Lebron better than Jordan? Phss...   en     False
# 1129  RT @MensHumor: Lebron better than Jordan? Phss...   en     False
# 1130  RT @MensHumor: Lebron better than Jordan? Phss...   en     False
# 1131  RT @AcrossTheCourt_: Players to average 30 PPG...   en     False
# 1132  @PhantasyMike @APfeifer24 @ProjectRoto lebron-...   en     False
# 1133  RT @MensHumor: Lebron better than Jordan? Phss...   en     False
# 1134  RT @AcrossTheCourt_: Players to average 30 PPG...   en     False
# 1135  RT @MensHumor: Lebron better than Jordan? Phss...   en     False
# 1136  “@HerveyChris: Nobody wants to watch Miami pla...   en     False
# 1137  RT @MensHumor: Lebron better than Jordan? Phss...   en     False
# 1138  RT @MensHumor: Lebron better than Jordan? Phss...   en     False
# 1139  RT @BrosConfessions: Lebron better than Jordan...   en     False
# 1140  New on Ebay UK! Nike LeBron James x10 limited ...   en     False
# 1141  RT @ClickHole: The Next LeBron James? This Bab...   en     False
# 1142  RT @Barajas_el: Gasol toreando a LeBron. PUTO ...   es     False
# 1143  RT @MensHumor: Lebron better than Jordan? Phss...   en     False
# 1144  RT @MensHumor: Lebron better than Jordan? Phss...   en     False
# 1145  RT @MensHumor: Lebron better than Jordan? Phss...   en     False
#
# [1146 rows x 3 columns]

# %%
english_tweets = tweets[(tweets['lang']=='en') & (tweets['retweeted']==False)]

# %%
english_tweets.drop_duplicates(subset='text');

# %%
text = ''
for line in english_tweets['text']:
    text = text + ' ' + line

# %%
# %matplotlib inline
from os import path
from scipy.misc import imread
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
d = path.dirname('/home/pybokeh/Downloads/')
# Read the whole text.
#text = strWords
#text = open(path.join(d, 'alice.txt')).read()

"""
additional_words = [
'rt',
'ebay'
]

for word in additional_words:
    STOPWORDS.add(word)"""

# read the mask image
# taken from
# http://www.stencilry.org/stencils/movies/alice%20in%20wonderland/255fk.jpg
# honda_mask = imread(path.join(d, "lebron_james_mask.png"), flatten=True)
# wc = WordCloud(background_color="black", max_words=2000, mask=honda_mask, stopwords=STOPWORDS)
wc = WordCloud(width=800, height=600).generate(text)

# generate word cloud
#wc.generate(text)

# store to file
wc.to_file(path.join(d, "lebron_word_cloud_simple.png"))

# show
plt.imshow(wc)
plt.axis("off")
#plt.figure()
#plt.imshow(honda_mask, cmap=plt.cm.gray)
#plt.axis("off")
plt.show()

# %%
# %matplotlib inline
from os import path
from scipy.misc import imread
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
d = path.dirname('/home/pybokeh/Downloads/')
# Read the whole text.
#text = strWords
#text = open(path.join(d, 'alice.txt')).read()

"""
additional_words = [
'rt',
'ebay'
]

for word in additional_words:
    STOPWORDS.add(word)"""

# read the mask image
# taken from
# http://www.stencilry.org/stencils/movies/alice%20in%20wonderland/255fk.jpg
honda_mask = imread(path.join(d, "lebron_james_mask.png"), flatten=True)
wc = WordCloud(background_color="black", max_words=2000, mask=honda_mask, stopwords=STOPWORDS)

# generate word cloud
wc.generate(text)

# store to file
wc.to_file(path.join(d, "lebron_word_cloud_masked.png"))

# show
plt.imshow(wc)
plt.axis("off")
#plt.figure()
#plt.imshow(honda_mask, cmap=plt.cm.gray)
#plt.axis("off")
plt.show()

# %%
wc.process_text(text)[:50]
# Out:
# [('Lebron', 1.0),
#  ('RT', 0.5300687285223368),
#  ('Jordan', 0.33075601374570446),
#  ('better', 0.3088487972508591),
#  ('talk', 0.30498281786941583),
#  ('Looney', 0.30412371134020616),
#  ('saves', 0.30412371134020616),
#  ('Alien', 0.30369415807560135),
#  ('Race', 0.30326460481099654),
#  ('t', 0.28307560137457044),
#  ('co', 0.27878006872852235),
#  ('Phsshh', 0.25687285223367695),
#  ('Toons', 0.25687285223367695),
#  ('MensHumor', 0.25171821305841924),
#  ('James', 0.125),
#  ('2x', 0.07388316151202749),
#  ('year', 0.06486254295532647),
#  ('Pshh', 0.04768041237113402),
#  ('Tunes', 0.04725085910652921),
#  ('Kobe', 0.040807560137457045),
#  ('looking', 0.040807560137457045),
#  ('BrosConfessions', 0.03951890034364261),
#  ('bald', 0.036941580756013746),
#  ('iLoveeCornbread', 0.036941580756013746),
#  ('son', 0.036941580756013746),
#  ('D6XkTAx8A9', 0.03479381443298969),
#  ('Nike', 0.03350515463917526),
#  ('Size', 0.03221649484536082),
#  ('fav', 0.03178694158075601),
#  ('PPG', 0.0313573883161512),
#  ('NBA', 0.0313573883161512),
#  ('average', 0.03049828178694158),
#  ('season', 0.029639175257731958),
#  ('Manstagram_', 0.029209621993127148),
#  ('Jackie', 0.028780068728522335),
#  ('Moon', 0.028780068728522335),
#  ('KA1Rg7PfwC', 0.028350515463917526),
#  ('https', 0.027920962199312716),
#  ('Players', 0.027920962199312716),
#  ('Kevin', 0.027061855670103094),
#  ('Durant', 0.02663230240549828),
#  ('last', 0.02620274914089347),
#  ('Bryant', 0.02577319587628866),
#  ('Allen', 0.02491408934707904),
#  ('Iver', 0.024054982817869417),
#  ('AcrossTheCourt_', 0.024054982817869417),
#  ('Cleveland', 0.02276632302405498),
#  ('Basketball', 0.019329896907216496),
#  ('look', 0.018900343642611683),
#  ('playing', 0.018470790378006873)]

# %%
STOPWORDS
# Out:
# {'',
#  'RT',
#  'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'eBay',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  "let's",
#  'like',
#  'me',
#  'more',
#  'most',
#  "mustn't",
#  'my',
#  'myself',
#  'no',
#  'nor',
#  'not',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'ought',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'r',
#  'same',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  'than',
#  'that',
#  "that's",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  "there's",
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  'very',
#  'was',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  "weren't",
#  'what',
#  "what's",
#  'when',
#  "when's",
#  'where',
#  "where's",
#  'which',
#  'while',
#  'who',
#  "who's",
#  'whom',
#  'why',
#  "why's",
#  'with',
#  "won't",
#  'would',
#  "wouldn't",
#  'www',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}
