# %% [markdown]
# # ZF Transmission Voucher Creation Orchestrator

# %%
from win10toast import ToastNotifier
import papermill as pm
import time

# %% [markdown]
# ### NOTE:

# %% [markdown]
# Prior to running this notebook, make sure all "No Reply" TPLs have been re-opened in the CQ portal.  Otherwise, they will be erroneously excluded from the vouchers which will result in under-charging ZF.

# %% [markdown]
# ### Define parameters to be used in the voucher creation process:

# %% [markdown]
# **NOTE:** When adding a new fixed model year for the first time, remember to set your start voucher date to 2014-01-01 so that we capture the newly added model year's claims from the very beginning.

# %%
fixed_model_years = ['2015','2016']
start_voucher_date = '2018-09-01'
end_voucher_date = '2018-09-30'
honda_hourly_labor_rate = 120
acura_hourly_labor_rate = 141
part_cost_factor = 0.9
handling_cost_factor = 0.63

# %% [markdown]
# ### 1) Execute notebook to obtain CLA claims with or without TPLs and save output to Excel:

# %%
# %%time
pm.execute_notebook(
    '1_Obtain_CLA_Claims_With_or_Without_TPLs.ipynb',
    'output/CLA_Claims_With_or_Without_TPLs.ipynb',
    cwd='D:\\jupyter\\projects\\ZF_Automation\\papermill',
    parameters = dict(fixed_model_years=fixed_model_years)
)
# Out:
# HBox(children=(IntProgress(value=0, max=52), HTML(value='')))
# Wall time: 10min 5s
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:14:58.138963',
#      'end_time': '2019-04-23T15:14:58.170220',
#      'duration': 0.031257,
#      'status': 'completed'}},
#    'source': '# PURPOSE:'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:14:58.201471',
#      'end_time': '2019-04-23T15:14:58.232725',
#      'duration': 0.031254,
#      'status': 'completed'}},
#    'source': '### Obtain and then prepare CLA claims with or without TPLs so that ZF transmission vouchers can be generated'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:14:58.287844',
#      'end_time': '2019-04-23T15:14:58.319098',
#      'duration': 0.031254,
#      'status': 'completed'}},
#    'source': 'Created by Daniel J. Kim - HAM Warranty Cost Analyst'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:14:58.334725',
#      'end_time': '2019-04-23T15:14:58.376104',
#      'duration': 0.041379,
#      'status': 'completed'}},
#    'source': '## Some data quality/anomaly issues to be aware of:\n\n- TRANS_SERIAL_NO in the WRSAL1 and WRTRN1 table has trailing white spaces.\n- Missing TRANS_SERIAL_NO will cause the creation of the E-Quote part # to be invalid'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:14:58.404321',
#      'end_time': '2019-04-23T15:14:58.419950',
#      'duration': 0.015629,
#      'status': 'completed'}},
#    'source': '## Input:'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:14:58.466830',
#      'end_time': '2019-04-23T15:14:58.498084',
#      'duration': 0.031254,
#      'status': 'completed'}},
#    'source': '- fixed model years'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:14:58.542662',
#      'end_time': '2019-04-23T15:14:58.569494',
#      'duration': 0.026832,
#      'status': 'completed'}},
#    'source': '## Output:'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:14:58.600748',
#      'end_time': '2019-04-23T15:14:58.632001',
#      'duration': 0.031253,
#      'status': 'completed'}},
#    'source': '- Excel file containing initial data for non-fixed claims (CLA claims with closed TPLs)\n- Excel file containing initial data for fixed claims (CLA claims without closed TPLs)'},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:14:58.666998',
#      'end_time': '2019-04-23T15:15:01.160685',
#      'duration': 2.493687,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "from datetime import datetime\nfrom pathlib import Path\nfrom win10toast import ToastNotifier\nimport numpy as np\nimport pandas as pd\nimport os\nimport os.path as op\nimport pyodbc\nimport scrapbook as sb\npd.options.display.max_columns=100\npd.options.display.max_rows=1000\npd.options.display.float_format = '{:20,.2f}'.format"},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:15:01.210429',
#      'end_time': '2019-04-23T15:15:01.272594',
#      'duration': 0.062165,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "username = os.environ['windowsuser']\npassword = os.environ['windowspwd']"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:15:01.322728',
#      'end_time': '2019-04-23T15:15:01.374868',
#      'duration': 0.05214,
#      'status': 'completed'}},
#    'source': '### Request input parameters from user:'},
#   {'cell_type': 'code',
#    'execution_count': 3,
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:15:01.420285',
#      'end_time': '2019-04-23T15:15:01.544974',
#      'duration': 0.124689,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "fixed_model_years = ['2015','2016']"},
#   {'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:15:01.576228',
#      'end_time': '2019-04-23T15:15:01.695738',
#      'duration': 0.11951,
#      'status': 'completed'}},
#    'execution_count': 4,
#    'source': '# Parameters\nfixed_model_years = ["2015", "2016"]\n',
#    'outputs': []},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:15:01.726993',
#      'end_time': '2019-04-23T15:15:01.779917',
#      'duration': 0.052924,
#      'status': 'completed'}},
#    'source': '### Obtain CLA "approved" claim records with or without TPLs:'},
#   {'cell_type': 'code',
#    'execution_count': 5,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:15:01.830050',
#      'end_time': '2019-04-23T15:24:06.936634',
#      'duration': 545.106584,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Obtaining CLA claim records with and without TPLs.  Will take more than 5 minutes...'},
#     {'output_type': 'stream', 'name': 'stdout', 'text': '\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Finished obtaining CLA claim records with and without TPLs'},
#     {'output_type': 'stream', 'name': 'stdout', 'text': '\n'},
#     {'output_type': 'stream', 'name': 'stdout', 'text': 'Wall time: 9min 5s'},
#     {'output_type': 'stream', 'name': 'stdout', 'text': '\n'}],
#    'source': '%%time\ncnxn_string = \'DSN=MMP-SQLP-CQP;UID=\' + username + \';PWD=\' + password\n\ncnxn = pyodbc.connect(cnxn_string)\ncursor = cnxn.cursor()\n\nsql = open(r\'\\\\mmpapp02\\mq_db\\wrp\\ZF_ATM_WRP_Project\\version4\\sql\\Main_Query_All_TPLs.txt\').read()\n\ntry:\n    print("Obtaining CLA claim records with and without TPLs.  Will take more than 5 minutes...")\n    claims = pd.read_sql(sql, cnxn, parse_dates=[\'SUBMITTED_DATE\', \'REOPENED_SUBMITTED_DATE\', \'REPAIR_ORDER_DATE\',\n                                              \'AF_OFF_DATE\', \'ENGINE_BUILD_DATE\'], index_col=None)\n\n    # Close connections\n    cursor.close()\n    cnxn.close()\nexcept:\n    print("Error connecting to CQ server")\n    cursor.close()\n    cnxn.close()\nprint("Finished obtaining CLA claim records with and without TPLs")'},
#   {'cell_type': 'code',
#    'execution_count': 6,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:06.999049',
#      'end_time': '2019-04-23T15:24:07.053152',
#      'duration': 0.054103,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '(33931, 71)'},
#      'execution_count': 6}],
#    'source': 'claims.shape'},
#   {'cell_type': 'code',
#    'execution_count': 7,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:07.092255',
#      'end_time': '2019-04-23T15:24:07.254995',
#      'duration': 0.16274,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '2016    24408\n2015     7273\n2017     1224\n2018      816\n2019      210\nName: MODEL_YEAR, dtype: int64'},
#      'execution_count': 7}],
#    'source': 'claims.MODEL_YEAR.value_counts()'},
#   {'cell_type': 'code',
#    'execution_count': 8,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:07.317298',
#      'end_time': '2019-04-23T15:24:07.440644',
#      'duration': 0.123346,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '                  VIN_DLR_CLM_SK  WAR_CLAIM_DATE                VIN  \\\n0  5FNYF6H9XGB502341001119953121          201609  5FNYF6H9XGB502341   \n1  5FNYF6H96GB501798001158721071          201609  5FNYF6H96GB501798   \n2  5FNYF6H96GB501798001158721071          201609  5FNYF6H96GB501798   \n3  5FNYF6H96GB501798001158721072          201610  5FNYF6H96GB501798   \n4  5FNYF6H91GB503328001113688052          201605  5FNYF6H91GB503328   \n\n             TPL_VIN PICKUP_DATE SUBMITTED_DATE REOPENED_DATE  \\\n0  5FNYF6H9XGB502341  2016-10-12     2016-11-16    2017-01-13   \n1  5FNYF6H96GB501798  2016-10-12     2016-11-16    2017-02-28   \n2  5FNYF6H96GB501798  2016-10-12     2016-11-16    2017-02-28   \n3  5FNYF6H96GB501798  2016-11-03     2016-12-08    2017-01-13   \n4  5FNYF6H91GB503328  2016-04-22     2016-06-07    2016-06-09   \n\n  REOPENED_SUBMITTED_DATE FINAL_CLOSURE_DATE STATUS_NAME STATUS_OPEN_CLOSED  \\\n0              2017-01-18         2017-01-18      CLOSED             CLOSED   \n1              2017-03-31         2017-03-31      CLOSED             CLOSED   \n2              2017-03-31         2017-03-31      CLOSED             CLOSED   \n3              2017-01-18         2017-01-18      CLOSED             CLOSED   \n4              2016-07-13         2016-07-13      CLOSED             CLOSED   \n\n  TPL_SHORT_PART_NO PART_CATEGORY      DAYS_TO_CLOSURE            DAYS_OPEN  \\\n0             06200  TRANSMISSION                98.00                98.00   \n1             06200  TRANSMISSION               170.00               170.00   \n2             06200  TRANSMISSION               170.00               170.00   \n3             06200  TRANSMISSION                76.00                76.00   \n4             06280           KIT                82.00                82.00   \n\n         WARR_PART_NO                            CUSTOMER_CONTENTION_TXT  \\\n0  062005EZC09         ROAD TEST FOR SLIPPAGE NOISE HEARD WHEN ACCELE...   \n1  062005EZC07RM       REPLACE TRANSMISSION AS PER TECHLINE RECOMMEND...   \n2  062005EZC07RM       REPLACE TRANSMISSION AS PER TECHLINE RECOMMEND...   \n3  062005EZC07RM       REPLACE TRANSMISSION AS PER TECHLINE RECOMMEND...   \n4  062015EZC05         REPLACED TRANSMISSION CONFIRMED WITH TECHLINE ...   \n\n                        VISUAL_INSPECTION_DETAIL_TXT  \\\n0  Visual inspection ok ~ Engine coolant leaking ...   \n1        Visual inspection ok ~ Visual inspection ok   \n2        Visual inspection ok ~ Visual inspection ok   \n3  Engine coolant leaking into ATF ~ Engine coola...   \n4   ~ Dana oil cooler is leaking engine coolant i...   \n\n                    FUNCTIONAL_INSPECTION_DETAIL_TXT  \\\n0  Functional ok ~ Slippage of gears, leaking, re...   \n1             Function ok ~ functional inspection ok   \n2             Function ok ~ functional inspection ok   \n3  Bad shift from 3rd to 4th; replaced transmissi...   \n4                   ~ Transmission has a harsh shift   \n\n              CATEGORY_DESC_TXT  \\\n0   Oil Cooler Diaphram Damaged   \n1            Old Style Clutch B   \n2            Old Style Clutch B   \n3   Oil Cooler Diaphram Damaged   \n4  Oil Cooler Diamphram damaged   \n\n                       SUPPLIER_ANALYSIS_SUMMARY_TXT DEALER_NO WAR_CLAIM_NO  \\\n0    Defective oil cooler responsible for contention    001119       953121   \n1  Transmission for Old Style Clutch B and 2 to 3...    001158       721071   \n2  Transmission for Old Style Clutch B and 2 to 3...    001158       721071   \n3    Defective oil cooler responsible for contention    001158       721072   \n4   Defective oil cooler caused transmission failure    001113       688052   \n\n                                  CUS_CONT_DESC_TEXT REPAIR_ORDER_DATE  \\\n0  ROAD TEST FOR SLIPPAGE NOISE HEARD WHEN ACCELE...        2016-08-09   \n1  REPLACE TRANSMISSION AS PER TECHLINE RECOMMEND...        2016-07-05   \n2  REPLACE TRANSMISSION AS PER TECHLINE RECOMMEND...        2016-07-05   \n3  REPLACE TR ...
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>VIN_DLR_CLM_SK</th>\n      <th>WAR_CLAIM_DATE</th>\n      <th>VIN</th>\n      <th>TPL_VIN</th>\n      <th>PICKUP_DATE</th>\n      <th>SUBMITTED_DATE</th>\n      <th>REOPENED_DATE</th>\n      <th>REOPENED_SUBMITTED_DATE</th>\n      <th>FINAL_CLOSURE_DATE</th>\n      <th>STATUS_NAME</th>\n      <th>STATUS_OPEN_CLOSED</th>\n      <th>TPL_SHORT_PART_NO</th>\n      <th>PART_CATEGORY</th>\n      <th>DAYS_TO_CLOSURE</th>\n      <th>DAYS_OPEN</th>\n      <th>WARR_PART_NO</th>\n      <th>CUSTOMER_CONTENTION_TXT</th>\n      <th>VISUAL_INSPECTION_DETAIL_TXT</th>\n      <th>FUNCTIONAL_INSPECTION_DETAIL_TXT</th>\n      <th>CATEGORY_DESC_TXT</th>\n      <th>SUPPLIER_ANALYSIS_SUMMARY_TXT</th>\n      <th>DEALER_NO</th>\n      <th>WAR_CLAIM_NO</th>\n      <th>CUS_CONT_DESC_TEXT</th>\n      <th>REPAIR_ORDER_DATE</th>\n      <th>RECEIVED_DATE</th>\n      <th>AF_OFF_DATE</th>\n      <th>ENGINE_BUILD_DATE</th>\n      <th>PRI_LABOR_OP_CODE</th>\n      <th>WAR_ORIG_DISTR_CDE</th>\n      <th>WAR_RESP_DISTR_CDE</th>\n      <th>VEHICLE_DESTN_CODE</th>\n      <th>FLAT_RATE_HRS_QTY</th>\n      <th>FRGT_SUBL_TAX_AMT_USD</th>\n      <th>DIAGNOSTIC_LABOR_HRS_QTY</th>\n      <th>TPL_CREATION_DATE</th>\n      <th>RESPONSIBILITY_PCT</th>\n      <th>CONCLUSION_DESC_TXT</th>\n      <th>VEH_MILEAGE</th>\n      <th>CURRENCY_TYPE_CODE</th>\n      <th>ACTUAL_PARTS_CHG_AMT_USD</th>\n      <th>ACTUAL_LABOR_CHG_AMT_USD</th>\n      <th>ACTUAL_HDLG_CHG_AMT_USD</th>\n      <th>ACTUAL_TOTAL_CHG_AMT_USD</th>\n      <th>CAMPAIGN_CODE</th>\n      <th>WAR_DEFECT_CODE</th>\n      <th>RECORD_DESC</th>\n      <th>RECORD_COUNT</th>\n      <th>REPLACED_PART5</th>\n      <th>REPLACED_PART_NO</th>\n      <th>PART_DESC</th>\n      <th>ACT_PARTS_QTY_NO</th>\n      <th>MTC_MODEL</th>\n      <th>MTC_TYPE</th>\n      <th>MTC_OPTION</th>\n      <th>TRANS_SERIAL_NO</th>\n      <th>NAMEPLATE</th>\n      <th>MODEL_YEAR</th>\n      <th>FACTORY</th>\n      <th>MOD_NAME</th>\n      <th>TRANSMISSION_GEARS</th>\n      <th>REPLACED_PART_EQUOTE_FMT</th>\n      <th>CLAIM_LABOR_HRS_QTY</th>\n      <th>WAR_EXCH_RATE_AMT</th>\n      <th>DLR_NET_PRCE_AMT_USD</th>\n      <th>PART_FOB_COST_USD</th>\n      <th>DLR_NET_PRCE_AMTx90_USD</th>\n      <th>PART_FOB_COSTx2_USD</th>\n      <th>MIN_PART_COST_USD</th>\n      <th>TRANSFER_PART_LIST_ITEM_DETAIL_SK</th>\n      <th>REPL_ROW_NUM</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>5FNYF6H9XGB502341001119953121</td>\n      <td>201609</td>\n      <td>5FNYF6H9XGB502341</td>\n      <td>5FNYF6H9XGB502341</td>\n      <td>2016-10-12</td>\n      <td>2016-11-16</td>\n      <td>2017-01-13</td>\n      <td>2017-01-18</td>\n      <td>2017-01-18</td>\n      <td>CLOSED</td>\n      <td>CLOSED</td>\n      <td>06200</td>\n      <td>TRANSMISSION</td>\n      <td>98.00</td>\n      <td>98.00</td>\n      <td>062005EZC09</td>\n      <td>ROAD TEST FOR SLIPPAGE NOISE HEARD WHEN ACCELE...</td>\n      <td>Visual inspection ok ~ Engine coolant leaking ...</td>\n      <td>Functional ok ~ Slippage of gears, leaking, re...</td>\n      <td>Oil Cooler Diaphram Damaged</td>\n      <td>Defective oil cooler responsible for contention</td>\n      <td>001119</td>\n      <td>953121</td>\n      <td>ROAD TEST FOR SLIPPAGE NOISE HEARD WHEN ACCELE...</td>\n      <td>2016-08-09</td>\n      <td>2016-09-21</td>\n      <td>2015-07-14</td>\n      <td>2015-07-10</td>\n      <td>2181U3</td>\n      <td>130</td>\n      <td>15A</td>\n      <td>KC</td>\n      <td>6.50</td>\n      <td>148.05</td>\n      <td>0.00</td>\n      <td>2016-10-10 13:48:46.733</td>\n      <td>100</td>\n      <td>Supplier Mfg. Defect</td> ...
#      'execution_count': 8}],
#    'source': 'claims.head()'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:07.471653',
#      'end_time': '2019-04-23T15:24:07.502881',
#      'duration': 0.031228,
#      'status': 'completed'}},
#    'source': "#### Discovered we can have VINs with missing transmission serial number (plain white space) which messes up the replaced part # formatted for equote: '20021' + SUBSTRING(WRSAL1.TRANS_SERIAL_NO,2,3) AS REPLACED_PART_EQUOTE_FMT"},
#   {'cell_type': 'code',
#    'execution_count': 9,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:07.546354',
#      'end_time': '2019-04-23T15:24:07.638029',
#      'duration': 0.091675,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '                      VIN_DLR_CLM_SK  WAR_CLAIM_DATE                VIN  \\\n31309  5FRYD4H92GB022416251336392305          201801  5FRYD4H92GB022416   \n\n      TPL_VIN PICKUP_DATE SUBMITTED_DATE REOPENED_DATE  \\\n31309    None         NaT            NaT           NaT   \n\n      REOPENED_SUBMITTED_DATE FINAL_CLOSURE_DATE STATUS_NAME  \\\n31309                     NaT                NaT        None   \n\n      STATUS_OPEN_CLOSED TPL_SHORT_PART_NO PART_CATEGORY      DAYS_TO_CLOSURE  \\\n31309               None              None          None                  nan   \n\n                 DAYS_OPEN        WARR_PART_NO CUSTOMER_CONTENTION_TXT  \\\n31309                  nan  062005NBA58                           None   \n\n      VISUAL_INSPECTION_DETAIL_TXT FUNCTIONAL_INSPECTION_DETAIL_TXT  \\\n31309                           ~                                ~    \n\n      CATEGORY_DESC_TXT SUPPLIER_ANALYSIS_SUMMARY_TXT DEALER_NO WAR_CLAIM_NO  \\\n31309              None                          None  251336     392305       \n\n              CUS_CONT_DESC_TEXT REPAIR_ORDER_DATE RECEIVED_DATE AF_OFF_DATE  \\\n31309  Zf 9 a/t trans warmer pud        2017-12-20    2018-01-05  2015-05-06   \n\n      ENGINE_BUILD_DATE PRI_LABOR_OP_CODE WAR_ORIG_DISTR_CDE  \\\n31309        2015-05-05           2180A7                 101   \n\n      WAR_RESP_DISTR_CDE VEHICLE_DESTN_CODE    FLAT_RATE_HRS_QTY  \\\n31309                15A                KA                  2.10   \n\n       FRGT_SUBL_TAX_AMT_USD  DIAGNOSTIC_LABOR_HRS_QTY TPL_CREATION_DATE  \\\n31309                   0.00                      0.00               NaT   \n\n      RESPONSIBILITY_PCT CONCLUSION_DESC_TXT          VEH_MILEAGE  \\\n31309               None                None            29,627.00   \n\n      CURRENCY_TYPE_CODE  ACTUAL_PARTS_CHG_AMT_USD  ACTUAL_LABOR_CHG_AMT_USD  \\\n31309                  $                     30.56                    230.75   \n\n       ACTUAL_HDLG_CHG_AMT_USD  ACTUAL_TOTAL_CHG_AMT_USD CAMPAIGN_CODE  \\\n31309                    27.08                    288.39             C   \n\n      WAR_DEFECT_CODE RECORD_DESC  RECORD_COUNT REPLACED_PART5  \\\n31309           6ZF00      Normal             1          06224   \n\n                                        REPLACED_PART_NO        PART_DESC  \\\n31309  062245J4305                                   ...  KIT, OIL COOLER   \n\n          ACT_PARTS_QTY_NO MTC_MODEL MTC_TYPE MTC_OPTION  \\\n31309                 1.00      GTZ6      AE5              \n\n            TRANS_SERIAL_NO NAMEPLATE MODEL_YEAR FACTORY MOD_NAME  \\\n31309                           ACURA       2016     HMA      MDX   \n\n         TRANSMISSION_GEARS REPLACED_PART_EQUOTE_FMT  CLAIM_LABOR_HRS_QTY  \\\n31309  9                                    20021                    2.10   \n\n         WAR_EXCH_RATE_AMT  DLR_NET_PRCE_AMT_USD    PART_FOB_COST_USD  \\\n31309                 1.00                 39.78                15.91   \n\n       DLR_NET_PRCE_AMTx90_USD  PART_FOB_COSTx2_USD    MIN_PART_COST_USD  \\\n31309                    35.80                31.82                31.82   \n\n       TRANSFER_PART_LIST_ITEM_DETAIL_SK  REPL_ROW_NUM  \n31309                                nan             1  ',
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>VIN_DLR_CLM_SK</th>\n      <th>WAR_CLAIM_DATE</th>\n      <th>VIN</th>\n      <th>TPL_VIN</th>\n      <th>PICKUP_DATE</th>\n      <th>SUBMITTED_DATE</th>\n      <th>REOPENED_DATE</th>\n      <th>REOPENED_SUBMITTED_DATE</th>\n      <th>FINAL_CLOSURE_DATE</th>\n      <th>STATUS_NAME</th>\n      <th>STATUS_OPEN_CLOSED</th>\n      <th>TPL_SHORT_PART_NO</th>\n      <th>PART_CATEGORY</th>\n      <th>DAYS_TO_CLOSURE</th>\n      <th>DAYS_OPEN</th>\n      <th>WARR_PART_NO</th>\n      <th>CUSTOMER_CONTENTION_TXT</th>\n      <th>VISUAL_INSPECTION_DETAIL_TXT</th>\n      <th>FUNCTIONAL_INSPECTION_DETAIL_TXT</th>\n      <th>CATEGORY_DESC_TXT</th>\n      <th>SUPPLIER_ANALYSIS_SUMMARY_TXT</th>\n      <th>DEALER_NO</th>\n      <th>WAR_CLAIM_NO</th>\n      <th>CUS_CONT_DESC_TEXT</th>\n      <th>REPAIR_ORDER_DATE</th>\n      <th>RECEIVED_DATE</th>\n      <th>AF_OFF_DATE</th>\n      <th>ENGINE_BUILD_DATE</th>\n      <th>PRI_LABOR_OP_CODE</th>\n      <th>WAR_ORIG_DISTR_CDE</th>\n      <th>WAR_RESP_DISTR_CDE</th>\n      <th>VEHICLE_DESTN_CODE</th>\n      <th>FLAT_RATE_HRS_QTY</th>\n      <th>FRGT_SUBL_TAX_AMT_USD</th>\n      <th>DIAGNOSTIC_LABOR_HRS_QTY</th>\n      <th>TPL_CREATION_DATE</th>\n      <th>RESPONSIBILITY_PCT</th>\n      <th>CONCLUSION_DESC_TXT</th>\n      <th>VEH_MILEAGE</th>\n      <th>CURRENCY_TYPE_CODE</th>\n      <th>ACTUAL_PARTS_CHG_AMT_USD</th>\n      <th>ACTUAL_LABOR_CHG_AMT_USD</th>\n      <th>ACTUAL_HDLG_CHG_AMT_USD</th>\n      <th>ACTUAL_TOTAL_CHG_AMT_USD</th>\n      <th>CAMPAIGN_CODE</th>\n      <th>WAR_DEFECT_CODE</th>\n      <th>RECORD_DESC</th>\n      <th>RECORD_COUNT</th>\n      <th>REPLACED_PART5</th>\n      <th>REPLACED_PART_NO</th>\n      <th>PART_DESC</th>\n      <th>ACT_PARTS_QTY_NO</th>\n      <th>MTC_MODEL</th>\n      <th>MTC_TYPE</th>\n      <th>MTC_OPTION</th>\n      <th>TRANS_SERIAL_NO</th>\n      <th>NAMEPLATE</th>\n      <th>MODEL_YEAR</th>\n      <th>FACTORY</th>\n      <th>MOD_NAME</th>\n      <th>TRANSMISSION_GEARS</th>\n      <th>REPLACED_PART_EQUOTE_FMT</th>\n      <th>CLAIM_LABOR_HRS_QTY</th>\n      <th>WAR_EXCH_RATE_AMT</th>\n      <th>DLR_NET_PRCE_AMT_USD</th>\n      <th>PART_FOB_COST_USD</th>\n      <th>DLR_NET_PRCE_AMTx90_USD</th>\n      <th>PART_FOB_COSTx2_USD</th>\n      <th>MIN_PART_COST_USD</th>\n      <th>TRANSFER_PART_LIST_ITEM_DETAIL_SK</th>\n      <th>REPL_ROW_NUM</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>31309</th>\n      <td>5FRYD4H92GB022416251336392305</td>\n      <td>201801</td>\n      <td>5FRYD4H92GB022416</td>\n      <td>None</td>\n      <td>NaT</td>\n      <td>NaT</td>\n      <td>NaT</td>\n      <td>NaT</td>\n      <td>NaT</td>\n      <td>None</td>\n      <td>None</td>\n      <td>None</td>\n      <td>None</td>\n      <td>nan</td>\n      <td>nan</td>\n      <td>062005NBA58</td>\n      <td>None</td>\n      <td>~</td>\n      <td>~</td>\n      <td>None</td>\n      <td>None</td>\n      <td>251336</td>\n      <td>392305</td>\n      <td>Zf 9 a/t trans warmer pud</td>\n      <td>2017-12-20</td>\n      <td>2018-01-05</td>\n      <td>2015-05-06</td>\n      <td>2015-05-05</td>\n      <td>2180A7</td>\n      <td>101</td>\n      <td>15A</td>\n      <td>KA</td>\n      <td>2.10</td>\n      <td>0.00</td>\n      <td>0.00</td>\n      <td>NaT</td>\n      <td>None</td>\n      <td>None</td>\n      <td>29,627.00</td>\n      <td>$</td>\n      <td>30.56</td>\n      <td>230.75</td>\n      <td>27.08</td>\n      <td>288.39</td>\n      <td>C</td>\n      <td>6ZF00</td>\n      <td>Normal</td>\n      <td>1</td>\n      <td>06224</td>\n      <td>062245J4305                                   ...</td>\n      <td>KIT, OIL COOLE ...
#      'execution_count': 9}],
#    'source': "claims[claims['TRANS_SERIAL_NO'].str.startswith(' ')]"},
#   {'cell_type': 'code',
#    'execution_count': 10,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:07.669282',
#      'end_time': '2019-04-23T15:24:07.792089',
#      'duration': 0.122807,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "array(['                    '], dtype=object)"},
#      'execution_count': 10}],
#    'source': "claims[claims['TRANS_SERIAL_NO'].str.startswith(' ')]['TRANS_SERIAL_NO'].values"},
#   {'cell_type': 'code',
#    'execution_count': 11,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:07.828406',
#      'end_time': '2019-04-23T15:24:07.955460',
#      'duration': 0.127054,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '31309    20021   \nName: REPLACED_PART_EQUOTE_FMT, dtype: object'},
#      'execution_count': 11}],
#    'source': "# This reads as: give me rows where replaced part equote = '20021   '' and bring back just the replaced_part_equote_fmt column:\nclaims.loc[claims['REPLACED_PART_EQUOTE_FMT']=='20021   ', 'REPLACED_PART_EQUOTE_FMT']"},
#   {'cell_type': 'code',
#    'execution_count': 12,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:07.986738',
#      'end_time': '2019-04-23T15:24:08.122665',
#      'duration': 0.135927,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "array(['20021   '], dtype=object)"},
#      'execution_count': 12}],
#    'source': "claims.loc[claims['REPLACED_PART_EQUOTE_FMT']=='20021   ', 'REPLACED_PART_EQUOTE_FMT'].values"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:08.185003',
#      'end_time': '2019-04-23T15:24:08.216248',
#      'duration': 0.031245,
#      'status': 'completed'}},
#    'source': '### Convert claims with bad E-Quote part # format as NaN and then forward fill missing E-Quote replaced part #'},
#   {'cell_type': 'code',
#    'execution_count': 13,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:08.255284',
#      'end_time': '2019-04-23T15:24:08.447306',
#      'duration': 0.192022,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "claims.loc[claims['REPLACED_PART_EQUOTE_FMT'] == '20021   ', 'REPLACED_PART_EQUOTE_FMT'] = np.nan\nclaims.sort_values(by=['MOD_NAME', 'MODEL_YEAR', 'AF_OFF_DATE'], inplace=True)\nclaims['REPLACED_PART_EQUOTE_FMT'].fillna(method='ffill', inplace=True)"},
#   {'cell_type': 'code',
#    'execution_count': 14,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:08.478553',
#      'end_time': '2019-04-23T15:24:08.543307',
#      'duration': 0.064754,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "assert len(claims.loc[claims['REPLACED_PART_EQUOTE_FMT']=='20021   ', 'REPLACED_PART_EQUOTE_FMT']) == 0"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:08.575392',
#      'end_time': '2019-04-23T15:24:08.607095',
#      'duration': 0.031703,
#      'status': 'completed'}},
#    'source': '### TRANS_SERIAL_NO has trailing white spaces, so need to remove them so that we can merge with ASN data'},
#   {'cell_type': 'code',
#    'execution_count': 15,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:08.638352',
#      'end_time': '2019-04-23T15:24:08.724392',
#      'duration': 0.08604,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "array(['Q5NC0011388         ', 'Q5NC0011360         ',\n       'Q5NC0011324         ', ..., 'Q5J40456287         ',\n       'Q5L90575501         ', 'Q5J40435973         '], dtype=object)"},
#      'execution_count': 15}],
#    'source': "claims['TRANS_SERIAL_NO'].values"},
#   {'cell_type': 'code',
#    'execution_count': 16,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:08.755649',
#      'end_time': '2019-04-23T15:24:08.889094',
#      'duration': 0.133445,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "claims['TRANS_SERIAL_NO'] = claims['TRANS_SERIAL_NO'].str.strip()"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:08.920239',
#      'end_time': '2019-04-23T15:24:08.951455',
#      'duration': 0.031216,
#      'status': 'completed'}},
#    'source': '# Now limit data set to just claims with closed TPLs and save as Excel file:'},
#   {'cell_type': 'code',
#    'execution_count': 17,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:08.992123',
#      'end_time': '2019-04-23T15:24:09.038666',
#      'duration': 0.046543,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "criteria1 = claims['TRANSFER_PART_LIST_ITEM_DETAIL_SK'].isna()\ncriteria2 = claims['MODEL_YEAR'].isin(fixed_model_years)"},
#   {'cell_type': 'code',
#    'execution_count': 18,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:09.069934',
#      'end_time': '2019-04-23T15:24:09.219897',
#      'duration': 0.149963,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'claims_with_tpl = claims[~criteria1 & ~criteria2]'},
#   {'cell_type': 'code',
#    'execution_count': 19,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:09.266618',
#      'end_time': '2019-04-23T15:24:09.371921',
#      'duration': 0.105303,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '(1479, 71)'},
#      'execution_count': 19}],
#    'source': 'claims_with_tpl.shape'},
#   {'cell_type': 'code',
#    'execution_count': 20,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:09.402891',
#      'end_time': '2019-04-23T15:24:09.520644',
#      'duration': 0.117753,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'today = datetime.today()'},
#   {'cell_type': 'code',
#    'execution_count': 21,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:09.551867',
#      'end_time': '2019-04-23T15:24:09.733614',
#      'duration': 0.181747,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'base_dir = "//mmpapp02/mq_db/wrp/ZF_ATM_WRP_Project/automated_vouchers/outputs/excel/NorthAmericanPlants/NonFixed"\np = Path(base_dir)\nsave_dir = p / datetime.strftime(today, "%Y-%m-%d")\nif not os.path.exists(save_dir):\n    os.makedirs(save_dir)'},
#   {'cell_type': 'code',
#    'execution_count': 22,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:09.780293',
#      'end_time': '2019-04-23T15:24:09.848942',
#      'duration': 0.068649,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "file_name_nonfixed = 'CLA_Claims_With_TPLs.xlsx'"},
#   {'cell_type': 'code',
#    'execution_count': 23,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:09.872299',
#      'end_time': '2019-04-23T15:24:20.931943',
#      'duration': 11.059644,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'claims_with_tpl.to_excel(save_dir / file_name_nonfixed, index=False)'},
#   {'cell_type': 'code',
#    'execution_count': 24,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:20.994443',
#      'end_time': '2019-04-23T15:24:21.062080',
#      'duration': 0.067637,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'\\\\\\\\mmpapp02\\\\mq_db\\\\wrp\\\\ZF_ATM_WRP_Project\\\\automated_vouchers\\\\outputs\\\\excel\\\\NorthAmericanPlants\\\\NonFixed\\\\2019-04-23\\\\CLA_Claims_With_TPLs.xlsx'"},
#      'execution_count': 24}],
#    'source': 'str(save_dir / file_name_nonfixed)'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:21.099529',
#      'end_time': '2019-04-23T15:24:21.138437',
#      'duration': 0.038908,
#      'status': 'completed'}},
#    'source': '### Now save/"glue" the save location or path to the Excel file containing CLA claims with closed TPL:'},
#   {'cell_type': 'code',
#    'execution_count': 25,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:21.167590',
#      'end_time': '2019-04-23T15:24:21.308267',
#      'duration': 0.140677,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'display_data',
#      'metadata': {'scrapbook': {'name': 'path_to_claims_with_tpl',
#        'data': True,
#        'display': False}},
#      'data': {'application/scrapbook.scrap.text+json': {'name': 'path_to_claims_with_tpl',
#        'data': '\\\\mmpapp02\\mq_db\\wrp\\ZF_ATM_WRP_Project\\automated_vouchers\\outputs\\excel\\NorthAmericanPlants\\NonFixed\\2019-04-23\\CLA_Claims_With_TPLs.xlsx',
#        'encoder': 'text',
#        'version': 1}}}],
#    'source': 'sb.glue("path_to_claims_with_tpl", str(save_dir / file_name_nonfixed))'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:21.339485',
#      'end_time': '2019-04-23T15:24:21.386400',
#      'duration': 0.046915,
#      'status': 'completed'}},
#    'source': '# Prepare data for fixed voucher (CLA claims without closed TPL):'},
#   {'cell_type': 'code',
#    'execution_count': 26,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:21.435340',
#      'end_time': '2019-04-23T15:24:21.513513',
#      'duration': 0.078173,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'base_dir = "//mmpapp02/mq_db/wrp/ZF_ATM_WRP_Project/automated_vouchers/outputs/excel/NorthAmericanPlants/Fixed"\np = Path(base_dir)\nsave_dir = p / datetime.strftime(today, "%Y-%m-%d")\nif not os.path.exists(save_dir):\n    os.makedirs(save_dir)'},
#   {'cell_type': 'code',
#    'execution_count': 27,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:21.544765',
#      'end_time': '2019-04-23T15:24:21.666070',
#      'duration': 0.121305,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': '# Claims without TPLs\ncriteria1 = (claims[\'TRANSFER_PART_LIST_ITEM_DETAIL_SK\'].isna())\n\n# Claims with TPLs, but not closed (in "limbo")\ncriteria2 = (claims[\'CONCLUSION_DESC_TXT\'].isna()) & claims[\'TRANSFER_PART_LIST_ITEM_DETAIL_SK\'] > 0\n\n# Claims from fixed model years\ncriteria3 = (claims[\'MODEL_YEAR\'].isin(fixed_model_years))\n\n# "Normal" claims\ncriteria4 = (claims[\'CAMPAIGN_CODE\'] == \'N\')'},
#   {'cell_type': 'code',
#    'execution_count': 28,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:21.712977',
#      'end_time': '2019-04-23T15:24:21.791643',
#      'duration': 0.078666,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'fixed_claims = claims[(criteria1 | criteria2) & criteria3 & criteria4]'},
#   {'cell_type': 'code',
#    'execution_count': 29,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:21.846828',
#      'end_time': '2019-04-23T15:24:21.931732',
#      'duration': 0.084904,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '(4399, 71)'},
#      'execution_count': 29}],
#    'source': 'fixed_claims.shape'},
#   {'cell_type': 'code',
#    'execution_count': 30,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:21.994241',
#      'end_time': '2019-04-23T15:24:22.082140',
#      'duration': 0.087899,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "file_name_fixed = 'CLA_Claims_Fixed.xlsx'"},
#   {'cell_type': 'code',
#    'execution_count': 31,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:22.114870',
#      'end_time': '2019-04-23T15:24:54.049268',
#      'duration': 31.934398,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'fixed_claims.to_excel(save_dir / file_name_fixed, index=False)'},
#   {'cell_type': 'code',
#    'execution_count': 32,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:54.080521',
#      'end_time': '2019-04-23T15:24:54.129583',
#      'duration': 0.049062,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'\\\\\\\\mmpapp02\\\\mq_db\\\\wrp\\\\ZF_ATM_WRP_Project\\\\automated_vouchers\\\\outputs\\\\excel\\\\NorthAmericanPlants\\\\Fixed\\\\2019-04-23\\\\CLA_Claims_Fixed.xlsx'"},
#      'execution_count': 32}],
#    'source': 'str(save_dir / file_name_fixed)'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:54.157933',
#      'end_time': '2019-04-23T15:24:54.189186',
#      'duration': 0.031253,
#      'status': 'completed'}},
#    'source': '### Now save/"glue" the save location or path to the Excel file containing fixed CLA claims:'},
#   {'cell_type': 'code',
#    'execution_count': 33,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:54.220466',
#      'end_time': '2019-04-23T15:24:54.304722',
#      'duration': 0.084256,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'display_data',
#      'metadata': {'scrapbook': {'name': 'path_to_fixed_claims',
#        'data': True,
#        'display': False}},
#      'data': {'application/scrapbook.scrap.text+json': {'name': 'path_to_fixed_claims',
#        'data': '\\\\mmpapp02\\mq_db\\wrp\\ZF_ATM_WRP_Project\\automated_vouchers\\outputs\\excel\\NorthAmericanPlants\\Fixed\\2019-04-23\\CLA_Claims_Fixed.xlsx',
#        'encoder': 'text',
#        'version': 1}}}],
#    'source': 'sb.glue("path_to_fixed_claims", str(save_dir / file_name_fixed))'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:54.335968',
#      'end_time': '2019-04-23T15:24:54.382849',
#      'duration': 0.046881,
#      'status': 'completed'}},
#    'source': '# Send Windows notification when complete'},
#   {'cell_type': 'code',
#    'execution_count': 34,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:24:54.434919',
#      'end_time': '2019-04-23T15:24:59.603556',
#      'duration': 5.168637,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stderr',
#      'text': "ERROR:root:Some trouble with the icon (D:\\jupyter\\projects\\ZF_Automation\\papermill\\images\\honda_logo.ico): (2, 'LoadImage', 'The system cannot find the file specified.')"},
#     {'output_type': 'stream', 'name': 'stderr', 'text': '\n'},
#     {'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': 'True'},
#      'execution_count': 34}],
#    'source': 'toaster = ToastNotifier()\ntoaster.show_toast("Papermill Orchestration Status",\n                   "Successfully provided data sets for voucher creation",\n                   icon_path="images/honda_logo.ico",\n                   duration=5)'}],
#  'metadata': {'hide_input': False,
#   'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.7.0',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'varInspector': {'cols': {'lenName': 16, 'lenType': 16, 'lenVar': 40},
#    'kernels_config': {'python': {'delete_cmd_postfix': '',
#      'delete_cmd_prefix': 'del ',
#      'library': 'var_list.py',
#      'varRefreshCmd': 'print(var_dic_list())'},
#     'r': {'delete_cmd_postfix': ') ',
#      'delete_cmd_prefix': 'rm(',
#      'library': 'var_list.r',
#      'varRefreshCmd': 'cat(var_dic_list()) '}},
#    'types_to_exclude': ['module',
#     'function',
#     'builtin_function_or_method',
#     'instance',
#     '_Feature'],
#    'window_display': False},
#   'papermill': {'parameters': {'fixed_model_years': ['2015', '2016']},
#    'environment_variables': {},
#    'version': '0.19.0',
#    'input_path': '1_Obtain_CLA_Claims_With_or_Without_TPLs.ipynb',
#    'output_path': 'output/CLA_Claims_With_or_Without_TPLs.ipynb',
#    'start_time': '2019-04-23T15:14:55.716141',
#    'end_time': '2019-04-23T15:25:00.881453',
#    'duration': 605.165312,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 2}

# %% [markdown]
# ### 2) Execute notebook to create NA Plants' non-fixed voucher:

# %%
# %%time
pm.execute_notebook(
    '2_Create_NonFixed_Voucher.ipynb',
    'output/NA_Plants_NonFixed_Voucher.ipynb',
    cwd='D:\\jupyter\\projects\\ZF_Automation\\papermill\prod',
    parameters = dict(start_voucher_date=start_voucher_date,
                      end_voucher_date = end_voucher_date,
                      honda_hourly_labor_rate = honda_hourly_labor_rate,
                      acura_hourly_labor_rate = acura_hourly_labor_rate,
                      part_cost_factor = part_cost_factor,
                      handling_cost_factor = handling_cost_factor
                 )
)
# Out:
# HBox(children=(IntProgress(value=0, max=115), HTML(value='')))
# Wall time: 1min 41s
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:49.827639',
#      'end_time': '2019-04-23T15:31:49.905658',
#      'duration': 0.078019,
#      'status': 'completed'}},
#    'source': '# Create NA Plants Non-Fixed Voucher'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:49.952529',
#      'end_time': '2019-04-23T15:31:50.022011',
#      'duration': 0.069482,
#      'status': 'completed'}},
#    'source': '## Input:'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:50.077993',
#      'end_time': '2019-04-23T15:31:50.124898',
#      'duration': 0.046905,
#      'status': 'completed'}},
#    'source': '- Path to Excel file containing claims with TPLs\n- start and end voucher dates\n- honda/acura hourly labor rates\n- part cost factor\n- handling cost factor'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:50.187423',
#      'end_time': '2019-04-23T15:31:50.249934',
#      'duration': 0.062511,
#      'status': 'completed'}},
#    'source': '## Output:'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:50.309623',
#      'end_time': '2019-04-23T15:31:50.377095',
#      'duration': 0.067472,
#      'status': 'completed'}},
#    'source': "- Excel voucher containing NA Plants' non-fixed voucher"},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:50.424001',
#      'end_time': '2019-04-23T15:31:52.777221',
#      'duration': 2.35322,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "from datetime import datetime\nfrom pathlib import Path\nfrom win10toast import ToastNotifier\nimport numpy as np\nimport pandas as pd\nimport os\nimport os.path as op\nimport pyodbc\nimport scrapbook as sb\npd.options.display.max_columns=100\npd.options.display.max_rows=1000\npd.options.display.float_format = '{:20,.2f}'.format"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:52.839730',
#      'end_time': '2019-04-23T15:31:52.917861',
#      'duration': 0.078131,
#      'status': 'completed'}},
#    'source': '### Parameters needed to generate voucher:'},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:52.988597',
#      'end_time': '2019-04-23T15:31:53.077696',
#      'duration': 0.089099,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "start_voucher_date = '2018-09-01'\nend_voucher_date = '2018-09-30'\nhonda_hourly_labor_rate = 120\nacura_hourly_labor_rate = 141\npart_cost_factor = 0.9\nhandling_cost_factor = 0.63"},
#   {'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:53.135907',
#      'end_time': '2019-04-23T15:31:53.254725',
#      'duration': 0.118818,
#      'status': 'completed'}},
#    'execution_count': 3,
#    'source': '# Parameters\nstart_voucher_date = "2018-09-01"\nend_voucher_date = "2018-09-30"\nhonda_hourly_labor_rate = 120\nacura_hourly_labor_rate = 141\npart_cost_factor = 0.9\nhandling_cost_factor = 0.63\n',
#    'outputs': []},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:53.317233',
#      'end_time': '2019-04-23T15:31:53.379740',
#      'duration': 0.062507,
#      'status': 'completed'}},
#    'source': '### Get current working directory:'},
#   {'cell_type': 'code',
#    'execution_count': 4,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:53.446744',
#      'end_time': '2019-04-23T15:31:53.525955',
#      'duration': 0.079211,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'D:\\\\jupyter\\\\projects\\\\ZF_Automation\\\\papermill\\\\prod'"},
#      'execution_count': 4}],
#    'source': 'cwd = os.getcwd()\ncwd'},
#   {'cell_type': 'code',
#    'execution_count': 5,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:53.584111',
#      'end_time': '2019-04-23T15:31:53.688388',
#      'duration': 0.104277,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "nb = sb.read_notebook(cwd + '\\\\output\\\\CLA_Claims_With_or_Without_TPLs.ipynb')\n\n# Run this instead for testing purposes outside of using papermill\n# nb = sb.read_notebook(cwd + '\\\\1_Obtain_CLA_Claims_With_or_Without_TPLs.ipynb')"},
#   {'cell_type': 'code',
#    'execution_count': 6,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:53.753560',
#      'end_time': '2019-04-23T15:31:53.843803',
#      'duration': 0.090243,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'\\\\\\\\mmpapp02\\\\mq_db\\\\wrp\\\\ZF_ATM_WRP_Project\\\\automated_vouchers\\\\outputs\\\\excel\\\\NorthAmericanPlants\\\\NonFixed\\\\2019-04-23\\\\CLA_Claims_With_TPLs.xlsx'"},
#      'execution_count': 6}],
#    'source': "nb.scraps['path_to_claims_with_tpl'].data"},
#   {'cell_type': 'code',
#    'execution_count': 7,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:53.905994',
#      'end_time': '2019-04-23T15:31:55.494861',
#      'duration': 1.588867,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "claims_with_tpl = pd.read_excel(nb.scraps['path_to_claims_with_tpl'].data, index=False)"},
#   {'cell_type': 'code',
#    'execution_count': 8,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:55.541582',
#      'end_time': '2019-04-23T15:31:55.679306',
#      'duration': 0.137724,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '                  VIN_DLR_CLM_SK  WAR_CLAIM_DATE                VIN  \\\n0  5FRYD4H85HB000032251369312271          201612  5FRYD4H85HB000032   \n1  5FRYD4H88HB000042251406314429          201803  5FRYD4H88HB000042   \n2  5FRYD4H52HB000091251061931424          201705  5FRYD4H52HB000091   \n3  5FRYD4H50HB000087251334346939          201806  5FRYD4H50HB000087   \n4  5FRYD4H54HB000089251593456691          201710  5FRYD4H54HB000089   \n\n             TPL_VIN PICKUP_DATE SUBMITTED_DATE REOPENED_DATE  \\\n0  5FRYD4H85HB000032  2016-12-23     2017-01-27           NaT   \n1  5FRYD4H88HB000042  2018-04-24     2018-06-07    2018-06-07   \n2  5FRYD4H52HB000091  2017-06-16     2017-08-07    2017-08-08   \n3  5FRYD4H50HB000087  2018-07-18     2018-08-30    2019-03-25   \n4  5FRYD4H54HB000089  2017-11-09     2018-01-03    2018-05-16   \n\n  REOPENED_SUBMITTED_DATE FINAL_CLOSURE_DATE            STATUS_NAME  \\\n0                     NaT         2017-01-27                 CLOSED   \n1              2018-06-26         2018-06-26                 CLOSED   \n2              2017-09-20         2017-09-20                 CLOSED   \n3                     NaT                NaT  REOPENED_FOR_ANALYSIS   \n4              2018-06-27         2018-06-27                 CLOSED   \n\n  STATUS_OPEN_CLOSED  TPL_SHORT_PART_NO PART_CATEGORY      DAYS_TO_CLOSURE  \\\n0             CLOSED               6200  TRANSMISSION                35.00   \n1             CLOSED               6200  TRANSMISSION                63.00   \n2             CLOSED               6200  TRANSMISSION                96.00   \n3               OPEN               6200  TRANSMISSION                  nan   \n4             CLOSED               6200  TRANSMISSION               230.00   \n\n   DAYS_OPEN        WARR_PART_NO  \\\n0         35  062015NCA31          \n1         63  062275J4010          \n2         96  062005NCA21          \n3        279  100025J6A12          \n4        230  062005NCA21RM        \n\n                             CUSTOMER_CONTENTION_TXT  \\\n0  CUSTOMER, STATES VEHICLE WILL NOT GO IN PARK A...   \n1  ATF WARMER LEAKED AND, CAUSED TRANSMISSION TO ...   \n2           CUSTOMER STATES TRANSMISSION IS SLIPPING   \n3  CUSTOMER STATES VEHICLE OVER HEATING ALL LIGHT...   \n4  CUSTOMER STATES WHILE ACCELERATING ON 2ND TO 3...   \n\n                        VISUAL_INSPECTION_DETAIL_TXT  \\\n0  Visual inspection revealed ferrous debris in H...   \n1                         ~ Defective oil cooler\\r\\n   \n2   ~ Completed visual inspection of transmission...   \n3                                                 ~    \n4                         ~ Defective oil cooler\\r\\n   \n\n                    FUNCTIONAL_INSPECTION_DETAIL_TXT  \\\n0  Transmission shifted to Park after ignition wa...   \n1                                                 ~    \n2   ~ During teardown drained oil, and found milk...   \n3                                                 ~    \n4                                                 ~    \n\n             CATEGORY_DESC_TXT  \\\n0            HCU Contamination   \n1  Oil Cooler Diaphram Damaged   \n2  Oil Cooler Diaphram Damaged   \n3                          NaN   \n4  Oil Cooler Diaphram Damaged   \n\n                       SUPPLIER_ANALYSIS_SUMMARY_TXT  DEALER_NO WAR_CLAIM_NO  \\\n0  HCU contamination caused claim of transmission...     251369   312271       \n1                                                NaN     251406   314429       \n2                 Known issue related to oil cooler.     251061   931424       \n3                                                NaN     251334   346939       \n4                                                NaN     251593   456691       \n\n                                  CUS_CONT_DESC_TEXT REPAIR_ORDER_DATE  \\\n0  CUSTOMER, STATES VEHICLE WILL NOT GO IN PARK A...        2016-12-10   \n1  ATF WARMER LEAKED AND, CAUSED TRANSMISSION TO ...        2018-03-16   \n2           CUSTOMER STATES TRANS ...
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>VIN_DLR_CLM_SK</th>\n      <th>WAR_CLAIM_DATE</th>\n      <th>VIN</th>\n      <th>TPL_VIN</th>\n      <th>PICKUP_DATE</th>\n      <th>SUBMITTED_DATE</th>\n      <th>REOPENED_DATE</th>\n      <th>REOPENED_SUBMITTED_DATE</th>\n      <th>FINAL_CLOSURE_DATE</th>\n      <th>STATUS_NAME</th>\n      <th>STATUS_OPEN_CLOSED</th>\n      <th>TPL_SHORT_PART_NO</th>\n      <th>PART_CATEGORY</th>\n      <th>DAYS_TO_CLOSURE</th>\n      <th>DAYS_OPEN</th>\n      <th>WARR_PART_NO</th>\n      <th>CUSTOMER_CONTENTION_TXT</th>\n      <th>VISUAL_INSPECTION_DETAIL_TXT</th>\n      <th>FUNCTIONAL_INSPECTION_DETAIL_TXT</th>\n      <th>CATEGORY_DESC_TXT</th>\n      <th>SUPPLIER_ANALYSIS_SUMMARY_TXT</th>\n      <th>DEALER_NO</th>\n      <th>WAR_CLAIM_NO</th>\n      <th>CUS_CONT_DESC_TEXT</th>\n      <th>REPAIR_ORDER_DATE</th>\n      <th>RECEIVED_DATE</th>\n      <th>AF_OFF_DATE</th>\n      <th>ENGINE_BUILD_DATE</th>\n      <th>PRI_LABOR_OP_CODE</th>\n      <th>WAR_ORIG_DISTR_CDE</th>\n      <th>WAR_RESP_DISTR_CDE</th>\n      <th>VEHICLE_DESTN_CODE</th>\n      <th>FLAT_RATE_HRS_QTY</th>\n      <th>FRGT_SUBL_TAX_AMT_USD</th>\n      <th>DIAGNOSTIC_LABOR_HRS_QTY</th>\n      <th>TPL_CREATION_DATE</th>\n      <th>RESPONSIBILITY_PCT</th>\n      <th>CONCLUSION_DESC_TXT</th>\n      <th>VEH_MILEAGE</th>\n      <th>CURRENCY_TYPE_CODE</th>\n      <th>ACTUAL_PARTS_CHG_AMT_USD</th>\n      <th>ACTUAL_LABOR_CHG_AMT_USD</th>\n      <th>ACTUAL_HDLG_CHG_AMT_USD</th>\n      <th>ACTUAL_TOTAL_CHG_AMT_USD</th>\n      <th>CAMPAIGN_CODE</th>\n      <th>WAR_DEFECT_CODE</th>\n      <th>RECORD_DESC</th>\n      <th>RECORD_COUNT</th>\n      <th>REPLACED_PART5</th>\n      <th>REPLACED_PART_NO</th>\n      <th>PART_DESC</th>\n      <th>ACT_PARTS_QTY_NO</th>\n      <th>MTC_MODEL</th>\n      <th>MTC_TYPE</th>\n      <th>MTC_OPTION</th>\n      <th>TRANS_SERIAL_NO</th>\n      <th>NAMEPLATE</th>\n      <th>MODEL_YEAR</th>\n      <th>FACTORY</th>\n      <th>MOD_NAME</th>\n      <th>TRANSMISSION_GEARS</th>\n      <th>REPLACED_PART_EQUOTE_FMT</th>\n      <th>CLAIM_LABOR_HRS_QTY</th>\n      <th>WAR_EXCH_RATE_AMT</th>\n      <th>DLR_NET_PRCE_AMT_USD</th>\n      <th>PART_FOB_COST_USD</th>\n      <th>DLR_NET_PRCE_AMTx90_USD</th>\n      <th>PART_FOB_COSTx2_USD</th>\n      <th>MIN_PART_COST_USD</th>\n      <th>TRANSFER_PART_LIST_ITEM_DETAIL_SK</th>\n      <th>REPL_ROW_NUM</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>5FRYD4H85HB000032251369312271</td>\n      <td>201612</td>\n      <td>5FRYD4H85HB000032</td>\n      <td>5FRYD4H85HB000032</td>\n      <td>2016-12-23</td>\n      <td>2017-01-27</td>\n      <td>NaT</td>\n      <td>NaT</td>\n      <td>2017-01-27</td>\n      <td>CLOSED</td>\n      <td>CLOSED</td>\n      <td>6200</td>\n      <td>TRANSMISSION</td>\n      <td>35.00</td>\n      <td>35</td>\n      <td>062015NCA31</td>\n      <td>CUSTOMER, STATES VEHICLE WILL NOT GO IN PARK A...</td>\n      <td>Visual inspection revealed ferrous debris in H...</td>\n      <td>Transmission shifted to Park after ignition wa...</td>\n      <td>HCU Contamination</td>\n      <td>HCU contamination caused claim of transmission...</td>\n      <td>251369</td>\n      <td>312271</td>\n      <td>CUSTOMER, STATES VEHICLE WILL NOT GO IN PARK A...</td>\n      <td>2016-12-10</td>\n      <td>2016-12-19</td>\n      <td>2016-06-07</td>\n      <td>2016-06-06</td>\n      <td>218102</td>\n      <td>101</td>\n      <td>15A</td>\n      <td>KA</td>\n      <td>5.90</td>\n      <td>150.00</td>\n      <td>2.20</td>\n      <td>2016-12-21 10:28:30.350</td>\n      <td>100.00</td>\n      <td>Supplier Mfg. Defect</td>\n      <td>5267</td>\n ...
#      'execution_count': 8}],
#    'source': 'claims_with_tpl.head()'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:55.726124',
#      'end_time': '2019-04-23T15:31:55.799317',
#      'duration': 0.073193,
#      'status': 'completed'}},
#    'source': '### Add WRPID column which is in the format: WRP219B + 2-digit month + 2-digit year where month/year depends on end voucher date'},
#   {'cell_type': 'code',
#    'execution_count': 9,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:55.861789',
#      'end_time': '2019-04-23T15:31:55.941602',
#      'duration': 0.079813,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'18'"},
#      'execution_count': 9}],
#    'source': 'year = end_voucher_date[2:4]\nyear'},
#   {'cell_type': 'code',
#    'execution_count': 10,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:55.999801',
#      'end_time': '2019-04-23T15:31:56.079249',
#      'duration': 0.079448,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'09'"},
#      'execution_count': 10}],
#    'source': 'month = end_voucher_date[5:7]\nmonth'},
#   {'cell_type': 'code',
#    'execution_count': 11,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:56.141413',
#      'end_time': '2019-04-23T15:31:56.230368',
#      'duration': 0.088955,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "claims_with_tpl = claims_with_tpl.assign(WRPID='WRP219B' + month + year)"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:56.318603',
#      'end_time': '2019-04-23T15:31:56.384780',
#      'duration': 0.066177,
#      'status': 'completed'}},
#    'source': "#### Let's confirm that ```WRPID``` has been created (scroll to far right):"},
#   {'cell_type': 'code',
#    'execution_count': 12,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:56.432021',
#      'end_time': '2019-04-23T15:31:56.574938',
#      'duration': 0.142917,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '                  VIN_DLR_CLM_SK  WAR_CLAIM_DATE                VIN  \\\n0  5FRYD4H85HB000032251369312271          201612  5FRYD4H85HB000032   \n1  5FRYD4H88HB000042251406314429          201803  5FRYD4H88HB000042   \n2  5FRYD4H52HB000091251061931424          201705  5FRYD4H52HB000091   \n3  5FRYD4H50HB000087251334346939          201806  5FRYD4H50HB000087   \n4  5FRYD4H54HB000089251593456691          201710  5FRYD4H54HB000089   \n\n             TPL_VIN PICKUP_DATE SUBMITTED_DATE REOPENED_DATE  \\\n0  5FRYD4H85HB000032  2016-12-23     2017-01-27           NaT   \n1  5FRYD4H88HB000042  2018-04-24     2018-06-07    2018-06-07   \n2  5FRYD4H52HB000091  2017-06-16     2017-08-07    2017-08-08   \n3  5FRYD4H50HB000087  2018-07-18     2018-08-30    2019-03-25   \n4  5FRYD4H54HB000089  2017-11-09     2018-01-03    2018-05-16   \n\n  REOPENED_SUBMITTED_DATE FINAL_CLOSURE_DATE            STATUS_NAME  \\\n0                     NaT         2017-01-27                 CLOSED   \n1              2018-06-26         2018-06-26                 CLOSED   \n2              2017-09-20         2017-09-20                 CLOSED   \n3                     NaT                NaT  REOPENED_FOR_ANALYSIS   \n4              2018-06-27         2018-06-27                 CLOSED   \n\n  STATUS_OPEN_CLOSED  TPL_SHORT_PART_NO PART_CATEGORY      DAYS_TO_CLOSURE  \\\n0             CLOSED               6200  TRANSMISSION                35.00   \n1             CLOSED               6200  TRANSMISSION                63.00   \n2             CLOSED               6200  TRANSMISSION                96.00   \n3               OPEN               6200  TRANSMISSION                  nan   \n4             CLOSED               6200  TRANSMISSION               230.00   \n\n   DAYS_OPEN        WARR_PART_NO  \\\n0         35  062015NCA31          \n1         63  062275J4010          \n2         96  062005NCA21          \n3        279  100025J6A12          \n4        230  062005NCA21RM        \n\n                             CUSTOMER_CONTENTION_TXT  \\\n0  CUSTOMER, STATES VEHICLE WILL NOT GO IN PARK A...   \n1  ATF WARMER LEAKED AND, CAUSED TRANSMISSION TO ...   \n2           CUSTOMER STATES TRANSMISSION IS SLIPPING   \n3  CUSTOMER STATES VEHICLE OVER HEATING ALL LIGHT...   \n4  CUSTOMER STATES WHILE ACCELERATING ON 2ND TO 3...   \n\n                        VISUAL_INSPECTION_DETAIL_TXT  \\\n0  Visual inspection revealed ferrous debris in H...   \n1                         ~ Defective oil cooler\\r\\n   \n2   ~ Completed visual inspection of transmission...   \n3                                                 ~    \n4                         ~ Defective oil cooler\\r\\n   \n\n                    FUNCTIONAL_INSPECTION_DETAIL_TXT  \\\n0  Transmission shifted to Park after ignition wa...   \n1                                                 ~    \n2   ~ During teardown drained oil, and found milk...   \n3                                                 ~    \n4                                                 ~    \n\n             CATEGORY_DESC_TXT  \\\n0            HCU Contamination   \n1  Oil Cooler Diaphram Damaged   \n2  Oil Cooler Diaphram Damaged   \n3                          NaN   \n4  Oil Cooler Diaphram Damaged   \n\n                       SUPPLIER_ANALYSIS_SUMMARY_TXT  DEALER_NO WAR_CLAIM_NO  \\\n0  HCU contamination caused claim of transmission...     251369   312271       \n1                                                NaN     251406   314429       \n2                 Known issue related to oil cooler.     251061   931424       \n3                                                NaN     251334   346939       \n4                                                NaN     251593   456691       \n\n                                  CUS_CONT_DESC_TEXT REPAIR_ORDER_DATE  \\\n0  CUSTOMER, STATES VEHICLE WILL NOT GO IN PARK A...        2016-12-10   \n1  ATF WARMER LEAKED AND, CAUSED TRANSMISSION TO ...        2018-03-16   \n2           CUSTOMER STATES TRANS ...
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>VIN_DLR_CLM_SK</th>\n      <th>WAR_CLAIM_DATE</th>\n      <th>VIN</th>\n      <th>TPL_VIN</th>\n      <th>PICKUP_DATE</th>\n      <th>SUBMITTED_DATE</th>\n      <th>REOPENED_DATE</th>\n      <th>REOPENED_SUBMITTED_DATE</th>\n      <th>FINAL_CLOSURE_DATE</th>\n      <th>STATUS_NAME</th>\n      <th>STATUS_OPEN_CLOSED</th>\n      <th>TPL_SHORT_PART_NO</th>\n      <th>PART_CATEGORY</th>\n      <th>DAYS_TO_CLOSURE</th>\n      <th>DAYS_OPEN</th>\n      <th>WARR_PART_NO</th>\n      <th>CUSTOMER_CONTENTION_TXT</th>\n      <th>VISUAL_INSPECTION_DETAIL_TXT</th>\n      <th>FUNCTIONAL_INSPECTION_DETAIL_TXT</th>\n      <th>CATEGORY_DESC_TXT</th>\n      <th>SUPPLIER_ANALYSIS_SUMMARY_TXT</th>\n      <th>DEALER_NO</th>\n      <th>WAR_CLAIM_NO</th>\n      <th>CUS_CONT_DESC_TEXT</th>\n      <th>REPAIR_ORDER_DATE</th>\n      <th>RECEIVED_DATE</th>\n      <th>AF_OFF_DATE</th>\n      <th>ENGINE_BUILD_DATE</th>\n      <th>PRI_LABOR_OP_CODE</th>\n      <th>WAR_ORIG_DISTR_CDE</th>\n      <th>WAR_RESP_DISTR_CDE</th>\n      <th>VEHICLE_DESTN_CODE</th>\n      <th>FLAT_RATE_HRS_QTY</th>\n      <th>FRGT_SUBL_TAX_AMT_USD</th>\n      <th>DIAGNOSTIC_LABOR_HRS_QTY</th>\n      <th>TPL_CREATION_DATE</th>\n      <th>RESPONSIBILITY_PCT</th>\n      <th>CONCLUSION_DESC_TXT</th>\n      <th>VEH_MILEAGE</th>\n      <th>CURRENCY_TYPE_CODE</th>\n      <th>ACTUAL_PARTS_CHG_AMT_USD</th>\n      <th>ACTUAL_LABOR_CHG_AMT_USD</th>\n      <th>ACTUAL_HDLG_CHG_AMT_USD</th>\n      <th>ACTUAL_TOTAL_CHG_AMT_USD</th>\n      <th>CAMPAIGN_CODE</th>\n      <th>WAR_DEFECT_CODE</th>\n      <th>RECORD_DESC</th>\n      <th>RECORD_COUNT</th>\n      <th>REPLACED_PART5</th>\n      <th>REPLACED_PART_NO</th>\n      <th>PART_DESC</th>\n      <th>ACT_PARTS_QTY_NO</th>\n      <th>MTC_MODEL</th>\n      <th>MTC_TYPE</th>\n      <th>MTC_OPTION</th>\n      <th>TRANS_SERIAL_NO</th>\n      <th>NAMEPLATE</th>\n      <th>MODEL_YEAR</th>\n      <th>FACTORY</th>\n      <th>MOD_NAME</th>\n      <th>TRANSMISSION_GEARS</th>\n      <th>REPLACED_PART_EQUOTE_FMT</th>\n      <th>CLAIM_LABOR_HRS_QTY</th>\n      <th>WAR_EXCH_RATE_AMT</th>\n      <th>DLR_NET_PRCE_AMT_USD</th>\n      <th>PART_FOB_COST_USD</th>\n      <th>DLR_NET_PRCE_AMTx90_USD</th>\n      <th>PART_FOB_COSTx2_USD</th>\n      <th>MIN_PART_COST_USD</th>\n      <th>TRANSFER_PART_LIST_ITEM_DETAIL_SK</th>\n      <th>REPL_ROW_NUM</th>\n      <th>WRPID</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>5FRYD4H85HB000032251369312271</td>\n      <td>201612</td>\n      <td>5FRYD4H85HB000032</td>\n      <td>5FRYD4H85HB000032</td>\n      <td>2016-12-23</td>\n      <td>2017-01-27</td>\n      <td>NaT</td>\n      <td>NaT</td>\n      <td>2017-01-27</td>\n      <td>CLOSED</td>\n      <td>CLOSED</td>\n      <td>6200</td>\n      <td>TRANSMISSION</td>\n      <td>35.00</td>\n      <td>35</td>\n      <td>062015NCA31</td>\n      <td>CUSTOMER, STATES VEHICLE WILL NOT GO IN PARK A...</td>\n      <td>Visual inspection revealed ferrous debris in H...</td>\n      <td>Transmission shifted to Park after ignition wa...</td>\n      <td>HCU Contamination</td>\n      <td>HCU contamination caused claim of transmission...</td>\n      <td>251369</td>\n      <td>312271</td>\n      <td>CUSTOMER, STATES VEHICLE WILL NOT GO IN PARK A...</td>\n      <td>2016-12-10</td>\n      <td>2016-12-19</td>\n      <td>2016-06-07</td>\n      <td>2016-06-06</td>\n      <td>218102</td>\n      <td>101</td>\n      <td>15A</td>\n      <td>KA</td>\n      <td>5.90</td>\n      <td>150.00</td>\n      <td>2.20</td>\n      <td>2016-12-21 10:28:30.350</td>\n      <td>100.00</td>\n      <td>Supplier Mfg. Defect</td>\ ...
#      'execution_count': 12}],
#    'source': 'claims_with_tpl.head()'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:56.640113',
#      'end_time': '2019-04-23T15:31:56.729133',
#      'duration': 0.08902,
#      'status': 'completed'}},
#    'source': '### Add ```HRLY_RATE_USD``` column:'},
#   {'cell_type': 'code',
#    'execution_count': 13,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:56.807343',
#      'end_time': '2019-04-23T15:31:56.904606',
#      'duration': 0.097263,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "claims_with_tpl['HRLY_RATE_USD'] = np.where(claims_with_tpl['NAMEPLATE'] == 'ACURA', int(acura_hourly_labor_rate), int(honda_hourly_labor_rate))"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:56.973811',
#      'end_time': '2019-04-23T15:31:57.039963',
#      'duration': 0.066152,
#      'status': 'completed'}},
#    'source': "#### Let's confirm that ```HRLY_RATE_USD``` column has been created (scroll to far right):"},
#   {'cell_type': 'code',
#    'execution_count': 14,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:57.103130',
#      'end_time': '2019-04-23T15:31:57.257386',
#      'duration': 0.154256,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '                  VIN_DLR_CLM_SK  WAR_CLAIM_DATE                VIN  \\\n0  5FRYD4H85HB000032251369312271          201612  5FRYD4H85HB000032   \n1  5FRYD4H88HB000042251406314429          201803  5FRYD4H88HB000042   \n2  5FRYD4H52HB000091251061931424          201705  5FRYD4H52HB000091   \n3  5FRYD4H50HB000087251334346939          201806  5FRYD4H50HB000087   \n4  5FRYD4H54HB000089251593456691          201710  5FRYD4H54HB000089   \n\n             TPL_VIN PICKUP_DATE SUBMITTED_DATE REOPENED_DATE  \\\n0  5FRYD4H85HB000032  2016-12-23     2017-01-27           NaT   \n1  5FRYD4H88HB000042  2018-04-24     2018-06-07    2018-06-07   \n2  5FRYD4H52HB000091  2017-06-16     2017-08-07    2017-08-08   \n3  5FRYD4H50HB000087  2018-07-18     2018-08-30    2019-03-25   \n4  5FRYD4H54HB000089  2017-11-09     2018-01-03    2018-05-16   \n\n  REOPENED_SUBMITTED_DATE FINAL_CLOSURE_DATE            STATUS_NAME  \\\n0                     NaT         2017-01-27                 CLOSED   \n1              2018-06-26         2018-06-26                 CLOSED   \n2              2017-09-20         2017-09-20                 CLOSED   \n3                     NaT                NaT  REOPENED_FOR_ANALYSIS   \n4              2018-06-27         2018-06-27                 CLOSED   \n\n  STATUS_OPEN_CLOSED  TPL_SHORT_PART_NO PART_CATEGORY      DAYS_TO_CLOSURE  \\\n0             CLOSED               6200  TRANSMISSION                35.00   \n1             CLOSED               6200  TRANSMISSION                63.00   \n2             CLOSED               6200  TRANSMISSION                96.00   \n3               OPEN               6200  TRANSMISSION                  nan   \n4             CLOSED               6200  TRANSMISSION               230.00   \n\n   DAYS_OPEN        WARR_PART_NO  \\\n0         35  062015NCA31          \n1         63  062275J4010          \n2         96  062005NCA21          \n3        279  100025J6A12          \n4        230  062005NCA21RM        \n\n                             CUSTOMER_CONTENTION_TXT  \\\n0  CUSTOMER, STATES VEHICLE WILL NOT GO IN PARK A...   \n1  ATF WARMER LEAKED AND, CAUSED TRANSMISSION TO ...   \n2           CUSTOMER STATES TRANSMISSION IS SLIPPING   \n3  CUSTOMER STATES VEHICLE OVER HEATING ALL LIGHT...   \n4  CUSTOMER STATES WHILE ACCELERATING ON 2ND TO 3...   \n\n                        VISUAL_INSPECTION_DETAIL_TXT  \\\n0  Visual inspection revealed ferrous debris in H...   \n1                         ~ Defective oil cooler\\r\\n   \n2   ~ Completed visual inspection of transmission...   \n3                                                 ~    \n4                         ~ Defective oil cooler\\r\\n   \n\n                    FUNCTIONAL_INSPECTION_DETAIL_TXT  \\\n0  Transmission shifted to Park after ignition wa...   \n1                                                 ~    \n2   ~ During teardown drained oil, and found milk...   \n3                                                 ~    \n4                                                 ~    \n\n             CATEGORY_DESC_TXT  \\\n0            HCU Contamination   \n1  Oil Cooler Diaphram Damaged   \n2  Oil Cooler Diaphram Damaged   \n3                          NaN   \n4  Oil Cooler Diaphram Damaged   \n\n                       SUPPLIER_ANALYSIS_SUMMARY_TXT  DEALER_NO WAR_CLAIM_NO  \\\n0  HCU contamination caused claim of transmission...     251369   312271       \n1                                                NaN     251406   314429       \n2                 Known issue related to oil cooler.     251061   931424       \n3                                                NaN     251334   346939       \n4                                                NaN     251593   456691       \n\n                                  CUS_CONT_DESC_TEXT REPAIR_ORDER_DATE  \\\n0  CUSTOMER, STATES VEHICLE WILL NOT GO IN PARK A...        2016-12-10   \n1  ATF WARMER LEAKED AND, CAUSED TRANSMISSION TO ...        2018-03-16   \n2           CUSTOMER STATES TRANS ...
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>VIN_DLR_CLM_SK</th>\n      <th>WAR_CLAIM_DATE</th>\n      <th>VIN</th>\n      <th>TPL_VIN</th>\n      <th>PICKUP_DATE</th>\n      <th>SUBMITTED_DATE</th>\n      <th>REOPENED_DATE</th>\n      <th>REOPENED_SUBMITTED_DATE</th>\n      <th>FINAL_CLOSURE_DATE</th>\n      <th>STATUS_NAME</th>\n      <th>STATUS_OPEN_CLOSED</th>\n      <th>TPL_SHORT_PART_NO</th>\n      <th>PART_CATEGORY</th>\n      <th>DAYS_TO_CLOSURE</th>\n      <th>DAYS_OPEN</th>\n      <th>WARR_PART_NO</th>\n      <th>CUSTOMER_CONTENTION_TXT</th>\n      <th>VISUAL_INSPECTION_DETAIL_TXT</th>\n      <th>FUNCTIONAL_INSPECTION_DETAIL_TXT</th>\n      <th>CATEGORY_DESC_TXT</th>\n      <th>SUPPLIER_ANALYSIS_SUMMARY_TXT</th>\n      <th>DEALER_NO</th>\n      <th>WAR_CLAIM_NO</th>\n      <th>CUS_CONT_DESC_TEXT</th>\n      <th>REPAIR_ORDER_DATE</th>\n      <th>RECEIVED_DATE</th>\n      <th>AF_OFF_DATE</th>\n      <th>ENGINE_BUILD_DATE</th>\n      <th>PRI_LABOR_OP_CODE</th>\n      <th>WAR_ORIG_DISTR_CDE</th>\n      <th>WAR_RESP_DISTR_CDE</th>\n      <th>VEHICLE_DESTN_CODE</th>\n      <th>FLAT_RATE_HRS_QTY</th>\n      <th>FRGT_SUBL_TAX_AMT_USD</th>\n      <th>DIAGNOSTIC_LABOR_HRS_QTY</th>\n      <th>TPL_CREATION_DATE</th>\n      <th>RESPONSIBILITY_PCT</th>\n      <th>CONCLUSION_DESC_TXT</th>\n      <th>VEH_MILEAGE</th>\n      <th>CURRENCY_TYPE_CODE</th>\n      <th>ACTUAL_PARTS_CHG_AMT_USD</th>\n      <th>ACTUAL_LABOR_CHG_AMT_USD</th>\n      <th>ACTUAL_HDLG_CHG_AMT_USD</th>\n      <th>ACTUAL_TOTAL_CHG_AMT_USD</th>\n      <th>CAMPAIGN_CODE</th>\n      <th>WAR_DEFECT_CODE</th>\n      <th>RECORD_DESC</th>\n      <th>RECORD_COUNT</th>\n      <th>REPLACED_PART5</th>\n      <th>REPLACED_PART_NO</th>\n      <th>PART_DESC</th>\n      <th>ACT_PARTS_QTY_NO</th>\n      <th>MTC_MODEL</th>\n      <th>MTC_TYPE</th>\n      <th>MTC_OPTION</th>\n      <th>TRANS_SERIAL_NO</th>\n      <th>NAMEPLATE</th>\n      <th>MODEL_YEAR</th>\n      <th>FACTORY</th>\n      <th>MOD_NAME</th>\n      <th>TRANSMISSION_GEARS</th>\n      <th>REPLACED_PART_EQUOTE_FMT</th>\n      <th>CLAIM_LABOR_HRS_QTY</th>\n      <th>WAR_EXCH_RATE_AMT</th>\n      <th>DLR_NET_PRCE_AMT_USD</th>\n      <th>PART_FOB_COST_USD</th>\n      <th>DLR_NET_PRCE_AMTx90_USD</th>\n      <th>PART_FOB_COSTx2_USD</th>\n      <th>MIN_PART_COST_USD</th>\n      <th>TRANSFER_PART_LIST_ITEM_DETAIL_SK</th>\n      <th>REPL_ROW_NUM</th>\n      <th>WRPID</th>\n      <th>HRLY_RATE_USD</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>5FRYD4H85HB000032251369312271</td>\n      <td>201612</td>\n      <td>5FRYD4H85HB000032</td>\n      <td>5FRYD4H85HB000032</td>\n      <td>2016-12-23</td>\n      <td>2017-01-27</td>\n      <td>NaT</td>\n      <td>NaT</td>\n      <td>2017-01-27</td>\n      <td>CLOSED</td>\n      <td>CLOSED</td>\n      <td>6200</td>\n      <td>TRANSMISSION</td>\n      <td>35.00</td>\n      <td>35</td>\n      <td>062015NCA31</td>\n      <td>CUSTOMER, STATES VEHICLE WILL NOT GO IN PARK A...</td>\n      <td>Visual inspection revealed ferrous debris in H...</td>\n      <td>Transmission shifted to Park after ignition wa...</td>\n      <td>HCU Contamination</td>\n      <td>HCU contamination caused claim of transmission...</td>\n      <td>251369</td>\n      <td>312271</td>\n      <td>CUSTOMER, STATES VEHICLE WILL NOT GO IN PARK A...</td>\n      <td>2016-12-10</td>\n      <td>2016-12-19</td>\n      <td>2016-06-07</td>\n      <td>2016-06-06</td>\n      <td>218102</td>\n      <td>101</td>\n      <td>15A</td>\n      <td>KA</td>\n      <td>5.90</td>\n      <td>150.00</td>\n      <td>2.20</td>\n      <td>2016-12-21 10:28:30.350</td>\n      <td>100.00</td>\n       ...
#      'execution_count': 14}],
#    'source': 'claims_with_tpl.query("NAMEPLATE == \'ACURA\'").head()'},
#   {'cell_type': 'code',
#    'execution_count': 15,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:57.329800',
#      'end_time': '2019-04-23T15:31:57.478010',
#      'duration': 0.14821,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "                    VIN_DLR_CLM_SK  WAR_CLAIM_DATE                VIN  \\\n515  5FNRL6H77JB002639208424805428          201812  5FNRL6H77JB002639   \n516  5FNRL6H76JB003023206648752829          201712  5FNRL6H76JB003023   \n517  5FNRL6H73JB003299206500724651          201805  5FNRL6H73JB003299   \n518  5FNRL6H78JB003346208703021248          201803  5FNRL6H78JB003346   \n519  5FNRL6H75JB003871208449387308          201805  5FNRL6H75JB003871   \n\n               TPL_VIN PICKUP_DATE SUBMITTED_DATE REOPENED_DATE  \\\n515  5FNRL6H77JB002639  2019-01-22     2019-03-06    2019-03-06   \n516  5FNRL6H76JB003023  2018-01-04     2018-02-16    2019-02-06   \n517  5FNRL6H73JB003299  2018-06-26     2018-08-15    2019-03-25   \n518  5FNRL6H78JB003346  2018-05-21     2018-07-11    2019-02-06   \n519  5FNRL6H75JB003871  2018-06-18     2018-08-07    2019-04-03   \n\n    REOPENED_SUBMITTED_DATE FINAL_CLOSURE_DATE            STATUS_NAME  \\\n515              2019-03-11         2019-03-11   AVAILABLE_FOR_REVIEW   \n516              2019-03-14         2019-03-14   AVAILABLE_FOR_REVIEW   \n517                     NaT                NaT  REOPENED_FOR_ANALYSIS   \n518              2019-03-11         2019-03-11   AVAILABLE_FOR_REVIEW   \n519                     NaT                NaT  REOPENED_FOR_ANALYSIS   \n\n    STATUS_OPEN_CLOSED  TPL_SHORT_PART_NO PART_CATEGORY      DAYS_TO_CLOSURE  \\\n515             CLOSED               6280           KIT                48.00   \n516             CLOSED               6200  TRANSMISSION               434.00   \n517               OPEN               6200  TRANSMISSION                  nan   \n518             CLOSED               6280           KIT               294.00   \n519               OPEN               6200  TRANSMISSION                  nan   \n\n     DAYS_OPEN        WARR_PART_NO  \\\n515         48  062805NZA31          \n516        434  062015NZA11          \n517        301  062005NZA31          \n518        294  062805NZA11          \n519        309  062005NZA11RM        \n\n                               CUSTOMER_CONTENTION_TXT  \\\n515     CUSTOMER STATES VEHICLE SHUTTERS WHEN SHIFTING   \n516  C/S THE VEHICLE IS SHIFTING ABNORMALLY. WHEN D...   \n517  CUSTOMER STATES ROAD DEPARTURE MITIGATION ; AC...   \n518  C/S: CUSTOMER STATES, HEARS A CLUNK FROM THE T...   \n519  CUSTOMER STATES SOMETIMES THREE TIMES SO FAR W...   \n\n    VISUAL_INSPECTION_DETAIL_TXT  \\\n515                           ~    \n516   ~ No visual defects found.   \n517                           ~    \n518                           ~    \n519                           ~    \n\n                      FUNCTIONAL_INSPECTION_DETAIL_TXT CATEGORY_DESC_TXT  \\\n515                                                 ~        No Analysis   \n516   ~ Full teardown performed with no findings. A...      Dealer Error   \n517                                                 ~                NaN   \n518                                                 ~        No Analysis   \n519                                                 ~                NaN   \n\n                         SUPPLIER_ANALYSIS_SUMMARY_TXT  DEALER_NO  \\\n515                                                NaN     208424   \n516  Dealer's Fault: Oil Level Adjustment Not OK.\\r...     206648   \n517                                                NaN     206500   \n518  GBL data only shows engine intervention fault ...     208703   \n519                                                NaN     208449   \n\n    WAR_CLAIM_NO                                 CUS_CONT_DESC_TEXT  \\\n515   805428         Customer States vehicle shutters when shifting   \n516   752829      C/S THE VEHICLE IS SHIFTING ABNORMALLY. WHEN D...   \n517   724651      CUSTOMER STATES ROAD DEPARTURE MITIGATION ; AC...   \n518   021248      C/S: CUSTOMER STATES, HEARS A CLUNK FROM THE T...   \n519   387308      CUSTOMER STATES SOMETIMES THREE TIMES SO FAR W...   \n\n    REPAIR_ORDER_DATE RECEIVED_DAT ...
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>VIN_DLR_CLM_SK</th>\n      <th>WAR_CLAIM_DATE</th>\n      <th>VIN</th>\n      <th>TPL_VIN</th>\n      <th>PICKUP_DATE</th>\n      <th>SUBMITTED_DATE</th>\n      <th>REOPENED_DATE</th>\n      <th>REOPENED_SUBMITTED_DATE</th>\n      <th>FINAL_CLOSURE_DATE</th>\n      <th>STATUS_NAME</th>\n      <th>STATUS_OPEN_CLOSED</th>\n      <th>TPL_SHORT_PART_NO</th>\n      <th>PART_CATEGORY</th>\n      <th>DAYS_TO_CLOSURE</th>\n      <th>DAYS_OPEN</th>\n      <th>WARR_PART_NO</th>\n      <th>CUSTOMER_CONTENTION_TXT</th>\n      <th>VISUAL_INSPECTION_DETAIL_TXT</th>\n      <th>FUNCTIONAL_INSPECTION_DETAIL_TXT</th>\n      <th>CATEGORY_DESC_TXT</th>\n      <th>SUPPLIER_ANALYSIS_SUMMARY_TXT</th>\n      <th>DEALER_NO</th>\n      <th>WAR_CLAIM_NO</th>\n      <th>CUS_CONT_DESC_TEXT</th>\n      <th>REPAIR_ORDER_DATE</th>\n      <th>RECEIVED_DATE</th>\n      <th>AF_OFF_DATE</th>\n      <th>ENGINE_BUILD_DATE</th>\n      <th>PRI_LABOR_OP_CODE</th>\n      <th>WAR_ORIG_DISTR_CDE</th>\n      <th>WAR_RESP_DISTR_CDE</th>\n      <th>VEHICLE_DESTN_CODE</th>\n      <th>FLAT_RATE_HRS_QTY</th>\n      <th>FRGT_SUBL_TAX_AMT_USD</th>\n      <th>DIAGNOSTIC_LABOR_HRS_QTY</th>\n      <th>TPL_CREATION_DATE</th>\n      <th>RESPONSIBILITY_PCT</th>\n      <th>CONCLUSION_DESC_TXT</th>\n      <th>VEH_MILEAGE</th>\n      <th>CURRENCY_TYPE_CODE</th>\n      <th>ACTUAL_PARTS_CHG_AMT_USD</th>\n      <th>ACTUAL_LABOR_CHG_AMT_USD</th>\n      <th>ACTUAL_HDLG_CHG_AMT_USD</th>\n      <th>ACTUAL_TOTAL_CHG_AMT_USD</th>\n      <th>CAMPAIGN_CODE</th>\n      <th>WAR_DEFECT_CODE</th>\n      <th>RECORD_DESC</th>\n      <th>RECORD_COUNT</th>\n      <th>REPLACED_PART5</th>\n      <th>REPLACED_PART_NO</th>\n      <th>PART_DESC</th>\n      <th>ACT_PARTS_QTY_NO</th>\n      <th>MTC_MODEL</th>\n      <th>MTC_TYPE</th>\n      <th>MTC_OPTION</th>\n      <th>TRANS_SERIAL_NO</th>\n      <th>NAMEPLATE</th>\n      <th>MODEL_YEAR</th>\n      <th>FACTORY</th>\n      <th>MOD_NAME</th>\n      <th>TRANSMISSION_GEARS</th>\n      <th>REPLACED_PART_EQUOTE_FMT</th>\n      <th>CLAIM_LABOR_HRS_QTY</th>\n      <th>WAR_EXCH_RATE_AMT</th>\n      <th>DLR_NET_PRCE_AMT_USD</th>\n      <th>PART_FOB_COST_USD</th>\n      <th>DLR_NET_PRCE_AMTx90_USD</th>\n      <th>PART_FOB_COSTx2_USD</th>\n      <th>MIN_PART_COST_USD</th>\n      <th>TRANSFER_PART_LIST_ITEM_DETAIL_SK</th>\n      <th>REPL_ROW_NUM</th>\n      <th>WRPID</th>\n      <th>HRLY_RATE_USD</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>515</th>\n      <td>5FNRL6H77JB002639208424805428</td>\n      <td>201812</td>\n      <td>5FNRL6H77JB002639</td>\n      <td>5FNRL6H77JB002639</td>\n      <td>2019-01-22</td>\n      <td>2019-03-06</td>\n      <td>2019-03-06</td>\n      <td>2019-03-11</td>\n      <td>2019-03-11</td>\n      <td>AVAILABLE_FOR_REVIEW</td>\n      <td>CLOSED</td>\n      <td>6280</td>\n      <td>KIT</td>\n      <td>48.00</td>\n      <td>48</td>\n      <td>062805NZA31</td>\n      <td>CUSTOMER STATES VEHICLE SHUTTERS WHEN SHIFTING</td>\n      <td>~</td>\n      <td>~</td>\n      <td>No Analysis</td>\n      <td>NaN</td>\n      <td>208424</td>\n      <td>805428</td>\n      <td>Customer States vehicle shutters when shifting</td>\n      <td>2018-12-10</td>\n      <td>2018-12-21</td>\n      <td>2017-04-26</td>\n      <td>2017-04-25</td>\n      <td>223199</td>\n      <td>101</td>\n      <td>15A</td>\n      <td>KA</td>\n      <td>0.60</td>\n      <td>0.00</td>\n      <td>0.60</td>\n      <td>2019-01-18 14:07:00.447</td>\n      <td>0.00</td>\n      <td>Systems Related</td>\n      <td>21036</td>\n      <td>$</td>\n      <td>282.57</td>\n      <td>159.60</td>\n      <td>173.89</td>\n   ...
#      'execution_count': 15}],
#    'source': 'claims_with_tpl.query("NAMEPLATE == \'HONDA\'").head()'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:57.542177',
#      'end_time': '2019-04-23T15:31:57.611384',
#      'duration': 0.069207,
#      'status': 'completed'}},
#    'source': '### Add calculated costs:'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:57.675196',
#      'end_time': '2019-04-23T15:31:57.743376',
#      'duration': 0.06818,
#      'status': 'completed'}},
#    'source': '#### Minimum part cost (lesser of: 2 x FOB or 90% dealer net) was already defined in the main SQL query:'},
#   {'cell_type': 'code',
#    'execution_count': 16,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:57.815568',
#      'end_time': '2019-04-23T15:31:57.901028',
#      'duration': 0.08546,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "claims_with_tpl = claims_with_tpl.assign(CALCULATED_PART_COST_USD=claims_with_tpl['MIN_PART_COST_USD'])"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:57.965200',
#      'end_time': '2019-04-23T15:31:58.036389',
#      'duration': 0.071189,
#      'status': 'completed'}},
#    'source': '#### Calculated flat rate labor cost (USD) is just the FLAT_RATE_HRS_QTY x nameplate hourly labor rate:'},
#   {'cell_type': 'code',
#    'execution_count': 17,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:58.104595',
#      'end_time': '2019-04-23T15:31:58.185037',
#      'duration': 0.080442,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "claims_with_tpl['CALCULATED_FLAT_RATE_LABOR_COST_USD'] = np.where(claims_with_tpl['NAMEPLATE'] == 'ACURA',\n                                                        claims_with_tpl['FLAT_RATE_HRS_QTY'] * int(acura_hourly_labor_rate),\n                                                        claims_with_tpl['FLAT_RATE_HRS_QTY'] * int(honda_hourly_labor_rate))"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:58.252101',
#      'end_time': '2019-04-23T15:31:58.340616',
#      'duration': 0.088515,
#      'status': 'completed'}},
#    'source': '#### Calculated diagnostic labor cost (USD) = (claim labor hours x hourly labor rate) - (flat rate hours x hourly labor rate)'},
#   {'cell_type': 'code',
#    'execution_count': 18,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:58.411483',
#      'end_time': '2019-04-23T15:31:58.506940',
#      'duration': 0.095457,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "claims_with_tpl = claims_with_tpl.assign(CALCULATED_DIAGNOSTIC_LABOR_COST_USD=(claims_with_tpl['CLAIM_LABOR_HRS_QTY'] *\n                               claims_with_tpl['HRLY_RATE_USD']) - (claims_with_tpl['FLAT_RATE_HRS_QTY'] *\n                               claims_with_tpl['HRLY_RATE_USD']))"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:58.559120',
#      'end_time': '2019-04-23T15:31:58.621627',
#      'duration': 0.062507,
#      'status': 'completed'}},
#    'source': '#### Calculated handling cost = dealer net part cost x handling cost factor:'},
#   {'cell_type': 'code',
#    'execution_count': 19,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:58.695100',
#      'end_time': '2019-04-23T15:31:58.772754',
#      'duration': 0.077654,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "claims_with_tpl = claims_with_tpl.assign(CALCULATED_HDLG_CHG_AMT_USD=claims_with_tpl['DLR_NET_PRCE_AMT_USD'] *\n                               float(handling_cost_factor))"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:58.842589',
#      'end_time': '2019-04-23T15:31:58.909525',
#      'duration': 0.066936,
#      'status': 'completed'}},
#    'source': '#### Calculated total charge = part cost + labor cost + handling cost + sublet/freight/tax (CLA labor - WHA labor)'},
#   {'cell_type': 'code',
#    'execution_count': 20,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:31:58.972031',
#      'end_time': '2019-04-23T15:31:59.064180',
#      'duration': 0.092149,
#      'status': 'completed'}},
#    'outputs': [],
# ...
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '                  VIN_DLR_CLM_SK  WAR_CLAIM_DATE                VIN  \\\n0  5J8YD4H54HL003171251241349358          201806  5J8YD4H54HL003171   \n1  5J8YD4H32HL007721251069756668          201808  5J8YD4H32HL007721   \n2  5J8YD4H35JL003104251554059141          201806  5J8YD4H35JL003104   \n3  5J8YD4H3XJL003096251580727411          201802  5J8YD4H3XJL003096   \n4  5J8YD4H51JL003408251494319514          201808  5J8YD4H51JL003408   \n\n             TPL_VIN PICKUP_DATE SUBMITTED_DATE REOPENED_DATE  \\\n0  5J8YD4H54HL003171  2018-06-22     2018-08-13    2018-08-13   \n1  5J8YD4H32HL007721  2018-09-06     2018-09-14           NaT   \n2  5J8YD4H35JL003104  2018-06-18     2018-08-07    2018-08-07   \n3  5J8YD4H3XJL003096  2018-02-23     2018-04-10    2018-08-28   \n4  5J8YD4H51JL003408  2018-09-10     2018-09-19           NaT   \n\n  REOPENED_SUBMITTED_DATE FINAL_CLOSURE_DATE STATUS_NAME STATUS_OPEN_CLOSED  \\\n0              2018-09-06         2018-09-06      CLOSED             CLOSED   \n1                     NaT         2018-09-14      CLOSED             CLOSED   \n2              2018-09-06         2018-09-06      CLOSED             CLOSED   \n3              2018-09-07         2018-09-07      CLOSED             CLOSED   \n4                     NaT         2018-09-19      CLOSED             CLOSED   \n\n   TPL_SHORT_PART_NO PART_CATEGORY      DAYS_TO_CLOSURE  DAYS_OPEN  \\\n0               6233           KIT                76.00         76   \n1               6233           KIT                 8.00          8   \n2               6233           KIT                80.00         80   \n3               6200  TRANSMISSION               196.00        196   \n4               6200  TRANSMISSION                 9.00          9   \n\n         WARR_PART_NO                            CUSTOMER_CONTENTION_TXT  \\\n0  200215L9053                                                       NaN   \n1  200215NB043         CUSTOMER STATES TRANSMISSION FLUID LEAKING CHE...   \n2  062335J4000         DIAGNOSIS (TRANSMISSION - NOT SHIFTING PROPERL...   \n3  062005DHA12RM       CUSTOMER STATES DID NOT LEAVE THE PARKING LOT ...   \n4  062005DHA12RM       C/S VEHICLE STALLED WHILE DRIVING; ALL WARNING...   \n\n                        VISUAL_INSPECTION_DETAIL_TXT  \\\n0             ~ End cover gasket found to be leaking   \n1                End cover gasket found defective ~    \n2               ~ End cover gasket found to be leaky   \n3   ~ Visual external inspection revealed no find...   \n4  Transmission passed visual inspection with no ...   \n\n                    FUNCTIONAL_INSPECTION_DETAIL_TXT CATEGORY_DESC_TXT  \\\n0                                                 ~    EK Gasket Leak    \n1                                                 ~    EK Gasket Leak    \n2                                                 ~    EK Gasket Leak    \n3   ~ Oil pan and HCU were removed and found pinc...     Wires Pinched   \n4  Full teardown revealed know issue related to w...      Weld Spatter   \n\n                       SUPPLIER_ANALYSIS_SUMMARY_TXT  DEALER_NO WAR_CLAIM_NO  \\\n0                                                NaN     251241   349358       \n1                                                NaN     251069   756668       \n2                                                NaN     251554   059141       \n3  Pinched wire from sensor unit would cause elec...     251580   727411       \n4               Known issue related to weld spatter.     251494   319514       \n\n                                  CUS_CONT_DESC_TEXT REPAIR_ORDER_DATE  \\\n0                                                NaN        2018-06-05   \n1  CUSTOMER STATES TRANSMISSION FLUID LEAKING CHE...        2018-08-15   \n2  DIAGNOSIS (TRANSMISSION - NOT SHIFTING PROPERL...        2018-05-25   \n3  CUSTOMER STATES DID NOT LEAVE THE PARKING LOT ...        2017-12-28   \n4  C/S VEHICLE STALLED WHILE DRIVING; ALL WARNING...        2018-08-05   \n\n  RECEIVED_DATE AF_O ...
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>VIN_DLR_CLM_SK</th>\n      <th>WAR_CLAIM_DATE</th>\n      <th>VIN</th>\n      <th>TPL_VIN</th>\n      <th>PICKUP_DATE</th>\n      <th>SUBMITTED_DATE</th>\n      <th>REOPENED_DATE</th>\n      <th>REOPENED_SUBMITTED_DATE</th>\n      <th>FINAL_CLOSURE_DATE</th>\n      <th>STATUS_NAME</th>\n      <th>STATUS_OPEN_CLOSED</th>\n      <th>TPL_SHORT_PART_NO</th>\n      <th>PART_CATEGORY</th>\n      <th>DAYS_TO_CLOSURE</th>\n      <th>DAYS_OPEN</th>\n      <th>WARR_PART_NO</th>\n      <th>CUSTOMER_CONTENTION_TXT</th>\n      <th>VISUAL_INSPECTION_DETAIL_TXT</th>\n      <th>FUNCTIONAL_INSPECTION_DETAIL_TXT</th>\n      <th>CATEGORY_DESC_TXT</th>\n      <th>SUPPLIER_ANALYSIS_SUMMARY_TXT</th>\n      <th>DEALER_NO</th>\n      <th>WAR_CLAIM_NO</th>\n      <th>CUS_CONT_DESC_TEXT</th>\n      <th>REPAIR_ORDER_DATE</th>\n      <th>RECEIVED_DATE</th>\n      <th>AF_OFF_DATE</th>\n      <th>ENGINE_BUILD_DATE</th>\n      <th>PRI_LABOR_OP_CODE</th>\n      <th>WAR_ORIG_DISTR_CDE</th>\n      <th>WAR_RESP_DISTR_CDE</th>\n      <th>VEHICLE_DESTN_CODE</th>\n      <th>FLAT_RATE_HRS_QTY</th>\n      <th>FRGT_SUBL_TAX_AMT_USD</th>\n      <th>DIAGNOSTIC_LABOR_HRS_QTY</th>\n      <th>TPL_CREATION_DATE</th>\n      <th>RESPONSIBILITY_PCT</th>\n      <th>CONCLUSION_DESC_TXT</th>\n      <th>VEH_MILEAGE</th>\n      <th>CURRENCY_TYPE_CODE</th>\n      <th>ACTUAL_PARTS_CHG_AMT_USD</th>\n      <th>ACTUAL_LABOR_CHG_AMT_USD</th>\n      <th>ACTUAL_HDLG_CHG_AMT_USD</th>\n      <th>ACTUAL_TOTAL_CHG_AMT_USD</th>\n      <th>CAMPAIGN_CODE</th>\n      <th>WAR_DEFECT_CODE</th>\n      <th>RECORD_DESC</th>\n      <th>RECORD_COUNT</th>\n      <th>REPLACED_PART5</th>\n      <th>REPLACED_PART_NO</th>\n      <th>PART_DESC</th>\n      <th>ACT_PARTS_QTY_NO</th>\n      <th>MTC_MODEL</th>\n      <th>MTC_TYPE</th>\n      <th>MTC_OPTION</th>\n      <th>TRANS_SERIAL_NO</th>\n      <th>NAMEPLATE</th>\n      <th>MODEL_YEAR</th>\n      <th>FACTORY</th>\n      <th>MOD_NAME</th>\n      <th>TRANSMISSION_GEARS</th>\n      <th>REPLACED_PART_EQUOTE_FMT</th>\n      <th>CLAIM_LABOR_HRS_QTY</th>\n      <th>WAR_EXCH_RATE_AMT</th>\n      <th>DLR_NET_PRCE_AMT_USD</th>\n      <th>PART_FOB_COST_USD</th>\n      <th>DLR_NET_PRCE_AMTx90_USD</th>\n      <th>PART_FOB_COSTx2_USD</th>\n      <th>MIN_PART_COST_USD</th>\n      <th>TRANSFER_PART_LIST_ITEM_DETAIL_SK</th>\n      <th>REPL_ROW_NUM</th>\n      <th>WRPID</th>\n      <th>HRLY_RATE_USD</th>\n      <th>CALCULATED_PART_COST_USD</th>\n      <th>CALCULATED_FLAT_RATE_LABOR_COST_USD</th>\n      <th>CALCULATED_DIAGNOSTIC_LABOR_COST_USD</th>\n      <th>CALCULATED_HDLG_CHG_AMT_USD</th>\n      <th>CALCULATED_TOTAL_COST_USD</th>\n      <th>CALCULATED_TOTAL_LABOR_COST_USD</th>\n      <th>ROW_NUM</th>\n      <th>ACTUAL_CLAIM_LEVEL_TOTAL_CHG_AMT_USD</th>\n      <th>ASN_RECEIVE_DATE</th>\n      <th>TransDTF</th>\n      <th>MassProCost_USD</th>\n      <th>MassProCostX205_USD</th>\n      <th>ACTUAL_CLAIM_LEVEL_TOTAL_CHG_AMT_USD_AFTER_PERC</th>\n      <th>CALCULATED_TOTAL_COST_USD_AFTER_PERC</th>\n      <th>WRP_VOUCHER_AMT_USD_INITIAL</th>\n      <th>WRP_VOUCHER_AMT_USD_FINAL</th>\n      <th>FIXED_YES_NO</th>\n      <th>SUPP_FIXED_PERC</th>\n      <th>WRP_ID</th>\n      <th>WRP_RECOVERY_COST_AFTER_PERC_USD_FINAL</th>\n      <th>_merge</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>5J8YD4H54HL003171251241349358</td>\n      <td>201806</td>\n      <td>5J8YD4H54HL003171</td>\n      <td>5J8YD4H54HL003171</td>\n      <td>2018-06-22</td>\n      <td>2018-08-13</td>\n      <td>2018-08-13</td>\n      <td>2018-09-06</td>\n      <td>2018-09-06</td>\n      <td>CLOSED</td>\n      <td>CLOS ...
#      'execution_count': 64}],
#    'source': 'voucher_nonfixed_final.head()'},
#   {'cell_type': 'code',
#    'execution_count': 65,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:33:15.753911',
#      'end_time': '2019-04-23T15:33:15.911711',
#      'duration': 0.1578,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': 'left_only     92\nboth           0\nright_only     0\nName: _merge, dtype: int64'},
#      'execution_count': 65}],
#    'source': "voucher_nonfixed_final['_merge'].value_counts()"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:33:16.005472',
#      'end_time': '2019-04-23T15:33:16.148400',
#      'duration': 0.142928,
#      'status': 'completed'}},
#    'source': '### Exclude already paid claims to prevent double-charging of supplier:'},
#   {'cell_type': 'code',
#    'execution_count': 66,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:33:16.244623',
#      'end_time': '2019-04-23T15:33:16.384632',
#      'duration': 0.140009,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "criteria = voucher_nonfixed_final['_merge'] == 'left_only'\nvoucher_nonfixed_final = voucher_nonfixed_final[criteria]"},
#   {'cell_type': 'code',
#    'execution_count': 67,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:33:16.477846',
#      'end_time': '2019-04-23T15:33:16.574956',
#      'duration': 0.09711,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '(92, 94)'},
#      'execution_count': 67}],
#    'source': 'voucher_nonfixed_final.shape'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:33:16.662408',
#      'end_time': '2019-04-23T15:33:16.748220',
#      'duration': 0.085812,
#      'status': 'completed'}},
#    'source': '### Delete redundant or unnecessary columns'},
#   {'cell_type': 'code',
#    'execution_count': 68,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:33:16.826354',
#      'end_time': '2019-04-23T15:33:16.929839',
#      'duration': 0.103485,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "del voucher_nonfixed_final['_merge']\ndel voucher_nonfixed_final['WRP_ID']\ndel voucher_nonfixed_final['WRP_RECOVERY_COST_AFTER_PERC_USD_FINAL']"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:33:17.007979',
#      'end_time': '2019-04-23T15:33:17.090275',
#      'duration': 0.082296,
#      'status': 'completed'}},
#    'source': '### Save voucher data as Excel file:'},
#   {'cell_type': 'code',
#    'execution_count': 69,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:33:17.194339',
#      'end_time': '2019-04-23T15:33:17.296025',
#      'duration': 0.101686,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'today = datetime.today()'},
#   {'cell_type': 'code',
#    'execution_count': 70,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:33:17.374151',
#      'end_time': '2019-04-23T15:33:17.477989',
#      'duration': 0.103838,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'base_dir = "//mmpapp02/mq_db/wrp/ZF_ATM_WRP_Project/automated_vouchers/outputs/excel/NorthAmericanPlants/NonFixed"\np = Path(base_dir)\nsave_dir = p / datetime.strftime(today, "%Y-%m-%d")\nif not os.path.exists(save_dir):\n    os.makedirs(save_dir)'},
#   {'cell_type': 'code',
#    'execution_count': 71,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:33:17.577050',
#      'end_time': '2019-04-23T15:33:17.716248',
#      'duration': 0.139198,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "file_name = 'NA_Plants_NonFixed_Voucher_FINAL.xlsx'"},
#   {'cell_type': 'code',
#    'execution_count': 72,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:33:17.794375',
#      'end_time': '2019-04-23T15:33:20.578200',
#      'duration': 2.783825,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'voucher_nonfixed_final.to_excel(save_dir / file_name, index=False)'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:33:20.750095',
#      'end_time': '2019-04-23T15:33:20.935880',
#      'duration': 0.185785,
#      'status': 'completed'}},
#    'source': '#### Where Excel file was saved to:'},
#   {'cell_type': 'code',
#    'execution_count': 73,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:33:21.107775',
#      'end_time': '2019-04-23T15:33:21.316370',
#      'duration': 0.208595,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'\\\\\\\\mmpapp02\\\\mq_db\\\\wrp\\\\ZF_ATM_WRP_Project\\\\automated_vouchers\\\\outputs\\\\excel\\\\NorthAmericanPlants\\\\NonFixed\\\\2019-04-23\\\\NA_Plants_NonFixed_Voucher_FINAL.xlsx'"},
#      'execution_count': 73}],
#    'source': 'str(save_dir / file_name)'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:33:21.472638',
#      'end_time': '2019-04-23T15:33:21.635167',
#      'duration': 0.162529,
#      'status': 'completed'}},
#    'source': '### Send out Windows notification when complete'},
#   {'cell_type': 'code',
#    'execution_count': 74,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T15:33:21.791435',
#      'end_time': '2019-04-23T15:33:27.053205',
#      'duration': 5.26177,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': 'True'},
#      'execution_count': 74}],
#    'source': 'toaster = ToastNotifier()\ntoaster.show_toast("Papermill Orchestration Status",\n                   "Successfully created non-fixed voucher",\n                   icon_path="images/honda_logo.ico",\n                   duration=5)'}],
#  'metadata': {'hide_input': False,
#   'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.7.0',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'varInspector': {'cols': {'lenName': 16, 'lenType': 16, 'lenVar': 40},
#    'kernels_config': {'python': {'delete_cmd_postfix': '',
#      'delete_cmd_prefix': 'del ',
#      'library': 'var_list.py',
#      'varRefreshCmd': 'print(var_dic_list())'},
#     'r': {'delete_cmd_postfix': ') ',
#      'delete_cmd_prefix': 'rm(',
#      'library': 'var_list.r',
#      'varRefreshCmd': 'cat(var_dic_list()) '}},
#    'types_to_exclude': ['module',
#     'function',
#     'builtin_function_or_method',
#     'instance',
#     '_Feature'],
#    'window_display': False},
#   'papermill': {'parameters': {'start_voucher_date': '2018-09-01',
#     'end_voucher_date': '2018-09-30',
#     'honda_hourly_labor_rate': 120,
#     'acura_hourly_labor_rate': 141,
#     'part_cost_factor': 0.9,
#     'handling_cost_factor': 0.63},
#    'environment_variables': {},
#    'version': '0.19.0',
#    'input_path': '2_Create_NonFixed_Voucher.ipynb',
#    'output_path': 'output/NA_Plants_NonFixed_Voucher.ipynb',
#    'start_time': '2019-04-23T15:31:47.430064',
#    'end_time': '2019-04-23T15:33:28.729075',
#    'duration': 101.299011,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 2}

# %% [markdown]
# ### 3) Execute notebook to create NA Plants' fixed voucher:

# %%
# %%time
pm.execute_notebook(
    '3_Create_Fixed_Voucher.ipynb',
    'output/NA_Plants_Fixed_Voucher.ipynb',
    cwd='D:\\jupyter\\projects\\ZF_Automation\\papermill\prod',
    parameters = dict(start_voucher_date=start_voucher_date,
                      end_voucher_date = end_voucher_date,
                      honda_hourly_labor_rate = honda_hourly_labor_rate,
                      acura_hourly_labor_rate = acura_hourly_labor_rate,
                      part_cost_factor = part_cost_factor,
                      handling_cost_factor = handling_cost_factor
                 )
)
# Out:
# HBox(children=(IntProgress(value=0, max=128), HTML(value='')))
# Wall time: 2min 51s
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:05.067258',
#      'end_time': '2019-04-23T16:12:05.166517',
#      'duration': 0.099259,
#      'status': 'completed'}},
#    'source': '# Create NA Plants Fixed Voucher'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:05.233697',
#      'end_time': '2019-04-23T16:12:05.324941',
#      'duration': 0.091244,
#      'status': 'completed'}},
#    'source': '## Input:'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:05.402147',
#      'end_time': '2019-04-23T16:12:05.478350',
#      'duration': 0.076203,
#      'status': 'completed'}},
#    'source': '- Path to Excel file containing claims with TPLs\n- start and end voucher dates\n- honda/acura hourly labor rates\n- part cost factor\n- handling cost factor'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:05.569619',
#      'end_time': '2019-04-23T16:12:05.637906',
#      'duration': 0.068287,
#      'status': 'completed'}},
#    'source': '## Output:'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:05.701074',
#      'end_time': '2019-04-23T16:12:05.771476',
#      'duration': 0.070402,
#      'status': 'completed'}},
#    'source': "- Excel voucher containing NA Plants' fixed voucher"},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:05.854698',
#      'end_time': '2019-04-23T16:12:18.528801',
#      'duration': 12.674103,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "from datetime import datetime\nfrom pathlib import Path\nfrom win10toast import ToastNotifier\nimport numpy as np\nimport pandas as pd\nimport os\nimport os.path as op\nimport pyodbc\nimport scrapbook as sb\npd.options.display.max_columns=100\npd.options.display.max_rows=1000\npd.options.display.float_format = '{:20,.2f}'.format"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:18.594368',
#      'end_time': '2019-04-23T16:12:18.694618',
#      'duration': 0.10025,
#      'status': 'completed'}},
#    'source': '### Parameters needed to generate voucher:'},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:18.757124',
#      'end_time': '2019-04-23T16:12:18.875174',
#      'duration': 0.11805,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "start_voucher_date = '2018-09-01'\nend_voucher_date = '2018-09-30'\nhonda_hourly_labor_rate = 120\nacura_hourly_labor_rate = 141\npart_cost_factor = 0.9\nhandling_cost_factor = 0.63"},
#   {'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:18.941262',
#      'end_time': '2019-04-23T16:12:19.027196',
#      'duration': 0.085934,
#      'status': 'completed'}},
#    'execution_count': 3,
#    'source': '# Parameters\nstart_voucher_date = "2018-09-01"\nend_voucher_date = "2018-09-30"\nhonda_hourly_labor_rate = 120\nacura_hourly_labor_rate = 141\npart_cost_factor = 0.9\nhandling_cost_factor = 0.63\n',
#    'outputs': []},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:19.127453',
#      'end_time': '2019-04-23T16:12:19.217695',
#      'duration': 0.090242,
#      'status': 'completed'}},
#    'source': '### Get current working directory:'},
#   {'cell_type': 'code',
#    'execution_count': 4,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:19.309939',
#      'end_time': '2019-04-23T16:12:19.408202',
#      'duration': 0.098263,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'D:\\\\jupyter\\\\projects\\\\ZF_Automation\\\\papermill\\\\prod'"},
#      'execution_count': 4}],
#    'source': 'cwd = os.getcwd()\ncwd'},
#   {'cell_type': 'code',
#    'execution_count': 5,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:19.460188',
#      'end_time': '2019-04-23T16:12:19.607684',
#      'duration': 0.147496,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "nb = sb.read_notebook(cwd + '\\\\output\\\\CLA_Claims_With_or_Without_TPLs.ipynb')\n\n# Run this instead for testing purposes outside of using papermill\n# nb = sb.read_notebook(cwd + '\\\\1_Obtain_CLA_Claims_With_or_Without_TPLs.ipynb')"},
#   {'cell_type': 'code',
#    'execution_count': 6,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:19.670196',
#      'end_time': '2019-04-23T16:12:19.762155',
#      'duration': 0.091959,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'\\\\\\\\mmpapp02\\\\mq_db\\\\wrp\\\\ZF_ATM_WRP_Project\\\\automated_vouchers\\\\outputs\\\\excel\\\\NorthAmericanPlants\\\\Fixed\\\\2019-04-23\\\\CLA_Claims_Fixed.xlsx'"},
#      'execution_count': 6}],
#    'source': "nb.scraps['path_to_fixed_claims'].data"},
#   {'cell_type': 'code',
#    'execution_count': 7,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:19.824355',
#      'end_time': '2019-04-23T16:12:23.428966',
#      'duration': 3.604611,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "claims_without_tpl = pd.read_excel(nb.scraps['path_to_fixed_claims'].data, index=False, dtype={'MODEL_YEAR': str, 'REPLACED_PART5': str},\n                                  parse_dates=['SUBMITTED_DATE','REOPENED_SUBMITTED_DATE','REPAIR_ORDER_DATE',\n                                               'AF_OFF_DATE','ENGINE_BUILD_DATE'])"},
#   {'cell_type': 'code',
#    'execution_count': 8,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:23.475712',
#      'end_time': '2019-04-23T16:12:23.650760',
#      'duration': 0.175048,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '                  VIN_DLR_CLM_SK  WAR_CLAIM_DATE                VIN  \\\n0  5FRYD4H97GB001027251144812311          201711  5FRYD4H97GB001027   \n1  5FRYD4H91GB001010251481035771          201705  5FRYD4H91GB001010   \n2  5FRYD4H98GB001022251482939970          201711  5FRYD4H98GB001022   \n3  5FRYD3H47GB001009251004114162          201808  5FRYD3H47GB001009   \n4  5FRYD3H47GB001009251004114162          201808  5FRYD3H47GB001009   \n\n             TPL_VIN PICKUP_DATE SUBMITTED_DATE REOPENED_DATE  \\\n0  5FRYD4H97GB001027  2017-11-22     2018-01-16    2019-03-25   \n1  5FRYD4H91GB001010  2017-06-16     2017-08-07    2019-03-25   \n2                NaN         NaT            NaT           NaT   \n3  5FRYD3H47GB001009  2018-09-10     2018-10-23    2019-03-25   \n4  5FRYD3H47GB001009  2018-09-10     2018-10-23    2019-03-25   \n\n  REOPENED_SUBMITTED_DATE   FINAL_CLOSURE_DATE            STATUS_NAME  \\\n0                     NaT                  nan  REOPENED_FOR_ANALYSIS   \n1                     NaT                  nan  REOPENED_FOR_ANALYSIS   \n2                     NaT                  nan                    NaN   \n3                     NaT                  nan  REOPENED_FOR_ANALYSIS   \n4                     NaT                  nan  REOPENED_FOR_ANALYSIS   \n\n  STATUS_OPEN_CLOSED    TPL_SHORT_PART_NO PART_CATEGORY      DAYS_TO_CLOSURE  \\\n0               OPEN             6,200.00  TRANSMISSION                  nan   \n1               OPEN             6,200.00  TRANSMISSION                  nan   \n2                NaN                  nan           NaN                  nan   \n3               OPEN             6,200.00  TRANSMISSION                  nan   \n4               OPEN             6,200.00  TRANSMISSION                  nan   \n\n             DAYS_OPEN        WARR_PART_NO  \\\n0               517.00  062005NCA79RM        \n1               676.00  062005NCA79RM        \n2                  nan  062005NCA79RM        \n3               225.00  062005NBA58RM        \n4               225.00  062005NBA58RM        \n\n                             CUSTOMER_CONTENTION_TXT  \\\n0  AFTER PERFORMING 17-026 FOUND NO CHANGE IN NOI...   \n1  SQUEAK UPON ACCELERATE; 30MPH TO A SLOW DOWN T...   \n2                                                NaN   \n3  WHEN BRAKING FROM SPEED AND ACCELERATING TO TU...   \n4  WHEN BRAKING FROM SPEED AND ACCELERATING TO TU...   \n\n  VISUAL_INSPECTION_DETAIL_TXT FUNCTIONAL_INSPECTION_DETAIL_TXT  \\\n0                           ~                                ~    \n1                           ~                                ~    \n2                           ~                                ~    \n3                           ~                                ~    \n4                           ~                                ~    \n\n  CATEGORY_DESC_TXT SUPPLIER_ANALYSIS_SUMMARY_TXT  DEALER_NO WAR_CLAIM_NO  \\\n0               NaN                           NaN     251144   812311       \n1               NaN                           NaN     251481   035771       \n2               NaN                           NaN     251482   939970       \n3               NaN                           NaN     251004   114162       \n4               NaN                           NaN     251004   114162       \n\n                                  CUS_CONT_DESC_TEXT REPAIR_ORDER_DATE  \\\n0  AFTER PERFORMING 17-026 FOUND NO CHANGE IN NOI...        2017-10-30   \n1  SQUEAK UPON ACCELERATE; 30MPH TO A SLOW DOWN T...        2017-04-25   \n2  WHEN DRIVING 70 MPH WHINNING NOISE,NOISE ON AC...        2017-10-02   \n3  WHEN BRAKING FROM SPEED AND ACCELERATING TO TU...        2018-07-24   \n4  WHEN BRAKING FROM SPEED AND ACCELERATING TO TU...        2018-07-24   \n\n  RECEIVED_DATE AF_OFF_DATE ENGINE_BUILD_DATE PRI_LABOR_OP_CODE  \\\n0    2017-11-15  2015-01-21        2015-01-20           218102    \n1    2017-05-11  2015-01-21        2015-01-20           218102    \n2    2017-11-22  2015-01-21     ...
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>VIN_DLR_CLM_SK</th>\n      <th>WAR_CLAIM_DATE</th>\n      <th>VIN</th>\n      <th>TPL_VIN</th>\n      <th>PICKUP_DATE</th>\n      <th>SUBMITTED_DATE</th>\n      <th>REOPENED_DATE</th>\n      <th>REOPENED_SUBMITTED_DATE</th>\n      <th>FINAL_CLOSURE_DATE</th>\n      <th>STATUS_NAME</th>\n      <th>STATUS_OPEN_CLOSED</th>\n      <th>TPL_SHORT_PART_NO</th>\n      <th>PART_CATEGORY</th>\n      <th>DAYS_TO_CLOSURE</th>\n      <th>DAYS_OPEN</th>\n      <th>WARR_PART_NO</th>\n      <th>CUSTOMER_CONTENTION_TXT</th>\n      <th>VISUAL_INSPECTION_DETAIL_TXT</th>\n      <th>FUNCTIONAL_INSPECTION_DETAIL_TXT</th>\n      <th>CATEGORY_DESC_TXT</th>\n      <th>SUPPLIER_ANALYSIS_SUMMARY_TXT</th>\n      <th>DEALER_NO</th>\n      <th>WAR_CLAIM_NO</th>\n      <th>CUS_CONT_DESC_TEXT</th>\n      <th>REPAIR_ORDER_DATE</th>\n      <th>RECEIVED_DATE</th>\n      <th>AF_OFF_DATE</th>\n      <th>ENGINE_BUILD_DATE</th>\n      <th>PRI_LABOR_OP_CODE</th>\n      <th>WAR_ORIG_DISTR_CDE</th>\n      <th>WAR_RESP_DISTR_CDE</th>\n      <th>VEHICLE_DESTN_CODE</th>\n      <th>FLAT_RATE_HRS_QTY</th>\n      <th>FRGT_SUBL_TAX_AMT_USD</th>\n      <th>DIAGNOSTIC_LABOR_HRS_QTY</th>\n      <th>TPL_CREATION_DATE</th>\n      <th>RESPONSIBILITY_PCT</th>\n      <th>CONCLUSION_DESC_TXT</th>\n      <th>VEH_MILEAGE</th>\n      <th>CURRENCY_TYPE_CODE</th>\n      <th>ACTUAL_PARTS_CHG_AMT_USD</th>\n      <th>ACTUAL_LABOR_CHG_AMT_USD</th>\n      <th>ACTUAL_HDLG_CHG_AMT_USD</th>\n      <th>ACTUAL_TOTAL_CHG_AMT_USD</th>\n      <th>CAMPAIGN_CODE</th>\n      <th>WAR_DEFECT_CODE</th>\n      <th>RECORD_DESC</th>\n      <th>RECORD_COUNT</th>\n      <th>REPLACED_PART5</th>\n      <th>REPLACED_PART_NO</th>\n      <th>PART_DESC</th>\n      <th>ACT_PARTS_QTY_NO</th>\n      <th>MTC_MODEL</th>\n      <th>MTC_TYPE</th>\n      <th>MTC_OPTION</th>\n      <th>TRANS_SERIAL_NO</th>\n      <th>NAMEPLATE</th>\n      <th>MODEL_YEAR</th>\n      <th>FACTORY</th>\n      <th>MOD_NAME</th>\n      <th>TRANSMISSION_GEARS</th>\n      <th>REPLACED_PART_EQUOTE_FMT</th>\n      <th>CLAIM_LABOR_HRS_QTY</th>\n      <th>WAR_EXCH_RATE_AMT</th>\n      <th>DLR_NET_PRCE_AMT_USD</th>\n      <th>PART_FOB_COST_USD</th>\n      <th>DLR_NET_PRCE_AMTx90_USD</th>\n      <th>PART_FOB_COSTx2_USD</th>\n      <th>MIN_PART_COST_USD</th>\n      <th>TRANSFER_PART_LIST_ITEM_DETAIL_SK</th>\n      <th>REPL_ROW_NUM</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>5FRYD4H97GB001027251144812311</td>\n      <td>201711</td>\n      <td>5FRYD4H97GB001027</td>\n      <td>5FRYD4H97GB001027</td>\n      <td>2017-11-22</td>\n      <td>2018-01-16</td>\n      <td>2019-03-25</td>\n      <td>NaT</td>\n      <td>nan</td>\n      <td>REOPENED_FOR_ANALYSIS</td>\n      <td>OPEN</td>\n      <td>6,200.00</td>\n      <td>TRANSMISSION</td>\n      <td>nan</td>\n      <td>517.00</td>\n      <td>062005NCA79RM</td>\n      <td>AFTER PERFORMING 17-026 FOUND NO CHANGE IN NOI...</td>\n      <td>~</td>\n      <td>~</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>251144</td>\n      <td>812311</td>\n      <td>AFTER PERFORMING 17-026 FOUND NO CHANGE IN NOI...</td>\n      <td>2017-10-30</td>\n      <td>2017-11-15</td>\n      <td>2015-01-21</td>\n      <td>2015-01-20</td>\n      <td>218102</td>\n      <td>101</td>\n      <td>15A</td>\n      <td>KA</td>\n      <td>5.90</td>\n      <td>125.00</td>\n      <td>3.10</td>\n      <td>2017-11-20 12:51:31.443</td>\n      <td>nan</td>\n      <td>nan</td>\n      <td>51221</td>\n      <td>$</td>\n      <td>2,881.81</td>\n      <td>1,520.00</td>\n      <td>2,572.40</td>\n      <td>6,974.21</td>\n      <td>N</td>\n      <td>3214</td ...
#      'execution_count': 8}],
#    'source': 'claims_without_tpl.head()'},
#   {'cell_type': 'code',
#    'execution_count': 9,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:23.728892',
#      'end_time': '2019-04-23T16:12:23.804349',
#      'duration': 0.075457,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '(4399, 71)'},
#      'execution_count': 9}],
#    'source': 'claims_without_tpl.shape'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:23.866573',
#      'end_time': '2019-04-23T16:12:23.919481',
#      'duration': 0.052908,
#      'status': 'completed'}},
#    'source': '### Obtain fixed percentages stored in an MS Access database:'},
#   {'cell_type': 'code',
#    'execution_count': 10,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:23.981990',
#      'end_time': '2019-04-23T16:12:42.394062',
#      'duration': 18.412072,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '\nSELECT\n    MODEL_YEAR,\n    SHORT_PART_NO,\n    SUPP_FIXED_PERC,\n    ANALYSIS_END_MTH\n\nFROM\n    tbl_Fixed_Percentages_Yr_Part \n'},
#     {'output_type': 'stream', 'name': 'stdout', 'text': '\n'}],
#    'source': 'conn_str = (\n    r\'DRIVER={Microsoft Access Driver (*.mdb, *.accdb)};\'\n    r\'DBQ=\\\\mmpapp02\\mq_db\\wrp\\ZF_ATM_WRP_Project\\version4\\databases\\WRP_DAT_ZF.accdb;\'\n)\ncnxn = pyodbc.connect(conn_str)\ncursor = cnxn.cursor()\n\nsql = """\nSELECT\n    MODEL_YEAR,\n    SHORT_PART_NO,\n    SUPP_FIXED_PERC,\n    ANALYSIS_END_MTH\n\nFROM\n    tbl_Fixed_Percentages_Yr_Part \n"""\n\ntry:\n    fixed_percentages = pd.read_sql(sql, cnxn)\n\n    # Close connections\n    cursor.close()\n    cnxn.close()\n    print(sql)\nexcept:\n    print("Error connecting to database")\n    cursor.close()\n    cnxn.close()'},
#   {'cell_type': 'code',
#    'execution_count': 11,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:42.518862',
#      'end_time': '2019-04-23T16:12:42.617482',
#      'duration': 0.09862,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '   MODEL_YEAR SHORT_PART_NO      SUPP_FIXED_PERC ANALYSIS_END_MTH\n0        2015         06200                 0.53           201806\n1        2015         06224                 0.88           201806\n2        2015         06225                 0.91           201806\n3        2015         06231                 1.00           201806\n4        2015         06233                 0.97           201806\n5        2015         06235                 0.80           201806\n6        2015         06280                 0.34           201806\n7        2016         06200                 0.93           201806\n8        2016         06221                 0.50           201806\n9        2016         06222                 1.00           201806\n10       2016         06224                 0.97           201806\n11       2016         06225                 0.92           201806\n12       2016         06231                 1.00           201806\n13       2016         06233                 0.99           201806\n14       2016         06235                 0.94           201806\n15       2016         06280                 0.60           201806',
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>MODEL_YEAR</th>\n      <th>SHORT_PART_NO</th>\n      <th>SUPP_FIXED_PERC</th>\n      <th>ANALYSIS_END_MTH</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>2015</td>\n      <td>06200</td>\n      <td>0.53</td>\n      <td>201806</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>2015</td>\n      <td>06224</td>\n      <td>0.88</td>\n      <td>201806</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>2015</td>\n      <td>06225</td>\n      <td>0.91</td>\n      <td>201806</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>2015</td>\n      <td>06231</td>\n      <td>1.00</td>\n      <td>201806</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>2015</td>\n      <td>06233</td>\n      <td>0.97</td>\n      <td>201806</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>2015</td>\n      <td>06235</td>\n      <td>0.80</td>\n      <td>201806</td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>2015</td>\n      <td>06280</td>\n      <td>0.34</td>\n      <td>201806</td>\n    </tr>\n    <tr>\n      <th>7</th>\n      <td>2016</td>\n      <td>06200</td>\n      <td>0.93</td>\n      <td>201806</td>\n    </tr>\n    <tr>\n      <th>8</th>\n      <td>2016</td>\n      <td>06221</td>\n      <td>0.50</td>\n      <td>201806</td>\n    </tr>\n    <tr>\n      <th>9</th>\n      <td>2016</td>\n      <td>06222</td>\n      <td>1.00</td>\n      <td>201806</td>\n    </tr>\n    <tr>\n      <th>10</th>\n      <td>2016</td>\n      <td>06224</td>\n      <td>0.97</td>\n      <td>201806</td>\n    </tr>\n    <tr>\n      <th>11</th>\n      <td>2016</td>\n      <td>06225</td>\n      <td>0.92</td>\n      <td>201806</td>\n    </tr>\n    <tr>\n      <th>12</th>\n      <td>2016</td>\n      <td>06231</td>\n      <td>1.00</td>\n      <td>201806</td>\n    </tr>\n    <tr>\n      <th>13</th>\n      <td>2016</td>\n      <td>06233</td>\n      <td>0.99</td>\n      <td>201806</td>\n    </tr>\n    <tr>\n      <th>14</th>\n      <td>2016</td>\n      <td>06235</td>\n      <td>0.94</td>\n      <td>201806</td>\n    </tr>\n    <tr>\n      <th>15</th>\n      <td>2016</td>\n      <td>06280</td>\n      <td>0.60</td>\n      <td>201806</td>\n    </tr>\n  </tbody>\n</table>\n</div>'},
#      'execution_count': 11}],
#    'source': 'fixed_percentages'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:42.665918',
#      'end_time': '2019-04-23T16:12:42.750608',
#      'duration': 0.08469,
#      'status': 'completed'}},
#    'source': '### Add ```SUPP_FIXED_PERC``` column by LEFT JOIN-ing to the fixed percentages data set:'},
#   {'cell_type': 'code',
#    'execution_count': 12,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:42.828742',
#      'end_time': '2019-04-23T16:12:43.060111',
#      'duration': 0.231369,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "claims_without_tpl = pd.merge(claims_without_tpl, fixed_percentages, how='left', left_on=['MODEL_YEAR', 'REPLACED_PART5'],\n                          right_on=['MODEL_YEAR', 'SHORT_PART_NO'], indicator=True)"},
#   {'cell_type': 'code',
#    'execution_count': 13,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:43.138263',
#      'end_time': '2019-04-23T16:12:43.232371',
#      'duration': 0.094108,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '  MODEL_YEAR REPLACED_PART5      SUPP_FIXED_PERC\n0       2016          06200                 0.93\n1       2016          06200                 0.93\n2       2016          06200                 0.93\n3       2016          06200                 0.93\n4       2016          06200                 0.93',
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>MODEL_YEAR</th>\n      <th>REPLACED_PART5</th>\n      <th>SUPP_FIXED_PERC</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>2016</td>\n      <td>06200</td>\n      <td>0.93</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>2016</td>\n      <td>06200</td>\n      <td>0.93</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>2016</td>\n      <td>06200</td>\n      <td>0.93</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>2016</td>\n      <td>06200</td>\n      <td>0.93</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>2016</td>\n      <td>06200</td>\n      <td>0.93</td>\n    </tr>\n  </tbody>\n</table>\n</div>'},
#      'execution_count': 13}],
#    'source': "claims_without_tpl[['MODEL_YEAR','REPLACED_PART5','SUPP_FIXED_PERC']].head()"},
#   {'cell_type': 'code',
#    'execution_count': 14,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:43.294869',
#      'end_time': '2019-04-23T16:12:43.382914',
#      'duration': 0.088045,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '0.93    1787\n0.53    1535\n0.60     352\n0.34     187\n0.99     100\n0.97      60\n0.94      50\n0.88      30\n1.00      25\n0.92      23\n0.97      22\n0.80       8\n0.91       5\n0.50       3\nName: SUPP_FIXED_PERC, dtype: int64'},
#      'execution_count': 14}],
#    'source': "claims_without_tpl['SUPP_FIXED_PERC'].value_counts()"},
#   {'cell_type': 'code',
#    'execution_count': 15,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:43.448749',
#      'end_time': '2019-04-23T16:12:54.833528',
#      'duration': 11.384779,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "claims_without_tpl.to_excel(r'D:\\temp\\fixed_claims.xlsx', index=False)"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:54.911650',
#      'end_time': '2019-04-23T16:12:54.974155',
#      'duration': 0.062505,
#      'status': 'completed'}},
#    'source': '### Add WRPID column which is in the format: WRP219F + 2-digit month + 2-digit year where month/year depends on end voucher date'},
#   {'cell_type': 'code',
#    'execution_count': 16,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:55.061481',
#      'end_time': '2019-04-23T16:12:55.183976',
#      'duration': 0.122495,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'18'"},
#      'execution_count': 16}],
#    'source': 'year = end_voucher_date[2:4]\nyear'},
#   {'cell_type': 'code',
#    'execution_count': 17,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:55.241355',
#      'end_time': '2019-04-23T16:12:55.455340',
#      'duration': 0.213985,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'09'"},
#      'execution_count': 17}],
#    'source': 'month = end_voucher_date[5:7]\nmonth'},
#   {'cell_type': 'code',
#    'execution_count': 18,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:55.533476',
#      'end_time': '2019-04-23T16:12:55.673652',
#      'duration': 0.140176,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "claims_without_tpl = claims_without_tpl.assign(WRPID='WRP219F' + month + year)"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:55.751788',
#      'end_time': '2019-04-23T16:12:55.850509',
#      'duration': 0.098721,
#      'status': 'completed'}},
#    'source': "#### Let's confirm that ```WRPID``` has been created (scroll to far right):"},
#   {'cell_type': 'code',
#    'execution_count': 19,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:55.939541',
#      'end_time': '2019-04-23T16:12:56.169546',
#      'duration': 0.230005,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '                  VIN_DLR_CLM_SK  WAR_CLAIM_DATE                VIN  \\\n0  5FRYD4H97GB001027251144812311          201711  5FRYD4H97GB001027   \n1  5FRYD4H91GB001010251481035771          201705  5FRYD4H91GB001010   \n2  5FRYD4H98GB001022251482939970          201711  5FRYD4H98GB001022   \n3  5FRYD3H47GB001009251004114162          201808  5FRYD3H47GB001009   \n4  5FRYD3H47GB001009251004114162          201808  5FRYD3H47GB001009   \n\n             TPL_VIN PICKUP_DATE SUBMITTED_DATE REOPENED_DATE  \\\n0  5FRYD4H97GB001027  2017-11-22     2018-01-16    2019-03-25   \n1  5FRYD4H91GB001010  2017-06-16     2017-08-07    2019-03-25   \n2                NaN         NaT            NaT           NaT   \n3  5FRYD3H47GB001009  2018-09-10     2018-10-23    2019-03-25   \n4  5FRYD3H47GB001009  2018-09-10     2018-10-23    2019-03-25   \n\n  REOPENED_SUBMITTED_DATE   FINAL_CLOSURE_DATE            STATUS_NAME  \\\n0                     NaT                  nan  REOPENED_FOR_ANALYSIS   \n1                     NaT                  nan  REOPENED_FOR_ANALYSIS   \n2                     NaT                  nan                    NaN   \n3                     NaT                  nan  REOPENED_FOR_ANALYSIS   \n4                     NaT                  nan  REOPENED_FOR_ANALYSIS   \n\n  STATUS_OPEN_CLOSED    TPL_SHORT_PART_NO PART_CATEGORY      DAYS_TO_CLOSURE  \\\n0               OPEN             6,200.00  TRANSMISSION                  nan   \n1               OPEN             6,200.00  TRANSMISSION                  nan   \n2                NaN                  nan           NaN                  nan   \n3               OPEN             6,200.00  TRANSMISSION                  nan   \n4               OPEN             6,200.00  TRANSMISSION                  nan   \n\n             DAYS_OPEN        WARR_PART_NO  \\\n0               517.00  062005NCA79RM        \n1               676.00  062005NCA79RM        \n2                  nan  062005NCA79RM        \n3               225.00  062005NBA58RM        \n4               225.00  062005NBA58RM        \n\n                             CUSTOMER_CONTENTION_TXT  \\\n0  AFTER PERFORMING 17-026 FOUND NO CHANGE IN NOI...   \n1  SQUEAK UPON ACCELERATE; 30MPH TO A SLOW DOWN T...   \n2                                                NaN   \n3  WHEN BRAKING FROM SPEED AND ACCELERATING TO TU...   \n4  WHEN BRAKING FROM SPEED AND ACCELERATING TO TU...   \n\n  VISUAL_INSPECTION_DETAIL_TXT FUNCTIONAL_INSPECTION_DETAIL_TXT  \\\n0                           ~                                ~    \n1                           ~                                ~    \n2                           ~                                ~    \n3                           ~                                ~    \n4                           ~                                ~    \n\n  CATEGORY_DESC_TXT SUPPLIER_ANALYSIS_SUMMARY_TXT  DEALER_NO WAR_CLAIM_NO  \\\n0               NaN                           NaN     251144   812311       \n1               NaN                           NaN     251481   035771       \n2               NaN                           NaN     251482   939970       \n3               NaN                           NaN     251004   114162       \n4               NaN                           NaN     251004   114162       \n\n                                  CUS_CONT_DESC_TEXT REPAIR_ORDER_DATE  \\\n0  AFTER PERFORMING 17-026 FOUND NO CHANGE IN NOI...        2017-10-30   \n1  SQUEAK UPON ACCELERATE; 30MPH TO A SLOW DOWN T...        2017-04-25   \n2  WHEN DRIVING 70 MPH WHINNING NOISE,NOISE ON AC...        2017-10-02   \n3  WHEN BRAKING FROM SPEED AND ACCELERATING TO TU...        2018-07-24   \n4  WHEN BRAKING FROM SPEED AND ACCELERATING TO TU...        2018-07-24   \n\n  RECEIVED_DATE AF_OFF_DATE ENGINE_BUILD_DATE PRI_LABOR_OP_CODE  \\\n0    2017-11-15  2015-01-21        2015-01-20           218102    \n1    2017-05-11  2015-01-21        2015-01-20           218102    \n2    2017-11-22  2015-01-21     ...
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>VIN_DLR_CLM_SK</th>\n      <th>WAR_CLAIM_DATE</th>\n      <th>VIN</th>\n      <th>TPL_VIN</th>\n      <th>PICKUP_DATE</th>\n      <th>SUBMITTED_DATE</th>\n      <th>REOPENED_DATE</th>\n      <th>REOPENED_SUBMITTED_DATE</th>\n      <th>FINAL_CLOSURE_DATE</th>\n      <th>STATUS_NAME</th>\n      <th>STATUS_OPEN_CLOSED</th>\n      <th>TPL_SHORT_PART_NO</th>\n      <th>PART_CATEGORY</th>\n      <th>DAYS_TO_CLOSURE</th>\n      <th>DAYS_OPEN</th>\n      <th>WARR_PART_NO</th>\n      <th>CUSTOMER_CONTENTION_TXT</th>\n      <th>VISUAL_INSPECTION_DETAIL_TXT</th>\n      <th>FUNCTIONAL_INSPECTION_DETAIL_TXT</th>\n      <th>CATEGORY_DESC_TXT</th>\n      <th>SUPPLIER_ANALYSIS_SUMMARY_TXT</th>\n      <th>DEALER_NO</th>\n      <th>WAR_CLAIM_NO</th>\n      <th>CUS_CONT_DESC_TEXT</th>\n      <th>REPAIR_ORDER_DATE</th>\n      <th>RECEIVED_DATE</th>\n      <th>AF_OFF_DATE</th>\n      <th>ENGINE_BUILD_DATE</th>\n      <th>PRI_LABOR_OP_CODE</th>\n      <th>WAR_ORIG_DISTR_CDE</th>\n      <th>WAR_RESP_DISTR_CDE</th>\n      <th>VEHICLE_DESTN_CODE</th>\n      <th>FLAT_RATE_HRS_QTY</th>\n      <th>FRGT_SUBL_TAX_AMT_USD</th>\n      <th>DIAGNOSTIC_LABOR_HRS_QTY</th>\n      <th>TPL_CREATION_DATE</th>\n      <th>RESPONSIBILITY_PCT</th>\n      <th>CONCLUSION_DESC_TXT</th>\n      <th>VEH_MILEAGE</th>\n      <th>CURRENCY_TYPE_CODE</th>\n      <th>ACTUAL_PARTS_CHG_AMT_USD</th>\n      <th>ACTUAL_LABOR_CHG_AMT_USD</th>\n      <th>ACTUAL_HDLG_CHG_AMT_USD</th>\n      <th>ACTUAL_TOTAL_CHG_AMT_USD</th>\n      <th>CAMPAIGN_CODE</th>\n      <th>WAR_DEFECT_CODE</th>\n      <th>RECORD_DESC</th>\n      <th>RECORD_COUNT</th>\n      <th>REPLACED_PART5</th>\n      <th>REPLACED_PART_NO</th>\n      <th>PART_DESC</th>\n      <th>ACT_PARTS_QTY_NO</th>\n      <th>MTC_MODEL</th>\n      <th>MTC_TYPE</th>\n      <th>MTC_OPTION</th>\n      <th>TRANS_SERIAL_NO</th>\n      <th>NAMEPLATE</th>\n      <th>MODEL_YEAR</th>\n      <th>FACTORY</th>\n      <th>MOD_NAME</th>\n      <th>TRANSMISSION_GEARS</th>\n      <th>REPLACED_PART_EQUOTE_FMT</th>\n      <th>CLAIM_LABOR_HRS_QTY</th>\n      <th>WAR_EXCH_RATE_AMT</th>\n      <th>DLR_NET_PRCE_AMT_USD</th>\n      <th>PART_FOB_COST_USD</th>\n      <th>DLR_NET_PRCE_AMTx90_USD</th>\n      <th>PART_FOB_COSTx2_USD</th>\n      <th>MIN_PART_COST_USD</th>\n      <th>TRANSFER_PART_LIST_ITEM_DETAIL_SK</th>\n      <th>REPL_ROW_NUM</th>\n      <th>SHORT_PART_NO</th>\n      <th>SUPP_FIXED_PERC</th>\n      <th>ANALYSIS_END_MTH</th>\n      <th>_merge</th>\n      <th>WRPID</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>5FRYD4H97GB001027251144812311</td>\n      <td>201711</td>\n      <td>5FRYD4H97GB001027</td>\n      <td>5FRYD4H97GB001027</td>\n      <td>2017-11-22</td>\n      <td>2018-01-16</td>\n      <td>2019-03-25</td>\n      <td>NaT</td>\n      <td>nan</td>\n      <td>REOPENED_FOR_ANALYSIS</td>\n      <td>OPEN</td>\n      <td>6,200.00</td>\n      <td>TRANSMISSION</td>\n      <td>nan</td>\n      <td>517.00</td>\n      <td>062005NCA79RM</td>\n      <td>AFTER PERFORMING 17-026 FOUND NO CHANGE IN NOI...</td>\n      <td>~</td>\n      <td>~</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>251144</td>\n      <td>812311</td>\n      <td>AFTER PERFORMING 17-026 FOUND NO CHANGE IN NOI...</td>\n      <td>2017-10-30</td>\n      <td>2017-11-15</td>\n      <td>2015-01-21</td>\n      <td>2015-01-20</td>\n      <td>218102</td>\n      <td>101</td>\n      <td>15A</td>\n      <td>KA</td>\n      <td>5.90</td>\n      <td>125.00</td>\n      <td>3.10</td>\n      <td>2017-11-20 12:51:31.443</td>\n      <td>nan</td>\n      <td>nan</td>\n      <td>51221</td>\n      <td>$</t ...
#      'execution_count': 19}],
#    'source': 'claims_without_tpl.head()'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:56.247679',
#      'end_time': '2019-04-23T16:12:56.341440',
#      'duration': 0.093761,
#      'status': 'completed'}},
#    'source': '### Add ```HRLY_RATE_USD``` column:'},
#   {'cell_type': 'code',
#    'execution_count': 20,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:56.438845',
#      'end_time': '2019-04-23T16:12:56.531116',
#      'duration': 0.092271,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "claims_without_tpl['HRLY_RATE_USD'] = np.where(claims_without_tpl['NAMEPLATE'] == 'ACURA', int(acura_hourly_labor_rate), int(honda_hourly_labor_rate))"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:56.589781',
#      'end_time': '2019-04-23T16:12:56.667915',
#      'duration': 0.078134,
#      'status': 'completed'}},
#    'source': "#### Let's confirm that ```HRLY_RATE_USD``` column has been created (scroll to far right):"},
#   {'cell_type': 'code',
#    'execution_count': 21,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:56.756332',
#      'end_time': '2019-04-23T16:12:56.970642',
#      'duration': 0.21431,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '                  VIN_DLR_CLM_SK  WAR_CLAIM_DATE                VIN  \\\n0  5FRYD4H97GB001027251144812311          201711  5FRYD4H97GB001027   \n1  5FRYD4H91GB001010251481035771          201705  5FRYD4H91GB001010   \n2  5FRYD4H98GB001022251482939970          201711  5FRYD4H98GB001022   \n3  5FRYD3H47GB001009251004114162          201808  5FRYD3H47GB001009   \n4  5FRYD3H47GB001009251004114162          201808  5FRYD3H47GB001009   \n\n             TPL_VIN PICKUP_DATE SUBMITTED_DATE REOPENED_DATE  \\\n0  5FRYD4H97GB001027  2017-11-22     2018-01-16    2019-03-25   \n1  5FRYD4H91GB001010  2017-06-16     2017-08-07    2019-03-25   \n2                NaN         NaT            NaT           NaT   \n3  5FRYD3H47GB001009  2018-09-10     2018-10-23    2019-03-25   \n4  5FRYD3H47GB001009  2018-09-10     2018-10-23    2019-03-25   \n\n  REOPENED_SUBMITTED_DATE   FINAL_CLOSURE_DATE            STATUS_NAME  \\\n0                     NaT                  nan  REOPENED_FOR_ANALYSIS   \n1                     NaT                  nan  REOPENED_FOR_ANALYSIS   \n2                     NaT                  nan                    NaN   \n3                     NaT                  nan  REOPENED_FOR_ANALYSIS   \n4                     NaT                  nan  REOPENED_FOR_ANALYSIS   \n\n  STATUS_OPEN_CLOSED    TPL_SHORT_PART_NO PART_CATEGORY      DAYS_TO_CLOSURE  \\\n0               OPEN             6,200.00  TRANSMISSION                  nan   \n1               OPEN             6,200.00  TRANSMISSION                  nan   \n2                NaN                  nan           NaN                  nan   \n3               OPEN             6,200.00  TRANSMISSION                  nan   \n4               OPEN             6,200.00  TRANSMISSION                  nan   \n\n             DAYS_OPEN        WARR_PART_NO  \\\n0               517.00  062005NCA79RM        \n1               676.00  062005NCA79RM        \n2                  nan  062005NCA79RM        \n3               225.00  062005NBA58RM        \n4               225.00  062005NBA58RM        \n\n                             CUSTOMER_CONTENTION_TXT  \\\n0  AFTER PERFORMING 17-026 FOUND NO CHANGE IN NOI...   \n1  SQUEAK UPON ACCELERATE; 30MPH TO A SLOW DOWN T...   \n2                                                NaN   \n3  WHEN BRAKING FROM SPEED AND ACCELERATING TO TU...   \n4  WHEN BRAKING FROM SPEED AND ACCELERATING TO TU...   \n\n  VISUAL_INSPECTION_DETAIL_TXT FUNCTIONAL_INSPECTION_DETAIL_TXT  \\\n0                           ~                                ~    \n1                           ~                                ~    \n2                           ~                                ~    \n3                           ~                                ~    \n4                           ~                                ~    \n\n  CATEGORY_DESC_TXT SUPPLIER_ANALYSIS_SUMMARY_TXT  DEALER_NO WAR_CLAIM_NO  \\\n0               NaN                           NaN     251144   812311       \n1               NaN                           NaN     251481   035771       \n2               NaN                           NaN     251482   939970       \n3               NaN                           NaN     251004   114162       \n4               NaN                           NaN     251004   114162       \n\n                                  CUS_CONT_DESC_TEXT REPAIR_ORDER_DATE  \\\n0  AFTER PERFORMING 17-026 FOUND NO CHANGE IN NOI...        2017-10-30   \n1  SQUEAK UPON ACCELERATE; 30MPH TO A SLOW DOWN T...        2017-04-25   \n2  WHEN DRIVING 70 MPH WHINNING NOISE,NOISE ON AC...        2017-10-02   \n3  WHEN BRAKING FROM SPEED AND ACCELERATING TO TU...        2018-07-24   \n4  WHEN BRAKING FROM SPEED AND ACCELERATING TO TU...        2018-07-24   \n\n  RECEIVED_DATE AF_OFF_DATE ENGINE_BUILD_DATE PRI_LABOR_OP_CODE  \\\n0    2017-11-15  2015-01-21        2015-01-20           218102    \n1    2017-05-11  2015-01-21        2015-01-20           218102    \n2    2017-11-22  2015-01-21     ...
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>VIN_DLR_CLM_SK</th>\n      <th>WAR_CLAIM_DATE</th>\n      <th>VIN</th>\n      <th>TPL_VIN</th>\n      <th>PICKUP_DATE</th>\n      <th>SUBMITTED_DATE</th>\n      <th>REOPENED_DATE</th>\n      <th>REOPENED_SUBMITTED_DATE</th>\n      <th>FINAL_CLOSURE_DATE</th>\n      <th>STATUS_NAME</th>\n      <th>STATUS_OPEN_CLOSED</th>\n      <th>TPL_SHORT_PART_NO</th>\n      <th>PART_CATEGORY</th>\n      <th>DAYS_TO_CLOSURE</th>\n      <th>DAYS_OPEN</th>\n      <th>WARR_PART_NO</th>\n      <th>CUSTOMER_CONTENTION_TXT</th>\n      <th>VISUAL_INSPECTION_DETAIL_TXT</th>\n      <th>FUNCTIONAL_INSPECTION_DETAIL_TXT</th>\n      <th>CATEGORY_DESC_TXT</th>\n      <th>SUPPLIER_ANALYSIS_SUMMARY_TXT</th>\n      <th>DEALER_NO</th>\n      <th>WAR_CLAIM_NO</th>\n      <th>CUS_CONT_DESC_TEXT</th>\n      <th>REPAIR_ORDER_DATE</th>\n      <th>RECEIVED_DATE</th>\n      <th>AF_OFF_DATE</th>\n      <th>ENGINE_BUILD_DATE</th>\n      <th>PRI_LABOR_OP_CODE</th>\n      <th>WAR_ORIG_DISTR_CDE</th>\n      <th>WAR_RESP_DISTR_CDE</th>\n      <th>VEHICLE_DESTN_CODE</th>\n      <th>FLAT_RATE_HRS_QTY</th>\n      <th>FRGT_SUBL_TAX_AMT_USD</th>\n      <th>DIAGNOSTIC_LABOR_HRS_QTY</th>\n      <th>TPL_CREATION_DATE</th>\n      <th>RESPONSIBILITY_PCT</th>\n      <th>CONCLUSION_DESC_TXT</th>\n      <th>VEH_MILEAGE</th>\n      <th>CURRENCY_TYPE_CODE</th>\n      <th>ACTUAL_PARTS_CHG_AMT_USD</th>\n      <th>ACTUAL_LABOR_CHG_AMT_USD</th>\n      <th>ACTUAL_HDLG_CHG_AMT_USD</th>\n      <th>ACTUAL_TOTAL_CHG_AMT_USD</th>\n      <th>CAMPAIGN_CODE</th>\n      <th>WAR_DEFECT_CODE</th>\n      <th>RECORD_DESC</th>\n      <th>RECORD_COUNT</th>\n      <th>REPLACED_PART5</th>\n      <th>REPLACED_PART_NO</th>\n      <th>PART_DESC</th>\n      <th>ACT_PARTS_QTY_NO</th>\n      <th>MTC_MODEL</th>\n      <th>MTC_TYPE</th>\n      <th>MTC_OPTION</th>\n      <th>TRANS_SERIAL_NO</th>\n      <th>NAMEPLATE</th>\n      <th>MODEL_YEAR</th>\n      <th>FACTORY</th>\n      <th>MOD_NAME</th>\n      <th>TRANSMISSION_GEARS</th>\n      <th>REPLACED_PART_EQUOTE_FMT</th>\n      <th>CLAIM_LABOR_HRS_QTY</th>\n      <th>WAR_EXCH_RATE_AMT</th>\n      <th>DLR_NET_PRCE_AMT_USD</th>\n      <th>PART_FOB_COST_USD</th>\n      <th>DLR_NET_PRCE_AMTx90_USD</th>\n      <th>PART_FOB_COSTx2_USD</th>\n      <th>MIN_PART_COST_USD</th>\n      <th>TRANSFER_PART_LIST_ITEM_DETAIL_SK</th>\n      <th>REPL_ROW_NUM</th>\n      <th>SHORT_PART_NO</th>\n      <th>SUPP_FIXED_PERC</th>\n      <th>ANALYSIS_END_MTH</th>\n      <th>_merge</th>\n      <th>WRPID</th>\n      <th>HRLY_RATE_USD</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>5FRYD4H97GB001027251144812311</td>\n      <td>201711</td>\n      <td>5FRYD4H97GB001027</td>\n      <td>5FRYD4H97GB001027</td>\n      <td>2017-11-22</td>\n      <td>2018-01-16</td>\n      <td>2019-03-25</td>\n      <td>NaT</td>\n      <td>nan</td>\n      <td>REOPENED_FOR_ANALYSIS</td>\n      <td>OPEN</td>\n      <td>6,200.00</td>\n      <td>TRANSMISSION</td>\n      <td>nan</td>\n      <td>517.00</td>\n      <td>062005NCA79RM</td>\n      <td>AFTER PERFORMING 17-026 FOUND NO CHANGE IN NOI...</td>\n      <td>~</td>\n      <td>~</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>251144</td>\n      <td>812311</td>\n      <td>AFTER PERFORMING 17-026 FOUND NO CHANGE IN NOI...</td>\n      <td>2017-10-30</td>\n      <td>2017-11-15</td>\n      <td>2015-01-21</td>\n      <td>2015-01-20</td>\n      <td>218102</td>\n      <td>101</td>\n      <td>15A</td>\n      <td>KA</td>\n      <td>5.90</td>\n      <td>125.00</td>\n      <td>3.10</td>\n      <td>2017-11-20 12:51:31.443</td>\n      <td>nan</td>\n      <td>nan</td>\n       ...
#      'execution_count': 21}],
#    'source': 'claims_without_tpl.query("NAMEPLATE == \'ACURA\'").head()'},
#   {'cell_type': 'code',
#    'execution_count': 22,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:12:57.048777',
#      'end_time': '2019-04-23T16:12:57.255397',
#      'duration': 0.20662,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
# ...
#      'metadata': {},
#      'data': {'text/plain': 'left_only     184\nboth            0\nright_only      0\nName: _merge, dtype: int64'},
#      'execution_count': 75}],
#    'source': "voucher_fixed_final['_merge'].value_counts()"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:14:38.099632',
#      'end_time': '2019-04-23T16:14:38.247453',
#      'duration': 0.147821,
#      'status': 'completed'}},
#    'source': '### Exclude already paid claims to prevent double-charging of supplier:'},
#   {'cell_type': 'code',
#    'execution_count': 76,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:14:38.372467',
#      'end_time': '2019-04-23T16:14:38.550713',
#      'duration': 0.178246,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "criteria = voucher_fixed_final['_merge'] == 'left_only'\nvoucher_fixed_final = voucher_fixed_final[criteria]"},
#   {'cell_type': 'code',
#    'execution_count': 77,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:14:38.675732',
#      'end_time': '2019-04-23T16:14:38.796886',
#      'duration': 0.121154,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '(184, 96)'},
#      'execution_count': 77}],
#    'source': 'voucher_fixed_final.shape'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:14:38.937527',
#      'end_time': '2019-04-23T16:14:39.062222',
#      'duration': 0.124695,
#      'status': 'completed'}},
#    'source': '### Delete redundant or unnecessary columns that came from merging with the MS Access already paid claims table'},
#   {'cell_type': 'code',
#    'execution_count': 78,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:14:39.171614',
#      'end_time': '2019-04-23T16:14:39.286621',
#      'duration': 0.115007,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "del voucher_fixed_final['_merge']\ndel voucher_fixed_final['WRP_ID']\ndel voucher_fixed_final['WRP_RECOVERY_COST_AFTER_PERC_USD_FINAL']"},
#   {'cell_type': 'code',
#    'execution_count': 79,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:14:39.362655',
#      'end_time': '2019-04-23T16:14:39.562605',
#      'duration': 0.19995,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '                  VIN_DLR_CLM_SK  WAR_CLAIM_DATE                VIN TPL_VIN  \\\n0  5FRYD4H68GB001169251057775001          201809  5FRYD4H68GB001169     NaN   \n1  5FRYD4H45GB002049251123228858          201809  5FRYD4H45GB002049     NaN   \n2  5FRYD4H83GB501080002174280552          201809  5FRYD4H83GB501080     NaN   \n3  5FRYD4H4XGB006999251027265521          201809  5FRYD4H4XGB006999     NaN   \n4  5FRYD4H45GB007929251174934224          201809  5FRYD4H45GB007929     NaN   \n\n  PICKUP_DATE SUBMITTED_DATE REOPENED_DATE REOPENED_SUBMITTED_DATE  \\\n0         NaT            NaT           NaT                     NaT   \n1         NaT            NaT           NaT                     NaT   \n2         NaT            NaT           NaT                     NaT   \n3         NaT            NaT           NaT                     NaT   \n4         NaT            NaT           NaT                     NaT   \n\n    FINAL_CLOSURE_DATE STATUS_NAME STATUS_OPEN_CLOSED    TPL_SHORT_PART_NO  \\\n0                  nan         NaN                NaN                  nan   \n1                  nan         NaN                NaN                  nan   \n2                  nan         NaN                NaN                  nan   \n3                  nan         NaN                NaN                  nan   \n4                  nan         NaN                NaN                  nan   \n\n  PART_CATEGORY      DAYS_TO_CLOSURE            DAYS_OPEN        WARR_PART_NO  \\\n0           NaN                  nan                  nan  062025J7A00          \n1           NaN                  nan                  nan  062355L9000          \n2           NaN                  nan                  nan  062005NCC79RM        \n3           NaN                  nan                  nan  200215NB043          \n4           NaN                  nan                  nan  062015NCA54          \n\n  CUSTOMER_CONTENTION_TXT VISUAL_INSPECTION_DETAIL_TXT  \\\n0                     NaN                           ~    \n1                     NaN                           ~    \n2                     NaN                           ~    \n3                     NaN                           ~    \n4                     NaN                           ~    \n\n  FUNCTIONAL_INSPECTION_DETAIL_TXT CATEGORY_DESC_TXT  \\\n0                               ~                NaN   \n1                               ~                NaN   \n2                               ~                NaN   \n3                               ~                NaN   \n4                               ~                NaN   \n\n  SUPPLIER_ANALYSIS_SUMMARY_TXT  DEALER_NO WAR_CLAIM_NO  \\\n0                           NaN     251057   775001       \n1                           NaN     251123   228858       \n2                           NaN       2174       280552   \n3                           NaN     251027   265521       \n4                           NaN     251174   934224       \n\n                                  CUS_CONT_DESC_TEXT REPAIR_ORDER_DATE  \\\n0  TECHLINE REF# 4149364 CUST STATES ENGINE SQUEE...        2018-08-30   \n1  CUSTOMER STATES THERE IS AN LEAK FROM BOTTOM O...        2018-05-30   \n2  REFERENCE LINE#1 428055 - CLICKING OR HISSING ...        2018-06-28   \n3                  C/S TRANSMISSION FLUID IS LEAKING        2018-09-07   \n4  CLIENT STATES WHILE DRIVING AT A SPEED BETWEEN...        2018-07-07   \n\n  RECEIVED_DATE AF_OFF_DATE ENGINE_BUILD_DATE PRI_LABOR_OP_CODE  \\\n0    2018-09-20  2015-02-02        2015-01-31           218102    \n1    2018-09-20  2015-02-05        2015-02-05           2191W5    \n2    2018-08-28  2015-02-09        2015-02-06           218102    \n3    2018-09-18  2015-02-23        2015-02-19           2321S2    \n4    2018-08-28  2015-02-27        2015-02-26           218102    \n\n   WAR_ORIG_DISTR_CDE WAR_RESP_DISTR_CDE VEHICLE_DESTN_CODE  \\\n0                 101                15A                KA    \n1                 101         ...
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>VIN_DLR_CLM_SK</th>\n      <th>WAR_CLAIM_DATE</th>\n      <th>VIN</th>\n      <th>TPL_VIN</th>\n      <th>PICKUP_DATE</th>\n      <th>SUBMITTED_DATE</th>\n      <th>REOPENED_DATE</th>\n      <th>REOPENED_SUBMITTED_DATE</th>\n      <th>FINAL_CLOSURE_DATE</th>\n      <th>STATUS_NAME</th>\n      <th>STATUS_OPEN_CLOSED</th>\n      <th>TPL_SHORT_PART_NO</th>\n      <th>PART_CATEGORY</th>\n      <th>DAYS_TO_CLOSURE</th>\n      <th>DAYS_OPEN</th>\n      <th>WARR_PART_NO</th>\n      <th>CUSTOMER_CONTENTION_TXT</th>\n      <th>VISUAL_INSPECTION_DETAIL_TXT</th>\n      <th>FUNCTIONAL_INSPECTION_DETAIL_TXT</th>\n      <th>CATEGORY_DESC_TXT</th>\n      <th>SUPPLIER_ANALYSIS_SUMMARY_TXT</th>\n      <th>DEALER_NO</th>\n      <th>WAR_CLAIM_NO</th>\n      <th>CUS_CONT_DESC_TEXT</th>\n      <th>REPAIR_ORDER_DATE</th>\n      <th>RECEIVED_DATE</th>\n      <th>AF_OFF_DATE</th>\n      <th>ENGINE_BUILD_DATE</th>\n      <th>PRI_LABOR_OP_CODE</th>\n      <th>WAR_ORIG_DISTR_CDE</th>\n      <th>WAR_RESP_DISTR_CDE</th>\n      <th>VEHICLE_DESTN_CODE</th>\n      <th>FLAT_RATE_HRS_QTY</th>\n      <th>FRGT_SUBL_TAX_AMT_USD</th>\n      <th>DIAGNOSTIC_LABOR_HRS_QTY</th>\n      <th>TPL_CREATION_DATE</th>\n      <th>RESPONSIBILITY_PCT</th>\n      <th>CONCLUSION_DESC_TXT</th>\n      <th>VEH_MILEAGE</th>\n      <th>CURRENCY_TYPE_CODE</th>\n      <th>ACTUAL_PARTS_CHG_AMT_USD</th>\n      <th>ACTUAL_LABOR_CHG_AMT_USD</th>\n      <th>ACTUAL_HDLG_CHG_AMT_USD</th>\n      <th>ACTUAL_TOTAL_CHG_AMT_USD</th>\n      <th>CAMPAIGN_CODE</th>\n      <th>WAR_DEFECT_CODE</th>\n      <th>RECORD_DESC</th>\n      <th>RECORD_COUNT</th>\n      <th>REPLACED_PART5</th>\n      <th>REPLACED_PART_NO</th>\n      <th>PART_DESC</th>\n      <th>ACT_PARTS_QTY_NO</th>\n      <th>MTC_MODEL</th>\n      <th>MTC_TYPE</th>\n      <th>MTC_OPTION</th>\n      <th>TRANS_SERIAL_NO</th>\n      <th>NAMEPLATE</th>\n      <th>MODEL_YEAR</th>\n      <th>FACTORY</th>\n      <th>MOD_NAME</th>\n      <th>TRANSMISSION_GEARS</th>\n      <th>REPLACED_PART_EQUOTE_FMT</th>\n      <th>CLAIM_LABOR_HRS_QTY</th>\n      <th>WAR_EXCH_RATE_AMT</th>\n      <th>DLR_NET_PRCE_AMT_USD</th>\n      <th>PART_FOB_COST_USD</th>\n      <th>DLR_NET_PRCE_AMTx90_USD</th>\n      <th>PART_FOB_COSTx2_USD</th>\n      <th>MIN_PART_COST_USD</th>\n      <th>TRANSFER_PART_LIST_ITEM_DETAIL_SK</th>\n      <th>REPL_ROW_NUM</th>\n      <th>SHORT_PART_NO</th>\n      <th>SUPP_FIXED_PERC</th>\n      <th>ANALYSIS_END_MTH</th>\n      <th>WRPID</th>\n      <th>HRLY_RATE_USD</th>\n      <th>CALCULATED_PART_COST_USD</th>\n      <th>CALCULATED_FLAT_RATE_LABOR_COST_USD</th>\n      <th>CALCULATED_DIAGNOSTIC_LABOR_COST_USD</th>\n      <th>CALCULATED_HDLG_CHG_AMT_USD</th>\n      <th>CALCULATED_TOTAL_COST_USD</th>\n      <th>CALCULATED_TOTAL_LABOR_COST_USD</th>\n      <th>ROW_NUM</th>\n      <th>ACTUAL_CLAIM_LEVEL_TOTAL_CHG_AMT_USD</th>\n      <th>ASN_RECEIVE_DATE</th>\n      <th>TransDTF</th>\n      <th>MassProCost_USD</th>\n      <th>MassProCostX205_USD</th>\n      <th>ACTUAL_CLAIM_LEVEL_TOTAL_CHG_AMT_USD_AFTER_PERC</th>\n      <th>CALCULATED_TOTAL_COST_USD_AFTER_PERC</th>\n      <th>WRP_VOUCHER_AMT_USD_INITIAL</th>\n      <th>WRP_VOUCHER_AMT_USD_FINAL</th>\n      <th>FIXED_YES_NO</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>5FRYD4H68GB001169251057775001</td>\n      <td>201809</td>\n      <td>5FRYD4H68GB001169</td>\n      <td>NaN</td>\n      <td>NaT</td>\n      <td>NaT</td>\n      <td>NaT</td>\n      <td>NaT</td>\n      <td>nan</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>nan</td>\n      <td>NaN</td>\n      <td>nan</td>\n      <td>nan</td>\n     ...
#      'execution_count': 79}],
#    'source': 'voucher_fixed_final.head()'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:14:39.682621',
#      'end_time': '2019-04-23T16:14:39.794597',
#      'duration': 0.111976,
#      'status': 'completed'}},
#    'source': '### Save voucher data as Excel file:'},
#   {'cell_type': 'code',
#    'execution_count': 80,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:14:39.888391',
#      'end_time': '2019-04-23T16:14:40.013994',
#      'duration': 0.125603,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'today = datetime.today()'},
#   {'cell_type': 'code',
#    'execution_count': 81,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:14:40.156935',
#      'end_time': '2019-04-23T16:14:40.310871',
#      'duration': 0.153936,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'base_dir = "//mmpapp02/mq_db/wrp/ZF_ATM_WRP_Project/automated_vouchers/outputs/excel/NorthAmericanPlants/Fixed"\np = Path(base_dir)\nsave_dir = p / datetime.strftime(today, "%Y-%m-%d")\nif not os.path.exists(save_dir):\n    os.makedirs(save_dir)'},
#   {'cell_type': 'code',
#    'execution_count': 82,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:14:40.404660',
#      'end_time': '2019-04-23T16:14:40.514051',
#      'duration': 0.109391,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "file_name = 'NA_Plants_Fixed_Voucher_FINAL.xlsx'"},
#   {'cell_type': 'code',
#    'execution_count': 83,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:14:40.609878',
#      'end_time': '2019-04-23T16:14:43.060538',
#      'duration': 2.45066,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'voucher_fixed_final.to_excel(save_dir / file_name, index=False)'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:14:43.169666',
#      'end_time': '2019-04-23T16:14:43.288749',
#      'duration': 0.119083,
#      'status': 'completed'}},
#    'source': '#### Where Excel file was saved to:'},
#   {'cell_type': 'code',
#    'execution_count': 84,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:14:43.386970',
#      'end_time': '2019-04-23T16:14:43.522979',
#      'duration': 0.136009,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "'\\\\\\\\mmpapp02\\\\mq_db\\\\wrp\\\\ZF_ATM_WRP_Project\\\\automated_vouchers\\\\outputs\\\\excel\\\\NorthAmericanPlants\\\\Fixed\\\\2019-04-23\\\\NA_Plants_Fixed_Voucher_FINAL.xlsx'"},
#      'execution_count': 84}],
#    'source': 'str(save_dir / file_name)'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:14:43.616776',
#      'end_time': '2019-04-23T16:14:43.721052',
#      'duration': 0.104276,
#      'status': 'completed'}},
#    'source': '### Send out Windows notification when complete'},
#   {'cell_type': 'code',
#    'execution_count': 85,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-04-23T16:14:43.799183',
#      'end_time': '2019-04-23T16:14:48.987080',
#      'duration': 5.187897,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': 'True'},
#      'execution_count': 85}],
#    'source': 'toaster = ToastNotifier()\ntoaster.show_toast("Papermill Orchestration Status",\n                   "Successfully created fixed voucher",\n                   icon_path="images/honda_logo.ico",\n                   duration=5)'}],
#  'metadata': {'hide_input': False,
#   'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.7.0',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'varInspector': {'cols': {'lenName': 16, 'lenType': 16, 'lenVar': 40},
#    'kernels_config': {'python': {'delete_cmd_postfix': '',
#      'delete_cmd_prefix': 'del ',
#      'library': 'var_list.py',
#      'varRefreshCmd': 'print(var_dic_list())'},
#     'r': {'delete_cmd_postfix': ') ',
#      'delete_cmd_prefix': 'rm(',
#      'library': 'var_list.r',
#      'varRefreshCmd': 'cat(var_dic_list()) '}},
#    'types_to_exclude': ['module',
#     'function',
#     'builtin_function_or_method',
#     'instance',
#     '_Feature'],
#    'window_display': False},
#   'papermill': {'parameters': {'start_voucher_date': '2018-09-01',
#     'end_voucher_date': '2018-09-30',
#     'honda_hourly_labor_rate': 120,
#     'acura_hourly_labor_rate': 141,
#     'part_cost_factor': 0.9,
#     'handling_cost_factor': 0.63},
#    'environment_variables': {},
#    'version': '0.19.0',
#    'input_path': '3_Create_Fixed_Voucher.ipynb',
#    'output_path': 'output/NA_Plants_Fixed_Voucher.ipynb',
#    'start_time': '2019-04-23T16:11:59.328178',
#    'end_time': '2019-04-23T16:14:50.812073',
#    'duration': 171.483895,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 2}

# %%
toaster = ToastNotifier()
toaster.show_toast("Papermill Orchestration Status",
                   "Successfully created ZF transmission vouchers",
                   icon_path="images/honda_logo.ico",
                   duration=5)
# Out:
# True
