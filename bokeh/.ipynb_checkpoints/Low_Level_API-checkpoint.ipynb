# %% [markdown]
# ## Making Bokeh plots using low-level API

# %%
from bokeh.charts import Line, output_notebook, show
from bokeh.models import HoverTool
from bokeh.plotting import figure, ColumnDataSource
import pandas as pd
import numpy as np
from itertools import cycle
from bokeh.palettes import Spectral6
output_notebook()

df = pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E'])

colors = Spectral6
colorcycler = cycle(colors)

source = ColumnDataSource(df)
p = figure(plot_width=800, plot_height=400, title="Bokeh Line Example")

for column in df.columns:
    line = p.line(x=df.index, y=column, source=source, line_color=next(colorcycler),
                  line_width=5, line_cap='round', line_join='round'
                 )
    p.add_tools(HoverTool(tooltips=[("x,y","$x,$y"),("column",column),], line_policy="interp", renderers=[line]))

show(p)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e76ca1cb-0c9f-4edf-8594-ccedd9242f17">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="4537033d-fdae-4933-9b40-2099f91c77ca"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4537033d-fdae-4933-9b40-2099f91c77ca");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4537033d-fdae-4933-9b40-2099f91c77ca' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"e44789c2-e5e4-4c55-844d-8267eaf9d719":{"roots":{"references":[{"attributes":{},"id":"eff0852d-992a-4c90-806a-4635bd220b06","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"E"}},"id":"c273762c-22f1-4ec9-b8a1-5dedd9610bb2","type":"Line"},{"attributes":{},"id":"7a7e454b-ee7a-4229-9330-5fed2b1380d3","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"91cb91e0-2c77-473f-a883-3bc53807f681","subtype":"Figure","type":"Plot"}},"id":"e2354f7f-8cf6-46e7-a9e9-a91da9eb9380","type":"PreviewSaveTool"},{"attributes":{"callback":null,"plot":{"id":"b97992c0-8221-471e-82f6-7b32cb9388b6","subtype":"Figure","type":"Plot"},"renderers":[{"id":"61cf5662-5d97-4303-9f03-db8216efc128","type":"GlyphRenderer"}],"tooltips":"This is E"},"id":"1878c8f1-b286-499c-880f-13a140707aa7","type":"HoverTool"},{"attributes":{"x":{"field":"x"},"y":{"field":"C"}},"id":"a7fe3a9e-bd54-4409-a058-69303e52e1ba","type":"Line"},{"attributes":{},"id":"20a35276-3541-4194-86a5-8a13123a5bc1","type":"BasicTicker"},{"attributes":{"callback":null,"line_policy":"next","plot":{"id":"8b9edc3b-394f-4c2d-9153-3600a65d57e2","subtype":"Figure","type":"Plot"},"renderers":[{"id":"e40bf8ff-a9ed-4198-a30b-5d9d956c27a0","type":"GlyphRenderer"}],"tooltips":"This is B"},"id":"30b8cc43-cdba-4479-ad26-d44c7e79bc62","type":"HoverTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b3f0e7ea-83f2-4dfc-b725-77b91856769f","type":"BoxAnnotation"},{"attributes":{},"id":"7242d26c-0a03-42f2-959b-78d39faf9745","type":"BasicTicker"},{"attributes":{"plot":{"id":"e9ef0cde-b075-4b63-9171-b67e2e8c4592","subtype":"Figure","type":"Plot"},"ticker":{"id":"270b9852-c059-47c3-abf2-96c724e1585c","type":"BasicTicker"}},"id":"6ed2b354-37df-42d8-923c-c12ae295a75d","type":"Grid"},{"attributes":{"data_source":{"id":"81e2d9a8-c902-4f33-9dfc-04463c45584d","type":"ColumnDataSource"},"glyph":{"id":"fb698abe-8041-4d70-b3e4-16fdbc5c418c","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"dcd6256e-2161-4973-bbab-83f3f2b8ff73","type":"Line"},"selection_glyph":null},"id":"5434110b-a960-46aa-939f-e64f06bfca1a","type":"GlyphRenderer"},{"attributes":{"callback":null,"plot":{"id":"34185fac-7804-41e3-ad29-8199653a06dd","subtype":"Figure","type":"Plot"},"renderers":[{"id":"3ed94e11-64e6-4c9b-b0d0-827c59a4bf25","type":"GlyphRenderer"}],"tooltips":"This is B"},"id":"74db4b04-0cee-4d22-9b12-1b6b4da6aa28","type":"HoverTool"},{"attributes":{"below":[{"id":"76107642-5dc8-4c3d-9d8c-9e6342607ba6","type":"LinearAxis"}],"left":[{"id":"5a0b8670-38ed-45d2-a3b6-37d6146d7a89","type":"LinearAxis"}],"plot_height":400,"plot_width":800,"renderers":[{"id":"76107642-5dc8-4c3d-9d8c-9e6342607ba6","type":"LinearAxis"},{"id":"450b4b95-c492-4eed-9a86-1f0f6dcbd9af","type":"Grid"},{"id":"5a0b8670-38ed-45d2-a3b6-37d6146d7a89","type":"LinearAxis"},{"id":"bca44034-fe2b-411d-ab43-bdcf6e850f0d","type":"Grid"},{"id":"61f4680e-d08b-488f-b0f8-157cea921583","type":"BoxAnnotation"}],"tool_events":{"id":"ac910f05-25e3-4e81-b0da-11bdd04bba74","type":"ToolEvents"},"tools":[{"id":"c21a01ce-e2ed-4adb-aa34-162306554939","type":"PanTool"},{"id":"0eeea965-0ac6-4fd0-a6a6-5cecfa32d036","type":"WheelZoomTool"},{"id":"6bfedb04-3a1e-45a1-866a-4b9505b31f45","type":"BoxZoomTool"},{"id":"8b5ece69-c196-42e6-8997-1c7e7a49a76f","type":"PreviewSaveTool"},{"id":"cf38ec1a-93f9-4ed4-8295-da5ab478a88b","type":"ResizeTool"},{"id":"80eaefac-d606-4f3e-a67d-587de442cb8b","type":"ResetTool"},{"id":"93b4df10-9ab5-408e-8d4a-1c68a7042a3a","type":"HelpTool"}],"x_range":{"id":"d4526c8b-6e4e-4da9-afdc-07c8386b0248","type":"DataRange1d"},"y_range":{"id":"0b506bfd-d60f-4529-8376-e6636ee011ea","type":"DataRange1d"}} ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[90]</strong>&gt;</code></p>

# %% [markdown]
# ### Comment from Sarah Bird from Continuum when asked about what defines a renderer:

# %% [markdown]
# A Glyph is a declaration like a Line, Circle, Rect, etc
# A GlyphRenderer is the combination of that Glyph and a data source.
#
# This all happens under the hood when you use plotting and charts.
#
# But the return value from p.line (or p.circle or p.rect or .....) is the GlyphRenderer.
#
# Bokeh has other renderers, but they're not relevant to hover tool.
