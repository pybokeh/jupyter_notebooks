# %% [markdown]
# ## Making Bokeh plots using low-level API

# %%
from bokeh.charts import Line, output_notebook, show
from bokeh.models import HoverTool
from bokeh.plotting import figure, ColumnDataSource
import pandas as pd
import numpy as np
from itertools import cycle
from bokeh.palettes import Spectral6
output_notebook()

df = pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E'])

colors = Spectral6
colorcycler = cycle(colors)

source = ColumnDataSource(df)
p = figure(plot_width=800, plot_height=400, title="Bokeh Line Example")

for column in df.columns:
    line = p.line(x=df.index, y=column, source=source, line_color=next(colorcycler),
                  line_width=5, line_cap='round', line_join='round'
                 )
    p.add_tools(HoverTool(tooltips=[("x,y","$x,$y"),("column",column),], line_policy="interp", renderers=[line]))

show(p)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="25910e3a-8e7e-4aeb-be78-33073d4f7b07">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="13f1dc56-22e0-46b3-8c37-3004a922a0d1"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("13f1dc56-22e0-46b3-8c37-3004a922a0d1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '13f1dc56-22e0-46b3-8c37-3004a922a0d1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"f63ae6e6-b8a8-446b-8e6b-b83acd45d460":{"roots":{"references":[{"attributes":{"data_source":{"id":"50ae97ca-a6ad-4677-b52d-e2ce095915fb","type":"ColumnDataSource"},"glyph":{"id":"8564195c-a77a-467e-83ed-fbc3d719884b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"cffa6f64-35e5-4813-8181-6f0259fed684","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"19cdb3e5-de9e-47f4-b6e6-5d08541a5a5a","type":"Rect"},{"attributes":{"plot":{"id":"f9827b6c-7eb5-447d-816a-0c918520fa07","subtype":"Figure","type":"Plot"},"ticker":{"id":"0d9f19d5-0470-4e72-a2d1-5d86075b6185","type":"BasicTicker"}},"id":"ceb315f4-60d7-4516-98af-865f9a036bda","type":"Grid"},{"attributes":{"dimension":1,"plot":{"id":"f71a31f7-7218-4539-8c78-a5be6bed900f","subtype":"Figure","type":"Plot"},"ticker":{"id":"fe69f7b0-a489-4dd4-b08b-fe3edfb3bbc2","type":"BasicTicker"}},"id":"49190838-5729-42a8-a99a-81f31acc038e","type":"Grid"},{"attributes":{"data_source":{"id":"85810a38-1ba0-4e98-8831-1d85a6e60675","type":"ColumnDataSource"},"glyph":{"id":"f4f00247-1c20-4e51-afb0-80e80214c492","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"55896072-a7c8-4835-80eb-2a6bb125ef9d","type":"GlyphRenderer"},{"attributes":{"callback":null,"line_policy":"interp","plot":{"id":"f19dbb55-33c4-4418-a144-8029bdbf5a67","subtype":"Figure","type":"Plot"},"renderers":[{"id":"0a180f0e-fecb-4a91-a1e9-484c9560b44e","type":"GlyphRenderer"}],"tooltips":[["x,y","$x,$y"],["column","A"]]},"id":"8bedefae-b51f-4fae-a837-d165790b453f","type":"HoverTool"},{"attributes":{"plot":{"id":"f71a31f7-7218-4539-8c78-a5be6bed900f","subtype":"Figure","type":"Plot"}},"id":"656c2182-ecf3-4c67-9dd4-702a276b9392","type":"PanTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7a3347a5-ea8e-4da5-9538-5bdde02ce5d0","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3afde485-b560-4e46-ac1c-08acff928fc1","type":"Rect"},{"attributes":{"line_cap":"round","line_color":{"value":"#fc8d59"},"line_join":"round","line_width":{"value":5},"x":{"field":"x"},"y":{"field":"E"}},"id":"1a05ce2d-2958-4031-9c35-c9caf84a4386","type":"Line"},{"attributes":{"data_source":{"id":"53812417-e9fc-4a3c-90af-31c0f7637393","type":"ColumnDataSource"},"glyph":{"id":"0222fb53-8730-47f9-88ec-53696aac901f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6918afb4-c7a8-4685-bd0a-b6f5318c0a70","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"09df07db-2aaf-4613-ba0e-05a02ac65f73","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"55c1e4b5-8e3c-4fbf-af7d-b4e873651f11","subtype":"Chart","type":"Plot"},"ticker":{"id":"652a62ac-96d9-445d-870b-8b3a3f257006","type":"CategoricalTicker"}},"id":"0b725111-3c49-4863-87be-9a96ec203eb6","type":"CategoricalAxis"},{"attributes":{"callback":null,"column_names":["y","height","fill_alpha","x","color","line_color","width","line_alpha"],"data":{"Model":["A"],"chart_index":[{"Model":"A","index":"2014-03"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.33],"index":["2014-03"],"line_alpha":[1.0],"line_color":["white"],"width":[0.2],"x":["2014-03:0.333333333333"],"y":[0.165]}},"id":"e4bf8469-3fba-44ec-8ebe-424155165645","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"142b1929-79dd-43ad-ac8c-63add935b093","subtype": ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[50]</strong>&gt;</code></p>

# %% [markdown]
# ### Comment from Sarah Bird from Continuum when asked about what defines a renderer:

# %% [markdown]
# A Glyph is a declaration like a Line, Circle, Rect, etc
# A GlyphRenderer is the combination of that Glyph and a data source.
#
# This all happens under the hood when you use plotting and charts.
#
# But the return value from p.line (or p.circle or p.rect or .....) is the GlyphRenderer.
#
# Bokeh has other renderers, but they're not relevant to hover tool.

# %%
from bokeh.charts import Line, output_notebook, show
from bokeh.models import HoverTool
from bokeh.plotting import figure, ColumnDataSource
import pandas as pd
import numpy as np
from itertools import cycle
from bokeh.palettes import Spectral6
output_notebook()

df = pd.read_clipboard().applymap(lambda x: float(str(x).replace('%','')))

colors = Spectral6
colorcycler = cycle(colors)

source = ColumnDataSource(df)
p = figure(plot_width=800, plot_height=500, title="Bokeh Line Example")

for column in df.columns:
    line = p.line(x=df.index, y=column, source=source, line_color=next(colorcycler),
                  line_width=5, line_cap='round', line_join='round'
                 )
    p.add_tools(HoverTool(tooltips=[("x,y","$x,$y"),("column",column),], line_policy="interp", renderers=[line]))

show(p)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d3f3217d-2a3b-4abc-b013-bb07d4ef3d1d">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="2b67ea8d-951d-4df9-979f-ac8ef48a93be"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2b67ea8d-951d-4df9-979f-ac8ef48a93be");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2b67ea8d-951d-4df9-979f-ac8ef48a93be' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"f9d5c9ad-d58a-4d1d-a854-564118860d80":{"roots":{"references":[{"attributes":{"plot":{"id":"ca47a0dc-2f6f-458b-8c42-36724eb1b7a2","subtype":"Figure","type":"Plot"}},"id":"9042ae23-4330-4fb6-bc37-faff957a1ac5","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"edf52788-a2c9-4b7a-9fce-a5e6b1169db9","type":"ColumnDataSource"},"glyph":{"id":"c6517574-b0f7-42a2-b901-07b21a714234","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"5deaae72-5851-4392-9f27-ec1f2d48079c","type":"Line"},"selection_glyph":null},"id":"9a1efab3-c5e5-4451-b027-e603cf10d1eb","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"7be2b2a8-1b82-4b19-a0b1-d88e86633c8b","type":"ColumnDataSource"},"glyph":{"id":"f67c6eba-4865-471e-a979-9cd7b3d21ebf","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"f0d20412-32eb-45bb-924e-6bb8e6d33955","type":"Line"},"selection_glyph":null},"id":"ba26217e-1185-4645-9f62-2ece5c8b48bf","type":"GlyphRenderer"},{"attributes":{},"id":"5de7bc9a-343a-43f3-9379-de1727c1b954","type":"ToolEvents"},{"attributes":{"line_cap":"round","line_color":{"value":"#99d594"},"line_join":"round","line_width":{"value":5},"x":{"field":"x"},"y":{"field":"B"}},"id":"ea408890-d0c0-4dca-83e1-3a92e043c1d0","type":"Line"},{"attributes":{"dimension":1,"plot":{"id":"ca47a0dc-2f6f-458b-8c42-36724eb1b7a2","subtype":"Figure","type":"Plot"},"ticker":{"id":"299ba888-3348-4136-936c-30146fa5ebc9","type":"BasicTicker"}},"id":"d04bcf78-ebb3-4823-9baf-566c4cad3a42","type":"Grid"},{"attributes":{},"id":"00901e57-2bab-4fe6-916a-277c401a8014","type":"ToolEvents"},{"attributes":{"plot":{"id":"8e382cdc-d276-42a4-9ea3-07c61308518f","subtype":"Figure","type":"Plot"}},"id":"39a2486d-b579-45d0-a312-22eccd48218c","type":"PreviewSaveTool"},{"attributes":{"plot":{"id":"5978ee99-691a-4821-8e08-29efeec42f71","subtype":"Figure","type":"Plot"}},"id":"e5850ea8-151c-4c40-90f1-7114cc6eba05","type":"ResetTool"},{"attributes":{"overlay":{"id":"f08de965-ab51-4f9b-aea6-8e11f20feaa1","type":"BoxAnnotation"},"plot":{"id":"b0d22b84-e25a-46c1-b084-065453b1d017","subtype":"Figure","type":"Plot"}},"id":"58460df3-8951-41e8-8fe0-0a53a6cd03a7","type":"BoxZoomTool"},{"attributes":{"formatter":{"id":"4b6ce2be-d7d6-4a6e-aef1-8220993f49bb","type":"BasicTickFormatter"},"plot":{"id":"b0d22b84-e25a-46c1-b084-065453b1d017","subtype":"Figure","type":"Plot"},"ticker":{"id":"0403b2ad-519b-4628-84ee-01473c8abcd0","type":"BasicTicker"}},"id":"0b9ece28-8cfb-4b6a-a5f7-19025866087e","type":"LinearAxis"},{"attributes":{"line_alpha":{"value":0.1},"line_cap":"round","line_color":{"value":"#1f77b4"},"line_join":"round","line_width":{"value":5},"x":{"field":"x"},"y":{"field":"B"}},"id":"2fbb5835-4134-4d35-81e8-355b95d11ab6","type":"Line"},{"attributes":{"overlay":{"id":"5868ba29-4d50-4124-8dcf-46180def183d","type":"BoxAnnotation"},"plot":{"id":"5978ee99-691a-4821-8e08-29efeec42f71","subtype":"Figure","type":"Plot"}},"id":"5fa74176-6edf-4dca-9509-c4b4408d30ec","type":"BoxZoomTool"},{"attributes":{},"id":"299ba888-3348-4136-936c-30146fa5ebc9","type":"BasicTicker"},{"attributes":{"plot":{"id":"ca47a0dc-2f6f-458b-8c42-36724eb1b7a2","subtype":"Figure","type":"Plot"}},"id":"d414070d-9a8e-4de5-92ba-536743e76862","type":"PanTool"},{"attributes":{"plot":{"id":"ca47a0dc-2f6f-458b-8c42-36724eb1b7a2","subtype":"Figure","type":"Plot"},"ticker":{"id":"fd436962-5345-4ea9-a374-844643d717c7","type":"BasicTicker"}},"id":"06ab42df-771e-4c7f-8da0-f9f5568e26ed","type":"Grid"},{"attributes":{"below":[{"id":"8079cd77-695b-4aa3-852e-7c97480610d6","type":"LinearAxis"}],"left":[{"id":"7be9a580-6b33-46d2-8c93-450ff0439cb1","type":"LinearAxis"}],"plot_height":400,"plot_width":800,"renderers":[{"id":"8079cd77-695b-4aa3-852e-7c97480610d6","type":"LinearAxis"},{"id":"d329aa12-27fa-4add-b12a-d921bf91dc90","type":"Grid"},{"id":"7be9a580-6b33-46d2-8c93-450ff0439cb1","type":"LinearAxis"},{"id":"1fc9ebf7-3e2d-4497-b647-d0d24b594ba1","type":"Grid"},{"id":"285cece6-5671-4a78-8caa-aa05f680ffd0","t ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[158]</strong>&gt;</code></p>

# %%
import pandas as pd
from bokeh.charts import Bar, output_notebook, show

# %%
df = pd.read_clipboard()

# %%
df_long = pd.melt(df, id_vars=['BUILD_MTH']).dropna()

# %%
df_long
df_long.value = df_long.value.str.replace('%','').replace('$','').replace(',','')

# %%
df_long.rename(columns={'variable':'Model','value':'Defect_Rate'}, inplace=True)

# %%
df_long.set_index('BUILD_MTH', inplace=True)

# %%
df_long.Defect_Rate = df_long.Defect_Rate.astype(float)

# %%
bar = Bar(df_long, df_long.index, group='Model', values='Defect_Rate', width=700, height=500,
         legend='top_right', xlabel='Build Month', ylabel='Defect Rate', title='Defect Rate by Build Month')
output_notebook()
show(bar)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="fe34b582-0666-46eb-a250-3559b2dc6824">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="6dd3dbfe-10b5-43d7-a2ab-17bb584e7cf6"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6dd3dbfe-10b5-43d7-a2ab-17bb584e7cf6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6dd3dbfe-10b5-43d7-a2ab-17bb584e7cf6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"30cca826-9bce-4511-ad25-964d4e25eba9":{"roots":{"references":[{"attributes":{"data_source":{"id":"50ae97ca-a6ad-4677-b52d-e2ce095915fb","type":"ColumnDataSource"},"glyph":{"id":"8564195c-a77a-467e-83ed-fbc3d719884b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"cffa6f64-35e5-4813-8181-6f0259fed684","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"19cdb3e5-de9e-47f4-b6e6-5d08541a5a5a","type":"Rect"},{"attributes":{"data_source":{"id":"85810a38-1ba0-4e98-8831-1d85a6e60675","type":"ColumnDataSource"},"glyph":{"id":"f4f00247-1c20-4e51-afb0-80e80214c492","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"55896072-a7c8-4835-80eb-2a6bb125ef9d","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7a3347a5-ea8e-4da5-9538-5bdde02ce5d0","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3afde485-b560-4e46-ac1c-08acff928fc1","type":"Rect"},{"attributes":{"data_source":{"id":"53812417-e9fc-4a3c-90af-31c0f7637393","type":"ColumnDataSource"},"glyph":{"id":"0222fb53-8730-47f9-88ec-53696aac901f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6918afb4-c7a8-4685-bd0a-b6f5318c0a70","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"09df07db-2aaf-4613-ba0e-05a02ac65f73","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"55c1e4b5-8e3c-4fbf-af7d-b4e873651f11","subtype":"Chart","type":"Plot"},"ticker":{"id":"652a62ac-96d9-445d-870b-8b3a3f257006","type":"CategoricalTicker"}},"id":"0b725111-3c49-4863-87be-9a96ec203eb6","type":"CategoricalAxis"},{"attributes":{"callback":null,"column_names":["y","height","fill_alpha","x","color","line_color","width","line_alpha"],"data":{"Model":["A"],"chart_index":[{"Model":"A","index":"2014-03"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.33],"index":["2014-03"],"line_alpha":[1.0],"line_color":["white"],"width":[0.2],"x":["2014-03:0.333333333333"],"y":[0.165]}},"id":"e4bf8469-3fba-44ec-8ebe-424155165645","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"462a4530-ee91-4d9e-8c62-bb494331eb6a","type":"ColumnDataSource"},"glyph":{"id":"40085260-a6f2-49cd-8ead-5ddba90fc799","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"86e8db14-7c40-4249-9e13-09961d599ca4","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"33f4743b-971d-4695-8941-636ce102b1ca","type":"Rect"},{"attributes":{"data_source":{"id":"4b5b8547-feee-419d-a227-40313c28b947","type":"ColumnDataSource"},"glyph":{"id":"05da4eae-bdbd-43bd-84b1-0d8a44c854a5","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"793effeb-60fc-40b4-b2cd-c034d5d35a59","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ad2687a2-987c-493d-83a6-3f0b3fb04e10","type":"Rect"},{"attributes":{"data_source":{"id":"94bad690-7ce7-456b-9e23-c ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[22]</strong>&gt;</code></p>

# %%
df_long
# Out:
#           Model  Defect_Rate    index
# BUILD_MTH
# 2014-01       A         0.43  2014-01
# 2014-02       A         0.37  2014-02
# 2014-03       A         0.33  2014-03
# 2014-04       A         0.30  2014-04
# 2014-05       A         0.28  2014-05
# 2014-06       A         0.25  2014-06
# 2014-07       A         0.22  2014-07
# 2014-08       B         0.21  2014-08
# 2014-09       B         0.19  2014-09
# 2014-09       B         0.14  2014-09
# 2014-10       B         0.10  2014-10
# 2014-11       B         0.07  2014-11
# 2014-12       B         0.03  2014-12
