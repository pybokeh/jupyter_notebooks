# %%
from bokeh.plotting import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-ddc21eaa6710> in <module>()
# ----> 1 from bokeh.plotting import *
#
# ImportError: No module named 'bokeh'

# %%
from bokeh import plotting

# %%
output_notebook()

# %%
from numpy import *
x = linspace(-6, 6, 100)
y = cos(x)
