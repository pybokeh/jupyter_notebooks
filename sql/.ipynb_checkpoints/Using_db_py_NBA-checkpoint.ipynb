# %% [markdown]
# <center><h1>Checking out Yhat's latest project: [db.py](https://github.com/yhat/db.py)</h1></center>

# %% [markdown]
# I've created a sqlite3 database using recall data from NHTSA's website

# %%
import pandas as pd
from db import DB

db = DB(filename="/home/pybokeh/temp/nhtsa", dbtype="sqlite")
# Out:
# Indexing schema. This will take a second...finished!
# Refreshing schema. Please wait...done!

# %%
db.tables.recalls
# Out:
# +-------------------------------------------------------------+
# |                           recalls                           |
# +-------------------+---------+--------------+----------------+
# | Column            | Type    | Foreign Keys | Reference Keys |
# +-------------------+---------+--------------+----------------+
# | RECORD_ID         | INTEGER |              |                |
# | CAMPNO            | TEXT    |              |                |
# | MAKETXT           | TEXT    |              |                |
# | MODELTXT          | TEXT    |              |                |
# | YEARTXT           | TEXT    |              |                |
# | MFGCAMPNO         | TEXT    |              |                |
# | COMPNAME          | TEXT    |              |                |
# | MFGNAME           | TEXT    |              |                |
# | BGMAN             | TEXT    |              |                |
# | ENDMAN            | TEXT    |              |                |
# ...

# %% [markdown]
# ### Let's set some display options

# %%
pd.set_option("display.max_columns",50)
pd.set_option("display.max_rows",999)

# %%
db.query("select * from recalls where maketxt like '%HONDA%' limit 5;")
# Out:
#    RECORD_ID     CAMPNO MAKETXT     MODELTXT YEARTXT MFGCAMPNO  \
# 0         49  02V250000   HONDA       FSC600    2002
# 1         50  02V250000   HONDA  SILVER WING    2002
# 2        229  02V196000   HONDA      INSIGHT    2001
# 3        510  02V251000   HONDA         CR-V    2002
# 4        744  02V226000   HONDA        PILOT    2003
#
#                            COMPNAME                   MFGNAME     BGMAN  \
# 0                            WHEELS  AMERICAN HONDA MOTOR CO.  20010808
# 1                            WHEELS  AMERICAN HONDA MOTOR CO.  20010808
# 2                  AIR BAGS:FRONTAL  AMERICAN HONDA MOTOR CO.  20010611
# 3                             SEATS  AMERICAN HONDA MOTOR CO.  20020708
# 4  ENGINE AND ENGINE COOLING:ENGINE  AMERICAN HONDA MOTOR CO.  20020709
#
#      ENDMAN RCLTYPECD  POTAFF     ODATE INFLUENCED_BY  \
# 0  20020708         V    2454  20020927           MFR
# 1  20020708         V    2454  20020927           MFR
# ...

# %%
type(db.query("select * from recalls where maketxt like '%HONDA%' limit 5;"))
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## The resultset of the query is a Pandas dataframe!  Very nice!
