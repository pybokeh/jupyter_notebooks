# %% [markdown]
# # Ohio teachers' salary data can be obtained [here](http://www.tos.ohio.gov/Transparency_Teacher.aspx)

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
pd.set_option("display.max_rows",100)
pd.set_option("display.max_columns",50)

# %%
df = pd.read_excel('http://www.tos.ohio.gov/Documents/Transparency/2013%20-%202014%20School%20Year%20Staff%20Salary%20Information.xlsx',
                  sheetname='Data tab')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 272731 entries, 0 to 272730
# Data columns (total 10 columns):
# LAST NAME               272710 non-null object
# FIRST NAME              272645 non-null object
# EDUCATION LEVEL         272731 non-null object
# JOB DESCRIPTION         272731 non-null object
# DISTRICT NAME           272638 non-null object
# SCHOOL NAME             261393 non-null object
# CITY NAME               261360 non-null object
# DAYS WORKED             272731 non-null int64
# HOURS WORKED PER DAY    272731 non-null float64
# PAY AMOUNT              272731 non-null float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 22.9+ MB

# %%
df.head()
# Out:
#   LAST NAME FIRST NAME EDUCATION LEVEL  \
# 0   LONGDEN     CHERYL         Masters
# 1     SIKES      LINDA         Masters
# 2     SMITH     SHERRY         Masters
# 3     BALOG     GEORGE         Masters
# 4     BAUER    RICHARD         Masters
#
#                                      JOB DESCRIPTION  \
# 0  Tutor/Small Group Instructor Assignment (Serve...
# 1                             Counseling Assignment
# 2             Other Professional  Other Assignment
# 3                                 Teacher Assignment
# 4                                 Teacher Assignment
#
#                      DISTRICT NAME                          SCHOOL NAME  \
# 0              Ashtabula Area City                 Lakeside High School
# 1  Yellow Springs Exempted Village  Yellow Springs/McKinney High School
# 2                Greene County ESC                    Greene County ESC
# 3                      Dayton City          Stivers School For The Arts
# 4               North Olmsted City          North Olmsted Middle School
#
#         CITY NAME  DAYS WORKED  HOURS WORKED PER DAY  PAY AMOUNT
# 0       Ashtabula          185                  7.00       23544
# 1  Yellow Springs          194                  7.00       80949
# 2  Yellow Springs          103                  7.50       24322
# 3          Dayton          200                  4.35       36964
# 4   North Olmsted          185                  7.50       91187

# %%
df.columns = [col.replace(' ', '_') for col in df.columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 272731 entries, 0 to 272730
# Data columns (total 10 columns):
# LAST_NAME               272710 non-null object
# FIRST_NAME              272645 non-null object
# EDUCATION_LEVEL         272731 non-null object
# JOB_DESCRIPTION         272731 non-null object
# DISTRICT_NAME           272638 non-null object
# SCHOOL_NAME             261393 non-null object
# CITY_NAME               261360 non-null object
# DAYS_WORKED             272731 non-null int64
# HOURS_WORKED_PER_DAY    272731 non-null float64
# PAY_AMOUNT              272731 non-null float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 22.9+ MB

# %%
df.JOB_DESCRIPTION.value_counts().sort_values(ascending=False)[:20].sort_values().plot.barh(alpha=0.4)
fig = plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %%
df.query("JOB_DESCRIPTION == 'Teacher Assignment'").DAYS_WORKED.plot.hist(alpha=0.7)
plt.show()

# %%
df.query("JOB_DESCRIPTION == 'Teacher Assignment'").HOURS_WORKED_PER_DAY.plot.hist(alpha=0.7)
plt.show()

# %%
# Criteria for "full time" teachers
qry = """
JOB_DESCRIPTION == 'Teacher Assignment' \
& HOURS_WORKED_PER_DAY >= 6 \
& DAYS_WORKED > 180
"""

pd.pivot_table(df.query(qry), index='DISTRICT_NAME', values='PAY_AMOUNT', 
               aggfunc='median').sort_values(ascending=False)[:50]
# Out:
# DISTRICT_NAME
# Beachwood City                                    89838.0
# Orange City                                       87939.0
# Polaris                                           85703.0
# Upper Arlington City                              84290.0
# Brecksville-Broadview Heights City                82548.0
# Cuyahoga Valley Career Center                     81862.5
# Shaker Heights City                               80934.0
# Solon City                                        79895.0
# Bexley City                                       79712.0
# Westlake City                                     79672.0
# Chagrin Falls Exempted Village                    79420.0
# Mayfield City                                     79288.0
# Danbury Local                                     79021.0
# Eastland-Fairfield Career/Tech                    77722.0
# Independence Local                                77652.0
# Miami Valley Career Tech                          77454.0
# Maumee City                                       77424.0
# South Euclid-Lyndhurst City                       77383.0
# Cleveland Heights-University Heights City         77212.0
# Ottawa Hills Local                                77069.0
# Dublin City                                       77029.0
# Sycamore Community City                           76853.0
# Hilliard City                                     76747.0
# Twinsburg City                                    76726.0
# Grandview Heights City                            76612.0
# Hudson City                                       76290.0
# Strongsville City                                 76014.0
# North Olmsted City                                75747.0
# Mariemont City                                    75483.0
# Revere Local                                      75451.0
# Lorain County JVS                                 75357.0
# Auburn                                            75211.0
# U S Grant                                         75199.0
# Promise Academy                                   74872.0
# Cleveland Municipal                               74872.0
# Rocky River City                                  74762.0
# Cuyahoga Heights Local                            74680.0
# Medina City SD                                    74396.0
# Medina County Joint Vocational School District    73951.0
# Put-In-Bay Local                                  73694.0
# Southwest Local                                   73616.0
# Oakwood City                                      73516.5
# Great Oaks Inst Of Technology                     73490.5
# North Royalton City                               73369.0
# Rossford Exempted Village                         72789.0
# Greene County Vocational School District          72672.0
# Aurora City                                       72385.0
# Lakewood City                                     72340.0
# Fairview Park City                                72222.5
# Bay Village City                                  72178.0
# Name: PAY_AMOUNT, dtype: float64

# %%
by_count = pd.pivot_table(df.query(qry), index='DISTRICT_NAME', values='PAY_AMOUNT', 
               aggfunc='count')
by_count
# Out:
# DISTRICT_NAME
# A+ Arts Academy                                          13
# A+ Children's Academy                                     7
# Academy for Urban Scholars Youngstown                     4
# Academy of Arts and Sciences                             13
# Academy of Educational Excellence                         5
# Accelerated Achievement Academy of Cincinnati             6
# Accelerated Achievement Academy of North Cincinnati       6
# Achieve Career Preparatory Academy                       11
# Ada Exempted Village                                     51
# Adams County/Ohio Valley Local                          219
# Adena Local                                              54
# Akron City                                             1379
# Akron Digital Academy                                    22
# Akron Preparatory School                                 10
# Akros Middle School                                      14
# Alexander Local                                          93
# Allen County ESC                                         30
# Allen East Local                                         55
# Alliance City                                           200
# Alternative Education Academy                            56
# Amanda-Clearcreek Local                                  87
# Amherst Exempted Village                                205
# Anna Local                                               60
# Ansonia Local                                            42
# Anthony Wayne Local                                     184
# Antwerp Local                                            44
# Apex Academy                                             21
# Apollo                                                   59
# Arcadia Local                                            28
# Arcanum-Butler Local                                     61
# Archbold-Area Local                                      66
# Arlington Local                                          36
# Arts & College Preparatory Academy                       23
# Arts and Science Preparatory Academy                      6
# Ashland City                                            172
# Ashland County-West Holmes                               31
# Ashtabula Area City                                     168
# Ashtabula County ESC                                     24
# Ashtabula County Technical and Career Center             52
# Athens City                                             191
# Athens-Meigs ESC                                         22
# Auburn                                                   25
# Auglaize County ESC                                      40
# Aurora Academy                                           13
# Aurora City                                             142
# Austintown Local                                        238
# Autism Model School                                      16
# Avon Lake City                                          190
# Avon Local                                              202
# Ayersville Local                                         42
#                                                        ...
# West Branch Local                                       135
# West Carrollton City                                    200
# West Clermont Local                                     377
# West Geauga Local                                       102
# West Holmes Local                                       121
# West Liberty-Salem Local                                 66
# West Muskingum Local                                     90
# West Park Academy                                        20
# West Preparatory Academy                                  9
# Western Brown Local                                     127
# Western Buckeye ESC                                      16
# Western Local                                            36
# Western Reserve Local                                   101
# Westerville City                                        801
# Westfall Local                                           97
# Westlake City                                           243
# Westside Academy                                          7
# Wheelersburg Local                                       80
# Whitehall City                                          160
# Whitehall Preparatory and Fitness Academy                29
# Wickliffe City                                          109
# Wildwood Environmental Academy                           19
# Willard City                                             87
# Williamsburg Local                                       46
# Willoughby-Eastlake City                                486
# Wilmington City                                         128
# Windham Exempted Village                                 33
# Winterfield Venture Academy                               8
# Winton Preparatory Academy                                9
# Winton Woods City                                       192
# Wolf Creek Local                                         40
# Wood County ESC                                          54
# Woodland Academy                                         30
# Woodmore Local                                           64
# Woodridge Local                                         115
# Wooster City                                            213
# Worthington City                                        561
# Wynford Local                                            64
# Wyoming City                                            112
# Xenia Community City                                    208
# Yellow Springs Exempted Village                          39
# Young Scholars Prep School                                6
# Youngstown Academy of Excellence                         12
# Youngstown City Schools                                 339
# Youngstown Community School                              27
# Youthbuild Columbus Community                             1
# Zane Trace Local                                         84
# Zanesville City                                         177
# Zenith Academy                                           24
# Zenith Academy East                                      15
# Name: PAY_AMOUNT, dtype: int64

# %%
by_median = pd.pivot_table(df.query(qry), index='DISTRICT_NAME', values='PAY_AMOUNT', 
               aggfunc='median')
by_median
# Out:
# DISTRICT_NAME
# A+ Arts Academy                                        35453.0
# A+ Children's Academy                                  28274.0
# Academy for Urban Scholars Youngstown                  33000.0
# Academy of Arts and Sciences                           32000.0
# Academy of Educational Excellence                      30000.0
# Accelerated Achievement Academy of Cincinnati          37500.0
# Accelerated Achievement Academy of North Cincinnati    38685.0
# Achieve Career Preparatory Academy                     30000.0
# Ada Exempted Village                                   55755.0
# Adams County/Ohio Valley Local                         52196.0
# Adena Local                                            56517.0
# Akron City                                             65219.0
# Akron Digital Academy                                  40236.0
# Akron Preparatory School                               30000.0
# Akros Middle School                                    33500.0
# Alexander Local                                        53365.0
# Allen County ESC                                       54212.0
# Allen East Local                                       49358.0
# Alliance City                                          54133.0
# Alternative Education Academy                          36771.0
# Amanda-Clearcreek Local                                45273.0
# Amherst Exempted Village                               67271.0
# Anna Local                                             64461.0
# Ansonia Local                                          53755.5
# Anthony Wayne Local                                    62918.0
# Antwerp Local                                          51083.5
# Apex Academy                                           38563.0
# Apollo                                                 67056.0
# Arcadia Local                                          52168.0
# Arcanum-Butler Local                                   53983.0
# Archbold-Area Local                                    59503.0
# Arlington Local                                        49292.5
# Arts & College Preparatory Academy                     36040.0
# Arts and Science Preparatory Academy                   30000.0
# Ashland City                                           52710.0
# Ashland County-West Holmes                             57592.0
# Ashtabula Area City                                    55655.0
# Ashtabula County ESC                                   45671.0
# Ashtabula County Technical and Career Center           57206.5
# Athens City                                            60310.0
# Athens-Meigs ESC                                       31251.0
# Auburn                                                 75211.0
# Auglaize County ESC                                    47019.5
# Aurora Academy                                         27047.0
# Aurora City                                            72385.0
# Austintown Local                                       54595.5
# Autism Model School                                    35742.0
# Avon Lake City                                         68299.0
# Avon Local                                             50952.0
# Ayersville Local                                       61775.0
#                                                         ...
# West Branch Local                                      49060.0
# West Carrollton City                                   61235.5
# West Clermont Local                                    63485.0
# West Geauga Local                                      64950.5
# West Holmes Local                                      58546.0
# West Liberty-Salem Local                               53675.0
# West Muskingum Local                                   48327.0
# West Park Academy                                      35500.0
# West Preparatory Academy                               36600.0
# Western Brown Local                                    63557.0
# Western Buckeye ESC                                    50880.0
# Western Local                                          55140.5
# Western Reserve Local                                  56786.0
# Westerville City                                       56106.0
# Westfall Local                                         46791.0
# Westlake City                                          79672.0
# Westside Academy                                       34376.0
# Wheelersburg Local                                     53263.0
# Whitehall City                                         56104.0
# Whitehall Preparatory and Fitness Academy              32000.0
# Wickliffe City                                         58703.0
# Wildwood Environmental Academy                         30000.0
# Willard City                                           59007.0
# Williamsburg Local                                     56140.0
# Willoughby-Eastlake City                               65452.0
# Wilmington City                                        55161.0
# Windham Exempted Village                               57587.0
# Winterfield Venture Academy                            34580.0
# Winton Preparatory Academy                             31000.0
# Winton Woods City                                      58812.0
# Wolf Creek Local                                       53377.0
# Wood County ESC                                        43444.0
# Woodland Academy                                       32000.0
# Woodmore Local                                         56397.5
# Woodridge Local                                        67158.0
# Wooster City                                           58236.0
# Worthington City                                       71403.0
# Wynford Local                                          51207.0
# Wyoming City                                           70776.0
# Xenia Community City                                   61588.0
# Yellow Springs Exempted Village                        63830.0
# Young Scholars Prep School                             29500.0
# Youngstown Academy of Excellence                       30000.0
# Youngstown City Schools                                55235.0
# Youngstown Community School                            38398.0
# Youthbuild Columbus Community                          40000.0
# Zane Trace Local                                       58233.0
# Zanesville City                                        53121.0
# Zenith Academy                                         31500.0
# Zenith Academy East                                    31000.0
# Name: PAY_AMOUNT, dtype: float64

# %%
by_counts_median = pd.concat([by_count, by_median], axis=1, 
                             keys=['Count','Median']).sort_values(by='Median', ascending=False)
by_counts_median.query("Count >= 50").Median.sort_values(ascending=False)[:20].sort_values().plot.barh(alpha=0.4)
fig = plt.gcf()
fig.set_size_inches(8,8)
plt.xticks(rotation=270)
plt.title('Top 20 Highest School Districts in Ohio - Median Salary')
plt.show()
