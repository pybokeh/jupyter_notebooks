# %% [markdown]
# # Ohio teachers' salary data can be obtained [here](http://www.tos.ohio.gov/Transparency_Teacher.aspx)

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
pd.set_option("display.max_rows",100)
pd.set_option("display.max_columns",50)

# %%
df = pd.read_excel('http://www.tos.ohio.gov/Documents/Transparency/2016-2017%20School%20year%20Staff%20Salary%20Information%20for%20download.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 352360 entries, 0 to 352359
# Data columns (total 11 columns):
# LAST NAME               352345 non-null object
# FIRST NAME              352348 non-null object
# EDUCATION LEVEL         352360 non-null object
# JOB DESCRIPTION         352360 non-null object
# DISTRICT NAME           352199 non-null object
# COUNTY                  352137 non-null object
# SCHOOL NAME             350662 non-null object
# CITY NAME               350662 non-null object
# DAYS WORKED             352360 non-null int64
# HOURS WORKED PER DAY    352360 non-null float64
# PAY AMOUNT              352360 non-null float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 29.6+ MB

# %%
df.head()
# Out:
#   LAST NAME FIRST NAME EDUCATION LEVEL  \
# 0   LONGDEN     CHERYL         Masters
# 1   LONGDEN     CHERYL         Masters
# 2  Mulligan  Bettylene         Masters
# 3  Mulligan  Bettylene         Masters
# 4     SMITH     SHERRY         Masters
#
#                                      JOB DESCRIPTION  \
# 0  Tutor/Small Group Instructor Assignment (Serve...
# 1        Other Professional  Educational Assignment
# 2  Full-time (Permanent) Substitute Teacher Assig...
# 3  Tutor/Small Group Instructor Assignment (Serve...
# 4              Other Professional  Other Assignment
#
#                 DISTRICT NAME     COUNTY                 SCHOOL NAME  \
# 0         Ashtabula Area City  Ashtabula        Lakeside High School
# 1         Ashtabula Area City  Ashtabula        Lakeside High School
# 2             Cincinnati City   Hamilton             Cincinnati City
# 3  Winton Preparatory Academy   Hamilton  Winton Preparatory Academy
# 4           Greene County ESC     Greene           Greene County ESC
#
#         CITY NAME  DAYS WORKED  HOURS WORKED PER DAY  PAY AMOUNT
# 0       Ashtabula          185                   7.0     25654.0
# 1       Ashtabula           90                   1.0      2000.0
# 2      Cincinnati          178                   7.0     21890.0
# 3      Cincinnati          172                   8.0     32000.0
# 4  Yellow Springs           40                   8.0     10015.0

# %%
df.columns = [col.replace(' ', '_') for col in df.columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 352360 entries, 0 to 352359
# Data columns (total 11 columns):
# LAST_NAME               352345 non-null object
# FIRST_NAME              352348 non-null object
# EDUCATION_LEVEL         352360 non-null object
# JOB_DESCRIPTION         352360 non-null object
# DISTRICT_NAME           352199 non-null object
# COUNTY                  352137 non-null object
# SCHOOL_NAME             350662 non-null object
# CITY_NAME               350662 non-null object
# DAYS_WORKED             352360 non-null int64
# HOURS_WORKED_PER_DAY    352360 non-null float64
# PAY_AMOUNT              352360 non-null float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 29.6+ MB

# %%
df.JOB_DESCRIPTION.value_counts().sort_values(ascending=False)[:20].sort_values().plot.barh(alpha=0.4)
fig = plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %%
df.query("JOB_DESCRIPTION == 'Teacher Assignment'").DAYS_WORKED.plot.hist(alpha=0.7)
plt.show()

# %%
df.query("JOB_DESCRIPTION == 'Teacher Assignment'").HOURS_WORKED_PER_DAY.plot.hist(alpha=0.7)
plt.show()

# %%
# Criteria for "full time" teachers
qry = """
JOB_DESCRIPTION == 'Teacher Assignment' \
& HOURS_WORKED_PER_DAY >= 6 \
& DAYS_WORKED >= 180
"""

pd.pivot_table(df.query(qry), index='DISTRICT_NAME', values='PAY_AMOUNT', 
               aggfunc='median').sort_values(by='PAY_AMOUNT', ascending=False)[:20]
# Out:
#                                            PAY_AMOUNT
# DISTRICT_NAME
# Beachwood City                                97518.0
# Orange City                                   91957.0
# Polaris                                       86388.5
# Shaker Heights City                           86072.0
# Cleveland Heights-University Heights City     85894.0
# Solon City                                    85155.5
# Rocky River City                              84932.0
# Indian Hill Exempted Village                  84125.0
# Upper Arlington City                          84042.0
# Dublin City                                   84005.0
# Hilliard City                                 83992.0
# Cuyahoga Valley Career Center                 83169.0
# Independence Local                            82406.0
# Wyoming City                                  81879.0
# North Olmsted City                            81787.0
# Westlake City                                 81664.0
# South Euclid-Lyndhurst City                   81544.0
# Bay Village City                              81475.0
# Eastland-Fairfield Career/Tech                80776.0
# Kirtland Local                                80579.0

# %%
by_count = pd.pivot_table(df.query(qry), index='DISTRICT_NAME', values='PAY_AMOUNT', 
               aggfunc='count')
by_count.rename({'PAY_AMOUNT': 'QTY_TEACHERS'}, axis='columns', inplace=True)
by_count
# Out:
#                                                     QTY_TEACHERS
# DISTRICT_NAME
# A+ Arts Academy                                               27
# A+ Children's Academy                                         10
# Academy for Urban Scholars Youngstown                          3
# Academy of Arts and Sciences                                   7
# Academy of Educational Excellence                              6
# Achieve Career Preparatory Academy                             5
# Ada Exempted Village                                          51
# Adams County Ohio Valley Local                               215
# Adena Local                                                   50
# Akron City                                                  1396
# Akron Digital Academy                                          7
# Akron Preparatory School                                      13
# Akros Middle School                                            9
# Albert Einstein Academy for Letters, Arts and S...            10
# Alexander Local                                               93
# Allen County ESC                                              27
# Allen East Local                                              52
# Alliance City                                                175
# Alternative Education Academy                                 40
# Amanda-Clearcreek Local                                       87
# Amherst Exempted Village                                     178
# Anna Local                                                    62
# Ansonia Local                                                 45
# Anthony Wayne Local                                          182
# Antwerp Local                                                 43
# Apex Academy                                                  21
# Apollo                                                        53
# Arcadia Local                                                 31
# Arcanum-Butler Local                                          55
# Archbold-Area Local                                           65
# Arlington Local                                               40
# Arts & College Preparatory Academy                             3
# Ashland City                                                 153
# Ashland County-West Holmes                                    32
# Ashtabula Area City                                          159
# Ashtabula County ESC                                          21
# Ashtabula County Technical and Career Center                  50
# Athens City                                                  168
# Athens-Meigs ESC                                               9
# Auburn                                                        26
# Auglaize County ESC                                           28
# Aurora Academy                                                10
# Aurora City                                                  139
# Austintown Local Schools                                     240
# Autism Model School                                           11
# Avon Lake City                                               186
# Avon Local                                                   180
# Ayersville Local                                              41
# Barberton City                                               208
# Barnesville Exempted Village                                  72
# ...                                                          ...
# Wellsville Local                                              54
# West Branch Local                                            110
# West Carrollton City                                         204
# West Central Learning Academy II                               2
# West Clermont Local                                          411
# West Geauga Local                                             86
# West Holmes Local                                            119
# West Liberty-Salem Local                                      64
# West Muskingum Local                                          92
# West Park Academy                                              9
# West Preparatory Academy                                       5
# Western Brown Local                                          139
# Western Buckeye ESC                                           13
# Western Local                                                 35
# Western Reserve Local                                         91
# Westerville City                                             806
# Westfall Local                                                82
# Westlake City                                                196
# Westside Academy                                              10
# Wheelersburg Local                                            77
# Whitehall City                                               183
# Whitehall Preparatory and Fitness Academy                     14
# Wickliffe City                                                97
# Wildwood Environmental Academy                                18
# Willard City                                                  86
# Williamsburg Local                                            44
# Willoughby-Eastlake City                                     448
# Wilmington City                                              130
# Windham Exempted Village                                      27
# Winterfield Venture Academy                                   19
# Winton Preparatory Academy                                     8
# Winton Woods City                                            203
# Wolf Creek Local                                              38
# Wood County ESC                                               26
# Woodmore Local                                                55
# Woodridge Local                                              125
# Wooster City                                                 191
# Worthington City                                             537
# Wynford Local                                                 66
# Wyoming City                                                 103
# Xenia Community City                                         210
# Yellow Springs Exempted Village                               40
# Youngstown Academy of Excellence                              10
# Youngstown City                                              327
# Youngstown Community School                                   26
# Zane Trace Local                                              68
# Zanesville City                                              183
# Zenith Academy                                                23
# Zenith Academy East                                           17
# Zenith Academy West                                           14
#
# [971 rows x 1 columns]

# %%
by_median = pd.pivot_table(df.query(qry), index='DISTRICT_NAME', values='PAY_AMOUNT', 
               aggfunc='median')
by_median
# Out:
#                                                     PAY_AMOUNT
# DISTRICT_NAME
# A+ Arts Academy                                        36517.0
# A+ Children's Academy                                  30945.0
# Academy for Urban Scholars Youngstown                  41000.0
# Academy of Arts and Sciences                           31000.0
# Academy of Educational Excellence                       1250.0
# Achieve Career Preparatory Academy                     35500.0
# Ada Exempted Village                                   58040.0
# Adams County Ohio Valley Local                         55900.0
# Adena Local                                            60184.5
# Akron City                                             68811.0
# Akron Digital Academy                                  40840.0
# Akron Preparatory School                               37000.0
# Akros Middle School                                    31500.0
# Albert Einstein Academy for Letters, Arts and S...         0.0
# Alexander Local                                        58927.0
# Allen County ESC                                       52729.0
# Allen East Local                                       57172.0
# Alliance City                                          56884.0
# Alternative Education Academy                          40564.0
# Amanda-Clearcreek Local                                49339.0
# Amherst Exempted Village                               71613.0
# Anna Local                                             67558.0
# Ansonia Local                                          56917.0
# Anthony Wayne Local                                    69564.0
# Antwerp Local                                          54186.0
# Apex Academy                                           43763.0
# Apollo                                                 59036.0
# Arcadia Local                                          55786.0
# Arcanum-Butler Local                                   58729.0
# Archbold-Area Local                                    60695.0
# Arlington Local                                        42985.5
# Arts & College Preparatory Academy                        25.0
# Ashland City                                           60502.0
# Ashland County-West Holmes                             57595.5
# Ashtabula Area City                                    57720.0
# Ashtabula County ESC                                   53264.0
# Ashtabula County Technical and Career Center           62420.0
# Athens City                                            68470.0
# Athens-Meigs ESC                                       30063.0
# Auburn                                                 71361.0
# Auglaize County ESC                                    51305.0
# Aurora Academy                                         32000.0
# Aurora City                                            79789.0
# Austintown Local Schools                               53946.5
# Autism Model School                                    37927.0
# Avon Lake City                                         72899.0
# Avon Local                                             59474.0
# Ayersville Local                                       57363.0
# Barberton City                                         67495.0
# Barnesville Exempted Village                           52870.5
# ...                                                        ...
# Wellsville Local                                       51758.0
# West Branch Local                                      51822.0
# West Carrollton City                                   62219.5
# West Central Learning Academy II                       34250.0
# West Clermont Local                                    54532.0
# West Geauga Local                                      75733.5
# West Holmes Local                                      59716.0
# West Liberty-Salem Local                               56682.0
# West Muskingum Local                                   52688.5
# West Park Academy                                      40000.0
# West Preparatory Academy                               33000.0
# Western Brown Local                                    67070.0
# Western Buckeye ESC                                    53930.0
# Western Local                                          61298.0
# Western Reserve Local                                  62360.0
# Westerville City                                       62368.0
# Westfall Local                                         50713.0
# Westlake City                                          81664.0
# Westside Academy                                       32718.5
# Wheelersburg Local                                     58201.0
# Whitehall City                                         56231.0
# Whitehall Preparatory and Fitness Academy              37000.0
# Wickliffe City                                         62122.0
# Wildwood Environmental Academy                         30000.0
# Willard City                                           66222.0
# Williamsburg Local                                     63552.0
# Willoughby-Eastlake City                               72388.0
# Wilmington City                                        61167.0
# Windham Exempted Village                               56646.0
# Winterfield Venture Academy                            39603.0
# Winton Preparatory Academy                             31500.0
# Winton Woods City                                      64413.0
# Wolf Creek Local                                       56634.0
# Wood County ESC                                        47127.5
# Woodmore Local                                         61220.0
# Woodridge Local                                        68544.0
# Wooster City                                           58275.0
# Worthington City                                       74973.0
# Wynford Local                                          51243.0
# Wyoming City                                           81879.0
# Xenia Community City                                   60784.0
# Yellow Springs Exempted Village                        67426.5
# Youngstown Academy of Excellence                       30000.0
# Youngstown City                                        50206.0
# Youngstown Community School                            37175.0
# Zane Trace Local                                       67174.0
# Zanesville City                                        50346.0
# Zenith Academy                                         33000.0
# Zenith Academy East                                    33000.0
# Zenith Academy West                                    33000.0
#
# [971 rows x 1 columns]

# %%
by_counts_median = pd.merge(by_median, by_count, how='inner', left_index=True, right_index=True)

# %%
by_counts_median.head()
# Out:
#                                        PAY_AMOUNT  QTY_TEACHERS
# DISTRICT_NAME
# A+ Arts Academy                           36517.0            27
# A+ Children's Academy                     30945.0            10
# Academy for Urban Scholars Youngstown     41000.0             3
# Academy of Arts and Sciences              31000.0             7
# Academy of Educational Excellence          1250.0             6

# %%
by_counts_median.sort_values(by='PAY_AMOUNT', ascending=False)[:20]
# Out:
#                                            PAY_AMOUNT  QTY_TEACHERS
# DISTRICT_NAME
# Beachwood City                                97518.0           111
# Orange City                                   91957.0           141
# Polaris                                       86388.5            46
# Shaker Heights City                           86072.0           327
# Cleveland Heights-University Heights City     85894.0           384
# Solon City                                    85155.5           244
# Rocky River City                              84932.0           143
# Indian Hill Exempted Village                  84125.0           128
# Upper Arlington City                          84042.0           400
# Dublin City                                   84005.0           800
# Hilliard City                                 83992.0           798
# Cuyahoga Valley Career Center                 83169.0            39
# Independence Local                            82406.0            60
# Wyoming City                                  81879.0           103
# North Olmsted City                            81787.0           204
# Westlake City                                 81664.0           196
# South Euclid-Lyndhurst City                   81544.0           189
# Bay Village City                              81475.0           153
# Eastland-Fairfield Career/Tech                80776.0            81
# Kirtland Local                                80579.0            55

# %%
by_counts_median.sort_values(by='PAY_AMOUNT', ascending=False).query("QTY_TEACHERS >= 100")['PAY_AMOUNT'][:20].sort_values(ascending=True).plot.barh(alpha=0.4)
fig = plt.gcf()
fig.set_size_inches(8,8)
plt.xticks(rotation=270)
plt.title('Top 20 Ohio School Districts by Median Salary\nwith at least 100 Teachers')
plt.show()
