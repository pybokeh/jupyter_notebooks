# %% [markdown]
# <center><h1>Analyzing Automobile Fuel Economy Data</h1></center>

# %% [markdown]
# ### QUESTION: Are Toyota vehicles more fuel efficient than Honda vehicles?

# %% [markdown]
# **To answer this question, I found a government web site that has the data I was looking for:**

# %% [markdown]
# Data source: [http://www.fueleconomy.gov/feg/ws/index.shtml](http://www.fueleconomy.gov/feg/ws/index.shtml)<br>
# Data file: [http://www.fueleconomy.gov/feg/epadata/vehicles.csv.zip](http://www.fueleconomy.gov/feg/epadata/vehicles.csv.zip)<br>
# Data meta data: [http://www.fueleconomy.gov/feg/ws/index.shtml#vehicle](http://www.fueleconomy.gov/feg/ws/index.shtml#vehicle)

# %% [markdown]
# In this notebook, I'll be using the Python programming language to profile, summarize, and visualize the data.

# %% [markdown]
# #### I've installed the usual packages for data analyis and plotting:

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pivottablejs import pivot_ui
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100
plt.style.use('ggplot')

# %%
# Read the downloaded csv file as input
vehicles = pd.read_csv('/home/pybokeh/temp/vehicles.csv')

# %% [markdown]
# ### Let's profile our data set

# %%
vehicles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36792 entries, 0 to 36791
# Data columns (total 83 columns):
# barrels08          36792 non-null float64
# barrelsA08         36792 non-null float64
# charge120          36792 non-null float64
# charge240          36792 non-null float64
# city08             36792 non-null int64
# city08U            36792 non-null float64
# cityA08            36792 non-null int64
# cityA08U           36792 non-null float64
# cityCD             36792 non-null float64
# cityE              36792 non-null float64
# cityUF             36792 non-null float64
# co2                36792 non-null int64
# co2A               36792 non-null int64
# co2TailpipeAGpm    36792 non-null float64
# co2TailpipeGpm     36792 non-null float64
# comb08             36792 non-null int64
# comb08U            36792 non-null float64
# combA08            36792 non-null int64
# combA08U           36792 non-null float64
# combE              36792 non-null float64
# combinedCD         36792 non-null float64
# combinedUF         36792 non-null float64
# cylinders          36694 non-null float64
# displ              36698 non-null float64
# drive              35603 non-null object
# engId              36792 non-null int64
# eng_dscr           21683 non-null object
# feScore            36792 non-null int64
# fuelCost08         36792 non-null int64
# fuelCostA08        36792 non-null int64
# fuelType           36792 non-null object
# fuelType1          36792 non-null object
# ghgScore           36792 non-null int64
# ghgScoreA          36792 non-null int64
# highway08          36792 non-null int64
# highway08U         36792 non-null float64
# highwayA08         36792 non-null int64
# highwayA08U        36792 non-null float64
# highwayCD          36792 non-null float64
# highwayE           36792 non-null float64
# highwayUF          36792 non-null float64
# hlv                36792 non-null int64
# hpv                36792 non-null int64
# id                 36792 non-null int64
# lv2                36792 non-null int64
# lv4                36792 non-null int64
# make               36792 non-null object
# model              36792 non-null object
# mpgData            36792 non-null object
# phevBlended        36792 non-null bool
# pv2                36792 non-null int64
# pv4                36792 non-null int64
# range              36792 non-null int64
# rangeCity          36792 non-null float64
# rangeCityA         36792 non-null float64
# rangeHwy           36792 non-null float64
# rangeHwyA          36792 non-null float64
# trany              36781 non-null object
# UCity              36792 non-null float64
# UCityA             36792 non-null float64
# UHighway           36792 non-null float64
# UHighwayA          36792 non-null float64
# VClass             36792 non-null object
# year               36792 non-null int64
# youSaveSpend       36792 non-null int64
# guzzler            2216 non-null object
# trans_dscr         15047 non-null object
# tCharger           4695 non-null object
# sCharger           623 non-null object
# atvType            2933 non-null object
# fuelType2          1346 non-null object
# rangeA             1341 non-null object
# evMotor            479 non-null object
# mfrCode            5974 non-null object
# c240Dscr           20 non-null object
# charge240b         36792 non-null float64
# c240bDscr          19 non-null object
# createdOn          36792 non-null object
# modifiedOn         36792 non-null object
# startStop          5087 non-null object
# phevCity           36792 non-null int64
# phevHwy            36792 non-null int64
# phevComb           36792 non-null int64
# dtypes: bool(1), float64(32), int64(27), object(23)
# memory usage: 23.3+ MB

# %% [markdown]
# **Se we have 36,792 rows and 83 columns of data. If you want to know the description of the data each column contains, the metadata can be viewed [here](http://www.fueleconomy.gov/feg/ws/index.shtml#vehicle)**

# %% [markdown]
# ### Let's look at the first 5 rows of data

# %%
vehicles.head()
# Out:
#    barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0  15.689436           0          0          0      19        0        0
# 1  29.950562           0          0          0       9        0        0
# 2  12.195570           0          0          0      23        0        0
# 3  29.950562           0          0          0      10        0        0
# 4  17.337486           0          0          0      17        0        0
#
#    cityA08U  cityCD  cityE  cityUF  co2  co2A  co2TailpipeAGpm  \
# 0         0       0      0       0   -1    -1                0
# 1         0       0      0       0   -1    -1                0
# 2         0       0      0       0   -1    -1                0
# 3         0       0      0       0   -1    -1                0
# 4         0       0      0       0   -1    -1                0
#
#    co2TailpipeGpm  comb08  comb08U  combA08  combA08U  combE  combinedCD  \
# 0      423.190476      21        0        0         0      0           0
# 1      807.909091      11        0        0         0      0           0
# 2      329.148148      27        0        0         0      0           0
# 3      807.909091      11        0        0         0      0           0
# 4      467.736842      19        0        0         0      0           0
#
#    combinedUF  cylinders  displ                       drive  engId  \
# 0           0          4    2.0            Rear-Wheel Drive   9011
# 1           0         12    4.9            Rear-Wheel Drive  22020
# 2           0          4    2.2           Front-Wheel Drive   2100
# 3           0          8    5.2            Rear-Wheel Drive   2850
# 4           0          4    2.2  4-Wheel or All-Wheel Drive  66031
#
#      eng_dscr  feScore  fuelCost08  fuelCostA08 fuelType         fuelType1  \
# 0       (FFS)       -1        1600            0  Regular  Regular Gasoline
# 1   (GUZZLER)       -1        3050            0  Regular  Regular Gasoline
# 2       (FFS)       -1        1250            0  Regular  Regular Gasoline
# 3         NaN       -1        3050            0  Regular  Regular Gasoline
# 4  (FFS,TRBO)       -1        2100            0  Premium  Premium Gasoline
#
#    ghgScore  ghgScoreA  highway08  highway08U  highwayA08  highwayA08U  \
# 0        -1         -1         25           0           0            0
# 1        -1         -1         14           0           0            0
# 2        -1         -1         33           0           0            0
# 3        -1         -1         12           0           0            0
# 4        -1         -1         23           0           0            0
#
#    highwayCD  highwayE  highwayUF  hlv  hpv     id  lv2  lv4        make  \
# 0          0         0          0    0    0      1    0    0  Alfa Romeo
# 1          0         0          0    0    0     10    0    0     Ferrari
# 2          0         0          0   19   77    100    0    0       Dodge
# 3          0         0          0    0    0   1000    0    0       Dodge
# 4          0         0          0    0    0  10000    0   14      Subaru
#
#                  model mpgData phevBlended  pv2  pv4  range  rangeCity  \
# 0   Spider Veloce 2000       Y       False    0    0      0          0
# 1           Testarossa       N       False    0    0      0          0
# 2              Charger       Y       False    0    0      0          0
# 3  B150/B250 Wagon 2WD       N       False    0    0      0          0
# 4     Legacy AWD Turbo       N       False    0   90      0          0
#
#    rangeCityA  rangeHwy  rangeHwyA            trany    UCity  UCityA  \
# 0           0         0          0     Manual 5-spd  23.3333       0
# 1           0         0          0     Manual 5-spd  11.0000       0
# 2           0         0          0     Manual 5-spd  29.0000       0
# 3           0         0          0  Automatic 3-spd  12.2222       0
# 4           0         0          0     Manual 5-spd  21.0000       0
#
#    UHighway  UHighwayA           VClass  year  youSaveSpend guzzler  \
# 0   35.0000          0      Two Seaters  1985         -1250     NaN
# 1   19.0000          0      Two Seaters  1985         -8500       T
# 2   47.0000          0  Subcompact Cars  1985           500     NaN
# 3   16.6667          0             Vans  1985         -8500     NaN
# 4   32.0000          0     Compact Cars  1993         -3750     NaN
#
#   trans_dscr tCharger sCharger atvType fuelType2 rangeA evMotor mfrCode  \
# 0        NaN      NaN      NaN     NaN       NaN    NaN     NaN     NaN
# 1        NaN      NaN      NaN     NaN       NaN    NaN     NaN     NaN
# 2        SIL      NaN      NaN     NaN       NaN    NaN     NaN     NaN
# 3        NaN      NaN      NaN     NaN       NaN    NaN     NaN     NaN
# 4        NaN        T      NaN     NaN       NaN    NaN     NaN     NaN
#
#   c240Dscr  charge240b c240bDscr                     createdOn  \
# 0      NaN           0       NaN  Tue Jan 01 00:00:00 EST 2013
# 1      NaN           0       NaN  Tue Jan 01 00:00:00 EST 2013
# 2      NaN           0       NaN  Tue Jan 01 00:00:00 EST 2013
# 3      NaN           0       NaN  Tue Jan 01 00:00:00 EST 2013
# 4      NaN           0       NaN  Tue Jan 01 00:00:00 EST 2013
#
#                      modifiedOn startStop  phevCity  phevHwy  phevComb
# 0  Tue Jan 01 00:00:00 EST 2013       NaN         0        0         0
# 1  Tue Jan 01 00:00:00 EST 2013       NaN         0        0         0
# 2  Tue Jan 01 00:00:00 EST 2013       NaN         0        0         0
# 3  Tue Jan 01 00:00:00 EST 2013       NaN         0        0         0
# 4  Tue Jan 01 00:00:00 EST 2013       NaN         0        0         0

# %% [markdown]
# ### If you rather observe the columns vertically, we can transpose just the 1st 3 rows of the dataframe:

# %%
vehicles.head(3).transpose()
# Out:
#                                             0                             1  \
# barrels08                             15.6894                       29.9506
# barrelsA08                                  0                             0
# charge120                                   0                             0
# charge240                                   0                             0
# city08                                     19                             9
# city08U                                     0                             0
# cityA08                                     0                             0
# cityA08U                                    0                             0
# cityCD                                      0                             0
# cityE                                       0                             0
# cityUF                                      0                             0
# co2                                        -1                            -1
# co2A                                       -1                            -1
# co2TailpipeAGpm                             0                             0
# co2TailpipeGpm                         423.19                       807.909
# comb08                                     21                            11
# comb08U                                     0                             0
# combA08                                     0                             0
# combA08U                                    0                             0
# combE                                       0                             0
# combinedCD                                  0                             0
# combinedUF                                  0                             0
# cylinders                                   4                            12
# displ                                       2                           4.9
# drive                        Rear-Wheel Drive              Rear-Wheel Drive
# engId                                    9011                         22020
# eng_dscr                                (FFS)                     (GUZZLER)
# feScore                                    -1                            -1
# fuelCost08                               1600                          3050
# fuelCostA08                                 0                             0
# fuelType                              Regular                       Regular
# fuelType1                    Regular Gasoline              Regular Gasoline
# ghgScore                                   -1                            -1
# ghgScoreA                                  -1                            -1
# highway08                                  25                            14
# highway08U                                  0                             0
# highwayA08                                  0                             0
# highwayA08U                                 0                             0
# highwayCD                                   0                             0
# highwayE                                    0                             0
# highwayUF                                   0                             0
# hlv                                         0                             0
# hpv                                         0                             0
# id                                          1                            10
# lv2                                         0                             0
# lv4                                         0                             0
# make                               Alfa Romeo                       Ferrari
# model                      Spider Veloce 2000                    Testarossa
# mpgData                                     Y                             N
# phevBlended                             False                         False
# pv2                                         0                             0
# pv4                                         0                             0
# range                                       0                             0
# rangeCity                                   0                             0
# rangeCityA                                  0                             0
# rangeHwy                                    0                             0
# rangeHwyA                                   0                             0
# trany                            Manual 5-spd                  Manual 5-spd
# UCity                                 23.3333                            11
# UCityA                                      0                             0
# UHighway                                   35                            19
# UHighwayA                                   0                             0
# VClass                            Two Seaters                   Two Seaters
# year                                     1985                          1985
# youSaveSpend                            -1250                         -8500
# guzzler                                   NaN                             T
# trans_dscr                                NaN                           NaN
# tCharger                                  NaN                           NaN
# sCharger                                  NaN                           NaN
# atvType                                   NaN                           NaN
# fuelType2                                 NaN                           NaN
# rangeA                                    NaN                           NaN
# evMotor                                   NaN                           NaN
# mfrCode                                   NaN                           NaN
# c240Dscr                                  NaN                           NaN
# charge240b                                  0                             0
# c240bDscr                                 NaN                           NaN
# createdOn        Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013
# modifiedOn       Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013
# startStop                                 NaN                           NaN
# phevCity                                    0                             0
# phevHwy                                     0                             0
# phevComb                                    0                             0
#
#                                             2
# barrels08                             12.1956
# barrelsA08                                  0
# charge120                                   0
# charge240                                   0
# city08                                     23
# city08U                                     0
# cityA08                                     0
# cityA08U                                    0
# cityCD                                      0
# cityE                                       0
# cityUF                                      0
# co2                                        -1
# co2A                                       -1
# co2TailpipeAGpm                             0
# co2TailpipeGpm                        329.148
# comb08                                     27
# comb08U                                     0
# combA08                                     0
# combA08U                                    0
# combE                                       0
# combinedCD                                  0
# combinedUF                                  0
# cylinders                                   4
# displ                                     2.2
# drive                       Front-Wheel Drive
# engId                                    2100
# eng_dscr                                (FFS)
# feScore                                    -1
# fuelCost08                               1250
# fuelCostA08                                 0
# fuelType                              Regular
# fuelType1                    Regular Gasoline
# ghgScore                                   -1
# ghgScoreA                                  -1
# highway08                                  33
# highway08U                                  0
# highwayA08                                  0
# highwayA08U                                 0
# highwayCD                                   0
# highwayE                                    0
# highwayUF                                   0
# hlv                                        19
# hpv                                        77
# id                                        100
# lv2                                         0
# lv4                                         0
# make                                    Dodge
# model                                 Charger
# mpgData                                     Y
# phevBlended                             False
# pv2                                         0
# pv4                                         0
# range                                       0
# rangeCity                                   0
# rangeCityA                                  0
# rangeHwy                                    0
# rangeHwyA                                   0
# trany                            Manual 5-spd
# UCity                                      29
# UCityA                                      0
# UHighway                                   47
# UHighwayA                                   0
# VClass                        Subcompact Cars
# year                                     1985
# youSaveSpend                              500
# guzzler                                   NaN
# trans_dscr                                SIL
# tCharger                                  NaN
# sCharger                                  NaN
# atvType                                   NaN
# fuelType2                                 NaN
# rangeA                                    NaN
# evMotor                                   NaN
# mfrCode                                   NaN
# c240Dscr                                  NaN
# charge240b                                  0
# c240bDscr                                 NaN
# createdOn        Tue Jan 01 00:00:00 EST 2013
# modifiedOn       Tue Jan 01 00:00:00 EST 2013
# startStop                                 NaN
# phevCity                                    0
# phevHwy                                     0
# phevComb                                    0

# %% [markdown]
# ## We can also create pivot tables!  Thanks to [pivottable.js](http://nicolas.kruchten.com/content/2015/09/jupyter_pivottablejs/).

# %% [markdown]
# It is not as feature-rich as Excel pivot tables, but it is pretty good nonetheless.

# %% [markdown]
# Just drag any of the columns on the left onto the emply gray area below the "Count" drop down or to the right of it.

# %%
from pivottablejs import pivot_ui
pivot_ui(vehicles)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### Let's say you are wondering how the overall combined fuel economy (highway + city) has improved with each successive model year of gasoline-based automobiles, how would you find out?

# %% [markdown]
# Looking at the data [metadata](http://www.fueleconomy.gov/feg/ws/index.shtml#vehicle), looks like I need to filter based off of "fuelType", "fuelType1", "fuelType2", and "atvType".

# %% [markdown]
# **Looks like we can't filter using "fuelType" since there are categories like "Gasoline and natural gas" which we don't want if we're just looking for gas only vehicles.**

# %%
vehicles.fuelType.value_counts()
# Out:
# Regular                        24616
# Premium                         9524
# Gasoline or E85                 1164
# Diesel                          1090
# Premium or E85                   116
# Electricity                       95
# Midgrade                          61
# CNG                               60
# Gasoline or natural gas           20
# Premium Gas or Electricity        14
# Regular Gas and Electricity       14
# Premium and Electricity            9
# Gasoline or propane                8
# Regular Gas or Electricity         1
# Name: fuelType, dtype: int64

# %% [markdown]
# **Looks like we can use "fuelType1" as the primary column to filter with**

# %%
vehicles.fuelType1.value_counts()
# Out:
# Regular Gasoline     25823
# Premium Gasoline      9663
# Diesel                1090
# Electricity             95
# Midgrade Gasoline       61
# Natural Gas             60
# Name: fuelType1, dtype: int64

# %%
vehicles.fuelType2.value_counts()
# Out:
# E85            1280
# Electricity      38
# Natural Gas      20
# Propane           8
# Name: fuelType2, dtype: int64

# %%
vehicles.atvType.value_counts()
# Out:
# FFV               1280
# Diesel            1018
# Hybrid             424
# EV                  95
# CNG                 50
# Plug-in Hybrid      38
# Bifuel (CNG)        20
# Bifuel (LPG)         8
# Name: atvType, dtype: int64

# %% [markdown]
# ### Our first attempt to filter our data to just gasoline powered vehicles

# %%
# Ensure automobile only takes gasoline as fuel
criteria1 = vehicles.fuelType1.isin(['Regular Gasoline','Premium Gasoline','Midgrade Gasoline'])

# Ensure it doesn't have a secondary fuel source
criteria2 = vehicles.fuelType2.isnull()

# I noticed after applying criteria 1 and 2, there were hybrids in my list under the atvType column
# So I want to ensure hybrids are excluded as well
criteria3 = vehicles.atvType.isnull()

# %%
# Apply the criteria
gas_vehicle_non_hybrid = vehicles[criteria1 & criteria2 & criteria3]

# %% [markdown]
# ### Let's double-check that we don't have non-gasoline models in our data set

# %% [markdown]
# Since I am mostly familiar with Hondas, let's filter our data to just Honda vehicles

# %%
only_honda = gas_vehicle_non_hybrid['make']=='Honda'

# Apply the criteria
honda = gas_vehicle_non_hybrid[only_honda]
honda.model.value_counts()
# Out:
# Civic                   151
# Accord                  141
# Prelude                  70
# Odyssey                  31
# CR-V 4WD                 30
# Civic CRX                29
# Fit                      27
# Passport 2WD             22
# CR-V 2WD                 21
# Civic Wagon              21
# Accord Wagon             20
# Accord Coupe             20
# Element 4WD              18
# Passport 4WD             18
# Element 2WD              17
# Pilot 4WD                15
# Civic Del Sol            14
# Civic CRX HF             14
# Civic HX                 12
# Pilot 2WD                12
# Del Sol                  10
# Civic Wagon 4WD          10
# S2000                    10
# Ridgeline Truck 4WD       9
# Crosstour 2WD             8
# Civic HB VX               8
# Civic HF                  4
# Crosstour 4WD             4
# Civic 4Dr                 3
# HR-V 2WD                  3
# HR-V 4WD                  2
# Accord Crosstour 4WD      2
# Accord Crosstour 2WD      2
# Name: model, dtype: int64

# %% [markdown]
# **Looks good to me.  I don't see the Insight or hybrid models in the list.**

# %% [markdown]
# ### OK, so let's chart the average overall combined MPG from all makes and models

# %%
# Group the data by model year
grouped = gas_vehicle_non_hybrid.groupby(['year'])

# %%
# Get the average mpg for each model year
average = grouped['comb08'].agg(np.mean)

# %%
# Let's plot the average mpg with each model year
average.plot()
plt.title("Average Combined Overall MPG by Model Year", weight='bold')
plt.show()

# %% [markdown]
# **If you're wondering why the decline in fuel economy beginning around mid-90s, more weight was subsequently added to the vehicles as more safety features were added (additional airbags, reinforced metals in frames and doors).  Also, during this time, is the introduction of more SUVs and minivans.  Sadly, the data set does not include vehicle weight which would have been nice to compare MPG on a per unit of weight basis.**

# %% [markdown]
# ## Let's compare combined (city + hwy) average overall mpg of gasonline-based Honda vs Toyota

# %%
criteria1 = vehicles.fuelType1.isin(['Regular Gasoline','Premium Gasoline','Midgrade Gasoline'])
criteria2 = vehicles.fuelType2.isnull()
criteria3 = vehicles.atvType.isnull()
criteria4 = vehicles.make.isin(['Honda','Toyota'])

honda_toyota_vehicle_non_hybrid = vehicles[criteria1 & criteria2 & criteria3 & criteria4]

# %%
# I'll perform a pandas pivot table on model year versus make
honda_toyota_average = honda_toyota_vehicle_non_hybrid.pivot_table('comb08', index='year',
    columns='make', aggfunc='mean')

# %% [markdown]
# ### Let's view just the first 5 rows of data

# %%
honda_toyota_average.head()
# Out:
# make      Honda     Toyota
# year
# 1984  28.083333  23.044118
# 1985  26.906250  22.925926
# 1986  27.650000  21.660714
# 1987  27.750000  21.875000
# 1988  27.791667  21.422535

# %% [markdown]
# ### Now, let's plot this data!

# %%
honda_toyota_average.plot()
plt.title("Overall Average Combined MPG\nHonda vs Toyota by Model Year")
plt.show()

# %% [markdown]
# **Looks like Toyota has lagged behind Honda for most of the years.  But I wonder if it is because Toyota has so many large trucks.  Also too bad the data source does not have vehicle weight.**

# %% [markdown]
# ### So to make things fair, let's limit our Honda/Toyota data to just smaller vehicles, SUVs, and minivans:

# %% [markdown]
# - Compact Cars
# - Subcompact Cars
# - Midsize Cars
# - Large Cars
# - Sport Utility Vehicle - 4WD
# - Sport Utility Vehicle - 2WD
# - Minivan - 2WD
# - Minivan - 4WD

# %% [markdown]
# Looking at the [metadata](http://www.fueleconomy.gov/feg/ws/index.shtml#vehicle) again, we can filter by vehicle class using the VClass column.

# %%
vehicles.VClass.value_counts()
# Out:
# Compact Cars                          5341
# Subcompact Cars                       4733
# Midsize Cars                          4193
# Standard Pickup Trucks                2354
# Sport Utility Vehicle - 4WD           2090
# Two Seaters                           1810
# Large Cars                            1759
# Sport Utility Vehicle - 2WD           1627
# Small Station Wagons                  1467
# Special Purpose Vehicles              1455
# Minicompact Cars                      1194
# Standard Pickup Trucks 2WD            1153
# Vans                                  1141
# Standard Pickup Trucks 4WD             954
# Midsize-Large Station Wagons           643
# Special Purpose Vehicle 2WD            590
# Small Pickup Trucks                    538
# Midsize Station Wagons                 526
# Vans, Cargo Type                       438
# Small Pickup Trucks 2WD                418
# Small Sport Utility Vehicle 4WD        399
# Minivan - 2WD                          330
# Standard Sport Utility Vehicle 4WD     330
# Small Sport Utility Vehicle 2WD        311
# Vans, Passenger Type                   301
# Special Purpose Vehicle 4WD            298
# Small Pickup Trucks 4WD                202
# Standard Sport Utility Vehicle 2WD     141
# Minivan - 4WD                           45
# Standard Pickup Trucks/2wd               4
# Special Purpose Vehicles/4wd             2
# Vans Passenger                           2
# Special Purpose Vehicles/2wd             2
# Special Purpose Vehicle                  1
# Name: VClass, dtype: int64

# %%
criteria1 = vehicles.fuelType1.isin(['Regular Gasoline','Premium Gasoline','Midgrade Gasoline'])
criteria2 = vehicles.fuelType2.isnull()
criteria3 = vehicles.atvType.isnull()
criteria4 = vehicles.make.isin(['Honda','Toyota'])
# We can use regular expressions to match partial strings and implement OR selection logic
criteria5 = vehicles.VClass.str.contains('Compact Cars|Subcompact Cars|Midsize Cars|Large Cars|Sport Utility|Minivan')

honda_toyota_vehicle_non_hybrid = vehicles[criteria1 & criteria2 & criteria3 & criteria4
                                           & criteria5]

honda_toyota_average = honda_toyota_vehicle_non_hybrid.pivot_table('comb08', index='year',
    columns='make', aggfunc='mean')

# %% [markdown]
# ### Before we plot the data, let's make sure we got the data we expect

# %%
honda_toyota_vehicle_non_hybrid.VClass.value_counts()
# Out:
# Subcompact Cars                       465
# Compact Cars                          293
# Sport Utility Vehicle - 4WD           194
# Midsize Cars                          178
# Sport Utility Vehicle - 2WD           164
# Minivan - 2WD                          47
# Small Sport Utility Vehicle 2WD        38
# Large Cars                             33
# Small Sport Utility Vehicle 4WD        32
# Standard Sport Utility Vehicle 4WD     19
# Minivan - 4WD                          12
# Standard Sport Utility Vehicle 2WD      8
# Name: VClass, dtype: int64

# %% [markdown]
# ### Looks to be ok, so let's plot the data

# %%
honda_toyota_average.plot()
plt.title("Overall Average MPG of Honda vs Toyota\nExcluding Trucks")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### Even though we limited our data to just smaller cars, SUVs, and minivans, for most model years, Honda vehicles are still more fuel efficient than Toyota vehicles.  2016 data should be disregarded since it is incomplete data.
