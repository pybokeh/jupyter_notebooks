# %% [markdown]
# # Conditional Formatting
#
# *New in version 0.17.1*
#
# <p style="color: red">*Provisional: This is a new feature and still under development. We'll be adding features and possibly making breaking changes in future releases. We'd love to hear your [feedback](https://github.com/pydata/pandas/issues).*<p style="color: red">
#
# You can apply **conditional formatting**, the visual styling of a DataFrame
# depending on the data within, by using the ``DataFrame.style`` property.
# This is a property that returns a ``pandas.Styler`` object, which has
# useful methods for formatting and displaying DataFrames.
#
# The styling is accomplished using CSS.
# You write functions that take scalars, `DataFrame`s or `Series`, and return *like-indexed* DataFrames or Series with CSS `"attribute: value"` pairs for the values.
# These functions can be incrementally passed to the `Styler` which collects the styles before rendering.
#
# ### Contents
#
# - [Building Styles](#Building Styles)
# - [Finer Control: Slicing](#Finer-Control:-Slicing)
# - [Builtin Styles](#Builtin Styles)
# - [Other options](#Other options)
# - [Limitations](#Limitations)
# - [Extensibility](#Extensibility)

# %% [markdown]
# # Building Styles
#
# Pass your style functions into one of the following methods:
#
# - `Styler.applymap`: elementwise
# - `Styler.apply`: column-/row-/table-wise
#
# Both of those methods take a function (and some other keyword arguments) and applies your function to the DataFrame in a certain way.
# `Styler.applymap` works through the DataFrame elementwise.
# `Styler.apply` passes each column or row into your DataFrame one-at-a-time or the entire table at once, depending on the `axis` keyword argument.
# For columnwise use `axis=0`, rowwise use `axis=1`, and for the entire table at once use `axis=None`.
#
# The result of the function application, a CSS attribute-value pair, is stored in an internal dictionary on your ``Styler`` object.
#
# Let's see some examples.

# %%
import pandas as pd
import numpy as np

np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
df.iloc[0, 2] = np.nan

# %% [markdown]
# Here's a boring example of rendering a DataFrame, without any (visible) styles:

# %%
df.style
# Out:
#             <style  type="text/css" >
#
#
#             </style>
#
#             <table id="T_11230092_8757_11e5_8510_a45e60bd97fb">
#
#
#             <thead>
#
#                 <tr>
#
#                     <th class="blank">
#
#                     <th class="col_heading level0 col0">A
#
#                     <th class="col_heading level0 col1">B
#
#                     <th class="col_heading level0 col2">C
#
#                     <th class="col_heading level0 col3">D
#
#                     <th class="col_heading level0 col4">E
#
#                 </tr>
#
#             </thead>
#             <tbody>
#
#                 <tr>
#
#                     <th id="T_11230092_8757_11e5_8510_a45e60bd97fb" class="row_heading level4 row0">
#
#                             0
#
#
#                     <td id="T_11230092_8757_11e5_8510_a45e60bd97fbrow0_col0" class="data row0 col0">
#
#                             1.0
#
#
#                     <td id="T_11230092_8757_11e5_8510_a45e60bd97fbrow0_col1" class="data row0 col1">
#
#                             1.329212
#
#
#                     <td id="T_11230092_8757_11e5_8510_a45e60bd97fbrow0_col2" class="data row0 col2">
#
#                             nan
#
#
#                     <td id="T_11230092_8757_11e5_8510_a45e60bd97fbrow0_col3" class="data row0 col3">
#
#                             -0.31628
#
#
#                     <td id="T_11230092_8757_11e5_8510_a45e60bd97fbrow0_col4" class="data row0 col4">
#
#                             -0.99081
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_11230092_8757_11e5_8510_a45e60bd97fb" class="row_heading level4 row1">
#
#                             1
#
#
#                     <td id="T_11230092_8757_11e5_8510_a45e60bd97fbrow1_col0" class="data row1 col0">
#
#                             2.0
#
#
#                     <td id="T_11230092_8757_11e5_8510_a45e60bd97fbrow1_col1" class="data row1 col1">
#
#                             -1.070816
#
#
#                     <td id="T_11230092_8757_11e5_8510_a45e60bd97fbrow1_col2" class="data row1 col2">
#
#                             -1.438713
#
#
#                     <td id="T_11230092_8757_11e5_8510_a45e60bd97fbrow1_col3" class="data row1 col3">
#
#                             0.564417
#
#
#                     <td id="T_11230092_8757_11e5_8510_a45e60bd97fbrow1_col4" class="data row1 col4">
#
#                             0.295722
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_11230092_8757_11e5_8510_a45e60bd97fb" class="row_heading level4 row2">
#
#                             2
#
#
#                     <td id="T_11230092_8757_11e5_8510_a45e60bd97fbrow2_col0" class="data row2 col0">
#
#                             3.0
#
#
#                     <td id="T_11230092_8757_11e5_8510_a45e60bd97fbrow2_col1" class="data row2 col1">
#
#                             -1.626404
#
#
#                     <td id="T_11230092_8757_11e5_8510_a45e60bd97fbrow2_col2" class="data row2 col2">
#
#                             0.219565
#
#
#                     <td id="T_11230092_8757_11e5_8510_a45e60bd97fbrow2_col3" class="data row2 col3">
#
#                             0.678805
#
#
#                     <td id="T_11230092_8757_11e5_8510_a45e60bd97fbrow2_col4" class="data row2 col4">
#
#                             1.889273
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_11230092_8757_11e5_8510_a45e60bd97fb" class="row_heading level4 row3">
#
#                             3
#
#
#                     <td id="T_11230092_8757_11e5_8510_a45e60bd97fbrow3_col0" class="data row3 col0">
#
#                             4.0
#
#
#                     <td id="T_11230092_8757_11e5_8510_a45e60bd97fbrow3_col1" class="data row3 col1">
#
#                             0.961538
#
#
#                     <td id="T_11230092_8757_11e5_8510_a45e60bd97fbrow3_col2" class="data row3 col2">
#
#                             0.104011
#
#
#                     <td id="T_11230092_8757_11e5_8510_a45e60bd97fbrow3_col3" class="data row3 col3">
#
#                             -0.481165
#
#
#                     <td id="T_11230092_8757_11e5_8510_a45e60bd97fbrow3_col4" class="data row3 col4">
#
#                             0.850229
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_11230092_8757_11e5_8510_a45e60bd97fb" class="row_heading level4 row4">
#
#                             4
#
#
#                     <td id="T_11230092_8757_11e5_8510_a45e60bd97fbrow4_col0" class="data row4 col0">
#
#                             5.0
#
#
#                     <td id="T_11230092_8757_11e5_8510_a45e60bd97fbrow4_col1" class="data row4 col1">
#
#                             1.453425
#
#
#                     <td id="T_11230092_8757_11e5_8510_a45e60bd97fbrow4_col2" class="data row4 col2">
#
#                             1.057737
#
#
#                     <td id="T_11230092_8757_11e5_8510_a45e60bd97fbrow4_col3" class="data row4 col3">
#
#                             0.165562
#
#
#                     <td id="T_11230092_8757_11e5_8510_a45e60bd97fbrow4_col4" class="data row4 col4">
#
#                             0.515018
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_11230092_8757_11e5_8510_a45e60bd97fb" class="row_heading level4 row5">
#
#                             5
#
#
#                     <td id="T_11230092_8757_11e5_8510_a45e60bd97fbrow5_col0" class="data row5 col0">
#
#                             6.0
#
#
#                     <td id="T_11230092_8757_11e5_8510_a45e60bd97fbrow5_col1" class="data row5 col1">

# %% [markdown]
# *Note*: The `DataFrame.style` attribute is a propetry that returns a `Styler` object. `Styler` has a `_repr_html_` method defined on it so they are rendered automatically. If you want the actual HTML back for further processing or for writing to file call the `.render()` method which returns a string.
#
# The above output looks very similar to the standard DataFrame HTML representation. But we've done some work behind the scenes to attach CSS classes to each cell. We can view these by calling the `.render` method.

# %%
df.style.render(trim=False).split('\n')[:10]  # ignore trim for now
# Out:
# ['',
#  '            <style  type="text/css" >',
#  '            ',
#  '            ',
#  '                #T_3bc80d1a_8757_11e5_a7fa_a45e60bd97fbrow0_col0 {',
#  '                ',
#  '                }',
#  '            ',
#  '                #T_3bc80d1a_8757_11e5_a7fa_a45e60bd97fbrow0_col1 {',
#  '                ']

# %% [markdown]
# The `row0_col0` is the identifier for that particular cell. We've also prepended each row/column identifier with a UUID unique to each DataFrame so that the style from one doesn't collied with the styling from another within the same notebook or page (you can set the `uuid` if you'd like to tie together the styling of two DataFrames).

# %% [markdown]
# Let's write a simple style function that will color negative numbers red and positive numbers black.

# %%
def color_negative_red(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'red' if val < 0 else 'black'
    return 'color: %s' % color

# %% [markdown]
# In this case, the cell's style depends only on it's own value.
# That means we should use the `Styler.applymap` method which works elementwise.

# %%
df.style.applymap(color_negative_red)
# Out:
#             <style  type="text/css" >
#
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow0_col0 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow0_col1 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow0_col2 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow0_col3 {
#
#                     color:  red;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow0_col4 {
#
#                     color:  red;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow1_col0 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow1_col1 {
#
#                     color:  red;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow1_col2 {
#
#                     color:  red;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow1_col3 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow1_col4 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow2_col0 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow2_col1 {
#
#                     color:  red;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow2_col2 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow2_col3 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow2_col4 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow3_col0 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow3_col1 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow3_col2 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow3_col3 {
#
#                     color:  red;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow3_col4 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow4_col0 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow4_col1 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow4_col2 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow4_col3 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow4_col4 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow5_col0 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow5_col1 {
#
#                     color:  red;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow5_col2 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow5_col3 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow5_col4 {
#
#                     color:  red;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow6_col0 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow6_col1 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow6_col2 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow6_col3 {
#
#                     color:  red;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow6_col4 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow7_col0 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow7_col1 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow7_col2 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow7_col3 {
#
#                     color:  red;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow7_col4 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow8_col0 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow8_col1 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow8_col2 {
#
#                     color:  red;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow8_col3 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow8_col4 {
#
#                     color:  red;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow9_col0 {
#
#                     color:  black;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow9_col1 {
#
#                     color:  red;
#
#                 }
#
#                 #T_7c13e440_8757_11e5_a403_a45e60bd97fbrow9_col2 {
#
#                     color:

# %% [markdown]
# Notice the similarity with the standard `df.applymap`, which operates on DataFrames elementwise. We want you to be able to resuse your existing knowledge of how to interact with DataFrames.
#
# Notice also that our function returned a string containing the CSS attribute and value, separated by a colon just like in a `<style>` tag. This will be a common theme.

# %% [markdown]
# Now suppose you wanted to highlight the maximum value in each column.
# We can't use `.applymap` anymore since that operated elementwise.
# Instead, we'll turn to `.apply` which operates columnwise (or rowwise using the `axis` keyword). Later on we'll see that something like `highlight_max` is already defined on `Styler` so you wouldn't need to write this yourself.

# %%
def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

# %%
df.style.apply(highlight_max)
# Out:
#             <style  type="text/css" >
#
#
#                 #T_9450332c_8757_11e5_802f_a45e60bd97fbrow2_col4 {
#
#                     background-color:  yellow;
#
#                 }
#
#                 #T_9450332c_8757_11e5_802f_a45e60bd97fbrow6_col2 {
#
#                     background-color:  yellow;
#
#                 }
#
#                 #T_9450332c_8757_11e5_802f_a45e60bd97fbrow8_col1 {
#
#                     background-color:  yellow;
#
#                 }
#
#                 #T_9450332c_8757_11e5_802f_a45e60bd97fbrow8_col3 {
#
#                     background-color:  yellow;
#
#                 }
#
#                 #T_9450332c_8757_11e5_802f_a45e60bd97fbrow9_col0 {
#
#                     background-color:  yellow;
#
#                 }
#
#             </style>
#
#             <table id="T_9450332c_8757_11e5_802f_a45e60bd97fb">
#
#
#             <thead>
#
#                 <tr>
#
#                     <th class="blank">
#
#                     <th class="col_heading level0 col0">A
#
#                     <th class="col_heading level0 col1">B
#
#                     <th class="col_heading level0 col2">C
#
#                     <th class="col_heading level0 col3">D
#
#                     <th class="col_heading level0 col4">E
#
#                 </tr>
#
#             </thead>
#             <tbody>
#
#                 <tr>
#
#                     <th id="T_9450332c_8757_11e5_802f_a45e60bd97fb" class="row_heading level4 row0">
#
#                             0
#
#
#                     <td id="T_9450332c_8757_11e5_802f_a45e60bd97fbrow0_col0" class="data row0 col0">
#
#                             1.0
#
#
#                     <td id="T_9450332c_8757_11e5_802f_a45e60bd97fbrow0_col1" class="data row0 col1">
#
#                             1.329212
#
#
#                     <td id="T_9450332c_8757_11e5_802f_a45e60bd97fbrow0_col2" class="data row0 col2">
#
#                             nan
#
#
#                     <td id="T_9450332c_8757_11e5_802f_a45e60bd97fbrow0_col3" class="data row0 col3">
#
#                             -0.31628
#
#
#                     <td id="T_9450332c_8757_11e5_802f_a45e60bd97fbrow0_col4" class="data row0 col4">
#
#                             -0.99081
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_9450332c_8757_11e5_802f_a45e60bd97fb" class="row_heading level4 row1">
#
#                             1
#
#
#                     <td id="T_9450332c_8757_11e5_802f_a45e60bd97fbrow1_col0" class="data row1 col0">
#
#                             2.0
#
#
#                     <td id="T_9450332c_8757_11e5_802f_a45e60bd97fbrow1_col1" class="data row1 col1">
#
#                             -1.070816
#
#
#                     <td id="T_9450332c_8757_11e5_802f_a45e60bd97fbrow1_col2" class="data row1 col2">
#
#                             -1.438713
#
#
#                     <td id="T_9450332c_8757_11e5_802f_a45e60bd97fbrow1_col3" class="data row1 col3">
#
#                             0.564417
#
#
#                     <td id="T_9450332c_8757_11e5_802f_a45e60bd97fbrow1_col4" class="data row1 col4">
#
#                             0.295722
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_9450332c_8757_11e5_802f_a45e60bd97fb" class="row_heading level4 row2">
#
#                             2
#
#
#                     <td id="T_9450332c_8757_11e5_802f_a45e60bd97fbrow2_col0" class="data row2 col0">
#
#                             3.0
#
#
#                     <td id="T_9450332c_8757_11e5_802f_a45e60bd97fbrow2_col1" class="data row2 col1">
#
#                             -1.626404
#
#
#                     <td id="T_9450332c_8757_11e5_802f_a45e60bd97fbrow2_col2" class="data row2 col2">
#
#                             0.219565
#
#
#                     <td id="T_9450332c_8757_11e5_802f_a45e60bd97fbrow2_col3" class="data row2 col3">
#
#                             0.678805
#
#
#                     <td id="T_9450332c_8757_11e5_802f_a45e60bd97fbrow2_col4" class="data row2 col4">
#
#                             1.889273
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_9450332c_8757_11e5_802f_a45e60bd97fb" class="row_heading level4 row3">
#
#                             3
#
#
#                     <td id="T_9450332c_8757_11e5_802f_a45e60bd97fbrow3_col0" class="data row3 col0">
#
#                             4.0
#
#
#                     <td id="T_9450332c_8757_11e5_802f_a45e60bd97fbrow3_col1" class="data row3 col1">
#
#                             0.961538
#
#
#                     <td id="T_9450332c_8757_11e5_802f_a45e60bd97fbrow3_col2" class="data row3 col2">
#
#                             0.104011
#
#
#                     <td id="T_9450332c_8757_11e5_802f_a45e60bd97fbrow3_col3" class="data row3 col3">
#
#                             -0.481165
#
#
#                     <td id="T_9450332c_8757_11e5_802f_a45e60bd97fbrow3_col4" class="data row3 col4">
#
#                             0.850229
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_9450332c_8757_11e5_802f_a45e60bd97fb" class="row_heading level4 row4">
#
#                             4
#
#
#                     <td id="T_9450332c_8757_11e5_802f_a45e60bd97fbrow4_col0" class="data row4 col0">
#
#                             5.0
#
#
#                     <td id="T_9450332c_8757_11e5_802f_a45e60bd97fbrow4_col1" class="data row4 col1">
#
#                             1.453425
#
#
#                     <td id="T_9450332c_8757_11e5_802f_a45e60bd97fbrow4_col2" class="data row4 col2">
#
#                             1.057737
#
#
#                     <td id="T_9450332c_8757_11e5_802f_a45e60bd97fbrow4_col3" class="data row4 col3">

# %% [markdown]
# We encourage you to use method chains to build up a style piecewise, before finally rending at the end of the chain.

# %%
df.style.\
    applymap(color_negative_red).\
    apply(highlight_max)
# Out:
#             <style  type="text/css" >
#
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow0_col0 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow0_col1 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow0_col2 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow0_col3 {
#
#                     color:  red;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow0_col4 {
#
#                     color:  red;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow1_col0 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow1_col1 {
#
#                     color:  red;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow1_col2 {
#
#                     color:  red;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow1_col3 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow1_col4 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow2_col0 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow2_col1 {
#
#                     color:  red;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow2_col2 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow2_col3 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow2_col4 {
#
#                     color:  black;
#
#                     background-color:  yellow;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow3_col0 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow3_col1 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow3_col2 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow3_col3 {
#
#                     color:  red;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow3_col4 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow4_col0 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow4_col1 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow4_col2 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow4_col3 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow4_col4 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow5_col0 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow5_col1 {
#
#                     color:  red;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow5_col2 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow5_col3 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow5_col4 {
#
#                     color:  red;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow6_col0 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow6_col1 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow6_col2 {
#
#                     color:  black;
#
#                     background-color:  yellow;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow6_col3 {
#
#                     color:  red;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow6_col4 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow7_col0 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow7_col1 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_fc05ad80_874f_11e5_ba2b_a45e60bd97fbrow7_col2 {
#
#                     color:  black;
#
#                     : ;
#
#                 }

# %% [markdown]
# Above we used `Styler.apply` to pass in each column one at a time.
#
# <p style="background-color: #DEDEBE">*Debugging Tip*: If you're having trouble writing your style function, try just passing it into <code style="background-color: #DEDEBE">df.apply</code>. <code style="background-color: #DEDEBE">Styler.apply</code> uses that internally, so the result (should) be the same.</p>
#
# What if you wanted to highlight just the maximum value in the entire table?
# Use `.apply(function, axis=None)` to indicate that your function wants the entire table, not one column or row at a time. Let's try that next.
#
# We'll rewrite our `highlight-max` to handle either Series (from `.apply(axis=0 or 1)`) or DataFrames (from `.apply(axis=None)`). We'll also allow the color to be adjustable, to demonstrate that `.apply`, and `.applymap` pass along keyword arguments.

# %%
def highlight_max(data, color='yellow'):
    '''
    highlight the maximum in a Series or DataFrame
    '''
    attr = 'background-color: {}'.format(color)
    if data.ndim == 1:  # Series from .apply(axis=0) or axis=1
        is_max = data == data.max()
        return [attr if v else '' for v in is_max]
    else:  # from .apply(axis=None)
        is_max = data == data.max().max()
        return pd.DataFrame(np.where(is_max, attr, ''),
                            index=data.index, columns=data.columns)

# %%
df.style.apply(highlight_max, color='darkorange', axis=None)
# Out:
#             <style  type="text/css" >
#
#
#                 #T_44208774_8759_11e5_bd50_a45e60bd97fbrow9_col0 {
#
#                     background-color:  darkorange;
#
#                 }
#
#             </style>
#
#             <table id="T_44208774_8759_11e5_bd50_a45e60bd97fb">
#
#
#             <thead>
#
#                 <tr>
#
#                     <th class="blank">
#
#                     <th class="col_heading level0 col0">A
#
#                     <th class="col_heading level0 col1">B
#
#                     <th class="col_heading level0 col2">C
#
#                     <th class="col_heading level0 col3">D
#
#                     <th class="col_heading level0 col4">E
#
#                 </tr>
#
#             </thead>
#             <tbody>
#
#                 <tr>
#
#                     <th id="T_44208774_8759_11e5_bd50_a45e60bd97fb" class="row_heading level4 row0">
#
#                             0
#
#
#                     <td id="T_44208774_8759_11e5_bd50_a45e60bd97fbrow0_col0" class="data row0 col0">
#
#                             1.0
#
#
#                     <td id="T_44208774_8759_11e5_bd50_a45e60bd97fbrow0_col1" class="data row0 col1">
#
#                             1.329212
#
#
#                     <td id="T_44208774_8759_11e5_bd50_a45e60bd97fbrow0_col2" class="data row0 col2">
#
#                             nan
#
#
#                     <td id="T_44208774_8759_11e5_bd50_a45e60bd97fbrow0_col3" class="data row0 col3">
#
#                             -0.31628
#
#
#                     <td id="T_44208774_8759_11e5_bd50_a45e60bd97fbrow0_col4" class="data row0 col4">
#
#                             -0.99081
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_44208774_8759_11e5_bd50_a45e60bd97fb" class="row_heading level4 row1">
#
#                             1
#
#
#                     <td id="T_44208774_8759_11e5_bd50_a45e60bd97fbrow1_col0" class="data row1 col0">
#
#                             2.0
#
#
#                     <td id="T_44208774_8759_11e5_bd50_a45e60bd97fbrow1_col1" class="data row1 col1">
#
#                             -1.070816
#
#
#                     <td id="T_44208774_8759_11e5_bd50_a45e60bd97fbrow1_col2" class="data row1 col2">
#
#                             -1.438713
#
#
#                     <td id="T_44208774_8759_11e5_bd50_a45e60bd97fbrow1_col3" class="data row1 col3">
#
#                             0.564417
#
#
#                     <td id="T_44208774_8759_11e5_bd50_a45e60bd97fbrow1_col4" class="data row1 col4">
#
#                             0.295722
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_44208774_8759_11e5_bd50_a45e60bd97fb" class="row_heading level4 row2">
#
#                             2
#
#
#                     <td id="T_44208774_8759_11e5_bd50_a45e60bd97fbrow2_col0" class="data row2 col0">
#
#                             3.0
#
#
#                     <td id="T_44208774_8759_11e5_bd50_a45e60bd97fbrow2_col1" class="data row2 col1">
#
#                             -1.626404
#
#
#                     <td id="T_44208774_8759_11e5_bd50_a45e60bd97fbrow2_col2" class="data row2 col2">
#
#                             0.219565
#
#
#                     <td id="T_44208774_8759_11e5_bd50_a45e60bd97fbrow2_col3" class="data row2 col3">
#
#                             0.678805
#
#
#                     <td id="T_44208774_8759_11e5_bd50_a45e60bd97fbrow2_col4" class="data row2 col4">
#
#                             1.889273
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_44208774_8759_11e5_bd50_a45e60bd97fb" class="row_heading level4 row3">
#
#                             3
#
#
#                     <td id="T_44208774_8759_11e5_bd50_a45e60bd97fbrow3_col0" class="data row3 col0">
#
#                             4.0
#
#
#                     <td id="T_44208774_8759_11e5_bd50_a45e60bd97fbrow3_col1" class="data row3 col1">
#
#                             0.961538
#
#
#                     <td id="T_44208774_8759_11e5_bd50_a45e60bd97fbrow3_col2" class="data row3 col2">
#
#                             0.104011
#
#
#                     <td id="T_44208774_8759_11e5_bd50_a45e60bd97fbrow3_col3" class="data row3 col3">
#
#                             -0.481165
#
#
#                     <td id="T_44208774_8759_11e5_bd50_a45e60bd97fbrow3_col4" class="data row3 col4">
#
#                             0.850229
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_44208774_8759_11e5_bd50_a45e60bd97fb" class="row_heading level4 row4">
#
#                             4
#
#
#                     <td id="T_44208774_8759_11e5_bd50_a45e60bd97fbrow4_col0" class="data row4 col0">
#
#                             5.0
#
#
#                     <td id="T_44208774_8759_11e5_bd50_a45e60bd97fbrow4_col1" class="data row4 col1">
#
#                             1.453425
#
#
#                     <td id="T_44208774_8759_11e5_bd50_a45e60bd97fbrow4_col2" class="data row4 col2">
#
#                             1.057737
#
#
#                     <td id="T_44208774_8759_11e5_bd50_a45e60bd97fbrow4_col3" class="data row4 col3">
#
#                             0.165562
#
#
#                     <td id="T_44208774_8759_11e5_bd50_a45e60bd97fbrow4_col4" class="data row4 col4">
#
#                             0.515018
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_44208774_8759_11e5_bd50_a45e60bd97fb" class="row_heading level4 row5">
#
#                             5
#
#
#                     <td id="T_44208774_8759_11e5_bd50_a45e60bd97fbrow5_col0" class="data row5 col0">
#
#                             6.0

# %% [markdown]
# ## Finer Control: Slicing

# %%
df.style.highlight_max(subset=['B', 'C'], axis=0)
# Out:
#             <style  type="text/css" >
#
#
#                 #T_fe316fca_874f_11e5_a5b1_a45e60bd97fbrow6_col2 {
#
#                     background-color:  yellow;
#
#                 }
#
#                 #T_fe316fca_874f_11e5_a5b1_a45e60bd97fbrow8_col1 {
#
#                     background-color:  yellow;
#
#                 }
#
#             </style>
#
#             <table id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fb">
#
#
#             <thead>
#
#                 <tr>
#
#                     <th class="blank">
#
#                     <th class="col_heading level0 col0">A
#
#                     <th class="col_heading level0 col1">B
#
#                     <th class="col_heading level0 col2">C
#
#                     <th class="col_heading level0 col3">D
#
#                     <th class="col_heading level0 col4">E
#
#                 </tr>
#
#             </thead>
#             <tbody>
#
#                 <tr>
#
#                     <th id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fb" class="row_heading level4 row0">
#
#                             0
#
#
#                     <td id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fbrow0_col0" class="data row0 col0">
#
#                             1.0
#
#
#                     <td id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fbrow0_col1" class="data row0 col1">
#
#                             1.329212
#
#
#                     <td id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fbrow0_col2" class="data row0 col2">
#
#                             nan
#
#
#                     <td id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fbrow0_col3" class="data row0 col3">
#
#                             -0.31628
#
#
#                     <td id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fbrow0_col4" class="data row0 col4">
#
#                             -0.99081
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fb" class="row_heading level4 row1">
#
#                             1
#
#
#                     <td id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fbrow1_col0" class="data row1 col0">
#
#                             2.0
#
#
#                     <td id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fbrow1_col1" class="data row1 col1">
#
#                             -1.070816
#
#
#                     <td id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fbrow1_col2" class="data row1 col2">
#
#                             -1.438713
#
#
#                     <td id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fbrow1_col3" class="data row1 col3">
#
#                             0.564417
#
#
#                     <td id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fbrow1_col4" class="data row1 col4">
#
#                             0.295722
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fb" class="row_heading level4 row2">
#
#                             2
#
#
#                     <td id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fbrow2_col0" class="data row2 col0">
#
#                             3.0
#
#
#                     <td id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fbrow2_col1" class="data row2 col1">
#
#                             -1.626404
#
#
#                     <td id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fbrow2_col2" class="data row2 col2">
#
#                             0.219565
#
#
#                     <td id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fbrow2_col3" class="data row2 col3">
#
#                             0.678805
#
#
#                     <td id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fbrow2_col4" class="data row2 col4">
#
#                             1.889273
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fb" class="row_heading level4 row3">
#
#                             3
#
#
#                     <td id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fbrow3_col0" class="data row3 col0">
#
#                             4.0
#
#
#                     <td id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fbrow3_col1" class="data row3 col1">
#
#                             0.961538
#
#
#                     <td id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fbrow3_col2" class="data row3 col2">
#
#                             0.104011
#
#
#                     <td id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fbrow3_col3" class="data row3 col3">
#
#                             -0.481165
#
#
#                     <td id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fbrow3_col4" class="data row3 col4">
#
#                             0.850229
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fb" class="row_heading level4 row4">
#
#                             4
#
#
#                     <td id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fbrow4_col0" class="data row4 col0">
#
#                             5.0
#
#
#                     <td id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fbrow4_col1" class="data row4 col1">
#
#                             1.453425
#
#
#                     <td id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fbrow4_col2" class="data row4 col2">
#
#                             1.057737
#
#
#                     <td id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fbrow4_col3" class="data row4 col3">
#
#                             0.165562
#
#
#                     <td id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fbrow4_col4" class="data row4 col4">
#
#                             0.515018
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_fe316fca_874f_11e5_a5b1_a45e60bd97fb" class="row_heading level4 row5">
#
#                             5

# %% [markdown]
# Both `Styler.apply`, and `Styler.applymap` accept a `subset` keyword.
# This allows you to apply styles to specific rows or columns, without having to code that logic into your `style` function.
#
# The value passed to `subset` behaves simlar to slicing a DataFrame.
#
# - A scalar is treated as a column label
# - A list (or series or numpy array)
# - A tuple is treated as `(row_indexer, column_indexer)`
#
# The last option let's you slice rows and columns simultanteously.
# Consider using `pd.IndexSlice` to construct the tuple for the last one.

# %%
df.style.apply(highlight_max, subset=['B', 'C', 'D'])
# Out:
#             <style  type="text/css" >
#
#
#                 #T_fe87dd38_874f_11e5_a20a_a45e60bd97fbrow6_col2 {
#
#                     background-color:  yellow;
#
#                 }
#
#                 #T_fe87dd38_874f_11e5_a20a_a45e60bd97fbrow8_col1 {
#
#                     background-color:  yellow;
#
#                 }
#
#                 #T_fe87dd38_874f_11e5_a20a_a45e60bd97fbrow8_col3 {
#
#                     background-color:  yellow;
#
#                 }
#
#             </style>
#
#             <table id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fb">
#
#
#             <thead>
#
#                 <tr>
#
#                     <th class="blank">
#
#                     <th class="col_heading level0 col0">A
#
#                     <th class="col_heading level0 col1">B
#
#                     <th class="col_heading level0 col2">C
#
#                     <th class="col_heading level0 col3">D
#
#                     <th class="col_heading level0 col4">E
#
#                 </tr>
#
#             </thead>
#             <tbody>
#
#                 <tr>
#
#                     <th id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fb" class="row_heading level4 row0">
#
#                             0
#
#
#                     <td id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fbrow0_col0" class="data row0 col0">
#
#                             1.0
#
#
#                     <td id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fbrow0_col1" class="data row0 col1">
#
#                             1.329212
#
#
#                     <td id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fbrow0_col2" class="data row0 col2">
#
#                             nan
#
#
#                     <td id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fbrow0_col3" class="data row0 col3">
#
#                             -0.31628
#
#
#                     <td id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fbrow0_col4" class="data row0 col4">
#
#                             -0.99081
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fb" class="row_heading level4 row1">
#
#                             1
#
#
#                     <td id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fbrow1_col0" class="data row1 col0">
#
#                             2.0
#
#
#                     <td id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fbrow1_col1" class="data row1 col1">
#
#                             -1.070816
#
#
#                     <td id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fbrow1_col2" class="data row1 col2">
#
#                             -1.438713
#
#
#                     <td id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fbrow1_col3" class="data row1 col3">
#
#                             0.564417
#
#
#                     <td id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fbrow1_col4" class="data row1 col4">
#
#                             0.295722
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fb" class="row_heading level4 row2">
#
#                             2
#
#
#                     <td id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fbrow2_col0" class="data row2 col0">
#
#                             3.0
#
#
#                     <td id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fbrow2_col1" class="data row2 col1">
#
#                             -1.626404
#
#
#                     <td id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fbrow2_col2" class="data row2 col2">
#
#                             0.219565
#
#
#                     <td id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fbrow2_col3" class="data row2 col3">
#
#                             0.678805
#
#
#                     <td id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fbrow2_col4" class="data row2 col4">
#
#                             1.889273
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fb" class="row_heading level4 row3">
#
#                             3
#
#
#                     <td id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fbrow3_col0" class="data row3 col0">
#
#                             4.0
#
#
#                     <td id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fbrow3_col1" class="data row3 col1">
#
#                             0.961538
#
#
#                     <td id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fbrow3_col2" class="data row3 col2">
#
#                             0.104011
#
#
#                     <td id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fbrow3_col3" class="data row3 col3">
#
#                             -0.481165
#
#
#                     <td id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fbrow3_col4" class="data row3 col4">
#
#                             0.850229
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fb" class="row_heading level4 row4">
#
#                             4
#
#
#                     <td id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fbrow4_col0" class="data row4 col0">
#
#                             5.0
#
#
#                     <td id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fbrow4_col1" class="data row4 col1">
#
#                             1.453425
#
#
#                     <td id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fbrow4_col2" class="data row4 col2">
#
#                             1.057737
#
#
#                     <td id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fbrow4_col3" class="data row4 col3">
#
#                             0.165562
#
#
#                     <td id="T_fe87dd38_874f_11e5_a20a_a45e60bd97fbrow4_col4" class="data row4 col4">
#
#                             0.515018
#
#
#                 </tr>
#
#                 <tr>

# %% [markdown]
# For row and column slicing, any valid indexer to `.loc` will work.

# %%
df.style.applymap(color_negative_red,
                  subset=pd.IndexSlice[2:5, ['B', 'D']])
# Out:
#             <style  type="text/css" >
#
#
#                 #T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow2_col1 {
#
#                     color:  red;
#
#                 }
#
#                 #T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow2_col3 {
#
#                     color:  black;
#
#                 }
#
#                 #T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow3_col1 {
#
#                     color:  black;
#
#                 }
#
#                 #T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow3_col3 {
#
#                     color:  red;
#
#                 }
#
#                 #T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow4_col1 {
#
#                     color:  black;
#
#                 }
#
#                 #T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow4_col3 {
#
#                     color:  black;
#
#                 }
#
#                 #T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow5_col1 {
#
#                     color:  red;
#
#                 }
#
#                 #T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow5_col3 {
#
#                     color:  black;
#
#                 }
#
#             </style>
#
#             <table id="T_feef7266_874f_11e5_a6fa_a45e60bd97fb">
#
#
#             <thead>
#
#                 <tr>
#
#                     <th class="blank">
#
#                     <th class="col_heading level0 col0">A
#
#                     <th class="col_heading level0 col1">B
#
#                     <th class="col_heading level0 col2">C
#
#                     <th class="col_heading level0 col3">D
#
#                     <th class="col_heading level0 col4">E
#
#                 </tr>
#
#             </thead>
#             <tbody>
#
#                 <tr>
#
#                     <th id="T_feef7266_874f_11e5_a6fa_a45e60bd97fb" class="row_heading level4 row0">
#
#                             0
#
#
#                     <td id="T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow0_col0" class="data row0 col0">
#
#                             1.0
#
#
#                     <td id="T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow0_col1" class="data row0 col1">
#
#                             1.329212
#
#
#                     <td id="T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow0_col2" class="data row0 col2">
#
#                             nan
#
#
#                     <td id="T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow0_col3" class="data row0 col3">
#
#                             -0.31628
#
#
#                     <td id="T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow0_col4" class="data row0 col4">
#
#                             -0.99081
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_feef7266_874f_11e5_a6fa_a45e60bd97fb" class="row_heading level4 row1">
#
#                             1
#
#
#                     <td id="T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow1_col0" class="data row1 col0">
#
#                             2.0
#
#
#                     <td id="T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow1_col1" class="data row1 col1">
#
#                             -1.070816
#
#
#                     <td id="T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow1_col2" class="data row1 col2">
#
#                             -1.438713
#
#
#                     <td id="T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow1_col3" class="data row1 col3">
#
#                             0.564417
#
#
#                     <td id="T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow1_col4" class="data row1 col4">
#
#                             0.295722
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_feef7266_874f_11e5_a6fa_a45e60bd97fb" class="row_heading level4 row2">
#
#                             2
#
#
#                     <td id="T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow2_col0" class="data row2 col0">
#
#                             3.0
#
#
#                     <td id="T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow2_col1" class="data row2 col1">
#
#                             -1.626404
#
#
#                     <td id="T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow2_col2" class="data row2 col2">
#
#                             0.219565
#
#
#                     <td id="T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow2_col3" class="data row2 col3">
#
#                             0.678805
#
#
#                     <td id="T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow2_col4" class="data row2 col4">
#
#                             1.889273
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_feef7266_874f_11e5_a6fa_a45e60bd97fb" class="row_heading level4 row3">
#
#                             3
#
#
#                     <td id="T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow3_col0" class="data row3 col0">
#
#                             4.0
#
#
#                     <td id="T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow3_col1" class="data row3 col1">
#
#                             0.961538
#
#
#                     <td id="T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow3_col2" class="data row3 col2">
#
#                             0.104011
#
#
#                     <td id="T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow3_col3" class="data row3 col3">
#
#                             -0.481165
#
#
#                     <td id="T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow3_col4" class="data row3 col4">
#
#                             0.850229
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_feef7266_874f_11e5_a6fa_a45e60bd97fb" class="row_heading level4 row4">
#
#                             4
#
#
#                     <td id="T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow4_col0" class="data row4 col0">
#
#                             5.0
#
#
#                     <td id="T_feef7266_874f_11e5_a6fa_a45e60bd97fbrow4_col1" class="data row4 col1">

# %% [markdown]
# Consider using `pd.IndexSlice` to make writing the slices easier.
#
# **N.B.** Only label-based slicing is supported right now, not positional.
#
# **N.B.** If your style function uses a `subset` keyword argument, consider wrapping your function in a `functools.partial`, partialing out that keyword.
#
# ```python
# my_func2 = functools.partial(my_func, subset=42)
# ```

# %% [markdown]
# ## Builtin Styles

# %% [markdown]
# Finally, we expect certain styling functions to be common enough that we've included a few "built-in" to the `Styler`, so you don't have to write them yourself.

# %%
df.style.highlight_null(null_color='red')
# Out:
#             <style  type="text/css" >
#
#
#                 #T_007ae692_8750_11e5_a362_a45e60bd97fbrow0_col2 {
#
#                     background-color:  red;
#
#                 }
#
#             </style>
#
#             <table id="T_007ae692_8750_11e5_a362_a45e60bd97fb">
#
#
#             <thead>
#
#                 <tr>
#
#                     <th class="blank">
#
#                     <th class="col_heading level0 col0">A
#
#                     <th class="col_heading level0 col1">B
#
#                     <th class="col_heading level0 col2">C
#
#                     <th class="col_heading level0 col3">D
#
#                     <th class="col_heading level0 col4">E
#
#                 </tr>
#
#             </thead>
#             <tbody>
#
#                 <tr>
#
#                     <th id="T_007ae692_8750_11e5_a362_a45e60bd97fb" class="row_heading level4 row0">
#
#                             0
#
#
#                     <td id="T_007ae692_8750_11e5_a362_a45e60bd97fbrow0_col0" class="data row0 col0">
#
#                             1.0
#
#
#                     <td id="T_007ae692_8750_11e5_a362_a45e60bd97fbrow0_col1" class="data row0 col1">
#
#                             1.329212
#
#
#                     <td id="T_007ae692_8750_11e5_a362_a45e60bd97fbrow0_col2" class="data row0 col2">
#
#                             nan
#
#
#                     <td id="T_007ae692_8750_11e5_a362_a45e60bd97fbrow0_col3" class="data row0 col3">
#
#                             -0.31628
#
#
#                     <td id="T_007ae692_8750_11e5_a362_a45e60bd97fbrow0_col4" class="data row0 col4">
#
#                             -0.99081
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_007ae692_8750_11e5_a362_a45e60bd97fb" class="row_heading level4 row1">
#
#                             1
#
#
#                     <td id="T_007ae692_8750_11e5_a362_a45e60bd97fbrow1_col0" class="data row1 col0">
#
#                             2.0
#
#
#                     <td id="T_007ae692_8750_11e5_a362_a45e60bd97fbrow1_col1" class="data row1 col1">
#
#                             -1.070816
#
#
#                     <td id="T_007ae692_8750_11e5_a362_a45e60bd97fbrow1_col2" class="data row1 col2">
#
#                             -1.438713
#
#
#                     <td id="T_007ae692_8750_11e5_a362_a45e60bd97fbrow1_col3" class="data row1 col3">
#
#                             0.564417
#
#
#                     <td id="T_007ae692_8750_11e5_a362_a45e60bd97fbrow1_col4" class="data row1 col4">
#
#                             0.295722
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_007ae692_8750_11e5_a362_a45e60bd97fb" class="row_heading level4 row2">
#
#                             2
#
#
#                     <td id="T_007ae692_8750_11e5_a362_a45e60bd97fbrow2_col0" class="data row2 col0">
#
#                             3.0
#
#
#                     <td id="T_007ae692_8750_11e5_a362_a45e60bd97fbrow2_col1" class="data row2 col1">
#
#                             -1.626404
#
#
#                     <td id="T_007ae692_8750_11e5_a362_a45e60bd97fbrow2_col2" class="data row2 col2">
#
#                             0.219565
#
#
#                     <td id="T_007ae692_8750_11e5_a362_a45e60bd97fbrow2_col3" class="data row2 col3">
#
#                             0.678805
#
#
#                     <td id="T_007ae692_8750_11e5_a362_a45e60bd97fbrow2_col4" class="data row2 col4">
#
#                             1.889273
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_007ae692_8750_11e5_a362_a45e60bd97fb" class="row_heading level4 row3">
#
#                             3
#
#
#                     <td id="T_007ae692_8750_11e5_a362_a45e60bd97fbrow3_col0" class="data row3 col0">
#
#                             4.0
#
#
#                     <td id="T_007ae692_8750_11e5_a362_a45e60bd97fbrow3_col1" class="data row3 col1">
#
#                             0.961538
#
#
#                     <td id="T_007ae692_8750_11e5_a362_a45e60bd97fbrow3_col2" class="data row3 col2">
#
#                             0.104011
#
#
#                     <td id="T_007ae692_8750_11e5_a362_a45e60bd97fbrow3_col3" class="data row3 col3">
#
#                             -0.481165
#
#
#                     <td id="T_007ae692_8750_11e5_a362_a45e60bd97fbrow3_col4" class="data row3 col4">
#
#                             0.850229
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_007ae692_8750_11e5_a362_a45e60bd97fb" class="row_heading level4 row4">
#
#                             4
#
#
#                     <td id="T_007ae692_8750_11e5_a362_a45e60bd97fbrow4_col0" class="data row4 col0">
#
#                             5.0
#
#
#                     <td id="T_007ae692_8750_11e5_a362_a45e60bd97fbrow4_col1" class="data row4 col1">
#
#                             1.453425
#
#
#                     <td id="T_007ae692_8750_11e5_a362_a45e60bd97fbrow4_col2" class="data row4 col2">
#
#                             1.057737
#
#
#                     <td id="T_007ae692_8750_11e5_a362_a45e60bd97fbrow4_col3" class="data row4 col3">
#
#                             0.165562
#
#
#                     <td id="T_007ae692_8750_11e5_a362_a45e60bd97fbrow4_col4" class="data row4 col4">
#
#                             0.515018
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_007ae692_8750_11e5_a362_a45e60bd97fb" class="row_heading level4 row5">
#
#                             5
#
#
#                     <td id="T_007ae692_8750_11e5_a362_a45e60bd97fbrow5_col0" class="data row5 col0">
#
#                             6.0

# %% [markdown]
# Gradients for the background color. These require matplotlib, and we'll use [Seaborn](http://stanford.edu/~mwaskom/software/seaborn/) to get a nice colormap.

# %%
import seaborn as sns

cm = sns.light_palette("green", as_cmap=True)

s = df.style.background_gradient(cmap=cm)
s
# Out:
#             <style  type="text/css" >
#
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow0_col0 {
#
#                     background-color:  #e5ffe5;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow0_col1 {
#
#                     background-color:  #188d18;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow0_col2 {
#
#                     background-color:  #e5ffe5;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow0_col3 {
#
#                     background-color:  #c7eec7;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow0_col4 {
#
#                     background-color:  #a6dca6;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow1_col0 {
#
#                     background-color:  #ccf1cc;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow1_col1 {
#
#                     background-color:  #c0eac0;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow1_col2 {
#
#                     background-color:  #e5ffe5;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow1_col3 {
#
#                     background-color:  #62b662;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow1_col4 {
#
#                     background-color:  #5cb35c;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow2_col0 {
#
#                     background-color:  #b3e3b3;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow2_col1 {
#
#                     background-color:  #e5ffe5;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow2_col2 {
#
#                     background-color:  #56af56;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow2_col3 {
#
#                     background-color:  #56af56;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow2_col4 {
#
#                     background-color:  #008000;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow3_col0 {
#
#                     background-color:  #99d599;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow3_col1 {
#
#                     background-color:  #329c32;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow3_col2 {
#
#                     background-color:  #5fb55f;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow3_col3 {
#
#                     background-color:  #daf9da;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow3_col4 {
#
#                     background-color:  #3ba13b;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow4_col0 {
#
#                     background-color:  #80c780;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow4_col1 {
#
#                     background-color:  #108910;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow4_col2 {
#
#                     background-color:  #0d870d;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow4_col3 {
#
#                     background-color:  #90d090;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow4_col4 {
#
#                     background-color:  #4fac4f;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow5_col0 {
#
#                     background-color:  #66b866;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow5_col1 {
#
#                     background-color:  #d2f4d2;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow5_col2 {
#
#                     background-color:  #389f38;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow5_col3 {
#
#                     background-color:  #048204;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow5_col4 {
#
#                     background-color:  #70be70;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow6_col0 {
#
#                     background-color:  #4daa4d;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow6_col1 {
#
#                     background-color:  #6cbc6c;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow6_col2 {
#
#                     background-color:  #008000;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow6_col3 {
#
#                     background-color:  #a3daa3;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow6_col4 {
#
#                     background-color:  #0e880e;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow7_col0 {
#
#                     background-color:  #329c32;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow7_col1 {
#
#                     background-color:  #5cb35c;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow7_col2 {
#
#                     background-color:  #0e880e;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow7_col3 {
#
#                     background-color:  #cff3cf;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow7_col4 {
#
#                     background-color:  #4fac4f;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow8_col0 {
#
#                     background-color:  #198e19;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow8_col1 {
#
#                     background-color:  #008000;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow8_col2 {
#
#                     background-color:  #dcfadc;
#
#                 }
#
#                 #T_00e5462e_8750_11e5_9303_a45e60bd97fbrow8_col3 {
#
#                     background-color:  #008000;
#
#                 }

# %% [markdown]
# `Styler.background_gradient` takes the keyword arguments `low` and `high`. Roughly speaking these extend the range of your data by `low` and `high` percent so that when we convert the colors, the colormap's entire range isn't used. This is useful so that you can actually read the text still.

# %%
# Uses the full color range
df.loc[:4].style.background_gradient(cmap='viridis')
# Out:
#             <style  type="text/css" >
#
#
#                 #T_015c1a40_8750_11e5_a119_a45e60bd97fbrow0_col0 {
#
#                     background-color:  #440154;
#
#                 }
#
#                 #T_015c1a40_8750_11e5_a119_a45e60bd97fbrow0_col1 {
#
#                     background-color:  #e5e419;
#
#                 }
#
#                 #T_015c1a40_8750_11e5_a119_a45e60bd97fbrow0_col2 {
#
#                     background-color:  #440154;
#
#                 }
#
#                 #T_015c1a40_8750_11e5_a119_a45e60bd97fbrow0_col3 {
#
#                     background-color:  #46327e;
#
#                 }
#
#                 #T_015c1a40_8750_11e5_a119_a45e60bd97fbrow0_col4 {
#
#                     background-color:  #440154;
#
#                 }
#
#                 #T_015c1a40_8750_11e5_a119_a45e60bd97fbrow1_col0 {
#
#                     background-color:  #3b528b;
#
#                 }
#
#                 #T_015c1a40_8750_11e5_a119_a45e60bd97fbrow1_col1 {
#
#                     background-color:  #433e85;
#
#                 }
#
#                 #T_015c1a40_8750_11e5_a119_a45e60bd97fbrow1_col2 {
#
#                     background-color:  #440154;
#
#                 }
#
#                 #T_015c1a40_8750_11e5_a119_a45e60bd97fbrow1_col3 {
#
#                     background-color:  #bddf26;
#
#                 }
#
#                 #T_015c1a40_8750_11e5_a119_a45e60bd97fbrow1_col4 {
#
#                     background-color:  #25838e;
#
#                 }
#
#                 #T_015c1a40_8750_11e5_a119_a45e60bd97fbrow2_col0 {
#
#                     background-color:  #21918c;
#
#                 }
#
#                 #T_015c1a40_8750_11e5_a119_a45e60bd97fbrow2_col1 {
#
#                     background-color:  #440154;
#
#                 }
#
#                 #T_015c1a40_8750_11e5_a119_a45e60bd97fbrow2_col2 {
#
#                     background-color:  #35b779;
#
#                 }
#
#                 #T_015c1a40_8750_11e5_a119_a45e60bd97fbrow2_col3 {
#
#                     background-color:  #fde725;
#
#                 }
#
#                 #T_015c1a40_8750_11e5_a119_a45e60bd97fbrow2_col4 {
#
#                     background-color:  #fde725;
#
#                 }
#
#                 #T_015c1a40_8750_11e5_a119_a45e60bd97fbrow3_col0 {
#
#                     background-color:  #5ec962;
#
#                 }
#
#                 #T_015c1a40_8750_11e5_a119_a45e60bd97fbrow3_col1 {
#
#                     background-color:  #95d840;
#
#                 }
#
#                 #T_015c1a40_8750_11e5_a119_a45e60bd97fbrow3_col2 {
#
#                     background-color:  #26ad81;
#
#                 }
#
#                 #T_015c1a40_8750_11e5_a119_a45e60bd97fbrow3_col3 {
#
#                     background-color:  #440154;
#
#                 }
#
#                 #T_015c1a40_8750_11e5_a119_a45e60bd97fbrow3_col4 {
#
#                     background-color:  #2cb17e;
#
#                 }
#
#                 #T_015c1a40_8750_11e5_a119_a45e60bd97fbrow4_col0 {
#
#                     background-color:  #fde725;
#
#                 }
#
#                 #T_015c1a40_8750_11e5_a119_a45e60bd97fbrow4_col1 {
#
#                     background-color:  #fde725;
#
#                 }
#
#                 #T_015c1a40_8750_11e5_a119_a45e60bd97fbrow4_col2 {
#
#                     background-color:  #fde725;
#
#                 }
#
#                 #T_015c1a40_8750_11e5_a119_a45e60bd97fbrow4_col3 {
#
#                     background-color:  #1f9e89;
#
#                 }
#
#                 #T_015c1a40_8750_11e5_a119_a45e60bd97fbrow4_col4 {
#
#                     background-color:  #1f958b;
#
#                 }
#
#             </style>
#
#             <table id="T_015c1a40_8750_11e5_a119_a45e60bd97fb">
#
#
#             <thead>
#
#                 <tr>
#
#                     <th class="blank">
#
#                     <th class="col_heading level0 col0">A
#
#                     <th class="col_heading level0 col1">B
#
#                     <th class="col_heading level0 col2">C
#
#                     <th class="col_heading level0 col3">D
#
#                     <th class="col_heading level0 col4">E
#
#                 </tr>
#
#             </thead>
#             <tbody>
#
#                 <tr>
#
#                     <th id="T_015c1a40_8750_11e5_a119_a45e60bd97fb" class="row_heading level4 row0">
#
#                             0
#
#
#                     <td id="T_015c1a40_8750_11e5_a119_a45e60bd97fbrow0_col0" class="data row0 col0">
#
#                             1.0
#
#
#                     <td id="T_015c1a40_8750_11e5_a119_a45e60bd97fbrow0_col1" class="data row0 col1">
#
#                             1.329212
#
#
#                     <td id="T_015c1a40_8750_11e5_a119_a45e60bd97fbrow0_col2" class="data row0 col2">
#
#                             nan
#
#
#                     <td id="T_015c1a40_8750_11e5_a119_a45e60bd97fbrow0_col3" class="data row0 col3">
#
#                             -0.31628
#
#
#                     <td id="T_015c1a40_8750_11e5_a119_a45e60bd97fbrow0_col4" class="data row0 col4">
#
#                             -0.99081
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_015c1a40_8750_11e5_a119_a45e60bd97fb" class="row_heading level4 row1">
#
#                             1
#
#
#                     <td id="T_015c1a40_8750_11e5_a119_a45e60bd97fbrow1_col0" class="data row1 col0">
#
#                             2.0
#
#
#                     <td id="T_015c1a40_8750_11e5_a119_a45e60bd97fbrow1_col1" class="data row1 col1">
#
#                             -1.070816
#
#
#                     <td id="T_015c1a40_8750_11e5_a119_a45e60bd97fbrow1_col2" class="data row1 col2">
#
#                             -1.438713
#
#
#                     <td id="T_015c1a40_8750_11e5_a119_a45e60bd97fbrow1_col3" class="data row1 col3">
#
#                             0.564417
#
#
#                     <td id="T_015c1a40_8750_11e5_a119_a45e60bd97fbrow1_col4" class="data row1 col4">
#
#                             0.295722
#
#
#                 </tr>
#
#                 <tr>

# %%
# Compreess the color range
(df.loc[:4]
    .style
    .background_gradient(cmap='viridis', low=.5, high=0)
    .highlight_null('red'))
# Out:
#             <style  type="text/css" >
#
#
#                 #T_019450b8_8750_11e5_a782_a45e60bd97fbrow0_col0 {
#
#                     background-color:  #31688e;
#
#                     : ;
#
#                 }
#
#                 #T_019450b8_8750_11e5_a782_a45e60bd97fbrow0_col1 {
#
#                     background-color:  #efe51c;
#
#                     : ;
#
#                 }
#
#                 #T_019450b8_8750_11e5_a782_a45e60bd97fbrow0_col2 {
#
#                     background-color:  #440154;
#
#                     background-color:  red;
#
#                 }
#
#                 #T_019450b8_8750_11e5_a782_a45e60bd97fbrow0_col3 {
#
#                     background-color:  #277f8e;
#
#                     : ;
#
#                 }
#
#                 #T_019450b8_8750_11e5_a782_a45e60bd97fbrow0_col4 {
#
#                     background-color:  #31688e;
#
#                     : ;
#
#                 }
#
#                 #T_019450b8_8750_11e5_a782_a45e60bd97fbrow1_col0 {
#
#                     background-color:  #21918c;
#
#                     : ;
#
#                 }
#
#                 #T_019450b8_8750_11e5_a782_a45e60bd97fbrow1_col1 {
#
#                     background-color:  #25858e;
#
#                     : ;
#
#                 }
#
#                 #T_019450b8_8750_11e5_a782_a45e60bd97fbrow1_col2 {
#
#                     background-color:  #31688e;
#
#                     : ;
#
#                 }
#
#                 #T_019450b8_8750_11e5_a782_a45e60bd97fbrow1_col3 {
#
#                     background-color:  #d5e21a;
#
#                     : ;
#
#                 }
#
#                 #T_019450b8_8750_11e5_a782_a45e60bd97fbrow1_col4 {
#
#                     background-color:  #29af7f;
#
#                     : ;
#
#                 }
#
#                 #T_019450b8_8750_11e5_a782_a45e60bd97fbrow2_col0 {
#
#                     background-color:  #35b779;
#
#                     : ;
#
#                 }
#
#                 #T_019450b8_8750_11e5_a782_a45e60bd97fbrow2_col1 {
#
#                     background-color:  #31688e;
#
#                     : ;
#
#                 }
#
#                 #T_019450b8_8750_11e5_a782_a45e60bd97fbrow2_col2 {
#
#                     background-color:  #6ccd5a;
#
#                     : ;
#
#                 }
#
#                 #T_019450b8_8750_11e5_a782_a45e60bd97fbrow2_col3 {
#
#                     background-color:  #fde725;
#
#                     : ;
#
#                 }
#
#                 #T_019450b8_8750_11e5_a782_a45e60bd97fbrow2_col4 {
#
#                     background-color:  #fde725;
#
#                     : ;
#
#                 }
#
#                 #T_019450b8_8750_11e5_a782_a45e60bd97fbrow3_col0 {
#
#                     background-color:  #90d743;
#
#                     : ;
#
#                 }
#
#                 #T_019450b8_8750_11e5_a782_a45e60bd97fbrow3_col1 {
#
#                     background-color:  #b8de29;
#
#                     : ;
#
#                 }
#
#                 #T_019450b8_8750_11e5_a782_a45e60bd97fbrow3_col2 {
#
#                     background-color:  #5ac864;
#
#                     : ;
#
#                 }
#
#                 #T_019450b8_8750_11e5_a782_a45e60bd97fbrow3_col3 {
#
#                     background-color:  #31688e;
#
#                     : ;
#
#                 }
#
#                 #T_019450b8_8750_11e5_a782_a45e60bd97fbrow3_col4 {
#
#                     background-color:  #63cb5f;
#
#                     : ;
#
#                 }
#
#                 #T_019450b8_8750_11e5_a782_a45e60bd97fbrow4_col0 {
#
#                     background-color:  #fde725;
#
#                     : ;
#
#                 }
#
#                 #T_019450b8_8750_11e5_a782_a45e60bd97fbrow4_col1 {
#
#                     background-color:  #fde725;
#
#                     : ;
#
#                 }
#
#                 #T_019450b8_8750_11e5_a782_a45e60bd97fbrow4_col2 {
#
#                     background-color:  #fde725;
#
#                     : ;
#
#                 }
#
#                 #T_019450b8_8750_11e5_a782_a45e60bd97fbrow4_col3 {
#
#                     background-color:  #46c06f;
#
#                     : ;
#
#                 }
#
#                 #T_019450b8_8750_11e5_a782_a45e60bd97fbrow4_col4 {
#
#                     background-color:  #3bbb75;
#
#                     : ;
#
#                 }
#
#             </style>
#
#             <table id="T_019450b8_8750_11e5_a782_a45e60bd97fb">
#
#
#             <thead>
#
#                 <tr>
#
#                     <th class="blank">
#
#                     <th class="col_heading level0 col0">A
#
#                     <th class="col_heading level0 col1">B
#
#                     <th class="col_heading level0 col2">C
#
#                     <th class="col_heading level0 col3">D
#
#                     <th class="col_heading level0 col4">E
#
#                 </tr>
#
#             </thead>
#             <tbody>
#
#                 <tr>
#
#                     <th id="T_019450b8_8750_11e5_a782_a45e60bd97fb" class="row_heading level4 row0">
#
#                             0
#
#
#                     <td id="T_019450b8_8750_11e5_a782_a45e60bd97fbrow0_col0" class="data row0 col0">
#
#                             1.0
#
#
#                     <td id="T_019450b8_8750_11e5_a782_a45e60bd97fbrow0_col1" class="data row0 col1">
#
#                             1.329212
#
#
#                     <td id="T_019450b8_8750_11e5_a782_a45e60bd97fbrow0_col2" class="data row0 col2">
#
#                             nan
#
#
#                     <td id="T_019450b8_8750_11e5_a782_a45e60bd97fbrow0_col3" class="data row0 col3">
#
#                             -0.31628
#
#
#                     <td id="T_019450b8_8750_11e5_a782_a45e60bd97fbrow0_col4" class="data row0 col4">
#
#                             -0.99081
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_019450b8_8750_11e5_a782_a45e60bd97fb" class="row_heading level4 row1">
#
#                             1
#
#
#                     <td id="T_019450b8_8750_11e5_a782_a45e60bd97fbrow1_col0" class="data row1 col

# %% [markdown]
# You got your barchart in my DataFrame!

# %%
df.style.bar(subset=['A', 'B'], color='#7F7FFF')
# Out:
#             <style  type="text/css" >
#
#
#                 #T_02155bb0_8750_11e5_b381_a45e60bd97fbrow0_col0 {
#
#                     width:  10em;
#
#                      height:  80%;
#
#                     background:  linear-gradient(90deg,#7F7FFF 0.0%, transparent 0%);
#
#                 }
#
#                 #T_02155bb0_8750_11e5_b381_a45e60bd97fbrow0_col1 {
#
#                     width:  10em;
#
#                      height:  80%;
#
#                     background:  linear-gradient(90deg,#7F7FFF 89.21303639960456%, transparent 0%);
#
#                 }
#
#                 #T_02155bb0_8750_11e5_b381_a45e60bd97fbrow1_col0 {
#
#                     width:  10em;
#
#                      height:  80%;
#
#                     background:  linear-gradient(90deg,#7F7FFF 11.11111111111111%, transparent 0%);
#
#                 }
#
#                 #T_02155bb0_8750_11e5_b381_a45e60bd97fbrow1_col1 {
#
#                     width:  10em;
#
#                      height:  80%;
#
#                     background:  linear-gradient(90deg,#7F7FFF 16.77000113307442%, transparent 0%);
#
#                 }
#
#                 #T_02155bb0_8750_11e5_b381_a45e60bd97fbrow2_col0 {
#
#                     width:  10em;
#
#                      height:  80%;
#
#                     background:  linear-gradient(90deg,#7F7FFF 22.22222222222222%, transparent 0%);
#
#                 }
#
#                 #T_02155bb0_8750_11e5_b381_a45e60bd97fbrow2_col1 {
#
#                     width:  10em;
#
#                      height:  80%;
#
#                     background:  linear-gradient(90deg,#7F7FFF 0.0%, transparent 0%);
#
#                 }
#
#                 #T_02155bb0_8750_11e5_b381_a45e60bd97fbrow3_col0 {
#
#                     width:  10em;
#
#                      height:  80%;
#
#                     background:  linear-gradient(90deg,#7F7FFF 33.333333333333336%, transparent 0%);
#
#                 }
#
#                 #T_02155bb0_8750_11e5_b381_a45e60bd97fbrow3_col1 {
#
#                     width:  10em;
#
#                      height:  80%;
#
#                     background:  linear-gradient(90deg,#7F7FFF 78.1150827834652%, transparent 0%);
#
#                 }
#
#                 #T_02155bb0_8750_11e5_b381_a45e60bd97fbrow4_col0 {
#
#                     width:  10em;
#
#                      height:  80%;
#
#                     background:  linear-gradient(90deg,#7F7FFF 44.44444444444444%, transparent 0%);
#
#                 }
#
#                 #T_02155bb0_8750_11e5_b381_a45e60bd97fbrow4_col1 {
#
#                     width:  10em;
#
#                      height:  80%;
#
#                     background:  linear-gradient(90deg,#7F7FFF 92.96229618327422%, transparent 0%);
#
#                 }
#
#                 #T_02155bb0_8750_11e5_b381_a45e60bd97fbrow5_col0 {
#
#                     width:  10em;
#
#                      height:  80%;
#
#                     background:  linear-gradient(90deg,#7F7FFF 55.55555555555556%, transparent 0%);
#
#                 }
#
#                 #T_02155bb0_8750_11e5_b381_a45e60bd97fbrow5_col1 {
#
#                     width:  10em;
#
#                      height:  80%;
#
#                     background:  linear-gradient(90deg,#7F7FFF 8.737388253449494%, transparent 0%);
#
#                 }
#
#                 #T_02155bb0_8750_11e5_b381_a45e60bd97fbrow6_col0 {
#
#                     width:  10em;
#
#                      height:  80%;
#
#                     background:  linear-gradient(90deg,#7F7FFF 66.66666666666667%, transparent 0%);
#
#                 }
#
#                 #T_02155bb0_8750_11e5_b381_a45e60bd97fbrow6_col1 {
#
#                     width:  10em;
#
#                      height:  80%;
#
#                     background:  linear-gradient(90deg,#7F7FFF 52.764243600289866%, transparent 0%);
#
#                 }
#
#                 #T_02155bb0_8750_11e5_b381_a45e60bd97fbrow7_col0 {
#
#                     width:  10em;
#
#                      height:  80%;
#
#                     background:  linear-gradient(90deg,#7F7FFF 77.77777777777777%, transparent 0%);
#
#                 }
#
#                 #T_02155bb0_8750_11e5_b381_a45e60bd97fbrow7_col1 {
#
#                     width:  10em;
#
#                      height:  80%;
#
#                     background:  linear-gradient(90deg,#7F7FFF 59.79187201238315%, transparent 0%);
#
#                 }
#
#                 #T_02155bb0_8750_11e5_b381_a45e60bd97fbrow8_col0 {
#
#                     width:  10em;
#
#                      height:  80%;
#
#                     background:  linear-gradient(90deg,#7F7FFF 88.88888888888889%, transparent 0%);
#
#                 }
#
#                 #T_02155bb0_8750_11e5_b381_a45e60bd97fbrow8_col1 {
#
#                     width:  10em;
#
#                      height:  80%;
#
#                     background:  linear-gradient(90deg,#7F7FFF 100.00000000000001%, transparent 0%);
#
#                 }
#
#                 #T_02155bb0_8750_11e5_b381_a45e60bd97fbrow9_col0 {
#
#                     width:  10em;
#
#                      height:  80%;
#
#                     background:  linear-gradient(90deg,#7F7FFF 100.0%, transparent 0%);
#
#                 }
#
#                 #T_02155bb0_8750_11e5_b381_a45e60bd97fbrow9_col1 {
#
#                     width:  10em;
#
#                      height:  80%;
#
#                     background:  linear-gradient(90deg,#7F7FFF 45.17326030334935%, transparent 0%);
#
#                 }
#
#             </style>
#
#             <table id="T_02155bb0_8750_11e5_b381_a45e60bd97fb">
#
#
#             <thead>
#
#                 <tr>
#
#                     <th class="blank">
#
#                     <th class="col_heading level0 col0">A
#
#                     <th class="col_heading level0 col1">B
#
#                     <th class="col_heading level0 col2">C
#
#                     <th class="col_heading level0 col3">D
#
#                     <th class="col_heading level0 col4">E
#
#                 </tr>
#
#             </thead>
#             <tbody>
#
#                 <tr>
#
#                     <th id="T_02155bb0_8750_11e5_b381_a45e60bd97fb" class="row_heading level4 row0">
#
#                             0
#
#
#                     <td id="T_02155bb0_8750_11e5_b381_a45e60bd97fbrow0_col0" class="data row0 col0">
#
#                             1.0
#
#
#                     <td id="T_02155bb0_8750_11e5_b381_a45e60bd97fbrow0_col1" class="data row0

# %% [markdown]
# Use `Styler.set_properties` when the style doesn't actually depend on the values.

# %%
df.style.set_properties(**{'background-color': 'black',
                           'color': 'lawngreen',
                           'border-color': 'white'})
# Out:
#             <style  type="text/css" >
#
#
#                 #T_02a564c8_8750_11e5_a0c0_a45e60bd97fbrow0_col0 {
#
#                     color:  lawngreen;
#
#                     background-color:  black;
#
#                     border-color:  white;
#
#                 }
#
#                 #T_02a564c8_8750_11e5_a0c0_a45e60bd97fbrow0_col1 {
#
#                     color:  lawngreen;
#
#                     background-color:  black;
#
#                     border-color:  white;
#
#                 }
#
#                 #T_02a564c8_8750_11e5_a0c0_a45e60bd97fbrow0_col2 {
#
#                     color:  lawngreen;
#
#                     background-color:  black;
#
#                     border-color:  white;
#
#                 }
#
#                 #T_02a564c8_8750_11e5_a0c0_a45e60bd97fbrow0_col3 {
#
#                     color:  lawngreen;
#
#                     background-color:  black;
#
#                     border-color:  white;
#
#                 }
#
#                 #T_02a564c8_8750_11e5_a0c0_a45e60bd97fbrow0_col4 {
#
#                     color:  lawngreen;
#
#                     background-color:  black;
#
#                     border-color:  white;
#
#                 }
#
#                 #T_02a564c8_8750_11e5_a0c0_a45e60bd97fbrow1_col0 {
#
#                     color:  lawngreen;
#
#                     background-color:  black;
#
#                     border-color:  white;
#
#                 }
#
#                 #T_02a564c8_8750_11e5_a0c0_a45e60bd97fbrow1_col1 {
#
#                     color:  lawngreen;
#
#                     background-color:  black;
#
#                     border-color:  white;
#
#                 }
#
#                 #T_02a564c8_8750_11e5_a0c0_a45e60bd97fbrow1_col2 {
#
#                     color:  lawngreen;
#
#                     background-color:  black;
#
#                     border-color:  white;
#
#                 }
#
#                 #T_02a564c8_8750_11e5_a0c0_a45e60bd97fbrow1_col3 {
#
#                     color:  lawngreen;
#
#                     background-color:  black;
#
#                     border-color:  white;
#
#                 }
#
#                 #T_02a564c8_8750_11e5_a0c0_a45e60bd97fbrow1_col4 {
#
#                     color:  lawngreen;
#
#                     background-color:  black;
#
#                     border-color:  white;
#
#                 }
#
#                 #T_02a564c8_8750_11e5_a0c0_a45e60bd97fbrow2_col0 {
#
#                     color:  lawngreen;
#
#                     background-color:  black;
#
#                     border-color:  white;
#
#                 }
#
#                 #T_02a564c8_8750_11e5_a0c0_a45e60bd97fbrow2_col1 {
#
#                     color:  lawngreen;
#
#                     background-color:  black;
#
#                     border-color:  white;
#
#                 }
#
#                 #T_02a564c8_8750_11e5_a0c0_a45e60bd97fbrow2_col2 {
#
#                     color:  lawngreen;
#
#                     background-color:  black;
#
#                     border-color:  white;
#
#                 }
#
#                 #T_02a564c8_8750_11e5_a0c0_a45e60bd97fbrow2_col3 {
#
#                     color:  lawngreen;
#
#                     background-color:  black;
#
#                     border-color:  white;
#
#                 }
#
#                 #T_02a564c8_8750_11e5_a0c0_a45e60bd97fbrow2_col4 {
#
#                     color:  lawngreen;
#
#                     background-color:  black;
#
#                     border-color:  white;
#
#                 }
#
#                 #T_02a564c8_8750_11e5_a0c0_a45e60bd97fbrow3_col0 {
#
#                     color:  lawngreen;
#
#                     background-color:  black;
#
#                     border-color:  white;
#
#                 }
#
#                 #T_02a564c8_8750_11e5_a0c0_a45e60bd97fbrow3_col1 {
#
#                     color:  lawngreen;
#
#                     background-color:  black;
#
#                     border-color:  white;
#
#                 }
#
#                 #T_02a564c8_8750_11e5_a0c0_a45e60bd97fbrow3_col2 {
#
#                     color:  lawngreen;
#
#                     background-color:  black;
#
#                     border-color:  white;
#
#                 }
#
#                 #T_02a564c8_8750_11e5_a0c0_a45e60bd97fbrow3_col3 {
#
#                     color:  lawngreen;
#
#                     background-color:  black;
#
#                     border-color:  white;
#
#                 }
#
#                 #T_02a564c8_8750_11e5_a0c0_a45e60bd97fbrow3_col4 {
#
#                     color:  lawngreen;
#
#                     background-color:  black;
#
#                     border-color:  white;
#
#                 }
#
#                 #T_02a564c8_8750_11e5_a0c0_a45e60bd97fbrow4_col0 {
#
#                     color:  lawngreen;
#
#                     background-color:  black;
#
#                     border-color:  white;
#
#                 }
#
#                 #T_02a564c8_8750_11e5_a0c0_a45e60bd97fbrow4_col1 {
#
#                     color:  lawngreen;
#
#                     background-color:  black;
#
#                     border-color:  white;
#
#                 }
#
#                 #T_02a564c8_8750_11e5_a0c0_a45e60bd97fbrow4_col2 {
#
#                     color:  lawngreen;
#
#                     background-color:  black;
#
#                     border-color:  white;
#
#                 }
#
#                 #T_02a564c8_8750_11e5_a0c0_a45e60bd97fbrow4_col3 {
#
#                     color:  lawngreen;
#
#                     background-color:  black;
#
#                     border-color:  white;
#
#                 }
#
#                 #T_02a564c8_8750_11e5_a0c0_a45e60bd97fbrow4_col4 {
#
#                     color:  lawngreen;
#
#                     background-color:  black;
#
#                     border-color:  white;
#
#                 }
#
#                 #T_02a564c8_8750_11e5_a0c0_a45e60bd97fbrow5_col0 {
#
#                     color:  lawngreen;
#
#                     background-color:  black;
#
#                     border-color:  white;
#
#                 }
#
#                 #T_02a564c8_8750_11e5_a0c0_a45e60bd97fbrow5_col1 {
#
#                     color:  lawngreen;
#
#                     background-color:  black;
#
#                     border-color:  white;
#
#                 }
#
#                 #T_02a56

# %% [markdown]
# ## Other options
#
# You've seen a few methods for data-driven styling.
# `Styler` also provides a few other options for styling that don't depend on the data.
#
# - precision
# - captions
# - table-wide styles
#
# Each of these can be specified in three ways:
#
# - A keyword argument to `pandas.core.Styler`
# - A keyword argument to `.render`
# - A call to one of the `.set_` methods, e.g. `.set_caption`
#
# The best method to use depends on the context. Use the `Styler` constructor when building many styled DataFrames that should all share the same properties. For interactive use, `.render` or `.set_` are more convinient.

# %% [markdown]
# ## Precision

# %% [markdown]
# You can control the precision of floats using pandas' regular `display.precision` option.

# %%
with pd.option_context('display.precision', 2):
    html = (df.style
              .applymap(color_negative_red)
              .apply(highlight_max))
html
# Out:
#             <style  type="text/css" >
#
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow0_col0 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow0_col1 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow0_col2 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow0_col3 {
#
#                     color:  red;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow0_col4 {
#
#                     color:  red;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow1_col0 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow1_col1 {
#
#                     color:  red;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow1_col2 {
#
#                     color:  red;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow1_col3 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow1_col4 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow2_col0 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow2_col1 {
#
#                     color:  red;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow2_col2 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow2_col3 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow2_col4 {
#
#                     color:  black;
#
#                     background-color:  yellow;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow3_col0 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow3_col1 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow3_col2 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow3_col3 {
#
#                     color:  red;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow3_col4 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow4_col0 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow4_col1 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow4_col2 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow4_col3 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow4_col4 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow5_col0 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow5_col1 {
#
#                     color:  red;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow5_col2 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow5_col3 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow5_col4 {
#
#                     color:  red;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow6_col0 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow6_col1 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow6_col2 {
#
#                     color:  black;
#
#                     background-color:  yellow;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow6_col3 {
#
#                     color:  red;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow6_col4 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow7_col0 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow7_col1 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9a9a7e1e_8759_11e5_8561_a45e60bd97fbrow7_col2 {
#
#                     color:  black;
#
#                     : ;
#
#                 }

# %% [markdown]
# Or through a `set_precision` method.

# %%
df.style\
  .applymap(color_negative_red)\
  .apply(highlight_max)\
  .set_precision(2)
# Out:
#             <style  type="text/css" >
#
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow0_col0 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow0_col1 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow0_col2 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow0_col3 {
#
#                     color:  red;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow0_col4 {
#
#                     color:  red;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow1_col0 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow1_col1 {
#
#                     color:  red;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow1_col2 {
#
#                     color:  red;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow1_col3 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow1_col4 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow2_col0 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow2_col1 {
#
#                     color:  red;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow2_col2 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow2_col3 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow2_col4 {
#
#                     color:  black;
#
#                     background-color:  yellow;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow3_col0 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow3_col1 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow3_col2 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow3_col3 {
#
#                     color:  red;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow3_col4 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow4_col0 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow4_col1 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow4_col2 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow4_col3 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow4_col4 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow5_col0 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow5_col1 {
#
#                     color:  red;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow5_col2 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow5_col3 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow5_col4 {
#
#                     color:  red;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow6_col0 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow6_col1 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow6_col2 {
#
#                     color:  black;
#
#                     background-color:  yellow;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow6_col3 {
#
#                     color:  red;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow6_col4 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow7_col0 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow7_col1 {
#
#                     color:  black;
#
#                     : ;
#
#                 }
#
#                 #T_9c446524_8759_11e5_9237_a45e60bd97fbrow7_col2 {
#
#                     color:  black;
#
#                     : ;
#
#                 }

# %% [markdown]
# Setting the precision only affects the printed number; the full-precision values are always passed to your style functions. You can always use `df.round(2).style` if you'd prefer to round from the start.

# %% [markdown]
# ### Captions

# %%
from pandas.core.style import Styler
s = Styler(df, caption='Colormaps, with a caption.')
s.background_gradient(cmap=cm)
# Out:
#             <style  type="text/css" >
#
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow0_col0 {
#
#                     background-color:  #e5ffe5;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow0_col1 {
#
#                     background-color:  #188d18;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow0_col2 {
#
#                     background-color:  #e5ffe5;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow0_col3 {
#
#                     background-color:  #c7eec7;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow0_col4 {
#
#                     background-color:  #a6dca6;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow1_col0 {
#
#                     background-color:  #ccf1cc;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow1_col1 {
#
#                     background-color:  #c0eac0;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow1_col2 {
#
#                     background-color:  #e5ffe5;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow1_col3 {
#
#                     background-color:  #62b662;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow1_col4 {
#
#                     background-color:  #5cb35c;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow2_col0 {
#
#                     background-color:  #b3e3b3;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow2_col1 {
#
#                     background-color:  #e5ffe5;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow2_col2 {
#
#                     background-color:  #56af56;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow2_col3 {
#
#                     background-color:  #56af56;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow2_col4 {
#
#                     background-color:  #008000;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow3_col0 {
#
#                     background-color:  #99d599;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow3_col1 {
#
#                     background-color:  #329c32;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow3_col2 {
#
#                     background-color:  #5fb55f;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow3_col3 {
#
#                     background-color:  #daf9da;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow3_col4 {
#
#                     background-color:  #3ba13b;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow4_col0 {
#
#                     background-color:  #80c780;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow4_col1 {
#
#                     background-color:  #108910;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow4_col2 {
#
#                     background-color:  #0d870d;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow4_col3 {
#
#                     background-color:  #90d090;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow4_col4 {
#
#                     background-color:  #4fac4f;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow5_col0 {
#
#                     background-color:  #66b866;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow5_col1 {
#
#                     background-color:  #d2f4d2;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow5_col2 {
#
#                     background-color:  #389f38;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow5_col3 {
#
#                     background-color:  #048204;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow5_col4 {
#
#                     background-color:  #70be70;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow6_col0 {
#
#                     background-color:  #4daa4d;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow6_col1 {
#
#                     background-color:  #6cbc6c;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow6_col2 {
#
#                     background-color:  #008000;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow6_col3 {
#
#                     background-color:  #a3daa3;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow6_col4 {
#
#                     background-color:  #0e880e;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow7_col0 {
#
#                     background-color:  #329c32;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow7_col1 {
#
#                     background-color:  #5cb35c;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow7_col2 {
#
#                     background-color:  #0e880e;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow7_col3 {
#
#                     background-color:  #cff3cf;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow7_col4 {
#
#                     background-color:  #4fac4f;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow8_col0 {
#
#                     background-color:  #198e19;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow8_col1 {
#
#                     background-color:  #008000;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow8_col2 {
#
#                     background-color:  #dcfadc;
#
#                 }
#
#                 #T_ac4e2ed2_8759_11e5_be4f_a45e60bd97fbrow8_col3 {
#
#                     background-color:  #008000;
#
#                 }

# %% [markdown]
# Alternativly, pass the caption in when rendering.

# %%
from IPython.display import HTML
HTML(
    df.style.background_gradient(cmap=cm).render(caption="Caption, from render.")
)
# Out:
#             <style  type="text/css" >
#
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow0_col0 {
#
#                     background-color:  #e5ffe5;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow0_col1 {
#
#                     background-color:  #188d18;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow0_col2 {
#
#                     background-color:  #e5ffe5;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow0_col3 {
#
#                     background-color:  #c7eec7;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow0_col4 {
#
#                     background-color:  #a6dca6;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow1_col0 {
#
#                     background-color:  #ccf1cc;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow1_col1 {
#
#                     background-color:  #c0eac0;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow1_col2 {
#
#                     background-color:  #e5ffe5;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow1_col3 {
#
#                     background-color:  #62b662;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow1_col4 {
#
#                     background-color:  #5cb35c;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow2_col0 {
#
#                     background-color:  #b3e3b3;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow2_col1 {
#
#                     background-color:  #e5ffe5;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow2_col2 {
#
#                     background-color:  #56af56;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow2_col3 {
#
#                     background-color:  #56af56;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow2_col4 {
#
#                     background-color:  #008000;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow3_col0 {
#
#                     background-color:  #99d599;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow3_col1 {
#
#                     background-color:  #329c32;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow3_col2 {
#
#                     background-color:  #5fb55f;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow3_col3 {
#
#                     background-color:  #daf9da;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow3_col4 {
#
#                     background-color:  #3ba13b;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow4_col0 {
#
#                     background-color:  #80c780;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow4_col1 {
#
#                     background-color:  #108910;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow4_col2 {
#
#                     background-color:  #0d870d;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow4_col3 {
#
#                     background-color:  #90d090;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow4_col4 {
#
#                     background-color:  #4fac4f;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow5_col0 {
#
#                     background-color:  #66b866;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow5_col1 {
#
#                     background-color:  #d2f4d2;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow5_col2 {
#
#                     background-color:  #389f38;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow5_col3 {
#
#                     background-color:  #048204;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow5_col4 {
#
#                     background-color:  #70be70;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow6_col0 {
#
#                     background-color:  #4daa4d;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow6_col1 {
#
#                     background-color:  #6cbc6c;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow6_col2 {
#
#                     background-color:  #008000;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow6_col3 {
#
#                     background-color:  #a3daa3;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow6_col4 {
#
#                     background-color:  #0e880e;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow7_col0 {
#
#                     background-color:  #329c32;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow7_col1 {
#
#                     background-color:  #5cb35c;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow7_col2 {
#
#                     background-color:  #0e880e;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow7_col3 {
#
#                     background-color:  #cff3cf;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow7_col4 {
#
#                     background-color:  #4fac4f;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow8_col0 {
#
#                     background-color:  #198e19;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow8_col1 {
#
#                     background-color:  #008000;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow8_col2 {
#
#                     background-color:  #dcfadc;
#
#                 }
#
#                 #T_e3e7d14a_8759_11e5_b63d_a45e60bd97fbrow8_col3 {
#
#                     background-color:  #008000;
#
#                 }

# %% [markdown]
# ### Table Styles

# %% [markdown]
# The next option you have are "table styles".
# These are styles that apply to the table as a whole, and don't look at the data.
# Certain sytlings, including pseudo-selectors like `:hover` can only be used this way.

# %%
def hover(hover_color="#ffff99"):
    return dict(selector="tr:hover",
                props=[("background-color", "%s" % hover_color)])

styles = [
    hover(),
    dict(selector="th", props=[("font-size", "150%"),
                               ("text-align", "center")]),
    dict(selector="caption", props=[("caption-side", "bottom")])
]
html = df.style.render(table_styles=styles, caption="Hover to highlight.")
HTML(html)
# Out:
#             <style  type="text/css" >
#
#                 #T_7f5b2122_875a_11e5_95a7_a45e60bd97fb tr:hover {
#
#                     background-color: #ffff99;
#
#                 }
#
#                 #T_7f5b2122_875a_11e5_95a7_a45e60bd97fb th {
#
#                     font-size: 150%;
#
#                     text-align: center;
#
#                 }
#
#                 #T_7f5b2122_875a_11e5_95a7_a45e60bd97fb caption {
#
#                     caption-side: bottom;
#
#                 }
#
#
#             </style>
#
#             <table id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fb">
#
#                 <caption>Hover to highlight.</caption>
#
#
#             <thead>
#
#                 <tr>
#
#                     <th class="blank">
#
#                     <th class="col_heading level0 col0">A
#
#                     <th class="col_heading level0 col1">B
#
#                     <th class="col_heading level0 col2">C
#
#                     <th class="col_heading level0 col3">D
#
#                     <th class="col_heading level0 col4">E
#
#                 </tr>
#
#             </thead>
#             <tbody>
#
#                 <tr>
#
#                     <th id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fb" class="row_heading level4 row0">
#
#                             0
#
#
#                     <td id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fbrow0_col0" class="data row0 col0">
#
#                             1.0
#
#
#                     <td id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fbrow0_col1" class="data row0 col1">
#
#                             1.329212
#
#
#                     <td id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fbrow0_col2" class="data row0 col2">
#
#                             nan
#
#
#                     <td id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fbrow0_col3" class="data row0 col3">
#
#                             -0.31628
#
#
#                     <td id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fbrow0_col4" class="data row0 col4">
#
#                             -0.99081
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fb" class="row_heading level4 row1">
#
#                             1
#
#
#                     <td id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fbrow1_col0" class="data row1 col0">
#
#                             2.0
#
#
#                     <td id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fbrow1_col1" class="data row1 col1">
#
#                             -1.070816
#
#
#                     <td id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fbrow1_col2" class="data row1 col2">
#
#                             -1.438713
#
#
#                     <td id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fbrow1_col3" class="data row1 col3">
#
#                             0.564417
#
#
#                     <td id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fbrow1_col4" class="data row1 col4">
#
#                             0.295722
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fb" class="row_heading level4 row2">
#
#                             2
#
#
#                     <td id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fbrow2_col0" class="data row2 col0">
#
#                             3.0
#
#
#                     <td id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fbrow2_col1" class="data row2 col1">
#
#                             -1.626404
#
#
#                     <td id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fbrow2_col2" class="data row2 col2">
#
#                             0.219565
#
#
#                     <td id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fbrow2_col3" class="data row2 col3">
#
#                             0.678805
#
#
#                     <td id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fbrow2_col4" class="data row2 col4">
#
#                             1.889273
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fb" class="row_heading level4 row3">
#
#                             3
#
#
#                     <td id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fbrow3_col0" class="data row3 col0">
#
#                             4.0
#
#
#                     <td id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fbrow3_col1" class="data row3 col1">
#
#                             0.961538
#
#
#                     <td id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fbrow3_col2" class="data row3 col2">
#
#                             0.104011
#
#
#                     <td id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fbrow3_col3" class="data row3 col3">
#
#                             -0.481165
#
#
#                     <td id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fbrow3_col4" class="data row3 col4">
#
#                             0.850229
#
#
#                 </tr>
#
#                 <tr>
#
#                     <th id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fb" class="row_heading level4 row4">
#
#                             4
#
#
#                     <td id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fbrow4_col0" class="data row4 col0">
#
#                             5.0
#
#
#                     <td id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fbrow4_col1" class="data row4 col1">
#
#                             1.453425
#
#
#                     <td id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fbrow4_col2" class="data row4 col2">
#
#                             1.057737
#
#
#                     <td id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fbrow4_col3" class="data row4 col3">
#
#                             0.165562
#
#
#                     <td id="T_7f5b2122_875a_11e5_95a7_a45e60bd97fbrow4_col4" class="data row4 col4">
#
#                             0.515018

# %% [markdown]
# `table_styles` should be a list of dictionaries.
# Each dictionary should have the `selector` and `props` keys.
# The value for `selector` should be a valid CSS selector.
# Recall that all the styles already attached to an `id`, unique to
# each `Styler`. This selector is in addition to that `id`.
# The value for `props` should be a list of tuples of `('attribute', 'value')`.
#
# `table_styles` are extremely flexible, but not as fun to type out by hand.
# We hope to collect some useful ones either in pandas, or preferable in a new package that [builds on top](#Extensibility) the tools here.

# %% [markdown]
# # Limitations
#
# - DataFrame only `(use Series.to_frame().style)`
# - The index and columns must be unique
# - No large repr, and performance isn't great; this is intended for summary DataFrames
# - You can only style the *values*, not the index or columns
# - You can only apply styles, you can't insert new HTML entities
#
# Some of these will be addressed in the future.

# %% [markdown]
# # Extensibility
#
# The core of pandas is, and will remain, its "high-performance, easy-to-use data structures".
# With that in mind, we hope that `DataFrame.style` accomplishes two goals
#
# - Provide an API that is pleasing to use interactively and is "good enough" for many tasks
# - Provide the foundations for dedicated libraries to build on
#
# If you build a great library on top of this, let us know and we'll [link](http://pandas.pydata.org/pandas-docs/stable/ecosystem.html) to it.
#
# ## Subclassing
#
# This section contains a bit of information about the implementation of `Styler`.
# Since the feature is so new all of this is subject to change, even more so than the end-use API.
#
# As users apply styles (via `.apply`, `.applymap`), we modify an internal `defaultdict(list)` called `self.ctx`.
# This maps `(row_position, col_position)` to a list of (for CSS) `'attribute: value'` strings.
# Every call to `.apply` or `.applymap` or one of the builtin stylers should update `self.ctx` and return `self` so that the chain can continue.
#
# Rendering uses [Jinja](http://jinja.pocoo.org/) templates.
# The `.translate` method takes `self.ctx` and builds another dictionary ready to be passed into `Styler.template.render`, the Jinja template.
#
#
# ## Alternate templates
#
# We've used [Jinja](http://jinja.pocoo.org/) templates to build up the HTML.
# The template is stored as a class variable ``Styler.template.``. Subclasses can override that.
#
# ```python
# class CustomStyle(Styler):
#     template = Template("""...""")
# ```

# %% [markdown]
# ## Fun stuff

# %%
# https://developer.mozilla.org/en-US/docs/Web/CSS/animation#Cylon_Eye
# no animation yet :(

def cylon(s):
    tpl = """
  background-color: red;
  background-image: -webkit-linear-gradient(    left, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
  background-image:    -moz-linear-gradient(    left, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
  background-image:      -o-linear-gradient(    left, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
  background-image:         linear-gradient(to right, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
  color: white;
  height: 100%;
  width: 20"""
    return pd.Series([tpl for i in s], index=s.index, name=s.name)

# %%
df.style.apply(cylon)
# Out:
#             <style  type="text/css" >
#
#
#                 #T_afcf4fb6_8644_11e5_b381_a45e60bd97fbrow0_col0 {
#
#
#   background-color:  red;
#
#
#   background-image:  -webkit-linear-gradient(    left, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   background-image:     -moz-linear-gradient(    left, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   background-image:       -o-linear-gradient(    left, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   background-image:          linear-gradient(to right, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   color:  white;
#
#
#   height:  100%;
#
#
#   width:  20;
#
#                 }
#
#                 #T_afcf4fb6_8644_11e5_b381_a45e60bd97fbrow0_col1 {
#
#
#   background-color:  red;
#
#
#   background-image:  -webkit-linear-gradient(    left, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   background-image:     -moz-linear-gradient(    left, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   background-image:       -o-linear-gradient(    left, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   background-image:          linear-gradient(to right, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   color:  white;
#
#
#   height:  100%;
#
#
#   width:  20;
#
#                 }
#
#                 #T_afcf4fb6_8644_11e5_b381_a45e60bd97fbrow0_col2 {
#
#
#   background-color:  red;
#
#
#   background-image:  -webkit-linear-gradient(    left, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   background-image:     -moz-linear-gradient(    left, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   background-image:       -o-linear-gradient(    left, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   background-image:          linear-gradient(to right, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   color:  white;
#
#
#   height:  100%;
#
#
#   width:  20;
#
#                 }
#
#                 #T_afcf4fb6_8644_11e5_b381_a45e60bd97fbrow0_col3 {
#
#
#   background-color:  red;
#
#
#   background-image:  -webkit-linear-gradient(    left, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   background-image:     -moz-linear-gradient(    left, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   background-image:       -o-linear-gradient(    left, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   background-image:          linear-gradient(to right, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   color:  white;
#
#
#   height:  100%;
#
#
#   width:  20;
#
#                 }
#
#                 #T_afcf4fb6_8644_11e5_b381_a45e60bd97fbrow0_col4 {
#
#
#   background-color:  red;
#
#
#   background-image:  -webkit-linear-gradient(    left, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   background-image:     -moz-linear-gradient(    left, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   background-image:       -o-linear-gradient(    left, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   background-image:          linear-gradient(to right, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   color:  white;
#
#
#   height:  100%;
#
#
#   width:  20;
#
#                 }
#
#                 #T_afcf4fb6_8644_11e5_b381_a45e60bd97fbrow1_col0 {
#
#
#   background-color:  red;
#
#
#   background-image:  -webkit-linear-gradient(    left, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   background-image:     -moz-linear-gradient(    left, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   background-image:       -o-linear-gradient(    left, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   background-image:          linear-gradient(to right, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   color:  white;
#
#
#   height:  100%;
#
#
#   width:  20;
#
#                 }
#
#                 #T_afcf4fb6_8644_11e5_b381_a45e60bd97fbrow1_col1 {
#
#
#   background-color:  red;
#
#
#   background-image:  -webkit-linear-gradient(    left, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   background-image:     -moz-linear-gradient(    left, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   background-image:       -o-linear-gradient(    left, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   background-image:          linear-gradient(to right, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   color:  white;
#
#
#   height:  100%;
#
#
#   width:  20;
#
#                 }
#
#                 #T_afcf4fb6_8644_11e5_b381_a45e60bd97fbrow1_col2 {
#
#
#   background-color:  red;
#
#
#   background-image:  -webkit-linear-gradient(    left, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   background-image:     -moz-linear-gradient(    left, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   background-image:       -o-linear-gradient(    left, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   background-image:          linear-gradient(to right, rgba( 0,0,0,0.9 ) 25%, rgba( 0,0,0,0.1 ) 50%, rgba( 0,0,0,0.9 ) 75%);
#
#
#   color:  white;
#
#
#   height:  100%;
#
#
#   width:  20;
#
#                 }

# %% [markdown]
# Interacts pretty well with widgets. If you're viewing this on NBViewer you're missing out on some interactivity.

# %%
from IPython.html import widgets
@widgets.interact
def f(h_neg=(0, 359, 1), h_pos=(0, 359), s=(0., 99.9), l=(0., 99.9)):
    return df.style.background_gradient(
        cmap=sns.palettes.diverging_palette(h_neg=h_neg, h_pos=h_pos, s=s, l=l,
                                            as_cmap=True)
    )
# Out:
#             <style  type="text/css" >
#
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow0_col0 {
#
#                     background-color:  #557e79;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow0_col1 {
#
#                     background-color:  #779894;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow0_col2 {
#
#                     background-color:  #557e79;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow0_col3 {
#
#                     background-color:  #809f9b;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow0_col4 {
#
#                     background-color:  #aec2bf;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow1_col0 {
#
#                     background-color:  #799995;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow1_col1 {
#
#                     background-color:  #8ba7a3;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow1_col2 {
#
#                     background-color:  #557e79;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow1_col3 {
#
#                     background-color:  #dfe8e7;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow1_col4 {
#
#                     background-color:  #d7e2e0;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow2_col0 {
#
#                     background-color:  #9cb5b1;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow2_col1 {
#
#                     background-color:  #557e79;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow2_col2 {
#
#                     background-color:  #cedbd9;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow2_col3 {
#
#                     background-color:  #cedbd9;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow2_col4 {
#
#                     background-color:  #557e79;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow3_col0 {
#
#                     background-color:  #c1d1cf;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow3_col1 {
#
#                     background-color:  #9cb5b1;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow3_col2 {
#
#                     background-color:  #dce5e4;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow3_col3 {
#
#                     background-color:  #668b86;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow3_col4 {
#
#                     background-color:  #a9bebb;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow4_col0 {
#
#                     background-color:  #e5eceb;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow4_col1 {
#
#                     background-color:  #6c908b;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow4_col2 {
#
#                     background-color:  #678c87;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow4_col3 {
#
#                     background-color:  #cedbd9;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow4_col4 {
#
#                     background-color:  #c5d4d2;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow5_col0 {
#
#                     background-color:  #e5eceb;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow5_col1 {
#
#                     background-color:  #71948f;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow5_col2 {
#
#                     background-color:  #a4bbb8;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow5_col3 {
#
#                     background-color:  #5a827d;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow5_col4 {
#
#                     background-color:  #f2f2f2;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow6_col0 {
#
#                     background-color:  #c1d1cf;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow6_col1 {
#
#                     background-color:  #edf3f2;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow6_col2 {
#
#                     background-color:  #557e79;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow6_col3 {
#
#                     background-color:  #b3c6c4;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow6_col4 {
#
#                     background-color:  #698e89;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow7_col0 {
#
#                     background-color:  #9cb5b1;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow7_col1 {
#
#                     background-color:  #d7e2e0;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow7_col2 {
#
#                     background-color:  #698e89;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow7_col3 {
#
#                     background-color:  #759792;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow7_col4 {
#
#                     background-color:  #c5d4d2;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow8_col0 {
#
#                     background-color:  #799995;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow8_col1 {
#
#                     background-color:  #557e79;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow8_col2 {
#
#                     background-color:  #628882;
#
#                 }
#
#                 #T_afe47602_8644_11e5_be9f_a45e60bd97fbrow8_col3 {
#
#                     background-color:  #557e79;
#
#                 }

# %%
# Don't do this
def panda(df):
    spots = [
        # left ear
        (0, 0), (1, 0), (0, 1),
        # right ear
        (0, 10), (1, 10), (0, 9),
        # left eye
        (5, 2), (4, 3), (5, 3),
        # right eye
        (5, 7), (4, 7), (5, 8),
        # nose
        (10, 4), (10, 5), (10, 6), (11, 5),
        (15, 5), (16, 5), (17, 5), (17, 4), (17, 6), (17, 3), (17, 7), (16, 2), (16, 8)
    ]

    rows = []
    for r in df.index:
        cols = []
        for c in df.columns:
            if (r, c) in spots:
                cols.append("background-color: black; color: white")
            else:
                cols.append("background-color: white; color: black")
        rows.append(cols)

    return pd.DataFrame(rows)

df = pd.DataFrame(np.random.randn(20, 11))
s = df.round(2).style
s._update_ctx(panda(df))
s
# Out:
#             <style  type="text/css" >
#
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow0_col0 {
#
#                     background-color:  black;
#
#                      color:  white;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow0_col1 {
#
#                     background-color:  black;
#
#                      color:  white;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow0_col2 {
#
#                     background-color:  white;
#
#                      color:  black;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow0_col3 {
#
#                     background-color:  white;
#
#                      color:  black;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow0_col4 {
#
#                     background-color:  white;
#
#                      color:  black;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow0_col5 {
#
#                     background-color:  white;
#
#                      color:  black;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow0_col6 {
#
#                     background-color:  white;
#
#                      color:  black;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow0_col7 {
#
#                     background-color:  white;
#
#                      color:  black;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow0_col8 {
#
#                     background-color:  white;
#
#                      color:  black;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow0_col9 {
#
#                     background-color:  black;
#
#                      color:  white;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow0_col10 {
#
#                     background-color:  black;
#
#                      color:  white;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow1_col0 {
#
#                     background-color:  black;
#
#                      color:  white;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow1_col1 {
#
#                     background-color:  white;
#
#                      color:  black;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow1_col2 {
#
#                     background-color:  white;
#
#                      color:  black;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow1_col3 {
#
#                     background-color:  white;
#
#                      color:  black;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow1_col4 {
#
#                     background-color:  white;
#
#                      color:  black;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow1_col5 {
#
#                     background-color:  white;
#
#                      color:  black;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow1_col6 {
#
#                     background-color:  white;
#
#                      color:  black;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow1_col7 {
#
#                     background-color:  white;
#
#                      color:  black;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow1_col8 {
#
#                     background-color:  white;
#
#                      color:  black;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow1_col9 {
#
#                     background-color:  white;
#
#                      color:  black;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow1_col10 {
#
#                     background-color:  black;
#
#                      color:  white;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow2_col0 {
#
#                     background-color:  white;
#
#                      color:  black;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow2_col1 {
#
#                     background-color:  white;
#
#                      color:  black;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow2_col2 {
#
#                     background-color:  white;
#
#                      color:  black;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow2_col3 {
#
#                     background-color:  white;
#
#                      color:  black;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow2_col4 {
#
#                     background-color:  white;
#
#                      color:  black;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow2_col5 {
#
#                     background-color:  white;
#
#                      color:  black;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow2_col6 {
#
#                     background-color:  white;
#
#                      color:  black;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow2_col7 {
#
#                     background-color:  white;
#
#                      color:  black;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow2_col8 {
#
#                     background-color:  white;
#
#                      color:  black;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow2_col9 {
#
#                     background-color:  white;
#
#                      color:  black;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow2_col10 {
#
#                     background-color:  white;
#
#                      color:  black;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow3_col0 {
#
#                     background-color:  white;
#
#                      color:  black;
#
#                 }
#
#                 #T_aff57ab0_8644_11e5_ac1f_a45e60bd97fbrow3_col1 {

# %%
df.index = np.arange(10)

# %%
def hover(hover_color="#ffff99"):
    return dict(selector="tr:hover",
                props=[("background-color", "%s" % hover_color)])

styles = [
    hover(),
    dict(selector="th", props=[("font-size", "150%"),
                               ("text-align", "center")]),
    dict(selector="caption", props=[("caption-side", "bottom")])
]
html = df.style.render(table_styles=styles, caption="Hover to highlight.")
HTML(html)

# %% [markdown]
# # For Rob

# %%
def blowup():
    return dict(selector="td:hover",
                props=[('max-width', '200px'),
                       ('font-size', '12pt !important')])

# %%
s = df.style
s.set_properties(**{'max-width': '80px', 'font-size': '4pt'})
s.set_table_styles([blowup()])
# Out:
#             <style  type="text/css" >
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fb td:hover {
#
#                     max-width: 200px;
#
#                     font-size: 12pt !important;
#
#                 }
#
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow0_col0 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow0_col1 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow0_col2 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow0_col3 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow0_col4 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow1_col0 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow1_col1 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow1_col2 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow1_col3 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow1_col4 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow2_col0 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow2_col1 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow2_col2 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow2_col3 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow2_col4 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow3_col0 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow3_col1 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow3_col2 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow3_col3 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow3_col4 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow4_col0 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow4_col1 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow4_col2 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow4_col3 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow4_col4 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow5_col0 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow5_col1 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow5_col2 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow5_col3 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow5_col4 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow6_col0 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow6_col1 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow6_col2 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow6_col3 {
#
#                     font-size:  4pt;
#
#                     max-width:  80px;
#
#                 }
#
#                 #T_f6128e6e_87cc_11e5_bdd1_a45e60bd97fbrow6_col4 {
