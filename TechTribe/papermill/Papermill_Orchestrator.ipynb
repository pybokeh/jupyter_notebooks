# %%
from getpass import getpass
import papermill as pm

# %%
RECIPIENT_EMAIL = input("Enter your recipient's email:")
GMAIL_PWD = getpass("Enter your gmail password")
# Out:
# Enter your recipient's email:somebody@some_company.com
# Enter your gmail password········

# %%
pm.execute_notebook(
    'Extract.ipynb',
    'output/Extract.ipynb'
)
# Out:
# HBox(children=(IntProgress(value=0, max=19), HTML(value='')))
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:46:11.664101',
#      'end_time': '2019-06-26T02:46:11.688901',
#      'duration': 0.0248,
#      'status': 'completed'}},
#    'source': '# Extract Task'},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:46:11.713392',
#      'end_time': '2019-06-26T02:46:12.105971',
#      'duration': 0.392579,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'import pandas as pd\npd.options.display.max_rows=1000\npd.options.display.max_columns=100'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:46:12.115763',
#      'end_time': '2019-06-26T02:46:12.126142',
#      'duration': 0.010379,
#      'status': 'completed'}},
#    'source': '### Read Excel file that was downloaded beforehand:'},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:46:12.139959',
#      'end_time': '2019-06-26T02:47:02.827211',
#      'duration': 50.687252,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'CPU times: user 50.5 s, sys: 125 ms, total: 50.7 s\nWall time: 50.7 s\n'}],
#    'source': "%%time\ndf = pd.read_excel('/home/pybokeh/Downloads/2017-2018-Teacher-Data-for-website.xlsx', index=False)"},
#   {'cell_type': 'code',
#    'execution_count': 3,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:47:02.837751',
#      'end_time': '2019-06-26T02:47:02.874583',
#      'duration': 0.036832,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '(350283, 11)'},
#      'execution_count': 3}],
#    'source': 'df.shape'},
#   {'cell_type': 'code',
#    'execution_count': 4,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:47:02.883674',
#      'end_time': '2019-06-26T02:47:03.124788',
#      'duration': 0.241114,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '  LAST NAME FIRST NAME EDUCATION LEVEL  \\\n0   LONGDEN     CHERYL         Masters   \n1  Mulligan  Bettylene         Masters   \n2     SMITH     SHERRY         Masters   \n3     BALOG     GEORGE         Masters   \n4     BAUER    RICHARD         Masters   \n\n                                     JOB DESCRIPTION  \\\n0  Tutor/Small Group Instructor Assignment (Serve...   \n1                                 Teacher Assignment   \n2              Other Professional - Other Assignment   \n3                                 Teacher Assignment   \n4                                 Teacher Assignment   \n\n                DISTRICT NAME      COUNTY                  SCHOOL NAME  \\\n0         Ashtabula Area City   Ashtabula          Ashtabula Area City   \n1  Winton Preparatory Academy    Hamilton   Winton Preparatory Academy   \n2           Greene County ESC      Greene            Greene County ESC   \n3                 Dayton City  Montgomery  Stivers School For The Arts   \n4          North Olmsted City    Cuyahoga  North Olmsted Middle School   \n\n        CITY NAME  DAYS WORKED  HOURS WORKED PER DAY  PAY AMOUNT  \n0       Ashtabula          185                  7.00     25900.0  \n1      Cincinnati           86                  8.00     34000.0  \n2  Yellow Springs           40                  8.00     10397.0  \n3          Dayton          200                  4.35     40792.0  \n4   North Olmsted          185                  7.50     97931.0  ',
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>LAST NAME</th>\n      <th>FIRST NAME</th>\n      <th>EDUCATION LEVEL</th>\n      <th>JOB DESCRIPTION</th>\n      <th>DISTRICT NAME</th>\n      <th>COUNTY</th>\n      <th>SCHOOL NAME</th>\n      <th>CITY NAME</th>\n      <th>DAYS WORKED</th>\n      <th>HOURS WORKED PER DAY</th>\n      <th>PAY AMOUNT</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>LONGDEN</td>\n      <td>CHERYL</td>\n      <td>Masters</td>\n      <td>Tutor/Small Group Instructor Assignment (Serve...</td>\n      <td>Ashtabula Area City</td>\n      <td>Ashtabula</td>\n      <td>Ashtabula Area City</td>\n      <td>Ashtabula</td>\n      <td>185</td>\n      <td>7.00</td>\n      <td>25900.0</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Mulligan</td>\n      <td>Bettylene</td>\n      <td>Masters</td>\n      <td>Teacher Assignment</td>\n      <td>Winton Preparatory Academy</td>\n      <td>Hamilton</td>\n      <td>Winton Preparatory Academy</td>\n      <td>Cincinnati</td>\n      <td>86</td>\n      <td>8.00</td>\n      <td>34000.0</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>SMITH</td>\n      <td>SHERRY</td>\n      <td>Masters</td>\n      <td>Other Professional - Other Assignment</td>\n      <td>Greene County ESC</td>\n      <td>Greene</td>\n      <td>Greene County ESC</td>\n      <td>Yellow Springs</td>\n      <td>40</td>\n      <td>8.00</td>\n      <td>10397.0</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>BALOG</td>\n      <td>GEORGE</td>\n      <td>Masters</td>\n      <td>Teacher Assignment</td>\n      <td>Dayton City</td>\n      <td>Montgomery</td>\n      <td>Stivers School For The Arts</td>\n      <td>Dayton</td>\n      <td>200</td>\n      <td>4.35</td>\n      <td>40792.0</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>BAUER</td>\n      <td>RICHARD</td>\n      <td>Masters</td>\n      <td>Teacher Assignment</td>\n      <td>North Olmsted City</td>\n      <td>Cuyahoga</td>\n      <td>North Olmsted Middle School</td>\n      <td>North Olmsted</td>\n      <td>185</td>\n      <td>7.50</td>\n      <td>97931.0</td>\n    </tr>\n  </tbody>\n</table>\n</div>'},
#      'execution_count': 4}],
#    'source': 'df.head()'},
#   {'cell_type': 'code',
#    'execution_count': 5,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:47:03.136159',
#      'end_time': '2019-06-26T02:47:03.305481',
#      'duration': 0.169322,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "Index(['LAST NAME', 'FIRST NAME', 'EDUCATION LEVEL', 'JOB DESCRIPTION',\n       'DISTRICT NAME', 'COUNTY', 'SCHOOL NAME', 'CITY NAME', 'DAYS WORKED',\n       'HOURS WORKED PER DAY', 'PAY AMOUNT'],\n      dtype='object')"},
#      'execution_count': 5}],
#    'source': 'df.columns'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:47:03.327596',
#      'end_time': '2019-06-26T02:47:03.354140',
#      'duration': 0.026544,
#      'status': 'completed'}},
#    'source': "### I don't like spaces in column names, so I will replace them with underscores:"},
#   {'cell_type': 'code',
#    'execution_count': 6,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:47:03.418602',
#      'end_time': '2019-06-26T02:47:03.531731',
#      'duration': 0.113129,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "df.columns = [column.replace(' ','_') for column in df.columns]"},
#   {'cell_type': 'code',
#    'execution_count': 7,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:47:03.550257',
#      'end_time': '2019-06-26T02:47:03.770181',
#      'duration': 0.219924,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "Index(['LAST_NAME', 'FIRST_NAME', 'EDUCATION_LEVEL', 'JOB_DESCRIPTION',\n       'DISTRICT_NAME', 'COUNTY', 'SCHOOL_NAME', 'CITY_NAME', 'DAYS_WORKED',\n       'HOURS_WORKED_PER_DAY', 'PAY_AMOUNT'],\n      dtype='object')"},
#      'execution_count': 7}],
#    'source': 'df.columns'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:47:03.795873',
#      'end_time': '2019-06-26T02:47:03.820863',
#      'duration': 0.02499,
#      'status': 'completed'}},
#    'source': "### Let's see what job descriptions there are and get counts:"},
#   {'cell_type': 'code',
#    'execution_count': 8,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:47:03.863141',
#      'end_time': '2019-06-26T02:47:04.026137',
#      'duration': 0.162996,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': 'Teacher Assignment                                                                              104185\nCoaching Assignment                                                                              44104\nAdvisor Assignment                                                                               27616\nVehicle Operating (Bus) Assignment                                                               14061\nOther Extra/Intra - Curricular Activities Assignment                                             13806\nFood Service Assignment                                                                          13518\nTeaching Aide Assignment                                                                         12948\nCustodian Assignment                                                                             11872\nInstructional Paraprofessional Assignment                                                        11497\nClerical Assignment                                                                              11471\nSupplemental Service Teaching Assignment (Serves Students with Disability Conditions Only)       10470\nOther Professional - Educational Assignment                                                       7120\nMonitoring Assignment                                                                             5291\nTutor/Small Group Instructor Assignment (Serves Students Without Disability Conditions Only)      4539\nCounseling Assignment                                                                             4161\nRemedial Specialist Assignment                                                                    3619\nPrincipal Assignment                                                                              3542\nSpeech and Language Therapist Assignment                                                          2986\nCoordinator Assignment                                                                            2342\nPsychologist Assignment                                                                           2241\nSupervisor/Manager Assignment                                                                     2238\nAttendant Assignment                                                                              2214\nAssistant Principal Assignment                                                                    2214\nGeneral Maintenance Assignment                                                                    1822\nLibrary Aide Assignment                                                                           1677\nCurriculum Specialist Assignment                                                                  1571\nDirector Assignment                                                                               1555\nOther Technical Assignment                                                                        1552\nRegistered Nursing Assignment                                                                     1458\nOther Professional - Other Assignment                                                             1326\nBookkeeping Assignment                                                                            1218\nOther Office/Clerical Assignment                                                                  1192\nTeacher Mentor/Evaluator Assignment                                                               1134\nGuard/Watchman Assignment                                                                         1060\nOccupational Therapist Assignment                                                                 1058\nOther Official/Administrative Assignment                                                           973\nLibrarian/Media Assignment                                                                         922\nTreasurer Assignment                                                                               910\nFull-time (Permanen ...
#      'execution_count': 8}],
#    'source': "df['JOB_DESCRIPTION'].value_counts()"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:47:04.037710',
#      'end_time': '2019-06-26T02:47:04.064498',
#      'duration': 0.026788,
#      'status': 'completed'}},
#    'source': '### Let\'s only do analysis on teachers ("Teacher Assignment"):'},
#   {'cell_type': 'code',
#    'execution_count': 9,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:47:04.088784',
#      'end_time': '2019-06-26T02:47:04.290325',
#      'duration': 0.201541,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'teachers = df.query("JOB_DESCRIPTION == \'Teacher Assignment\'")'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:47:04.303622',
#      'end_time': '2019-06-26T02:47:04.314632',
#      'duration': 0.01101,
#      'status': 'completed'}},
#    'source': '### Save our dataframe as a parquet format:'},
#   {'cell_type': 'code',
#    'execution_count': 10,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:47:04.329020',
#      'end_time': '2019-06-26T02:47:04.645093',
#      'duration': 0.316073,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'CPU times: user 203 ms, sys: 12.1 ms, total: 215 ms\nWall time: 230 ms\n'}],
#    'source': "%%time\nteachers.to_parquet('/home/pybokeh/Downloads/teachers')"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:47:04.657550',
#      'end_time': '2019-06-26T02:47:04.671432',
#      'duration': 0.013882,
#      'status': 'completed'}},
#    'source': "### For comparison, let's save our dataframe as an Excel file:"},
#   {'cell_type': 'code',
#    'execution_count': 11,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:47:04.741308',
#      'end_time': '2019-06-26T02:47:35.618645',
#      'duration': 30.877337,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'CPU times: user 30.6 s, sys: 252 ms, total: 30.8 s\nWall time: 30.8 s\n'}],
#    'source': "%%time\nteachers.to_excel('/home/pybokeh/Downloads/teachers.xlsx', index=False)"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:47:35.638751',
#      'end_time': '2019-06-26T02:47:35.659747',
#      'duration': 0.020996,
#      'status': 'completed'}},
#    'source': '### As we can see, saving to parquet format is so much faster!'}],
#  'metadata': {'hide_input': False,
#   'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.7.3',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'parameters': {},
#    'environment_variables': {},
#    'version': '1.0.1',
#    'input_path': 'Extract.ipynb',
#    'output_path': 'output/Extract.ipynb',
#    'start_time': '2019-06-26T02:46:09.938884',
#    'end_time': '2019-06-26T02:47:36.985696',
#    'duration': 87.046812,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 2}

# %%
pm.execute_notebook(
    'Transform.ipynb',
    'output/Transform.ipynb'
)
# Out:
# HBox(children=(IntProgress(value=0, max=59), HTML(value='')))
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:47:39.075931',
#      'end_time': '2019-06-26T02:47:39.128879',
#      'duration': 0.052948,
#      'status': 'completed'}},
#    'source': '# Transform Task'},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:47:39.162410',
#      'end_time': '2019-06-26T02:47:40.231387',
#      'duration': 1.068977,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "%matplotlib inline\nimport matplotlib.pyplot as plt\nimport pandas as pd\nimport numpy as np\nimport scrapbook as sb\nimport seaborn as sns\npd.options.display.max_rows=1000\npd.options.display.max_columns=100\nplt.rcParams['figure.figsize'] = [9, 6]"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:47:40.257994',
#      'end_time': '2019-06-26T02:47:40.284260',
#      'duration': 0.026266,
#      'status': 'completed'}},
#    'source': '### Read in parquet file containing information for just teachers:'},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:47:40.313993',
#      'end_time': '2019-06-26T02:47:40.485508',
#      'duration': 0.171515,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'CPU times: user 115 ms, sys: 28.8 ms, total: 143 ms\nWall time: 118 ms\n'}],
#    'source': "%%time\nteachers = pd.read_parquet('/home/pybokeh/Downloads/teachers')"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:47:40.511843',
#      'end_time': '2019-06-26T02:47:40.575425',
#      'duration': 0.063582,
#      'status': 'completed'}},
#    'source': '### For comparison, read in an Excel file version:'},
#   {'cell_type': 'code',
#    'execution_count': 3,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:47:40.622706',
#      'end_time': '2019-06-26T02:47:58.980464',
#      'duration': 18.357758,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'CPU times: user 18.2 s, sys: 87.3 ms, total: 18.3 s\nWall time: 18.3 s\n'}],
#    'source': "%%time\nteachers2 = pd.read_excel('/home/pybokeh/Downloads/teachers.xlsx')"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:47:59.007908',
#      'end_time': '2019-06-26T02:47:59.049888',
#      'duration': 0.04198,
#      'status': 'completed'}},
#    'source': '#### As expected, reading in an Excel file takes so much longer'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:47:59.096178',
#      'end_time': '2019-06-26T02:47:59.124290',
#      'duration': 0.028112,
#      'status': 'completed'}},
#    'source': '### Looks like teachers for the most part work about 6 months out of the year:'},
#   {'cell_type': 'code',
#    'execution_count': 4,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:47:59.151510',
#      'end_time': '2019-06-26T02:47:59.194969',
#      'duration': 0.043459,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '184    30309\n185    25954\n183    12285\n186     8947\n182     6015\n195     3744\n190     3366\n191     1622\n187     1578\n188     1130\n200      826\n180      698\n189      677\n192      540\n196      346\n178      344\n177      330\n213      304\n175      288\n181      272\n179      216\n194      213\n211      189\n260      186\n0        182\n204      131\n205      126\n193      111\n202       84\n206       78\n171       78\n207       72\n92        71\n93        69\n197       67\n174       65\n250       64\n176       47\n158       46\n173       45\n201       44\n203       43\n90        42\n199       38\n1         38\n232       37\n198       36\n153       36\n215       35\n170       35\n165       32\n100       30\n209       28\n20        28\n7         28\n224       27\n163       27\n120       26\n160       26\n164       26\n221       26\n147       25\n94        24\n210       24\n166       24\n222       24\n225       24\n150       23\n159       22\n168       22\n214       22\n161       22\n145       21\n154       21\n10        21\n95        21\n89        21\n148       20\n208       20\n36        20\n157       19\n91        19\n96        19\n156       18\n60        18\n125       17\n124       17\n172       17\n104       16\n71        16\n61        16\n5         16\n155       16\n261       16\n142       16\n244       16\n212       16\n167       16\n135       15\n243       15\n123       15\n223       15\n74        14\n130       14\n47        14\n84        14\n216       13\n127       13\n152       13\n149       13\n98        13\n37        13\n162       13\n109       13\n15        13\n88        13\n138       13\n101       12\n99        12\n144       12\n143       12\n2         12\n50        12\n140       11\n151       11\n136       11\n122       11\n133       11\n119       10\n146       10\n121       10\n126       10\n111       10\n110       10\n97        10\n35        10\n44        10\n139        9\n56         9\n72         9\n87         9\n169        9\n85         9\n73         9\n118        9\n103        9\n12         9\n80         8\n18         8\n30         8\n137        8\n62         8\n112        8\n114        8\n234        8\n106        8\n116        8\n132        8\n229        8\n75         8\n54         8\n117        7\n57         7\n63         7\n67         7\n128        7\n24         7\n134        7\n48         7\n14         7\n105        7\n231        7\n34         7\n76         7\n81         7\n13         6\n141        6\n27         6\n29         6\n25         6\n240        6\n21         6\n40         6\n45         6\n220        6\n108        6\n53         5\n33         5\n39         5\n8          5\n115        5\n46         5\n131        5\n113        5\n239        5\n3          5\n68         5\n28         5\n16         5\n83         5\n79         5\n22         5\n64         5\n78         5\n58         4\n49         4\n237        4\n242        4\n86         4\n23         4\n219        4\n66         4\n38         4\n228        4\n31         4\n9          4\n26         4\n65         4\n19         3\n77         3\n69         3\n11         3\n233        3\n52         3\n102        3\n107        3\n41         3\n70         3\n4          2\n129        2\n51         2\n55         2\n245        2\n17         2\n238        2\n235        2\n43         2\n82         2\n42         2\n230        2\n226        2\n32         2\n218        2\n217        2\n247        2\n59         1\n6          1\n236        1\n262        1\n270        1\nName: DAYS_WORKED, dtype: int64'},
#      'execution_count': 4}],
#    'source': "teachers['DAYS_WORKED'].value_counts()"},
#   {'cell_type': 'code',
#    'execution_count': 5,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:47:59.222255',
#      'end_time': '2019-06-26T02:47:59.637853',
#      'duration': 0.415598,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'display_data',
#      'metadata': {'needs_background': 'light'},
#      'data': {'text/plain': '<Figure size 432x288 with 1 Axes>',
#       'image/png': '...\n'}}],
#    'source': "teachers['DAYS_WORKED'].hist()\nsns.despine();"},
#   {'cell_type': 'code',
#    'execution_count': 6,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:47:59.672563',
#      'end_time': '2019-06-26T02:48:00.369507',
#      'duration': 0.696944,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'display_data',
#      'metadata': {'needs_background': 'light'},
#      'data': {'text/plain': '<Figure size 432x288 with 1 Axes>',
#       'image/png': '...\n'}}],
#    'source': "sns.distplot(teachers['DAYS_WORKED'].values)\nsns.despine()"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:00.397807',
#      'end_time': '2019-06-26T02:48:00.425408',
#      'duration': 0.027601,
#      'status': 'completed'}},
#    'source': '### Also curious about hours worked per day:'},
#   {'cell_type': 'code',
#    'execution_count': 7,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:00.456198',
#      'end_time': '2019-06-26T02:48:00.504623',
#      'duration': 0.048425,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '7.50     37056\n7.00     17542\n8.00     12906\n7.25     10162\n7.33      3956\n7.75      3130\n6.75      2309\n6.25      2129\n6.50      1979\n7.67      1492\n1.00       870\n3.75       734\n6.00       683\n3.50       639\n7.42       624\n4.00       538\n7.08       459\n7.30       379\n7.17       329\n7.34       290\n2.00       223\n3.00       220\n8.50       196\n7.10       189\n7.58       170\n1.50       155\n4.50       151\n5.00       148\n7.60       140\n2.50       131\n0.25       130\n5.50       130\n0.75       117\n0.00       114\n3.63       111\n1.75        96\n7.20        93\n6.92        79\n6.60        77\n2.90        66\n3.88        63\n3.25        60\n3.62        60\n5.25        59\n0.50        59\n7.77        57\n7.66        57\n1.25        56\n7.16        54\n2.25        50\n4.35        49\n6.91        48\n6.30        45\n1.87        40\n1.60        38\n2.80        38\n5.63        38\n3.87        36\n3.67        35\n4.20        34\n6.57        34\n1.45        34\n4.80        33\n2.75        33\n6.40        32\n2.33        31\n4.25        31\n1.88        31\n1.40        31\n5.60        29\n6.83        28\n3.20        27\n7.15        25\n2.47        25\n3.37        24\n3.66        23\n3.38        23\n5.75        23\n2.42        23\n2.10        22\n1.05        21\n2.93        20\n4.75        20\n2.31        19\n3.12        19\n0.80        19\n5.80        18\n1.81        17\n0.90        17\n1.55        17\n2.40        16\n1.30        16\n0.70        15\n2.63        14\n5.44        14\n3.10        13\n4.65        13\n2.60        13\n1.20        13\n0.72        12\n2.48        12\n3.13        12\n4.91        12\n2.34        12\n3.58        12\n6.64        12\n3.59        11\n2.17        11\n5.81        11\n4.40        11\n3.60        11\n5.02        11\n4.95        11\n3.71        11\n6.20        10\n5.62        10\n2.72        10\n4.90        10\n2.03        10\n4.30        10\n1.08        10\n0.73        10\n1.28        10\n6.42        10\n1.01        10\n6.38        10\n4.88        10\n1.94        10\n3.15        10\n2.45        10\n0.97        10\n3.55        10\n0.60         9\n2.55         9\n2.56         9\n2.39         9\n0.87         9\n1.27         9\n5.36         9\n4.67         8\n6.45         8\n2.64         8\n4.97         8\n9.00         8\n3.83         8\n5.82         8\n2.30         8\n1.92         8\n1.68         8\n0.95         8\n1.24         7\n2.62         7\n0.40         7\n3.65         7\n1.17         7\n5.33         7\n2.32         7\n1.13         7\n6.67         7\n1.90         7\n4.69         7\n2.20         7\n1.12         6\n6.53         6\n3.79         6\n1.83         6\n1.95         6\n2.13         6\n1.04         6\n0.37         6\n0.98         6\n1.36         6\n5.95         6\n1.61         6\n6.16         6\n3.85         6\n1.32         6\n0.91         5\n2.98         5\n5.19         5\n5.57         5\n0.67         5\n5.20         5\n0.83         5\n3.04         5\n1.09         5\n4.55         5\n3.80         5\n6.09         5\n0.84         5\n0.78         5\n1.47         5\n1.82         5\n2.16         5\n4.13         5\n0.82         5\n6.23         5\n2.41         5\n4.87         5\n7.32         4\n3.35         4\n6.33         4\n2.85         4\n2.66         4\n3.33         4\n5.03         4\n0.49         4\n3.05         4\n5.37         4\n6.88         4\n3.84         4\n4.60         4\n0.65         4\n3.90         4\n4.34         4\n5.18         4\n4.16         4\n1.73         4\n1.19         4\n4.70         4\n3.28         4\n1.35         4\n3.29         4\n3.23         4\n3.11         4\n1.43         4\n1.85         4\n4.05         4\n2.37         4\n4.22         4\n6.52         4\n4.18         4\n0.86         4\n4.27         4\n4.85         4\n2.14         4\n1.10         4\n2.46         3\n5.52         3\n3.08         3\n4.79         3\n7.35         3\n0.93         3\n2.36         3\n7.45         3\n2.12         3\n5.83         3\n5.07         3\n2.9 ...
#      'execution_count': 7}],
#    'source': "teachers['HOURS_WORKED_PER_DAY'].value_counts()"},
#   {'cell_type': 'code',
#    'execution_count': 8,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:00.534513',
#      'end_time': '2019-06-26T02:48:00.846187',
#      'duration': 0.311674,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'display_data',
#      'metadata': {'needs_background': 'light'},
#      'data': {'text/plain': '<Figure size 432x288 with 1 Axes>',
#       'image/png': '...\n'}}],
#    'source': "teachers['HOURS_WORKED_PER_DAY'].hist()\nsns.despine();"},
#   {'cell_type': 'code',
#    'execution_count': 9,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:00.875445',
#      'end_time': '2019-06-26T02:48:01.737319',
#      'duration': 0.861874,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'display_data',
#      'metadata': {'needs_background': 'light'},
#      'data': {'text/plain': '<Figure size 432x288 with 1 Axes>',
#       'image/png': '...\n'}}],
#    'source': "sns.distplot(teachers['HOURS_WORKED_PER_DAY'].values)\nsns.despine()"},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:01.767596',
#      'end_time': '2019-06-26T02:48:01.805057',
#      'duration': 0.037461,
#      'status': 'completed'}},
#    'source': '#### So it appears most teachers work at least 7 hours per day'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:01.839370',
#      'end_time': '2019-06-26T02:48:01.869634',
#      'duration': 0.030264,
#      'status': 'completed'}},
#    'source': '#### Based on these findings, we should probably limit our data set to "full-time" teachers.  We will define full-time to mean having worked at least 180 days out of the year and at least 7 hours per day:'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:01.900527',
#      'end_time': '2019-06-26T02:48:01.930673',
#      'duration': 0.030146,
#      'status': 'completed'}},
#    'source': '### Limit to just full-time teachers:'},
#   {'cell_type': 'code',
#    'execution_count': 10,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:01.963774',
#      'end_time': '2019-06-26T02:48:02.016445',
#      'duration': 0.052671,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'full_time = teachers.query("HOURS_WORKED_PER_DAY >=7 and DAYS_WORKED >= 180")'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:02.046289',
#      'end_time': '2019-06-26T02:48:02.079219',
#      'duration': 0.03293,
#      'status': 'completed'}},
#    'source': "### Let's calculate hourly rate:"},
#   {'cell_type': 'code',
#    'execution_count': 11,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:02.109272',
#      'end_time': '2019-06-26T02:48:02.236801',
#      'duration': 0.127529,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "full_time = full_time.assign(TOTAL_HOURS_WORKED = full_time['DAYS_WORKED'] * full_time['HOURS_WORKED_PER_DAY'])\nfull_time = full_time.assign(HRLY_RATE = full_time['PAY_AMOUNT'] / full_time['TOTAL_HOURS_WORKED'])"},
#   {'cell_type': 'code',
#    'execution_count': 12,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:02.267460',
#      'end_time': '2019-06-26T02:48:02.310797',
#      'duration': 0.043337,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '(86372, 13)'},
#      'execution_count': 12}],
#    'source': 'full_time.shape'},
#   {'cell_type': 'code',
#    'execution_count': 13,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:02.342365',
#      'end_time': '2019-06-26T02:48:02.484213',
#      'duration': 0.141848,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '       LAST_NAME FIRST_NAME EDUCATION_LEVEL     JOB_DESCRIPTION  \\\n4          BAUER    RICHARD         Masters  Teacher Assignment   \n7          HOGUE     LESLIE         Masters  Teacher Assignment   \n10    Sciarretta     Teresa         Masters  Teacher Assignment   \n11  LUTZ-HACKETT  ELIZABETH         Masters  Teacher Assignment   \n13       JENKINS   JENNIFER         Masters  Teacher Assignment   \n\n                      DISTRICT_NAME      COUNTY  \\\n4                North Olmsted City    Cuyahoga   \n7                  Beavercreek City      Greene   \n10        Springboro Community City      Warren   \n11  Yellow Springs Exempted Village      Greene   \n13            Trotwood-Madison City  Montgomery   \n\n                            SCHOOL_NAME       CITY_NAME  DAYS_WORKED  \\\n4           North Olmsted Middle School   North Olmsted          185   \n7               Jacob Coy Middle School           Xenia          184   \n10                               Dennis      Springboro          185   \n11  Yellow Springs/McKinney High School  Yellow Springs          184   \n13       Trotwood-Madison Middle School        Trotwood          186   \n\n    HOURS_WORKED_PER_DAY  PAY_AMOUNT  TOTAL_HOURS_WORKED  HRLY_RATE  \n4                   7.50     97931.0             1387.50  70.580901  \n7                   7.50     88369.0             1380.00  64.035507  \n10                  7.25     80247.0             1341.25  59.830009  \n11                  7.00     82682.0             1288.00  64.194099  \n13                  7.00     61490.0             1302.00  47.227343  ',
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>LAST_NAME</th>\n      <th>FIRST_NAME</th>\n      <th>EDUCATION_LEVEL</th>\n      <th>JOB_DESCRIPTION</th>\n      <th>DISTRICT_NAME</th>\n      <th>COUNTY</th>\n      <th>SCHOOL_NAME</th>\n      <th>CITY_NAME</th>\n      <th>DAYS_WORKED</th>\n      <th>HOURS_WORKED_PER_DAY</th>\n      <th>PAY_AMOUNT</th>\n      <th>TOTAL_HOURS_WORKED</th>\n      <th>HRLY_RATE</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>4</th>\n      <td>BAUER</td>\n      <td>RICHARD</td>\n      <td>Masters</td>\n      <td>Teacher Assignment</td>\n      <td>North Olmsted City</td>\n      <td>Cuyahoga</td>\n      <td>North Olmsted Middle School</td>\n      <td>North Olmsted</td>\n      <td>185</td>\n      <td>7.50</td>\n      <td>97931.0</td>\n      <td>1387.50</td>\n      <td>70.580901</td>\n    </tr>\n    <tr>\n      <th>7</th>\n      <td>HOGUE</td>\n      <td>LESLIE</td>\n      <td>Masters</td>\n      <td>Teacher Assignment</td>\n      <td>Beavercreek City</td>\n      <td>Greene</td>\n      <td>Jacob Coy Middle School</td>\n      <td>Xenia</td>\n      <td>184</td>\n      <td>7.50</td>\n      <td>88369.0</td>\n      <td>1380.00</td>\n      <td>64.035507</td>\n    </tr>\n    <tr>\n      <th>10</th>\n      <td>Sciarretta</td>\n      <td>Teresa</td>\n      <td>Masters</td>\n      <td>Teacher Assignment</td>\n      <td>Springboro Community City</td>\n      <td>Warren</td>\n      <td>Dennis</td>\n      <td>Springboro</td>\n      <td>185</td>\n      <td>7.25</td>\n      <td>80247.0</td>\n      <td>1341.25</td>\n      <td>59.830009</td>\n    </tr>\n    <tr>\n      <th>11</th>\n      <td>LUTZ-HACKETT</td>\n      <td>ELIZABETH</td>\n      <td>Masters</td>\n      <td>Teacher Assignment</td>\n      <td>Yellow Springs Exempted Village</td>\n      <td>Greene</td>\n      <td>Yellow Springs/McKinney High School</td>\n      <td>Yellow Springs</td>\n      <td>184</td>\n      <td>7.00</td>\n      <td>82682.0</td>\n      <td>1288.00</td>\n      <td>64.194099</td>\n    </tr>\n    <tr>\n      <th>13</th>\n      <td>JENKINS</td>\n      <td>JENNIFER</td>\n      <td>Masters</td>\n      <td>Teacher Assignment</td>\n      <td>Trotwood-Madison City</td>\n      <td>Montgomery</td>\n      <td>Trotwood-Madison Middle School</td>\n      <td>Trotwood</td>\n      <td>186</td>\n      <td>7.00</td>\n      <td>61490.0</td>\n      <td>1302.00</td>\n      <td>47.227343</td>\n    </tr>\n  </tbody>\n</table>\n</div>'},
#      'execution_count': 13}],
#    'source': 'full_time.head()'},
#   {'cell_type': 'code',
#    'execution_count': 14,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:02.528932',
#      'end_time': '2019-06-26T02:48:02.624932',
#      'duration': 0.096,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': "<class 'pandas.core.frame.DataFrame'>\nInt64Index: 86372 entries, 4 to 350260\nData columns (total 13 columns):\nLAST_NAME               86368 non-null object\nFIRST_NAME              86370 non-null object\nEDUCATION_LEVEL         86372 non-null object\nJOB_DESCRIPTION         86372 non-null object\nDISTRICT_NAME           86372 non-null object\nCOUNTY                  86370 non-null object\nSCHOOL_NAME             86372 non-null object\nCITY_NAME               86372 non-null object\nDAYS_WORKED             86372 non-null int64\nHOURS_WORKED_PER_DAY    86372 non-null float64\nPAY_AMOUNT              86372 non-null float64\nTOTAL_HOURS_WORKED      86372 non-null float64\nHRLY_RATE               86372 non-null float64\ndtypes: float64(4), int64(1), object(8)\nmemory usage: 9.2+ MB\n"}],
#    'source': 'full_time.info()'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:02.661349',
#      'end_time': '2019-06-26T02:48:02.692225',
#      'duration': 0.030876,
#      'status': 'completed'}},
#    'source': "### Let's now make pivot table to obtain median pay and median hourly rate:"},
#   {'cell_type': 'code',
#    'execution_count': 15,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:02.725304',
#      'end_time': '2019-06-26T02:48:02.782936',
#      'duration': 0.057632,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "teachers_by_district = full_time.pivot_table(index=['DISTRICT_NAME'], values=['PAY_AMOUNT','HRLY_RATE'],\n                                            aggfunc=['median'])"},
#   {'cell_type': 'code',
#    'execution_count': 16,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:02.814135',
#      'end_time': '2019-06-26T02:48:03.122607',
#      'duration': 0.308472,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "                                                       median           \n                                                    HRLY_RATE PAY_AMOUNT\nDISTRICT_NAME                                                           \nA+ Arts Academy                                     26.497696  36517.000\nA+ Children's Academy                               24.038462  35000.000\nAcademy for Urban Scholars Youngstown               29.029304  43750.000\nAcademy of Educational Excellence                   22.297297  32500.000\nAchieve Career Preparatory Academy                  21.794872  34000.000\nAda Exempted Village                                42.915483  58901.500\nAdams County Ohio Valley Local                      42.484249  59232.000\nAdena Local                                         43.243842  58187.000\nAkron City                                          49.357193  70334.000\nAkron Digital Academy                               26.375329  40090.500\nAkron Preparatory School                            22.235007  35000.000\nAkros Middle School                                 24.408015  33500.000\nAlbert Einstein Academy for Letters, Arts and S...  23.648649  34636.000\nAlexander Local                                     48.338017  61921.000\nAllen County ESC                                    42.272370  53855.000\nAllen East Local                                    43.837874  58243.000\nAlliance City                                       41.808288  58009.000\nAlternative Education Academy                       24.907488  40250.500\nAmanda-Clearcreek Local                             38.881159  53656.000\nAmherst Exempted Village                            56.186335  72368.000\nAnna Local                                          50.575311  66185.000\nAnsonia Local                                       23.509189  32619.000\nAnthony Wayne Local                                 51.668107  73406.000\nAntwerp Local                                       42.149137  53698.000\nApex Academy                                        30.557005  44491.000\nApollo                                              47.844653  61289.000\nArcadia Local                                       42.617122  58492.000\nArcanum-Butler Local                                46.679160  62270.000\nArchbold-Area Local                                 47.836442  63467.000\nArlington Local                                     31.511840  43250.000\nArts & College Preparatory Academy                   0.016622     25.000\nAshland City                                        44.901261  62120.000\nAshland County-West Holmes                          46.052303  58993.000\nAshtabula Area City                                 45.000000  58275.000\nAshtabula County ESC                                42.654503  54939.000\nAshtabula County Technical and Career Center        48.618267  62280.000\nAthens City                                         51.676557  71115.000\nAthens-Meigs ESC                                    24.069859  31794.000\nAuburn                                              52.344505  72628.000\nAuglaize County ESC                                 37.177536  51305.000\nAurora Academy                                      19.946809  30000.000\nAurora City                                         63.875676  82719.000\nAustintown Local Schools                            39.400000  54372.000\nAutism Model School                                 18.164272  37713.000\nAvon Lake City                                      50.772973  75144.000\nAvon Local                                          45.310145  62528.000\nAyersville Local                                    47.274005  60558.000\nBarberton City                                      49.618739  68846.000\nBarnesville Exempted Village                        40.659420  56110.000\nBatavia Local                                       46.279537  59932.000\nBath Local                                        ...
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead tr th {\n        text-align: left;\n    }\n\n    .dataframe thead tr:last-of-type th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr>\n      <th></th>\n      <th colspan="2" halign="left">median</th>\n    </tr>\n    <tr>\n      <th></th>\n      <th>HRLY_RATE</th>\n      <th>PAY_AMOUNT</th>\n    </tr>\n    <tr>\n      <th>DISTRICT_NAME</th>\n      <th></th>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>A+ Arts Academy</th>\n      <td>26.497696</td>\n      <td>36517.000</td>\n    </tr>\n    <tr>\n      <th>A+ Children\'s Academy</th>\n      <td>24.038462</td>\n      <td>35000.000</td>\n    </tr>\n    <tr>\n      <th>Academy for Urban Scholars Youngstown</th>\n      <td>29.029304</td>\n      <td>43750.000</td>\n    </tr>\n    <tr>\n      <th>Academy of Educational Excellence</th>\n      <td>22.297297</td>\n      <td>32500.000</td>\n    </tr>\n    <tr>\n      <th>Achieve Career Preparatory Academy</th>\n      <td>21.794872</td>\n      <td>34000.000</td>\n    </tr>\n    <tr>\n      <th>Ada Exempted Village</th>\n      <td>42.915483</td>\n      <td>58901.500</td>\n    </tr>\n    <tr>\n      <th>Adams County Ohio Valley Local</th>\n      <td>42.484249</td>\n      <td>59232.000</td>\n    </tr>\n    <tr>\n      <th>Adena Local</th>\n      <td>43.243842</td>\n      <td>58187.000</td>\n    </tr>\n    <tr>\n      <th>Akron City</th>\n      <td>49.357193</td>\n      <td>70334.000</td>\n    </tr>\n    <tr>\n      <th>Akron Digital Academy</th>\n      <td>26.375329</td>\n      <td>40090.500</td>\n    </tr>\n    <tr>\n      <th>Akron Preparatory School</th>\n      <td>22.235007</td>\n      <td>35000.000</td>\n    </tr>\n    <tr>\n      <th>Akros Middle School</th>\n      <td>24.408015</td>\n      <td>33500.000</td>\n    </tr>\n    <tr>\n      <th>Albert Einstein Academy for Letters, Arts and Sciences-Ohio</th>\n      <td>23.648649</td>\n      <td>34636.000</td>\n    </tr>\n    <tr>\n      <th>Alexander Local</th>\n      <td>48.338017</td>\n      <td>61921.000</td>\n    </tr>\n    <tr>\n      <th>Allen County ESC</th>\n      <td>42.272370</td>\n      <td>53855.000</td>\n    </tr>\n    <tr>\n      <th>Allen East Local</th>\n      <td>43.837874</td>\n      <td>58243.000</td>\n    </tr>\n    <tr>\n      <th>Alliance City</th>\n      <td>41.808288</td>\n      <td>58009.000</td>\n    </tr>\n    <tr>\n      <th>Alternative Education Academy</th>\n      <td>24.907488</td>\n      <td>40250.500</td>\n    </tr>\n    <tr>\n      <th>Amanda-Clearcreek Local</th>\n      <td>38.881159</td>\n      <td>53656.000</td>\n    </tr>\n    <tr>\n      <th>Amherst Exempted Village</th>\n      <td>56.186335</td>\n      <td>72368.000</td>\n    </tr>\n    <tr>\n      <th>Anna Local</th>\n      <td>50.575311</td>\n      <td>66185.000</td>\n    </tr>\n    <tr>\n      <th>Ansonia Local</th>\n      <td>23.509189</td>\n      <td>32619.000</td>\n    </tr>\n    <tr>\n      <th>Anthony Wayne Local</th>\n      <td>51.668107</td>\n      <td>73406.000</td>\n    </tr>\n    <tr>\n      <th>Antwerp Local</th>\n      <td>42.149137</td>\n      <td>53698.000</td>\n    </tr>\n    <tr>\n      <th>Apex Academy</th>\n      <td>30.557005</td>\n      <td>44491.000</td>\n    </tr>\n    <tr>\n      <th>Apollo</th>\n      <td>47.844653</td>\n      <td>61289.000</td>\n    </tr>\n    <tr>\n      <th>Arcadia Local</th>\n      <td>42.617122</td>\n      <td>58492.000</td>\n    </tr>\n    <tr>\n      <th>Arcanum-Butler Local</th>\n      <td>46.679160</td>\n      <td>62270.000</td>\n    </tr>\n    <tr>\n      <th>Archbold-Area Local</th>\n      <td>47.836442</td>\n      <td>63467.000</td>\n    </tr>\n    <tr>\n      <th>Arlington Local</th>\n      <td>31.511840</td>\n      <td>43250.000</td>\n    </tr>\n    ...
#      'execution_count': 16}],
#    'source': 'teachers_by_district'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:03.174197',
#      'end_time': '2019-06-26T02:48:03.217316',
#      'duration': 0.043119,
#      'status': 'completed'}},
#    'source': "### Let's remove the unnecessary column row:"},
#   {'cell_type': 'code',
#    'execution_count': 17,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:03.258738',
#      'end_time': '2019-06-26T02:48:03.308313',
#      'duration': 0.049575,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "MultiIndex(levels=[['median'], ['HRLY_RATE', 'PAY_AMOUNT']],\n           codes=[[0, 0], [0, 1]])"},
#      'execution_count': 17}],
#    'source': 'teachers_by_district.columns'},
#   {'cell_type': 'code',
#    'execution_count': 18,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:03.346129',
#      'end_time': '2019-06-26T02:48:03.564185',
#      'duration': 0.218056,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "teachers_by_district.columns.set_levels(['MEDIAN_HRLY_RATE', 'MEDIAN_PAY'], level=1, inplace=True)"},
#   {'cell_type': 'code',
#    'execution_count': 19,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:03.618776',
#      'end_time': '2019-06-26T02:48:03.877005',
#      'duration': 0.258229,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "                                                             median           \n                                                   MEDIAN_HRLY_RATE MEDIAN_PAY\nDISTRICT_NAME                                                                 \nA+ Arts Academy                                           26.497696  36517.000\nA+ Children's Academy                                     24.038462  35000.000\nAcademy for Urban Scholars Youngstown                     29.029304  43750.000\nAcademy of Educational Excellence                         22.297297  32500.000\nAchieve Career Preparatory Academy                        21.794872  34000.000\nAda Exempted Village                                      42.915483  58901.500\nAdams County Ohio Valley Local                            42.484249  59232.000\nAdena Local                                               43.243842  58187.000\nAkron City                                                49.357193  70334.000\nAkron Digital Academy                                     26.375329  40090.500\nAkron Preparatory School                                  22.235007  35000.000\nAkros Middle School                                       24.408015  33500.000\nAlbert Einstein Academy for Letters, Arts and S...        23.648649  34636.000\nAlexander Local                                           48.338017  61921.000\nAllen County ESC                                          42.272370  53855.000\nAllen East Local                                          43.837874  58243.000\nAlliance City                                             41.808288  58009.000\nAlternative Education Academy                             24.907488  40250.500\nAmanda-Clearcreek Local                                   38.881159  53656.000\nAmherst Exempted Village                                  56.186335  72368.000\nAnna Local                                                50.575311  66185.000\nAnsonia Local                                             23.509189  32619.000\nAnthony Wayne Local                                       51.668107  73406.000\nAntwerp Local                                             42.149137  53698.000\nApex Academy                                              30.557005  44491.000\nApollo                                                    47.844653  61289.000\nArcadia Local                                             42.617122  58492.000\nArcanum-Butler Local                                      46.679160  62270.000\nArchbold-Area Local                                       47.836442  63467.000\nArlington Local                                           31.511840  43250.000\nArts & College Preparatory Academy                         0.016622     25.000\nAshland City                                              44.901261  62120.000\nAshland County-West Holmes                                46.052303  58993.000\nAshtabula Area City                                       45.000000  58275.000\nAshtabula County ESC                                      42.654503  54939.000\nAshtabula County Technical and Career Center              48.618267  62280.000\nAthens City                                               51.676557  71115.000\nAthens-Meigs ESC                                          24.069859  31794.000\nAuburn                                                    52.344505  72628.000\nAuglaize County ESC                                       37.177536  51305.000\nAurora Academy                                            19.946809  30000.000\nAurora City                                               63.875676  82719.000\nAustintown Local Schools                                  39.400000  54372.000\nAutism Model School                                       18.164272  37713.000\nAvon Lake City                                            50.772973  75144.000\nAvon Local                                                45.310145  62528.000\nAyersville Local                                    ...
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead tr th {\n        text-align: left;\n    }\n\n    .dataframe thead tr:last-of-type th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr>\n      <th></th>\n      <th colspan="2" halign="left">median</th>\n    </tr>\n    <tr>\n      <th></th>\n      <th>MEDIAN_HRLY_RATE</th>\n      <th>MEDIAN_PAY</th>\n    </tr>\n    <tr>\n      <th>DISTRICT_NAME</th>\n      <th></th>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>A+ Arts Academy</th>\n      <td>26.497696</td>\n      <td>36517.000</td>\n    </tr>\n    <tr>\n      <th>A+ Children\'s Academy</th>\n      <td>24.038462</td>\n      <td>35000.000</td>\n    </tr>\n    <tr>\n      <th>Academy for Urban Scholars Youngstown</th>\n      <td>29.029304</td>\n      <td>43750.000</td>\n    </tr>\n    <tr>\n      <th>Academy of Educational Excellence</th>\n      <td>22.297297</td>\n      <td>32500.000</td>\n    </tr>\n    <tr>\n      <th>Achieve Career Preparatory Academy</th>\n      <td>21.794872</td>\n      <td>34000.000</td>\n    </tr>\n    <tr>\n      <th>Ada Exempted Village</th>\n      <td>42.915483</td>\n      <td>58901.500</td>\n    </tr>\n    <tr>\n      <th>Adams County Ohio Valley Local</th>\n      <td>42.484249</td>\n      <td>59232.000</td>\n    </tr>\n    <tr>\n      <th>Adena Local</th>\n      <td>43.243842</td>\n      <td>58187.000</td>\n    </tr>\n    <tr>\n      <th>Akron City</th>\n      <td>49.357193</td>\n      <td>70334.000</td>\n    </tr>\n    <tr>\n      <th>Akron Digital Academy</th>\n      <td>26.375329</td>\n      <td>40090.500</td>\n    </tr>\n    <tr>\n      <th>Akron Preparatory School</th>\n      <td>22.235007</td>\n      <td>35000.000</td>\n    </tr>\n    <tr>\n      <th>Akros Middle School</th>\n      <td>24.408015</td>\n      <td>33500.000</td>\n    </tr>\n    <tr>\n      <th>Albert Einstein Academy for Letters, Arts and Sciences-Ohio</th>\n      <td>23.648649</td>\n      <td>34636.000</td>\n    </tr>\n    <tr>\n      <th>Alexander Local</th>\n      <td>48.338017</td>\n      <td>61921.000</td>\n    </tr>\n    <tr>\n      <th>Allen County ESC</th>\n      <td>42.272370</td>\n      <td>53855.000</td>\n    </tr>\n    <tr>\n      <th>Allen East Local</th>\n      <td>43.837874</td>\n      <td>58243.000</td>\n    </tr>\n    <tr>\n      <th>Alliance City</th>\n      <td>41.808288</td>\n      <td>58009.000</td>\n    </tr>\n    <tr>\n      <th>Alternative Education Academy</th>\n      <td>24.907488</td>\n      <td>40250.500</td>\n    </tr>\n    <tr>\n      <th>Amanda-Clearcreek Local</th>\n      <td>38.881159</td>\n      <td>53656.000</td>\n    </tr>\n    <tr>\n      <th>Amherst Exempted Village</th>\n      <td>56.186335</td>\n      <td>72368.000</td>\n    </tr>\n    <tr>\n      <th>Anna Local</th>\n      <td>50.575311</td>\n      <td>66185.000</td>\n    </tr>\n    <tr>\n      <th>Ansonia Local</th>\n      <td>23.509189</td>\n      <td>32619.000</td>\n    </tr>\n    <tr>\n      <th>Anthony Wayne Local</th>\n      <td>51.668107</td>\n      <td>73406.000</td>\n    </tr>\n    <tr>\n      <th>Antwerp Local</th>\n      <td>42.149137</td>\n      <td>53698.000</td>\n    </tr>\n    <tr>\n      <th>Apex Academy</th>\n      <td>30.557005</td>\n      <td>44491.000</td>\n    </tr>\n    <tr>\n      <th>Apollo</th>\n      <td>47.844653</td>\n      <td>61289.000</td>\n    </tr>\n    <tr>\n      <th>Arcadia Local</th>\n      <td>42.617122</td>\n      <td>58492.000</td>\n    </tr>\n    <tr>\n      <th>Arcanum-Butler Local</th>\n      <td>46.679160</td>\n      <td>62270.000</td>\n    </tr>\n    <tr>\n      <th>Archbold-Area Local</th>\n      <td>47.836442</td>\n      <td>63467.000</td>\n    </tr>\n    <tr>\n      <th>Arlington Local</th>\n      <td>31.511840</td>\n      <td>43250.000</td>\n    </t ...
#      'execution_count': 19}],
#    'source': 'teachers_by_district'},
#   {'cell_type': 'code',
#    'execution_count': 20,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:03.924975',
#      'end_time': '2019-06-26T02:48:04.065671',
#      'duration': 0.140696,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'teachers_by_district.columns = teachers_by_district.columns.droplevel(level=0)'},
#   {'cell_type': 'code',
#    'execution_count': 21,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:04.127323',
#      'end_time': '2019-06-26T02:48:04.382193',
#      'duration': 0.25487,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "                                                    MEDIAN_HRLY_RATE  \\\nDISTRICT_NAME                                                          \nA+ Arts Academy                                            26.497696   \nA+ Children's Academy                                      24.038462   \nAcademy for Urban Scholars Youngstown                      29.029304   \nAcademy of Educational Excellence                          22.297297   \nAchieve Career Preparatory Academy                         21.794872   \nAda Exempted Village                                       42.915483   \nAdams County Ohio Valley Local                             42.484249   \nAdena Local                                                43.243842   \nAkron City                                                 49.357193   \nAkron Digital Academy                                      26.375329   \nAkron Preparatory School                                   22.235007   \nAkros Middle School                                        24.408015   \nAlbert Einstein Academy for Letters, Arts and S...         23.648649   \nAlexander Local                                            48.338017   \nAllen County ESC                                           42.272370   \nAllen East Local                                           43.837874   \nAlliance City                                              41.808288   \nAlternative Education Academy                              24.907488   \nAmanda-Clearcreek Local                                    38.881159   \nAmherst Exempted Village                                   56.186335   \nAnna Local                                                 50.575311   \nAnsonia Local                                              23.509189   \nAnthony Wayne Local                                        51.668107   \nAntwerp Local                                              42.149137   \nApex Academy                                               30.557005   \nApollo                                                     47.844653   \nArcadia Local                                              42.617122   \nArcanum-Butler Local                                       46.679160   \nArchbold-Area Local                                        47.836442   \nArlington Local                                            31.511840   \nArts & College Preparatory Academy                          0.016622   \nAshland City                                               44.901261   \nAshland County-West Holmes                                 46.052303   \nAshtabula Area City                                        45.000000   \nAshtabula County ESC                                       42.654503   \nAshtabula County Technical and Career Center               48.618267   \nAthens City                                                51.676557   \nAthens-Meigs ESC                                           24.069859   \nAuburn                                                     52.344505   \nAuglaize County ESC                                        37.177536   \nAurora Academy                                             19.946809   \nAurora City                                                63.875676   \nAustintown Local Schools                                   39.400000   \nAutism Model School                                        18.164272   \nAvon Lake City                                             50.772973   \nAvon Local                                                 45.310145   \nAyersville Local                                           47.274005   \nBarberton City                                             49.618739   \nBarnesville Exempted Village                               40.659420   \nBatavia Local                                              46.279537   \nBath Local                                                 43.541392   \nBay Village City                                           56.923128   \nBeachwood City               ...
# ...
#      'execution_count': 38}],
#    'source': 'top_median_hrly_rate[:20]'},
#   {'cell_type': 'code',
#    'execution_count': 39,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:09.199055',
#      'end_time': '2019-06-26T02:48:09.305115',
#      'duration': 0.10606,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'top_20_median_salary = top_median_salary[:20].reset_index(drop=True)\ntop_20_median_salary.index += 1'},
#   {'cell_type': 'code',
#    'execution_count': 40,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:09.395203',
#      'end_time': '2019-06-26T02:48:09.511059',
#      'duration': 0.115856,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '                                     DISTRICT_NAME    COUNTY  \\\n1                                   Beachwood City  Cuyahoga   \n2                                      Orange City  Cuyahoga   \n3                                          Polaris  Cuyahoga   \n4                             Upper Arlington City  Franklin   \n5                                 Rocky River City  Cuyahoga   \n6                              Shaker Heights City  Cuyahoga   \n7                                    Mayfield City  Cuyahoga   \n8        Cleveland Heights-University Heights City  Cuyahoga   \n9                                       Solon City  Cuyahoga   \n10                    Indian Hill Exempted Village  Hamilton   \n11                                   Hilliard City  Franklin   \n12                              North Olmsted City  Cuyahoga   \n13                                Bay Village City  Cuyahoga   \n14                          Cuyahoga Heights Local  Cuyahoga   \n15  Medina County Joint Vocational School District    Medina   \n16                                     Dublin City  Franklin   \n17                     South Euclid-Lyndhurst City  Cuyahoga   \n18              Brecksville-Broadview Heights City  Cuyahoga   \n19                                  Kirtland Local      Lake   \n20                                   Westlake City  Cuyahoga   \n\n    MEDIAN_HRLY_RATE  MEDIAN_PAY  COUNT  \n1          69.070678     96863.5    104  \n2          66.520663     95374.0    138  \n3          63.895495     91236.0     47  \n4          60.135081     89481.0    347  \n5          63.818885     88703.5    138  \n6          61.218919     88588.0    323  \n7          63.786667     88504.0    238  \n8          60.633333     87312.0    363  \n9          62.545520     87251.0    240  \n10         66.986100     86747.0    122  \n11         67.142857     86480.0    809  \n12         60.433333     85579.0    190  \n13         56.923128     85157.0    147  \n14         60.608200     85003.0     39  \n15         64.126050     83941.0     55  \n16         56.701351     83918.0    784  \n17         56.625000     83805.0    186  \n18         56.192876     83615.0    181  \n19         63.117761     83270.0     49  \n20         57.143102     83257.5    198  ',
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>DISTRICT_NAME</th>\n      <th>COUNTY</th>\n      <th>MEDIAN_HRLY_RATE</th>\n      <th>MEDIAN_PAY</th>\n      <th>COUNT</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>1</th>\n      <td>Beachwood City</td>\n      <td>Cuyahoga</td>\n      <td>69.070678</td>\n      <td>96863.5</td>\n      <td>104</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Orange City</td>\n      <td>Cuyahoga</td>\n      <td>66.520663</td>\n      <td>95374.0</td>\n      <td>138</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>Polaris</td>\n      <td>Cuyahoga</td>\n      <td>63.895495</td>\n      <td>91236.0</td>\n      <td>47</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>Upper Arlington City</td>\n      <td>Franklin</td>\n      <td>60.135081</td>\n      <td>89481.0</td>\n      <td>347</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>Rocky River City</td>\n      <td>Cuyahoga</td>\n      <td>63.818885</td>\n      <td>88703.5</td>\n      <td>138</td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>Shaker Heights City</td>\n      <td>Cuyahoga</td>\n      <td>61.218919</td>\n      <td>88588.0</td>\n      <td>323</td>\n    </tr>\n    <tr>\n      <th>7</th>\n      <td>Mayfield City</td>\n      <td>Cuyahoga</td>\n      <td>63.786667</td>\n      <td>88504.0</td>\n      <td>238</td>\n    </tr>\n    <tr>\n      <th>8</th>\n      <td>Cleveland Heights-University Heights City</td>\n      <td>Cuyahoga</td>\n      <td>60.633333</td>\n      <td>87312.0</td>\n      <td>363</td>\n    </tr>\n    <tr>\n      <th>9</th>\n      <td>Solon City</td>\n      <td>Cuyahoga</td>\n      <td>62.545520</td>\n      <td>87251.0</td>\n      <td>240</td>\n    </tr>\n    <tr>\n      <th>10</th>\n      <td>Indian Hill Exempted Village</td>\n      <td>Hamilton</td>\n      <td>66.986100</td>\n      <td>86747.0</td>\n      <td>122</td>\n    </tr>\n    <tr>\n      <th>11</th>\n      <td>Hilliard City</td>\n      <td>Franklin</td>\n      <td>67.142857</td>\n      <td>86480.0</td>\n      <td>809</td>\n    </tr>\n    <tr>\n      <th>12</th>\n      <td>North Olmsted City</td>\n      <td>Cuyahoga</td>\n      <td>60.433333</td>\n      <td>85579.0</td>\n      <td>190</td>\n    </tr>\n    <tr>\n      <th>13</th>\n      <td>Bay Village City</td>\n      <td>Cuyahoga</td>\n      <td>56.923128</td>\n      <td>85157.0</td>\n      <td>147</td>\n    </tr>\n    <tr>\n      <th>14</th>\n      <td>Cuyahoga Heights Local</td>\n      <td>Cuyahoga</td>\n      <td>60.608200</td>\n      <td>85003.0</td>\n      <td>39</td>\n    </tr>\n    <tr>\n      <th>15</th>\n      <td>Medina County Joint Vocational School District</td>\n      <td>Medina</td>\n      <td>64.126050</td>\n      <td>83941.0</td>\n      <td>55</td>\n    </tr>\n    <tr>\n      <th>16</th>\n      <td>Dublin City</td>\n      <td>Franklin</td>\n      <td>56.701351</td>\n      <td>83918.0</td>\n      <td>784</td>\n    </tr>\n    <tr>\n      <th>17</th>\n      <td>South Euclid-Lyndhurst City</td>\n      <td>Cuyahoga</td>\n      <td>56.625000</td>\n      <td>83805.0</td>\n      <td>186</td>\n    </tr>\n    <tr>\n      <th>18</th>\n      <td>Brecksville-Broadview Heights City</td>\n      <td>Cuyahoga</td>\n      <td>56.192876</td>\n      <td>83615.0</td>\n      <td>181</td>\n    </tr>\n    <tr>\n      <th>19</th>\n      <td>Kirtland Local</td>\n      <td>Lake</td>\n      <td>63.117761</td>\n      <td>83270.0</td>\n      <td>49</td>\n    </tr>\n    <tr>\n      <th>20</th>\n      <td>Westlake City</td>\n      <td>Cuyahoga</td>\n      <td>57.143102</td>\n      <td>83257.5</td>\n      <td>198</td>\n    </tr>\n  </tbody>\n</table>\n</div>'},
#      'execution_count': 40}],
#    'source': 'top_20_median_salary'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:09.606841',
#      'end_time': '2019-06-26T02:48:09.702695',
#      'duration': 0.095854,
#      'status': 'completed'}},
#    'source': '### Persist the top 20 median salaray html report by "glue"ing it to this notebook:'},
#   {'cell_type': 'code',
#    'execution_count': 41,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:09.834275',
#      'end_time': '2019-06-26T02:48:09.946553',
#      'duration': 0.112278,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'display_data',
#      'metadata': {'scrapbook': {'name': 'HTML_Report',
#        'data': True,
#        'display': False}},
#      'data': {'application/scrapbook.scrap.text+json': {'name': 'HTML_Report',
#        'data': '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>DISTRICT_NAME</th>\n      <th>COUNTY</th>\n      <th>MEDIAN_HRLY_RATE</th>\n      <th>MEDIAN_PAY</th>\n      <th>COUNT</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>1</th>\n      <td>Beachwood City</td>\n      <td>Cuyahoga</td>\n      <td>69.070678</td>\n      <td>96863.5</td>\n      <td>104</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Orange City</td>\n      <td>Cuyahoga</td>\n      <td>66.520663</td>\n      <td>95374.0</td>\n      <td>138</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>Polaris</td>\n      <td>Cuyahoga</td>\n      <td>63.895495</td>\n      <td>91236.0</td>\n      <td>47</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>Upper Arlington City</td>\n      <td>Franklin</td>\n      <td>60.135081</td>\n      <td>89481.0</td>\n      <td>347</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>Rocky River City</td>\n      <td>Cuyahoga</td>\n      <td>63.818885</td>\n      <td>88703.5</td>\n      <td>138</td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>Shaker Heights City</td>\n      <td>Cuyahoga</td>\n      <td>61.218919</td>\n      <td>88588.0</td>\n      <td>323</td>\n    </tr>\n    <tr>\n      <th>7</th>\n      <td>Mayfield City</td>\n      <td>Cuyahoga</td>\n      <td>63.786667</td>\n      <td>88504.0</td>\n      <td>238</td>\n    </tr>\n    <tr>\n      <th>8</th>\n      <td>Cleveland Heights-University Heights City</td>\n      <td>Cuyahoga</td>\n      <td>60.633333</td>\n      <td>87312.0</td>\n      <td>363</td>\n    </tr>\n    <tr>\n      <th>9</th>\n      <td>Solon City</td>\n      <td>Cuyahoga</td>\n      <td>62.545520</td>\n      <td>87251.0</td>\n      <td>240</td>\n    </tr>\n    <tr>\n      <th>10</th>\n      <td>Indian Hill Exempted Village</td>\n      <td>Hamilton</td>\n      <td>66.986100</td>\n      <td>86747.0</td>\n      <td>122</td>\n    </tr>\n    <tr>\n      <th>11</th>\n      <td>Hilliard City</td>\n      <td>Franklin</td>\n      <td>67.142857</td>\n      <td>86480.0</td>\n      <td>809</td>\n    </tr>\n    <tr>\n      <th>12</th>\n      <td>North Olmsted City</td>\n      <td>Cuyahoga</td>\n      <td>60.433333</td>\n      <td>85579.0</td>\n      <td>190</td>\n    </tr>\n    <tr>\n      <th>13</th>\n      <td>Bay Village City</td>\n      <td>Cuyahoga</td>\n      <td>56.923128</td>\n      <td>85157.0</td>\n      <td>147</td>\n    </tr>\n    <tr>\n      <th>14</th>\n      <td>Cuyahoga Heights Local</td>\n      <td>Cuyahoga</td>\n      <td>60.608200</td>\n      <td>85003.0</td>\n      <td>39</td>\n    </tr>\n    <tr>\n      <th>15</th>\n      <td>Medina County Joint Vocational School District</td>\n      <td>Medina</td>\n      <td>64.126050</td>\n      <td>83941.0</td>\n      <td>55</td>\n    </tr>\n    <tr>\n      <th>16</th>\n      <td>Dublin City</td>\n      <td>Franklin</td>\n      <td>56.701351</td>\n      <td>83918.0</td>\n      <td>784</td>\n    </tr>\n    <tr>\n      <th>17</th>\n      <td>South Euclid-Lyndhurst City</td>\n      <td>Cuyahoga</td>\n      <td>56.625000</td>\n      <td>83805.0</td>\n      <td>186</td>\n    </tr>\n    <tr>\n      <th>18</th>\n      <td>Brecksville-Broadview Heights City</td>\n      <td>Cuyahoga</td>\n      <td>56.192876</td>\n      <td>83615.0</td>\n      <td>181</td>\n    </tr>\n    <tr>\n      <th>19</th>\n      <td>Kirtland Local</td>\n      <td>Lake</td>\n      <td>63.117761</td>\n      <td>83270.0</td>\n      <td>49</td>\n    </tr>\n    <tr>\n      <th>20</th>\n      <td>Westlake City</td>\n      <td>Cuyahoga</td>\n      <td>57.143102</td>\n      <td>83257.5</td>\n      <td>198</td>\n    </tr>\n  </tbody>\n</table>',
#        'encoder': 'text',
#        'version': 1}}}],
#    'source': 'sb.glue("HTML_Report", top_20_median_salary.to_html())'}],
#  'metadata': {'hide_input': False,
#   'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.7.3',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'parameters': {},
#    'environment_variables': {},
#    'version': '1.0.1',
#    'input_path': 'Transform.ipynb',
#    'output_path': 'output/Transform.ipynb',
#    'start_time': '2019-06-26T02:47:37.165353',
#    'end_time': '2019-06-26T02:48:10.799227',
#    'duration': 33.633874,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 2}

# %%
pm.execute_notebook(
    'Load.ipynb',
    'output/Load.ipynb',
    parameters=dict(RECIPIENT_EMAIL=RECIPIENT_EMAIL,
                    GMAIL_PWD=GMAIL_PWD
                   )
)
# Out:
# HBox(children=(IntProgress(value=0, max=7), HTML(value='')))
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:12.886116',
#      'end_time': '2019-06-26T02:48:13.545309',
#      'duration': 0.659193,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'import scrapbook as sb\nimport smtplib\nfrom email.mime.text import MIMEText\nfrom email.utils import COMMASPACE'},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:13.551146',
#      'end_time': '2019-06-26T02:48:13.672614',
#      'duration': 0.121468,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '\'<table border="1" class="dataframe">\\n  <thead>\\n    <tr style="text-align: right;">\\n      <th></th>\\n      <th>DISTRICT_NAME</th>\\n      <th>COUNTY</th>\\n      <th>MEDIAN_HRLY_RATE</th>\\n      <th>MEDIAN_PAY</th>\\n      <th>COUNT</th>\\n    </tr>\\n  </thead>\\n  <tbody>\\n    <tr>\\n      <th>1</th>\\n      <td>Beachwood City</td>\\n      <td>Cuyahoga</td>\\n      <td>69.070678</td>\\n      <td>96863.5</td>\\n      <td>104</td>\\n    </tr>\\n    <tr>\\n      <th>2</th>\\n      <td>Orange City</td>\\n      <td>Cuyahoga</td>\\n      <td>66.520663</td>\\n      <td>95374.0</td>\\n      <td>138</td>\\n    </tr>\\n    <tr>\\n      <th>3</th>\\n      <td>Polaris</td>\\n      <td>Cuyahoga</td>\\n      <td>63.895495</td>\\n      <td>91236.0</td>\\n      <td>47</td>\\n    </tr>\\n    <tr>\\n      <th>4</th>\\n      <td>Upper Arlington City</td>\\n      <td>Franklin</td>\\n      <td>60.135081</td>\\n      <td>89481.0</td>\\n      <td>347</td>\\n    </tr>\\n    <tr>\\n      <th>5</th>\\n      <td>Rocky River City</td>\\n      <td>Cuyahoga</td>\\n      <td>63.818885</td>\\n      <td>88703.5</td>\\n      <td>138</td>\\n    </tr>\\n    <tr>\\n      <th>6</th>\\n      <td>Shaker Heights City</td>\\n      <td>Cuyahoga</td>\\n      <td>61.218919</td>\\n      <td>88588.0</td>\\n      <td>323</td>\\n    </tr>\\n    <tr>\\n      <th>7</th>\\n      <td>Mayfield City</td>\\n      <td>Cuyahoga</td>\\n      <td>63.786667</td>\\n      <td>88504.0</td>\\n      <td>238</td>\\n    </tr>\\n    <tr>\\n      <th>8</th>\\n      <td>Cleveland Heights-University Heights City</td>\\n      <td>Cuyahoga</td>\\n      <td>60.633333</td>\\n      <td>87312.0</td>\\n      <td>363</td>\\n    </tr>\\n    <tr>\\n      <th>9</th>\\n      <td>Solon City</td>\\n      <td>Cuyahoga</td>\\n      <td>62.545520</td>\\n      <td>87251.0</td>\\n      <td>240</td>\\n    </tr>\\n    <tr>\\n      <th>10</th>\\n      <td>Indian Hill Exempted Village</td>\\n      <td>Hamilton</td>\\n      <td>66.986100</td>\\n      <td>86747.0</td>\\n      <td>122</td>\\n    </tr>\\n    <tr>\\n      <th>11</th>\\n      <td>Hilliard City</td>\\n      <td>Franklin</td>\\n      <td>67.142857</td>\\n      <td>86480.0</td>\\n      <td>809</td>\\n    </tr>\\n    <tr>\\n      <th>12</th>\\n      <td>North Olmsted City</td>\\n      <td>Cuyahoga</td>\\n      <td>60.433333</td>\\n      <td>85579.0</td>\\n      <td>190</td>\\n    </tr>\\n    <tr>\\n      <th>13</th>\\n      <td>Bay Village City</td>\\n      <td>Cuyahoga</td>\\n      <td>56.923128</td>\\n      <td>85157.0</td>\\n      <td>147</td>\\n    </tr>\\n    <tr>\\n      <th>14</th>\\n      <td>Cuyahoga Heights Local</td>\\n      <td>Cuyahoga</td>\\n      <td>60.608200</td>\\n      <td>85003.0</td>\\n      <td>39</td>\\n    </tr>\\n    <tr>\\n      <th>15</th>\\n      <td>Medina County Joint Vocational School District</td>\\n      <td>Medina</td>\\n      <td>64.126050</td>\\n      <td>83941.0</td>\\n      <td>55</td>\\n    </tr>\\n    <tr>\\n      <th>16</th>\\n      <td>Dublin City</td>\\n      <td>Franklin</td>\\n      <td>56.701351</td>\\n      <td>83918.0</td>\\n      <td>784</td>\\n    </tr>\\n    <tr>\\n      <th>17</th>\\n      <td>South Euclid-Lyndhurst City</td>\\n      <td>Cuyahoga</td>\\n      <td>56.625000</td>\\n      <td>83805.0</td>\\n      <td>186</td>\\n    </tr>\\n    <tr>\\n      <th>18</th>\\n      <td>Brecksville-Broadview Heights City</td>\\n      <td>Cuyahoga</td>\\n      <td>56.192876</td>\\n      <td>83615.0</td>\\n      <td>181</td>\\n    </tr>\\n    <tr>\\n      <th>19</th>\\n      <td>Kirtland Local</td>\\n      <td>Lake</td>\\n      <td>63.117761</td>\\n      <td>83270.0</td>\\n      <td>49</td>\\n    </tr>\\n    <tr>\\n      <th>20</th>\\n      <td>Westlake City</td>\\n      <td>Cuyahoga</td>\\n      <td>57.143102</td>\\n      <td>83257.5</td>\\n      <td>198</td>\\n    </tr>\\n  </tbody>\\n</table>\''},
#      'execution_count': 2}],
#    'source': "nb = sb.read_notebook('output/Transform.ipynb')\nnb.scraps['HTML_Report'].data"},
#   {'cell_type': 'code',
#    'execution_count': 3,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:13.678376',
#      'end_time': '2019-06-26T02:48:13.693220',
#      'duration': 0.014844,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "GMAIL_USER = 'pybokeh@gmail.com'"},
#   {'cell_type': 'code',
#    'execution_count': 4,
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:13.698122',
#      'end_time': '2019-06-26T02:48:13.832006',
#      'duration': 0.133884,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': "RECIPIENT_EMAIL = 'pybokeh@protonmail.com'\nGMAIL_PWD = 'jasonandalex'"},
#   {'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:13.847219',
#      'end_time': '2019-06-26T02:48:13.975308',
#      'duration': 0.128089,
#      'status': 'completed'}},
#    'execution_count': 5,
#    'source': '# Parameters\nRECIPIENT_EMAIL = "pybokeh@protonmail.com"\nGMAIL_PWD = "jasonandalex"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'execution_count': 6,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:13.993199',
#      'end_time': '2019-06-26T02:48:14.116660',
#      'duration': 0.123461,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': 'SUBJECT = \'Top 20 Ohio School Districts by Median Salary\'\nTO = RECIPIENT_EMAIL\nBODY = nb.scraps[\'HTML_Report\'].data + \'\\n\\nBrought to you by a Python script!\'\n\ndef sendEmail(sender, pwd, to, subject, message):\n    recipient = to if type(to) is list else [to]\n    msg = MIMEText(message)\n    msg[\'Subject\'] = subject\n    msg[\'From\'] = sender\n    msg[\'To\'] = COMMASPACE.join(recipient)\n    server = smtplib.SMTP(\'smtp.gmail.com:587\')\n    server.ehlo()\n    server.starttls()\n\n    try:\n        server.login(sender,pwd)\n        print(\'Successfully authenticated...\')\n    except smtplib.SMTPAuthenticationError:               # Check for authentication error\n        return " Authentication ERROR"\n\n    try:\n        server.sendmail(sender,recipient,msg.as_string())\n        print(\'Email sent!\')\n    except smtplib.SMTPRecipientsRefused:                # Check if recipient\'s email was accepted by the server\n        return "ERROR"\n    server.quit()'},
#   {'cell_type': 'code',
#    'execution_count': 7,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-06-26T02:48:14.131766',
#      'end_time': '2019-06-26T02:48:15.906794',
#      'duration': 1.775028,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'Successfully authenticated...\n'},
#     {'output_type': 'stream', 'name': 'stdout', 'text': 'Email sent!\n'}],
#    'source': 'sendEmail(GMAIL_USER, GMAIL_PWD, TO, SUBJECT, BODY)'}],
#  'metadata': {'hide_input': False,
#   'kernelspec': {'display_name': 'Python 3',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.7.3',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'parameters': {'RECIPIENT_EMAIL': 'pybokeh@protonmail.com',
#     'GMAIL_PWD': 'jasonandalex'},
#    'environment_variables': {},
#    'version': '1.0.1',
#    'input_path': 'Load.ipynb',
#    'output_path': 'output/Load.ipynb',
#    'start_time': '2019-06-26T02:48:11.092262',
#    'end_time': '2019-06-26T02:48:16.654789',
#    'duration': 5.562527,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 2}
