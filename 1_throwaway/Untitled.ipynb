# %% [markdown]
# ### This is heading

# %%
import pdb
pdb.set_trace()

print('hello')
# Out:
# --Return--
# > <ipython-input-3-2aef5fc47a65>(2)<module>()->None
# -> pdb.set_trace()
# (Pdb) l
#   1  	import pdb
#   2  ->	pdb.set_trace()
#   3  	print('hello')
# [EOF]
# (Pdb) n
# > /home/pybokeh/envs/jupyter/lib/python3.5/site-packages/IPython/core/interactiveshell.py(2888)run_code()
# -> sys.excepthook = old_excepthook
# (Pdb) l
# 2883 	                self.hooks.pre_run_code_hook()
# 2884 	                #rprint('Running code', repr(code_obj)) # dbg
# 2885 	                exec(code_obj, self.user_global_ns, self.user_ns)
# 2886 	            finally:
# 2887 	                # Reset our crash handler in place
# 2888 ->	                sys.excepthook = old_excepthook
# 2889 	        except SystemExit as e:
# 2890 	            if result is not None:
# 2891 	                result.error_in_exec = e
# 2892 	            self.showtraceback(exception_only=True)
# 2893 	            warn("To exit: use 'exit', 'quit', or Ctrl-D.", level=1)
# (Pdb) n
# ...
